# %%
import os
import json 
import getpass
import logging
from pathlib import Path
from time import sleep
import subprocess
import sys
import re
import pandas as pd
import ast
import time

from langchain_core.tools import Tool
from langgraph.graph import StateGraph, END
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage, AIMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
from langchain.callbacks import get_openai_callback
from langchain.tools import BaseTool

from cluster_tester import ClusterTester
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
import traceback

from typing import TypedDict, Dict, List, Any, Optional, Tuple

from PyDI.io import load_xml, load_parquet, load_csv
try:
    from PyDI.profiling import DataProfiler
except ImportError:
    from PyDI.utils.profiler import DataProfiler
from blocking_tester import BlockingTester
from matching_tester import MatchingTester
from PyDI.entitymatching import RuleBasedMatcher
from schema_matching_node import run_schema_matching
from fusion_size_monitor import compare_estimates_with_actual

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# print(sys.getrecursionlimit())
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# sys.setrecursionlimit(5000)
# print(sys.getrecursionlimit())
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Initialize

# %%
OUTPUT_DIR = "output/"
INPUT_DIR = "input/"

INCLUDE_DOCS = False # IMPORTANT: Use carefully since token usage is increased drastically with documentation
USE_LLM = "gpt"
#USE_LLM = "gemini"
#USE_LLM = "groq"
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
if USE_LLM == "gemini": # or USE_LLM == "gemini_broken":
    if "GOOGLE_API_KEY" not in os.environ:
        os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")
elif USE_LLM == "groq":
    if "GROQ_API_KEY" not in os.environ:
        os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")
elif USE_LLM == "gpt":
    if "OPENAI_API_KEY" not in os.environ:
        os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
logging.basicConfig(filename= OUTPUT_DIR + 'agent.log',
                    filemode='a',
                    format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.DEBUG,
                    encoding='utf-8')
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Utilities

# %%
def load_dataset(path):
    # check file exists
    if not os.path.exists(path):
        raise FileNotFoundError(f"Dataset not found at: {path}")
    ext = os.path.splitext(path)[1].lower()

    # load dataset according to extension
    if ext == ".parquet":
        df = load_parquet(path)
    elif ext == ".csv":
        df = load_csv(path)
    elif ext == ".xml":
        df = load_xml(path, nested_handling="aggregate")
    else:
        raise ValueError(f"Unsupported format: {ext}. Supported: .csv, .parquet, .xml")
    return df
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Tools

# %%
class ProfileDatasetTool(BaseTool):
    name: str = "profile_dataset"
    description: str = """
        A tool that takes the path as a argument called `path` of type str of the dataset file as string and performs data analysis. 
        A JSON string is returned with the profile data.
    """
    
    def _run(self, path) -> str:   
        return self.create_profile(path)

    def create_profile(self, path):

        if not path or not isinstance(path, str):
                raise ValueError("ProfileDatasetTool requires a single path string argument.")

        df = load_dataset(path)    
        
        if df is None or getattr(df, "empty", False):
            # return a structured JSON error string (LLM will see this as content)
            return json.dumps({"error": f"Dataset at {path} loaded as empty or failed to load."})

        profiler = DataProfiler()
        profile = profiler.summary(df, print_summary=False)

        # ensure to return a JSON string (your docstring promised JSON string)
        try:
            profile_json = json.dumps(profile, default=str)
        except Exception:
            # fallback: convert to str if not json-serializable
            profile_json = json.dumps({"profile_str": str(profile)})

        return profile_json
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
class SearchDocumentationTool(BaseTool):
    """
    A tool to search the PyDI documentation vector database.
    """
    name: str = "search_documentation"
    description: str = (
        "Searches the PyDI library documentation for a given query. "
        "Use this to find information about functions, classes, or how-to instructions. "
        "The input should be a specific question about the library."
    )
    call_count: int = 0

    def _clean_text(self, text: str) -> str:
        """
        Cleans and normalizes LLM or tool output text.
        Safe for LangChain AIMessage.content or ToolMessage.content.
        """

        if text is None:
            return ""

        text = str(text)
        text = text.replace("\r\n", "\n").replace("\r", "\n")
        text = re.sub(r"\n\s*\n+", "\n\n", text)
        text = re.sub(r"[ \t]+", " ", text)
        text = text.strip()

        return text


    def _run(self, query: str) -> str:
        """Executes the documentation search."""
        self.call_count += 1
        print(f"[SEARCH TOOL CALL {self.call_count}]: Asking '{query}'")
        
        embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
        vector_db_path = os.path.join(INPUT_DIR, "api_documentation/pydi_apidocs_vector_db/")

        if not os.path.exists(vector_db_path):
            error_msg = f"Error: Vector DB not found at {vector_db_path}"
            # self._save_query_response(query, error_msg)
            return error_msg
        try:
            db = Chroma(persist_directory=vector_db_path, embedding_function=embeddings)
            docs = db.similarity_search(query, k=4)
            
            if not docs:
                response = "No relevant documentation found for your query."
            else:
                response = "\n\n-----\n\n".join([r.page_content for r in docs])
                response = self._clean_text(response)
            
            # Save query and response to JSON file
            # self._save_query_response(query, response)
            
            return response
        except Exception as e:
            error_response = f"An error occurred while searching documentation: {str(e)}\n{traceback.format_exc()}"
            # self._save_query_response(query, error_response)
            return error_response
    
    # def _save_query_response(self, query: str, response: str) -> None:
    #     """Save query and response to JSON file."""
    #     output_file = os.path.join(OUTPUT_DIR, "searchtool_response.json")
        
    #     # Ensure output directory exists
    #     os.makedirs(OUTPUT_DIR, exist_ok=True)
        
    #     # Load existing data or create new list
    #     if os.path.exists(output_file):
    #         with open(output_file, 'r', encoding='utf-8') as f:
    #             try:
    #                 data = json.load(f)
    #                 if isinstance(data, list) and len(data) > 50:
    #                     data = data[-50:]  # Keep only the last 50 entries to prevent file from growing indefinitely
    #                 else:
    #                     pass
    #             except json.JSONDecodeError:
    #                 data = []
    #     else:
    #         data = []
        
    #     # Append new query-response pair
    #     data.append({
    #         "call_number": self.call_count,
    #         "query": query,
    #         "response": response
    #     })
        
    #     # Write back to file
    #     with open(output_file, 'w', encoding='utf-8') as f:
    #         json.dump(data, f, indent=2, ensure_ascii=False)

    def reset(self):
        """Resets the call count for a new agent run."""
        self.call_count = 0
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Agents

# %%
class SimpleModelAgentState(TypedDict):
    datasets: list
    entity_matching_testsets: list
    fusion_testset: str
    validation_fusion_testset: str
    blocking_config: Dict  # NEW: Blocking config from BlockingTester
    matching_config: Dict  # NEW: Matching config from MatchingTester
    matcher_mode: str  # NEW: Matcher mode (rule_based/ml/auto)
    schema_correspondences: Dict  # NEW: Schema matching results
    
    data_profiles: Dict

    messages: List[AnyMessage] # Save conversation history during research
    eval_messages: List[AnyMessage] # Save conversation history during evaluation

    cluster_analysis_result: Dict
    
    integration_pipeline_code: str
    pipeline_execution_result: str
    pipeline_execution_attempts: int

    evaluation_code: str
    evaluation_execution_result: str
    evaluation_execution_attempts: int
    integration_diagnostics_code: str
    integration_diagnostics_execution_result: str
    integration_diagnostics_report: Dict
    human_review_code: str
    human_review_execution_result: str
    human_review_report: Dict
    final_test_evaluation_execution_result: str
    final_test_evaluation_metrics: Dict
    sealed_test_metrics_final: Dict
    run_audit_path: str
    run_report_path: str
    run_id: str
    run_output_root: str

    evaluation_attempts: int
    evaluation_metrics: Dict
    evaluation_analysis: str
    fusion_size_comparison: Dict
    auto_diagnostics: Dict
    normalization_execution_result: str
    normalization_attempts: int
    normalization_report: Dict
    normalized_datasets: List[str]
    original_datasets: List[str]
    normalization_rework_required: bool
    normalization_rework_reasons: List[str]
    normalization_directives: Dict
    investigator_action_plan: List[Dict[str, Any]]
    investigator_decision: str
    pipeline_run_started_at: float
    pipeline_run_finished_at: float

class SimpleModelAgent:
    
    def __init__(self, model, tools: Dict[str, BaseTool]):
        # initialize logger
        self.logger = logging.getLogger()
        self.logger.setLevel(logging.INFO)
        log_path = os.path.join(OUTPUT_DIR, "agent_run.log")
        os.makedirs(os.path.dirname(log_path), exist_ok=True)
        if not any(isinstance(h, logging.FileHandler) and h.baseFilename == os.path.abspath(log_path) for h in self.logger.handlers):
            file_handler = logging.FileHandler(log_path, mode="w", encoding="utf-8")
            formatter = logging.Formatter("%(asctime)s | %(levelname)s | %(message)s")
            file_handler.setFormatter(formatter)
            self.logger.addHandler(file_handler)
        
        self.token_usage = {"prompt_tokens": 0, "completion_tokens": 0, "total_tokens": 0, "total_cost": 0.0}
        self.tools = tools
        self.model = model.bind_tools(list(self.tools.values()))
        self.base_model = model
        self.run_id = ""
        self.run_output_root = ""

        # prepare the StateGraph
        graph = StateGraph(SimpleModelAgentState)

        # create nodes
        graph.add_node("match_schemas", self.match_schemas)
        graph.add_node("profile_data", self.profile_data)
        try:
            from helpers.normalization_orchestrator import run_normalization_node
            from helpers.evaluation_orchestrator import run_evaluation_node
            from helpers.investigator_orchestrator import run_investigator_node
        except Exception:
            from agents.helpers.normalization_orchestrator import run_normalization_node
            from agents.helpers.evaluation_orchestrator import run_evaluation_node
            from agents.helpers.investigator_orchestrator import run_investigator_node

        graph.add_node("normalization_node", lambda state: run_normalization_node(self, state, load_dataset))
        graph.add_node("run_blocking_tester", self.run_blocking_tester)
        graph.add_node("run_matching_tester", self.run_matching_tester)
        graph.add_node("pipeline_adaption", self.pipeline_adaption)
        graph.add_node("execute_pipeline", self.execute_pipeline)
        graph.add_node("evaluation_node", lambda state: run_evaluation_node(self, state))
        graph.add_node("investigator_node", lambda state: run_investigator_node(self, state))
        graph.add_node("human_review_export", self.human_review_export)
        graph.add_node("sealed_final_test_evaluation", self.sealed_final_test_evaluation)
        graph.add_node("save_results", self.save_results)

        # create edges
        graph.add_edge("match_schemas", "profile_data")
        graph.add_edge("profile_data", "normalization_node")
        graph.add_edge("normalization_node", "run_blocking_tester")
        graph.add_edge("run_blocking_tester", "run_matching_tester")
        graph.add_edge("run_matching_tester", "pipeline_adaption")
        
        graph.add_conditional_edges(
            "pipeline_adaption",
            self.should_continue_research,
            {
                "continue": "pipeline_adaption",
                "end": "execute_pipeline"
            }
        )
        
        graph.add_conditional_edges(
            "execute_pipeline",
            lambda state: (
                "evaluation_node"
                if state.get("pipeline_execution_result", "")
                .lower()
                .startswith("success")
                else (
                    "pipeline_adaption"
                    if state.get("pipeline_execution_attempts", 0) < 3
                    else END
                )
            ),
            {
                "evaluation_node": "evaluation_node",
                "pipeline_adaption": "pipeline_adaption",
                END: END,
            },
        )

        # Consolidated evaluation + investigation area

        graph.add_conditional_edges(
            "evaluation_node",
            lambda state: (
                "investigator_node"
                if isinstance(state.get("evaluation_execution_result", ""), str)
                   and state["evaluation_execution_result"].lower().startswith("success")
                else END
            ),
            {
                "investigator_node": "investigator_node",
                END: END,
            }
        )

        graph.add_conditional_edges(
            "investigator_node",
            lambda state: state.get("investigator_decision", "human_review_export"),
            {
                "normalization_node": "normalization_node",
                "pipeline_adaption": "pipeline_adaption",
                "human_review_export": "human_review_export",
                END: END
            }
        )
        graph.add_conditional_edges(
            "human_review_export",
            lambda state: (
                "sealed_final_test_evaluation"
                if self._sealed_eval_active(state)
                else "save_results"
            ),
            {
                "sealed_final_test_evaluation": "sealed_final_test_evaluation",
                "save_results": "save_results",
                END: END,
            },
        )
        graph.add_edge("sealed_final_test_evaluation", "save_results")
        graph.add_edge("save_results", END)

        graph.set_entry_point("match_schemas")
        self.graph = graph.compile()

    def _extract_usage_from_result(self, result: Any) -> Dict[str, int]:
        def _to_int(value: Any) -> int:
            try:
                return int(value)
            except Exception:
                return 0

        prompt_tokens = 0
        completion_tokens = 0
        total_tokens = 0

        usage_meta = getattr(result, "usage_metadata", None)
        if isinstance(usage_meta, dict):
            prompt_tokens = _to_int(usage_meta.get("input_tokens") or usage_meta.get("prompt_tokens"))
            completion_tokens = _to_int(usage_meta.get("output_tokens") or usage_meta.get("completion_tokens"))
            total_tokens = _to_int(usage_meta.get("total_tokens"))

        response_meta = getattr(result, "response_metadata", None)
        if isinstance(response_meta, dict):
            token_usage = response_meta.get("token_usage", {})
            if isinstance(token_usage, dict):
                if prompt_tokens <= 0:
                    prompt_tokens = _to_int(token_usage.get("prompt_tokens") or token_usage.get("input_tokens"))
                if completion_tokens <= 0:
                    completion_tokens = _to_int(token_usage.get("completion_tokens") or token_usage.get("output_tokens"))
                if total_tokens <= 0:
                    total_tokens = _to_int(token_usage.get("total_tokens"))

        if total_tokens <= 0:
            total_tokens = prompt_tokens + completion_tokens

        return {
            "prompt_tokens": max(0, prompt_tokens),
            "completion_tokens": max(0, completion_tokens),
            "total_tokens": max(0, total_tokens),
        }

    def _resolve_model_name(self, result: Any) -> str:
        response_meta = getattr(result, "response_metadata", None)
        if isinstance(response_meta, dict):
            model_name = str(response_meta.get("model_name") or response_meta.get("model") or "").strip()
            if model_name:
                return model_name
        model_name = str(getattr(self.base_model, "model_name", "") or getattr(self.base_model, "model", "")).strip()
        return model_name

    def _resolve_openai_rates_per_1m(self, model_name: str) -> Tuple[Optional[float], Optional[float]]:
        input_override = os.getenv("OPENAI_INPUT_COST_PER_1M")
        output_override = os.getenv("OPENAI_OUTPUT_COST_PER_1M")
        if input_override and output_override:
            try:
                return float(input_override), float(output_override)
            except Exception:
                pass

        # Local fallback rate card (USD per 1M tokens); update if you change models/pricing.
        rate_card = {
            "gpt-5.2": (1.25, 10.0),
            "gpt-5": (1.25, 10.0),
            "gpt-4o-mini": (0.15, 0.60),
            "gpt-4o": (5.0, 15.0),
            "gpt-4.1-mini": (0.40, 1.60),
            "gpt-4.1": (2.0, 8.0),
            "gpt-4.1-nano": (0.10, 0.40),
        }

        key = str(model_name or "").strip().lower()
        for prefix, rates in rate_card.items():
            if key.startswith(prefix):
                return rates

        return None, None

    def _estimate_openai_cost(self, prompt_tokens: int, completion_tokens: int, model_name: str) -> Optional[float]:
        in_rate, out_rate = self._resolve_openai_rates_per_1m(model_name)
        if in_rate is None or out_rate is None:
            return None
        return (float(prompt_tokens) * in_rate + float(completion_tokens) * out_rate) / 1_000_000.0

    def _invoke_with_usage(self, message, tag):
        with get_openai_callback() as cb:
            result = self.model.invoke(message)

        prompt_tokens = int(cb.prompt_tokens or 0)
        completion_tokens = int(cb.completion_tokens or 0)
        total_tokens = int(cb.total_tokens or 0)
        estimated_cost = float(cb.total_cost or 0.0)

        # Fallback: extract usage directly from response metadata if callback values are unavailable.
        if prompt_tokens <= 0 and completion_tokens <= 0:
            usage = self._extract_usage_from_result(result)
            prompt_tokens = int(usage.get("prompt_tokens", 0))
            completion_tokens = int(usage.get("completion_tokens", 0))
            total_tokens = int(usage.get("total_tokens", 0))

        if total_tokens <= 0:
            total_tokens = prompt_tokens + completion_tokens

        model_name = self._resolve_model_name(result)
        if estimated_cost <= 0.0 and (prompt_tokens > 0 or completion_tokens > 0):
            estimated = self._estimate_openai_cost(prompt_tokens, completion_tokens, model_name)
            if estimated is not None:
                estimated_cost = estimated

        self.token_usage["prompt_tokens"] += prompt_tokens
        self.token_usage["completion_tokens"] += completion_tokens
        self.token_usage["total_tokens"] += total_tokens
        self.token_usage["total_cost"] += estimated_cost

        print(f"TOKEN USAGE ({tag}):")
        print(f"   Model: {model_name or 'unknown'}")
        print(f"   Prompt tokens: {prompt_tokens:,}")
        print(f"   Completion tokens: {completion_tokens:,}")
        print(f"   Total tokens: {total_tokens:,}")
        print(f"   Estimated cost: ${estimated_cost:.6f}")

        return result

    def _print_total_usage(self):
        t = self.token_usage
        print("TOTAL TOKEN USAGE:")
        print(f"   Prompt tokens: {t['prompt_tokens']:,}")
        print(f"   Completion tokens: {t['completion_tokens']:,}")
        print(f"   Total tokens: {t['total_tokens']:,}")
        print(f"   Estimated cost: ${t['total_cost']:.6f}")

    def _log_action(self, step: str, action: str, why: str, improvement: str = "", details: dict | None = None):
        payload = {
            "step": step,
            "action": action,
            "why": why,
            "improvement": improvement,
        }
        if details:
            payload["details"] = details
        self.logger.info(json.dumps(payload, ensure_ascii=False))

    def _sealed_eval_active(self, state: SimpleModelAgentState) -> bool:
        validation_path = state.get("validation_fusion_testset")
        test_path = state.get("fusion_testset")
        return bool(
            validation_path
            and test_path
            and os.path.exists(validation_path)
            and os.path.exists(test_path)
        )

    def _evaluation_testset_path(self, state: SimpleModelAgentState, force_test: bool = False) -> str:
        if force_test:
            return state.get("fusion_testset", "")
        if self._sealed_eval_active(state):
            return state.get("validation_fusion_testset", "")
        return state.get("fusion_testset", "")

    def _evaluation_stage_label(self, state: SimpleModelAgentState, force_test: bool = False) -> str:
        if force_test:
            return "sealed_test"
        return "validation" if self._sealed_eval_active(state) else "test"

    def _update_pipeline_matching_thresholds(self,
        pipeline_code: str, matching_config: Dict[str, Any]
    ) -> str:
        """
        Updates the matching thresholds in the generated pipeline code based on the provided
        matching configuration. This function is designed to be called after the LLM
        generates the initial pipeline code.
        """
        if not matching_config or "matching_strategies" not in matching_config:
            return pipeline_code

        updated_code = pipeline_code
        strategies = matching_config["matching_strategies"]

        for pair_key, config in strategies.items():
            if isinstance(config, dict) and "threshold" in config:
                threshold_value = config["threshold"]

                # The LLM will be instructed to generate variable names like threshold_discogs_lastfm.
                # So, the var_name directly corresponds to the pair_key with 'threshold_' prefix.
                var_name = f"threshold_{pair_key}"

                # Pattern to find a variable assignment like 'threshold_discogs_lastfm = 0.7'
                # The regex handles potential whitespace around '=' and different float formats.
                pattern_var_assignment = rf"({re.escape(var_name)}\s*=\s*)([0-9]*\.?[0-9]+)"

                if re.search(pattern_var_assignment, updated_code):
                    updated_code = re.sub(
                        pattern_var_assignment,
                        rf"\g<1>{threshold_value}",
                        updated_code,
                        count=1,
                    )
                    print(
                        f"[DEBUG] Updated variable assignment for {pair_key} to {threshold_value}"
                    )
                else:
                    print(
                        f"[DEBUG] Could not find explicit variable assignment for {var_name}. "
                        f"Relying on LLM to generate it correctly. Current code not modified for this pair."
                    )
                    pass

        return updated_code

    def _apply_pipeline_guardrails(self, pipeline_code: str, state: SimpleModelAgentState) -> str:
        """
        Apply safe, generic guardrails based on diagnostics.
        Keeps logic dataset-agnostic and only touches well-defined flags.
        """
        try:
            from helpers.code_guardrails import apply_pipeline_guardrails as helper_apply_pipeline_guardrails
        except Exception:
            try:
                from agents.helpers.code_guardrails import (
                    apply_pipeline_guardrails as helper_apply_pipeline_guardrails,
                )
            except Exception:
                helper_apply_pipeline_guardrails = None
        if callable(helper_apply_pipeline_guardrails):
            try:
                return helper_apply_pipeline_guardrails(pipeline_code, state if isinstance(state, dict) else {})
            except Exception as helper_err:
                print(f"[WARN] helper apply_pipeline_guardrails failed, using inline fallback: {helper_err}")

        updated_code = pipeline_code
        diagnostics = state.get("auto_diagnostics", {}) if isinstance(state, dict) else {}
        metrics = state.get("evaluation_metrics", {}) if isinstance(state, dict) else {}

        id_alignment = diagnostics.get("id_alignment", {}) if isinstance(diagnostics, dict) else {}
        mapped_ratio = id_alignment.get("mapped_coverage_ratio")
        debug_ratios = diagnostics.get("debug_reason_ratios", {}) if isinstance(diagnostics, dict) else {}
        missing_ratio = debug_ratios.get("missing_fused_value", 0.0)
        overall_acc = metrics.get("overall_accuracy")

        force_singletons = False
        try:
            if mapped_ratio is not None and float(mapped_ratio) < 0.85:
                force_singletons = True
        except Exception:
            pass
        try:
            if missing_ratio is not None and float(missing_ratio) > 0.20:
                force_singletons = True
        except Exception:
            pass
        try:
            if overall_acc is not None and float(overall_acc) < 0.60:
                force_singletons = True
        except Exception:
            pass

        if force_singletons:
            updated_code, replaced = re.subn(
                r"(include_singletons\s*=\s*)False",
                r"\1True",
                updated_code,
                count=1,
            )
            if replaced:
                print("[GUARDRAIL] Forced include_singletons=True due to coverage diagnostics.")

        # Ensure custom fusers are PyDI-compatible when runtime kwargs (e.g., sources) are passed.
        def _patch_custom_fuser_signature(match: re.Match) -> str:
            indent = match.group("indent")
            fn_name = match.group("name")
            params = match.group("params")
            if "fuser" not in fn_name.lower() or "**kwargs" in params:
                return match.group(0)

            param_tokens = [p.strip() for p in params.split(",") if p.strip()]
            if len(param_tokens) < 2:
                return match.group(0)
            if param_tokens[0] != "inputs" or param_tokens[1] != "context":
                return match.group(0)

            return f"{indent}def {fn_name}({params}, **kwargs):"

        updated_code, fuser_sig_updates = re.subn(
            r"(?P<indent>^[ \t]*)def\s+(?P<name>[A-Za-z_][A-Za-z0-9_]*)\s*\((?P<params>[^\)]*)\)\s*:",
            _patch_custom_fuser_signature,
            updated_code,
            flags=re.MULTILINE,
        )
        if fuser_sig_updates:
            print(f"[GUARDRAIL] Updated {fuser_sig_updates} custom fuser signature(s) to accept **kwargs.")

        updated_code, lambda_updates = re.subn(
            r"lambda\s+inputs\s*,\s*context\s*:",
            "lambda inputs, **kwargs:",
            updated_code,
        )
        if lambda_updates:
            print(f"[GUARDRAIL] Updated {lambda_updates} lambda fuser signature(s) to accept **kwargs.")

        # Make local helper imports robust across execution directories.
        list_norm_import = "from list_normalization import detect_list_like_columns, normalize_list_like_columns"
        if list_norm_import in updated_code and "except ModuleNotFoundError" not in updated_code:
            robust_import_block = """
import os
import sys
try:
    from list_normalization import detect_list_like_columns, normalize_list_like_columns
except ModuleNotFoundError:
    _module_name = "list_normalization.py"
    _candidates = []
    try:
        _candidates.append(os.path.abspath(os.path.join(os.path.dirname(__file__), "..", "..")))
    except Exception:
        pass
    _candidates.append(os.getcwd())
    _candidates.append(os.path.abspath(os.path.join(os.getcwd(), "agents")))
    for _path in _candidates:
        if os.path.isfile(os.path.join(_path, _module_name)) and _path not in sys.path:
            sys.path.append(_path)
    from list_normalization import detect_list_like_columns, normalize_list_like_columns
""".strip()
            updated_code = updated_code.replace(list_norm_import, robust_import_block, 1)
            print("[GUARDRAIL] Rewrote list_normalization import to robust fallback block.")

        # Ensure NumericComparator has explicit list_strategy for list-valued numeric fields.
        def _ensure_numeric_list_strategy(match: re.Match) -> str:
            block = match.group(0)
            if "list_strategy" in block:
                return block
            return re.sub(
                r"\\n([ \\t]*)\\)$",
                r"\\n\\1    list_strategy=\\\"average\\\",\\n\\1)",
                block,
                count=1,
            )

        updated_code, numeric_list_updates = re.subn(
            r"NumericComparator\\(\\n(?:[ \\t]+[^\\n]*\\n)+?[ \\t]*\\)",
            _ensure_numeric_list_strategy,
            updated_code,
            flags=re.MULTILINE,
        )
        if numeric_list_updates:
            print(f"[GUARDRAIL] Added list_strategy to {numeric_list_updates} NumericComparator call(s).")

        # Ensure StringComparator has explicit list_strategy when omitted.
        # Prevents runtime comparator failures if the compared values are list-like.
        def _ensure_string_list_strategy(match: re.Match) -> str:
            block = match.group(0)
            if "list_strategy" in block:
                return block
            strategy = "concatenate"
            try:
                if re.search(r"similarity_function\\s*=\\s*[\"\\']jaccard[\"\\']", block):
                    strategy = "set_jaccard"
            except Exception:
                strategy = "concatenate"
            return re.sub(
                r"\\n([ \\t]*)\\)$",
                rf"\\n\\1    list_strategy=\\\"{strategy}\\\",\\n\\1)",
                block,
                count=1,
            )

        updated_code, string_list_updates = re.subn(
            r"StringComparator\\(\\n(?:[ \\t]+[^\\n]*\\n)+?[ \\t]*\\)",
            _ensure_string_list_strategy,
            updated_code,
            flags=re.MULTILINE,
        )
        if string_list_updates:
            print(f"[GUARDRAIL] Added list_strategy to {string_list_updates} StringComparator call(s).")

        # Patch unsafe `if pd.isna(x):` checks that crash on array/list-like values.
        def _patch_unsafe_pd_isna(match: re.Match) -> str:
            indent = match.group("indent")
            return (
                f"{indent}try:\\n"
                f"{indent}    _is_na = pd.isna(x)\\n"
                f"{indent}    if isinstance(_is_na, (list, tuple, set, dict)) or hasattr(_is_na, '__array__'):\\n"
                f"{indent}        _is_na = False\\n"
                f"{indent}    else:\\n"
                f"{indent}        _is_na = bool(_is_na)\\n"
                f"{indent}except Exception:\\n"
                f"{indent}    _is_na = False\\n"
                f"{indent}if _is_na:\\n"
                f"{indent}    return np.nan"
            )

        updated_code, pd_isna_updates = re.subn(
            r"(?m)^(?P<indent>[ \\t]*)if pd\\.isna\\(x\\):\\n(?P=indent)[ \\t]*return np\\.nan",
            _patch_unsafe_pd_isna,
            updated_code,
        )
        if pd_isna_updates:
            print(f"[GUARDRAIL] Hardened {pd_isna_updates} unsafe pd.isna(x) check(s).")

        return updated_code

    def _compute_auto_diagnostics(self, state: SimpleModelAgentState, metrics: Dict[str, Any]) -> Dict[str, Any]:
        from helpers.evaluation_helpers import (
            compute_auto_diagnostics as helper_compute_auto_diagnostics,
            compute_id_alignment as helper_compute_id_alignment,
        )

        force_test_eval = bool(state.get("_force_test_eval"))
        eval_testset_path = self._evaluation_testset_path(state, force_test=force_test_eval)
        eval_stage_label = self._evaluation_stage_label(state, force_test=force_test_eval)
        return helper_compute_auto_diagnostics(
            state=state,
            metrics=metrics,
            evaluation_testset_path=eval_testset_path,
            evaluation_stage_label=eval_stage_label,
            load_dataset_fn=load_dataset,
            compute_id_alignment_fn=helper_compute_id_alignment,
        )

    def _assess_normalization_with_llm(self, state: SimpleModelAgentState) -> Dict[str, Any]:
        from helpers.evaluation_helpers import extract_json_object as helper_extract_json_object
        from helpers.normalization_policy import (
            collect_eval_debug_signals as helper_collect_eval_debug_signals,
            infer_country_output_format_from_validation as helper_infer_country_output_format_from_validation,
            infer_validation_text_case_map as helper_infer_validation_text_case_map,
        )

        default_system_prompt = """
        You are an investigation assistant deciding whether data normalization should be rerun.

        Focus on canonicalization issues such as:
        - country naming mismatches (e.g., long-form vs short-form country names)
        - list formatting inconsistencies (JSON-string lists vs scalar strings vs nested structures)
        - whitespace/casing/format inconsistencies that break exact comparisons

        Use evidence from metrics, diagnostics and reasoning text only.

        Return STRICT JSON (no markdown) with keys:
        {
          "needs_normalization": bool,
          "reasons": [str],
          "country_columns": [str],
          "list_columns": [str],
          "text_columns": [str],
          "lowercase_columns": [str],
          "country_output_format": "alpha_2|alpha_3|numeric|name|official_name",
          "list_normalization_required": bool,
          "recommendation_summary": str,
          "confidence": float
        }

        Keep lists short and only include columns that are clearly indicated by evidence.
        """
        try:
            from prompts.investigator_prompt import NORMALIZATION_ASSESSMENT_SYSTEM_PROMPT
        except Exception:
            NORMALIZATION_ASSESSMENT_SYSTEM_PROMPT = None
        system_prompt = (
            NORMALIZATION_ASSESSMENT_SYSTEM_PROMPT
            if isinstance(NORMALIZATION_ASSESSMENT_SYSTEM_PROMPT, str) and NORMALIZATION_ASSESSMENT_SYSTEM_PROMPT.strip()
            else default_system_prompt
        )

        validation_style: Dict[str, Any] = {}
        try:
            validation_path = self._evaluation_testset_path(state, force_test=False)
            validation_df = load_dataset(validation_path) if validation_path else None
            case_map = helper_infer_validation_text_case_map(validation_df)
            inferred_country_format = helper_infer_country_output_format_from_validation(validation_df)
            validation_style = {
                "validation_path": validation_path,
                "inferred_country_output_format": inferred_country_format,
                "lowercase_columns_hint": [
                    c for c, meta in case_map.items() if bool(meta.get("prefer_lowercase"))
                ],
                "case_profile": case_map,
            }
        except Exception:
            validation_style = {}

        debug_signals = helper_collect_eval_debug_signals()

        human_content = f"""
        Evaluation metrics:
        {json.dumps(state.get("evaluation_metrics", {}), indent=2)}

        Auto diagnostics:
        {json.dumps(state.get("auto_diagnostics", {}), indent=2)}

        Integration diagnostics report:
        {json.dumps(state.get("integration_diagnostics_report", {}), indent=2)}

        Evaluation reasoning summary:
        {state.get("evaluation_analysis", "")}

        Data profiles:
        {json.dumps(state.get("data_profiles", {}), indent=2)}

        Validation style hints (use these to avoid over-normalization):
        {json.dumps(validation_style, indent=2)}

        Debug mismatch style signals:
        {json.dumps(debug_signals, indent=2)}
        """

        message = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content),
        ]
        result = self._invoke_with_usage(message, "investigator_normalization_assessment")
        parsed = helper_extract_json_object(result)

        if not parsed:
            inferred_country_format = str(validation_style.get("inferred_country_output_format", "name"))
            lowercase_hint = validation_style.get("lowercase_columns_hint", [])
            if not isinstance(lowercase_hint, list):
                lowercase_hint = []
            return {
                "needs_normalization": False,
                "reasons": [],
                "country_columns": [],
                "list_columns": [],
                "text_columns": [],
                "lowercase_columns": [str(c) for c in lowercase_hint if str(c).strip()],
                "country_output_format": inferred_country_format,
                "list_normalization_required": False,
                "recommendation_summary": "",
                "confidence": 0.0,
            }

        for key in ("reasons", "country_columns", "list_columns", "text_columns", "lowercase_columns"):
            value = parsed.get(key, [])
            if not isinstance(value, list):
                parsed[key] = []
            else:
                parsed[key] = [str(v) for v in value if str(v).strip()]

        parsed["needs_normalization"] = bool(parsed.get("needs_normalization", False))
        parsed["list_normalization_required"] = bool(parsed.get("list_normalization_required", False))
        allowed_country_formats = {"alpha_2", "alpha_3", "numeric", "name", "official_name"}
        inferred_country_format = str(validation_style.get("inferred_country_output_format", "name"))
        proposed_country_format = str(parsed.get("country_output_format", inferred_country_format)).strip()
        if proposed_country_format not in allowed_country_formats:
            proposed_country_format = inferred_country_format if inferred_country_format in allowed_country_formats else "name"
        parsed["country_output_format"] = proposed_country_format
        try:
            parsed["confidence"] = float(parsed.get("confidence", 0.0))
        except Exception:
            parsed["confidence"] = 0.0
        parsed["recommendation_summary"] = str(parsed.get("recommendation_summary", ""))

        return parsed

    def _apply_evaluation_guardrails(self, evaluation_code: str) -> str:
        """
        Patch common portability/runtime issues in generated evaluation code.
        """
        try:
            from helpers.code_guardrails import apply_evaluation_guardrails as helper_apply_evaluation_guardrails
        except Exception:
            helper_apply_evaluation_guardrails = None
        if callable(helper_apply_evaluation_guardrails):
            try:
                return helper_apply_evaluation_guardrails(evaluation_code)
            except Exception as helper_err:
                print(f"[WARN] helper apply_evaluation_guardrails failed, using inline fallback: {helper_err}")

        updated = evaluation_code
        list_norm_import = "from list_normalization import detect_list_like_columns, normalize_list_like_columns"
        if list_norm_import in updated and "except ModuleNotFoundError" not in updated:
            robust_import_block = """
import os
import sys
from pathlib import Path
try:
    from list_normalization import detect_list_like_columns, normalize_list_like_columns
except ModuleNotFoundError:
    _module_name = "list_normalization.py"
    _candidates = [
        Path.cwd(),
        Path.cwd() / "agents",
        Path(__file__).resolve().parent,
        Path(__file__).resolve().parent.parent,
        Path(__file__).resolve().parent.parent.parent,
    ]
    for _path in _candidates:
        if (_path / _module_name).is_file():
            _path_str = str(_path.resolve())
            if _path_str not in sys.path:
                sys.path.append(_path_str)
    from list_normalization import detect_list_like_columns, normalize_list_like_columns
""".strip()
            updated = updated.replace(list_norm_import, robust_import_block, 1)
            print("[GUARDRAIL] Rewrote evaluation list_normalization import to robust fallback block.")
        return updated

    def should_continue_research(self, state: SimpleModelAgentState) -> str:
        """Determines whether to continue the research loop or end."""
        messages = state['messages']
        last_message = messages[-1]
        # If the LLM made a tool call, continue the loop to process it.
        if isinstance(last_message, AIMessage) and last_message.tool_calls:
            return "continue"
        # If the LLM responded with code (no tool call), end the loop.
        else:
            return "end"

    # Creates tool calls to profile the data and saves it into agent state 
    def match_schemas(self, state: SimpleModelAgentState):
        self._log_action("match_schemas", "start", "Align dataset schemas before blocking/matching", "Improves comparator compatibility", {"datasets": state.get("datasets")})

        self.logger.info("----------------------- Entering match_schemas -----------------------")
        if state.get("schema_correspondences"):
            print("[*] Schema correspondences already present; skipping match_schemas")
            return {}

        print("[*] Running schema matching")
        result = run_schema_matching(
            dataset_paths=state["datasets"],
            model=self.base_model,
            output_dir="output/schema-matching",
        )
        self.logger.info("Leaving match_schemas")
        return result

    def profile_data(self, state:SimpleModelAgentState):
        self._log_action("profile_data", "start", "Profile datasets to guide feature/threshold choices", "Improves matching signal selection", {"datasets": state.get("datasets")})

        self.logger.info('----------------------- Entering profile_data -----------------------')

        print("[*] Profiling datasets")

        system_prompt = """
            You are a data scientist tasked with the integration of several datasets.
            For each dataset path provided, call the tool `profile_dataset` with the path
            (one tool call per dataset).
        """
        
        datasets_list_str = "\n".join(state['datasets'])
        human_content = f"Please profile these datasets (one call per dataset):\n{datasets_list_str}"
        message = [SystemMessage(content=system_prompt), HumanMessage(content=human_content)]
        self.logger.info("Input Message:" + str(message))
        
        result = self._invoke_with_usage(message, "profile_data")
        self.logger.info("RESULT:" + str(result))

        # call tools
        tool_calls = result.tool_calls

        self.logger.info("Tool Calls:" + str(tool_calls))
        results = {}
        for t in tool_calls:
            if not t['name'] in self.tools:      # check for bad tool name from LLM
                self.logger.info("adapt_pipeline: ....bad tool name....")
                result = "bad tool name, retry"  # instruct LLM to retry if bad
            else:
                result = self.tools[t['name']].invoke(t['args'])
            
#            if USE_LLM == "groq" or USE_LLM == "gpt" or USE_LLM == "gemini":
            results[t['args']['path']] = result
#            elif USE_LLM == "gemini_broken":
#                results[t['args']['__arg1']] = result

        with open(OUTPUT_DIR + "profile/profiles.json", "w") as file:
            file.write(json.dumps(results, indent=2))
          
        self.logger.info('Leaving profile_data')
        return {'data_profiles': results}

    def run_blocking_tester(self, state: SimpleModelAgentState):
        self._log_action("run_blocking_tester", "start", "Select blocking strategy to reduce candidates", "Improves runtime and recall balance", {"skip": SKIP_BLOCKING_TESTER})

        self.logger.info("----------------------- Entering run_blocking_tester -----------------------")

        if SKIP_BLOCKING_TESTER:
            path = Path(OUTPUT_DIR + "blocking-evaluation/blocking_config.json")
            if path.exists():
                with path.open("r", encoding="utf-8") as f:
                    blocking_config = json.load(f)
                    cfg_names = blocking_config.get("dataset_names", []) if isinstance(blocking_config, dict) else []
                    expected = sorted([Path(p).stem for p in state.get("datasets", [])])
                    got = sorted([str(x) for x in cfg_names]) if isinstance(cfg_names, list) else []
                    if got and got != expected:
                        print("[WARN] Saved blocking config dataset signature mismatch; recomputing blocking.")
                    else:
                        print("[+] Using saved blocking strategy: " + json.dumps(blocking_config, indent=2))
                        return {"blocking_config": blocking_config}
            else:
                print("[-] Cannot skip blocking tester. No saved blocking strategy found")
        
        if state.get("blocking_config"):
            cfg = state.get("blocking_config", {})
            cfg_names = cfg.get("dataset_names", []) if isinstance(cfg, dict) else []
            expected = sorted([Path(p).stem for p in state.get("datasets", [])])
            got = sorted([str(x) for x in cfg_names]) if isinstance(cfg_names, list) else []
            if got and got != expected:
                print("[WARN] State blocking config dataset signature mismatch; recomputing blocking.")
            else:
                print("[*] Blocking config already present in state; skipping BlockingTester")
                return {"blocking_config": cfg}

        print("[*] Running BlockingTester")
        tester = BlockingTester(
            llm=self.base_model,
            datasets=state["datasets"],
            max_candidates=350000,
            blocking_testsets=state['entity_matching_testsets'],
            output_dir="output/blocking-evaluation",
            pc_threshold=0.9,
            max_attempts=5,
            max_error_retries=2,
            verbose=True
        )
        _, blocking_config = tester.run_all_pairs()
        print("[*] Blocking config computed:\n" + json.dumps(blocking_config, indent=2))
        self.logger.info("Leaving run_blocking_tester")
        return {"blocking_config": blocking_config}

    def run_matching_tester(self, state: SimpleModelAgentState):
        self._log_action("run_matching_tester", "start", "Select matching strategy and thresholds", "Improves correspondence quality", {"skip": SKIP_MATCHING_TESTER, "matcher_mode": state.get("matcher_mode")})

        self.logger.info("----------------------- Entering run_matching_tester -----------------------")
        matcher_mode = str(state.get("matcher_mode", "ml")).strip().lower().replace("-", "_")
        if matcher_mode == "rulebased":
            matcher_mode = "rule_based"
        state["matcher_mode"] = matcher_mode

        def _config_has_list_based_comparators(cfg: Dict[str, Any]) -> bool:
            try:
                strategies = cfg.get("matching_strategies", {}) if isinstance(cfg, dict) else {}
                for _, pair_cfg in strategies.items():
                    comps = pair_cfg.get("comparators", []) if isinstance(pair_cfg, dict) else []
                    for comp in comps:
                        if bool((comp or {}).get("list_strategy")):
                            return True
                return False
            except Exception:
                return False

        def _config_matches_datasets(cfg: Dict[str, Any]) -> bool:
            try:
                if not isinstance(cfg, dict):
                    return False
                cfg_names = cfg.get("dataset_names", [])
                if not isinstance(cfg_names, list) or not cfg_names:
                    return True
                expected = sorted([Path(p).stem for p in state.get("datasets", [])])
                got = sorted([str(x) for x in cfg_names])
                return expected == got
            except Exception:
                return False

        if SKIP_MATCHING_TESTER:
            path = Path(OUTPUT_DIR + "matching-evaluation/matching_config.json")
            if path.exists():
                with path.open("r", encoding="utf-8") as f:
                    matching_config = json.load(f)
                    if not _config_matches_datasets(matching_config):
                        print("[WARN] Saved matching config dataset signature mismatch; recomputing matcher.")
                    elif _config_has_list_based_comparators(matching_config):
                        print("[WARN] Saved matching config contains list-based comparators; recomputing matcher.")
                    else:
                        print("[+] Using saved matching strategy: " + json.dumps(matching_config, indent=2))
                        return {"matching_config": matching_config}
            else:
                print("[-] Cannot skip matching tester. No saved matching strategy found")
        
        if state.get("matching_config"):
            existing_cfg = state.get("matching_config", {})
            if not _config_matches_datasets(existing_cfg):
                print("[WARN] State matching config dataset signature mismatch; recomputing matcher.")
            elif _config_has_list_based_comparators(existing_cfg):
                print("[WARN] State matching config contains list-based comparators; recomputing matcher.")
            else:
                print("[*] Matching config already present in state; skipping MatchingTester")
                return {"matching_config": existing_cfg, "matcher_mode": matcher_mode}

        # Always reload matching_tester from disk so notebook sessions do not use stale class code.
        try:
            import importlib
            import matching_tester as _matching_tester_module
            _matching_tester_module = importlib.reload(_matching_tester_module)
            RuntimeMatchingTester = _matching_tester_module.MatchingTester
            if hasattr(_matching_tester_module, "__file__"):
                print(f"[*] Using MatchingTester module: {_matching_tester_module.__file__}")
        except Exception as e:
            print(f"[WARN] Could not reload matching_tester module: {e}")
            RuntimeMatchingTester = MatchingTester

        print("[*] Running MatchingTester")
        tester = RuntimeMatchingTester(
            llm=self.base_model,
            datasets=state["datasets"],
            matching_testsets=state['entity_matching_testsets'],
            blocking_config=state.get("blocking_config", {}),
            output_dir="output/matching-evaluation",
            f1_threshold=0.75,
            max_attempts=4,
            max_error_retries=2,
            verbose=True,
            matcher_mode=matcher_mode,
            disallow_list_comparators=True,
        )
        _, matching_config = tester.run_all()
        print("[*] Matching config computed:\n" + json.dumps(matching_config, indent=2))
        self.logger.info("Leaving run_matching_tester")
        return {"matching_config": matching_config, "matcher_mode": matcher_mode}


    def pipeline_adaption(self, state: SimpleModelAgentState):
        self._log_action("pipeline_adaption", "start", "Generate integration pipeline code", "Incorporates configs and prior feedback")

        self.logger.info('----------------------- Entering pipeline_adaption -----------------------')
        try:
            from prompts.pipeline_prompt import (
                PIPELINE_NORMALIZATION_RULES_BLOCK,
                PIPELINE_MATCHING_SAFETY_RULES_BLOCK,
            )
        except Exception:
            PIPELINE_NORMALIZATION_RULES_BLOCK = (
                "IMPORTANT NORMALIZATION RULES:\n"
                "- Validation set style drives normalization. Do NOT blindly lowercase text globally.\n"
                "- Keep IDs unchanged (case and content must be preserved exactly).\n"
                "- If you convert a column to list-like values, any comparator on that column MUST set list_strategy.\n"
                "- If StringComparator is used on potentially list-like columns (artist/name/tracks/etc.), set list_strategy explicitly.\n"
                "- Prefer normalization that aligns fused output with validation representation, not a random canonical style."
            )
            PIPELINE_MATCHING_SAFETY_RULES_BLOCK = (
                "MATCHING/COMPARATOR SAFETY RULES (MANDATORY):\n"
                "- Never leave StringComparator list_strategy unspecified when values may be lists.\n"
                "- Never leave NumericComparator list_strategy unspecified when values may be lists.\n"
                "- Avoid introducing preprocessing that changes representation style away from validation set conventions unless diagnostics explicitly justify it."
            )

        ####### PREPARE SYSTEM PROMT #######

        # Sync matching_config from disk only when dataset signature matches current run
        matching_path = os.path.join(OUTPUT_DIR, "matching-evaluation", "matching_config.json")
        if os.path.exists(matching_path):
            with open(matching_path, "r", encoding="utf-8") as f:
                disk_matching_config = json.load(f)
            cfg_names = disk_matching_config.get("dataset_names", []) if isinstance(disk_matching_config, dict) else []
            expected = sorted([Path(p).stem for p in state.get("datasets", [])])
            got = sorted([str(x) for x in cfg_names]) if isinstance(cfg_names, list) else []
            if not got or got == expected:
                state["matching_config"] = disk_matching_config
            else:
                print("[WARN] Ignoring disk matching_config due to dataset signature mismatch.")
    
        # Load example pipeline code
        matcher_mode = str(state.get("matcher_mode", "ml")).strip().lower().replace("-", "_")
        if matcher_mode == "rulebased":
            matcher_mode = "rule_based"
        state["matcher_mode"] = matcher_mode
        example_name = "example_pipeline_ml.py" if matcher_mode == "ml" else "example_pipeline.py"
        example_pipeline_path = os.path.join(INPUT_DIR, f"example_pipelines/{example_name}")
        if not os.path.exists(example_pipeline_path):
            raise FileNotFoundError(f"Example pipeline not found at: {example_pipeline_path}")
    
        with open(example_pipeline_path, "r", encoding="utf-8") as f:
            example_pipeline_code = f.read()

        # Prepare first-row previews for each dataset
        dataset_previews = {}
        for path in state['datasets']:
            df = load_dataset(path)
            if df is not None and not df.empty:
                # Take only first row and convert to dictionary
                dataset_previews[path] = df.iloc[0].to_dict()
            else:
                dataset_previews[path] = "Failed to load or empty dataset"
                
        # Prepare prompt for the model
        entity_matching_section = ""

        if matcher_mode == "ml":
            entity_matching_section = f"""
            2b. Entity matching testsets paths:
            {state["entity_matching_testsets"]}
            """
        
        system_prompt = f"""
        You are a data scientist tasked with the integration of several datasets.
        You are provided with the following inputs:

        1. An example integration pipeline (Python code using PyDI library). Pay
        attention to the comments within the pipeline, as they also contain important instructions:
        {example_pipeline_code}
    
        2. A list of dataset file paths:
        {json.dumps(state['datasets'], indent=2)}

        {entity_matching_section}
    
        3. The first row of each dataset to help understand the structure:
        {json.dumps(dataset_previews, indent=2)}
    
        4. A dictionary containing the profile data of the datasets
        (including number of rows, nulls_per_column and dtypes of 
        the columns):
        {json.dumps(state['data_profiles'], indent=2)}
        """

        normalization_context = {
            "normalization_execution_result": state.get("normalization_execution_result", ""),
            "normalization_attempts": state.get("normalization_attempts", 0),
            "normalization_directives": state.get("normalization_directives", {}),
            "normalization_report": state.get("normalization_report", {}),
        }
        system_prompt += f"""

        4b. NORMALIZATION CONTEXT (important for robust generation):
        {json.dumps(normalization_context, indent=2)}

        {PIPELINE_NORMALIZATION_RULES_BLOCK}
        """
        
        # Include blocking config if available (from BlockingTester)
        blocking_config = state.get('blocking_config')
        if blocking_config:
            system_prompt += f"""

        5. **BLOCKING CONFIGURATION** (pre-computed optimal blocking strategies):
        This configuration was determined by a blocking evaluation agent. Use these settings
        for your blocking step in the pipeline:
        {json.dumps(blocking_config, indent=2)}
        
        IMPORTANT: Use the id_columns and blocking_strategies from this config:
        - Use the correct id_column for each dataset as specified
        - Use the recommended strategy (exact_match_single/multi or semantic_similarity)
        - Use the recommended columns for blocking
        - Strategy to blocker mapping:
          * exact_match_single / exact_match_multi -> StandardBlocker (exact match on columns)
          * token_blocking / ngram_blocking -> TokenBlocker (token or n-gram blocking)
          * sorted_neighbourhood -> SortedNeighbourhoodBlocker (window)
          * semantic_similarity -> EmbeddingBlocker (top_k)
        """

        # Include matching config if available (from MatchingTester)
        matching_config = state.get('matching_config')
        if matching_config:
            if matcher_mode == "ml":
                system_prompt += f"""

        6. **MATCHING CONFIGURATION** (pre-computed comparator settings):
        This configuration was determined by a matching evaluation agent. Use these settings
        for your MLBasedMatcher feature extraction and training:
        {json.dumps(matching_config, indent=2)}

        IMPORTANT: Use the matching_strategies from this config:
        - Build comparators (StringComparator/NumericComparator/DateComparator) for each dataset pair
        - Use the comparators as features in FeatureExtractor
        - Train a classifier on the labeled pairs (labels in the testset) and use MLBasedMatcher
        - Do NOT set weights; ML model learns weights internally
        - Do NOT add RuleBasedMatcher fallback branches
        - Follow the example ML pipeline structure and naming closely; do not invent new variable roles
        - Gold correspondence files can use different pair-id column names (e.g., id1/id2, id_a/id_b). Infer pair columns dynamically and normalize them before feature extraction.
        - preprocess mapping: "lower" -> str.lower, "strip" -> str.strip, "lower_strip" -> lambda x: str(x).lower().strip()

        - For NumericComparator on potentially list-valued columns (e.g., duration fields), set `list_strategy` explicitly (recommended: "average") or safely scalarize before matching.
        """
            else:
                system_prompt += f"""

        6. **MATCHING CONFIGURATION** (pre-computed comparator settings):
        This configuration was determined by a matching evaluation agent. Use these settings
        for your RuleBasedMatcher step in the pipeline:
        {json.dumps(matching_config, indent=2)}

        IMPORTANT: Use the matching_strategies from this config:
        - Build comparators (StringComparator/NumericComparator/DateComparator) for each dataset pair
        - Use the specified weights and threshold.
        - For each pair in `matching_strategies`, you **MUST** define a
            variable named `threshold_[original_pair_key]` (e.g.,
            `threshold_discogs_lastfm = 0.7`) with the corresponding threshold value.
            Ensure your RuleBasedMatcher instances use these variables for their
            `threshold` parameter.
        - preprocess mapping: "lower" -> str.lower, "strip" -> str.strip, "lower_strip" -> lambda x: str(x).lower().strip()

        - For NumericComparator on potentially list-valued columns (e.g., duration fields), set `list_strategy` explicitly (recommended: "average") or safely scalarize before matching.
        """

        system_prompt += """

        Your task is to **create a similar integration pipeline** so that it works with
        the datasets provided. Output should only consist of the relevant Python code
        for the integration pipeline.

        FUSION RULES (MANDATORY):
        - Use PyDI built-in fusers as the default and preferred choice.
        - Do NOT define custom fusion resolvers or lambda resolvers unless absolutely unavoidable.
        - If unavoidable, custom fusers must be minimal, PyDI-compatible, and justified by diagnostics evidence.
        - Prefer this built-in mapping by inferred attribute type:
          * string-like scalar fields -> `longest_string` or `prefer_higher_trust`
          * numeric fields -> `median` (or `average` when justified)
          * date/time fields -> `most_recent` (or `earliest` when justified)
          * list-like fields -> `union` (or `intersection` when diagnostics indicate noise)
        - For trust-based fusion, pass trust configuration only at registration time:
          `strategy.add_attribute_fuser(attr, prefer_higher_trust, trust_map=trust_map)`
        - Do NOT wrap `prefer_higher_trust` in another function that hardcodes `trust_map` again.

        {PIPELINE_MATCHING_SAFETY_RULES_BLOCK}
        """

        evaluation_analysis = state.get("evaluation_analysis", None)
        if evaluation_analysis:
            system_prompt += f"""
            8. Evaluation reasoning from prior pipeline run:
            {evaluation_analysis}
            """

        auto_diagnostics = state.get("auto_diagnostics")
        if auto_diagnostics:
            system_prompt += f"""
            9. AUTO DIAGNOSTICS FROM THE LAST EXECUTION:
            {json.dumps(auto_diagnostics, indent=2)}

            You MUST react to these diagnostics:
            - If mapped ID coverage is low or missing_fused_value is high, set `include_singletons=True` and preserve source IDs for evaluation alignment.
            - If list-attribute accuracy is very low, do not blindly union noisy lists; use a robust strategy (trusted-source selection or consensus with normalization).
            - Always write correspondence files for every evaluated pair to `output/correspondences/` so cluster analysis uses current run artifacts.
            """
        integration_diagnostics_report = state.get("integration_diagnostics_report")
        if integration_diagnostics_report:
            system_prompt += f"""
            10. INTEGRATION DIAGNOSTICS REPORT FROM THE LAST EXECUTION:
            {json.dumps(integration_diagnostics_report, indent=2)}

            Use this report as hard evidence and prioritize fixes that address the highest-severity findings first.
            If present, directly use `fusion_policy_recommendations` and `source_attribute_agreement` to choose per-attribute fusion strategies (e.g., trust-based source preference where agreement clearly favors one source).
            """
        investigator_action_plan = state.get("investigator_action_plan")
        if investigator_action_plan:
            system_prompt += f"""
            11. INVESTIGATOR ACTION PLAN (RANKED):
            {json.dumps(investigator_action_plan, indent=2)}

            Implement highest-priority actions first.
            Do not implement low-confidence actions unless supported by additional evidence.
            """
        #### Cluster Analysis ####
        cluster_analysis = state.get("cluster_analysis_result")
        cluster_recommendation = None
        cluster_parameters = {}
        cluster_recommendation_source = None

        if cluster_analysis:
            overall = cluster_analysis.get("_overall", {}) if isinstance(cluster_analysis, dict) else {}
            if isinstance(overall, dict) and overall.get("recommended_strategy") not in (None, "", "None"):
                cluster_recommendation = overall.get("recommended_strategy")
                cluster_parameters = overall.get("parameters", {})
                cluster_recommendation_source = "_overall"
            else:
                for key, value in (cluster_analysis or {}).items():
                    if not isinstance(value, dict):
                        continue
                    rec = value.get("recommended_strategy")
                    if rec and rec != "None":
                        cluster_recommendation = rec
                        cluster_parameters = value.get("parameters", {})
                        cluster_recommendation_source = key
                        break

        if cluster_analysis:
            cluster_example_name = "example_pipeline_ml_cluster.py" if matcher_mode == "ml" else "example_pipeline_cluster.py"
            cluster_example_pipeline_path = os.path.join(INPUT_DIR, f"example_pipelines/{cluster_example_name}")

            if not os.path.exists(cluster_example_pipeline_path):
                raise FileNotFoundError(f"Cluster example pipeline not found at: {cluster_example_pipeline_path}")
            
            with open(cluster_example_pipeline_path, "r", encoding="utf-8") as f:
                cluster_example_pipeline_code = f.read()

            system_prompt += f"""

        **CLUSTER ANALYSIS FEEDBACK FROM PREVIOUS RUN:**
        Report: {json.dumps(cluster_analysis, indent=2)}

        CLUSTER ANALYSIS: The report includes per-file results and may include an `_overall` summary with a `recommended_strategy`.

        **POST-CLUSTERING ACTION REQUIRED:**
        - Recommended strategy: {cluster_recommendation or "None"}
        - Parameters: {json.dumps(cluster_parameters, indent=2)}
        - Source: {cluster_recommendation_source or "n/a"}

        1.  **Analyze the feedback:** Prefer `_overall.recommended_strategy` if present; otherwise scan the per-file entries.
        2.  **CLUSTER-DRIVEN ACTIONS:**
                - If the Recommended strategy is `AdjustMatchingConfig`, do NOT change matching thresholds. Keep pre-tested matching_config unchanged.
                - If the Recommended strategy is a post-clustering function, you **MUST** add that step to your generated code.
        3.  **FOLLOW THIS EXAMPLE FOR INCORPORATING POST-CLUSTERING:**
                - DO NOT change the earlier parts of the pipeline (data loading, blocking, matching).
                - After the entity matching step and before fusion, add the post-clustering step as shown below.
                - Use the exact function as per the Recommended strategy above.
                - Example of applying a post-clustering step:
                {cluster_example_pipeline_code}
        
        Your task is to modify the integration pipeline to incorporate the recommended post-clustering step.
        """

        # Determine if this is initial generation, fix due to execution error, or fix due to poor evaluation
        if "pipeline_execution_result" not in state and "evaluation_metrics" not in state:
            print("[*] Creating initial pipeline")
            human_content = "Create the integration pipeline for the provided datasets."
    
        else:
            # Either a pipeline execution error or evaluation-based adaption
            broken_pipeline_path = OUTPUT_DIR + "code/pipeline.py"
            with open(broken_pipeline_path, "r", encoding="utf-8", errors="ignore") as f:
                broken_code = f.read()
    
            human_content = "You previously generated Python integration pipeline code.\n"
            
            # Add execution error if exists
            if "pipeline_execution_result" in state and state["pipeline_execution_result"].lower().startswith("error"):
                print("[*] Trying to fix pipeline")
                human_content += f"Executing this pipeline caused the following error:\n{state['pipeline_execution_result']}\n"
    
            # Add evaluation feedback if available
            if "evaluation_metrics" in state:
                print("[*] Trying to improve pipeline based on evaluation")
                human_content += f"Evaluation of the last run shows the following metrics:\n{json.dumps(state['evaluation_metrics'], indent=2)}\n"
                human_content += "Improve the pipeline to increase overall accuracy and correct errors highlighted by the evaluation.\n"
    
            human_content += "Here is the current pipeline code:\n" + broken_code
            human_content += "\nOutput ONLY the corrected Python code."
            
        ####### SEARCH DOCUMENTATION TOOL #######
        if "search_documentation" in self.tools:
            self.tools["search_documentation"].reset()

        # Rebuild prompt each attempt so latest failures/metrics are included.
        system_prompt += """
            **PROCESS:**
            1.  **THINK**: Analyze the provided data profiles, configurations, and any previous error reports.
            2.  **RESEARCH**: If you are unsure how to use a PyDI function or class, you MUST use the `search_documentation` tool. You can call it multiple times based on given information such as, blocking configurations, matching configurations, data profile etc. Ask specific questions (e.g., "How to use SortedNeighbourhoodBlocker?", "What are the parameters for RuleBasedMatcher?").
            3.  **CODE**: Once you have gathered enough information, write the complete, executable Python code for the pipeline. **Your final output in this process must be only the Python code itself.**
            4.  **FUSION SAFETY**: Ensure custom fusers/lambda fusers accept `**kwargs` so PyDI runtime kwargs do not fail."""

        messages = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content)
        ]
        state["messages"] = messages
    
        self.logger.info("Input Message:" + str(messages))
    
        # Call the model
        adapted_pipeline = self._invoke_with_usage(messages, "pipeline_adaption")
        messages.append(adapted_pipeline)

        if adapted_pipeline.tool_calls:
            tool_messages = []
            for tool_call in adapted_pipeline.tool_calls:
                tool_name = tool_call.get("name", "")
                tool_args = tool_call.get("args", {})
                tool_id = tool_call.get("id")
                try:
                    if tool_name in self.tools:
                        tool_output = self.tools[tool_name].invoke(tool_args)
                    else:
                        tool_output = (
                            f"Tool '{tool_name}' not available. "
                            f"Available tools: {list(self.tools.keys())}"
                        )
                except Exception as tool_err:
                    tool_output = f"Tool '{tool_name}' execution error: {tool_err}"
                if tool_id:
                    tool_messages.append(
                        ToolMessage(content=str(tool_output), tool_call_id=tool_id)
                    )
            messages.extend(tool_messages)
            
            # After tool calls, invoke the model again to get the final code
            final_response = self._invoke_with_usage(messages, "pipeline_adaption")
            messages.append(final_response)
            adapted_pipeline = final_response
        
        # Extract the code from the final response
        if hasattr(adapted_pipeline, 'tool_calls') and adapted_pipeline.tool_calls:
            # If still has tool calls after second invocation, recursively handle
            adapted_pipeline = "Pipeline code not available - too many tool calls"
        else:
            adapted_pipeline = adapted_pipeline.content if hasattr(adapted_pipeline, "content") else str(adapted_pipeline)
            self.logger.info("RESULT:" + str(adapted_pipeline))
            # if state.get("matching_config"):
                # adapted_pipeline = self._apply_matching_thresholds(adapted_pipeline, state.get("matching_config", dict()))
            if adapted_pipeline.startswith("```python") and adapted_pipeline.endswith("```"):
                adapted_pipeline = adapted_pipeline.strip("```python").strip("```").strip()
                adapted_pipeline = self._apply_pipeline_guardrails(adapted_pipeline, state)

                os.makedirs(OUTPUT_DIR + "code/", exist_ok=True)
                with open(OUTPUT_DIR + "code/pipeline.py", 'w', errors="ignore") as file:
                    file.write(str(adapted_pipeline))
                    # self._rewrite_pipeline_thresholds(OUTPUT_DIR + "code/pipeline.py", state.get("matching_config", {}))
            elif not adapted_pipeline.startswith("Pipeline code not available"):
                # Code without markdown markers - still save it
                adapted_pipeline = self._apply_pipeline_guardrails(str(adapted_pipeline), state)
                os.makedirs(OUTPUT_DIR + "code/", exist_ok=True)
                with open(OUTPUT_DIR + "code/pipeline.py", 'w', errors="ignore") as file:
                    file.write(str(adapted_pipeline))
                    # self._rewrite_pipeline_thresholds(OUTPUT_DIR + "code/pipeline.py", state.get("matching_config", {}))

        self.logger.info('Leaving pipeline_adaption')
        return {"messages": messages, "integration_pipeline_code": adapted_pipeline}

    def execute_pipeline(self, state: SimpleModelAgentState):
        self._log_action("execute_pipeline", "start", "Run generated pipeline", "Produces correspondences for analysis", {"attempt": state.get("pipeline_execution_attempts", 0)+1})

        self.logger.info('----------------------- Entering execute_pipeline -----------------------')

        print("[*] Running generated pipeline")

        attempts = state.get("pipeline_execution_attempts", 0) + 1
        state["pipeline_execution_attempts"] = attempts

        pipeline_path = OUTPUT_DIR + "code/pipeline.py"
        run_started_at = time.time()
        fusion_size_comparison = {}

        try:
            result = subprocess.run(
                [sys.executable, pipeline_path],
                capture_output=True,
                text=True,
                timeout=3600
            )

            if result.returncode == 0:
                print("[+] Pipeline successfully completed")
                execution_result = "success"
                if result.stdout:
                    print("[PIPELINE STDOUT]")
                    print(result.stdout)
                if result.stderr:
                    print("[PIPELINE STDERR]")
                    print(result.stderr)

                # Compare estimate vs actual fused size right after successful pipeline run.
                estimate_path = "output/pipeline_evaluation/fusion_size_estimate.json"
                fused_csv_path = "output/data_fusion/fusion_data.csv"
                if os.path.exists(estimate_path) and os.path.exists(fused_csv_path):
                    try:
                        fusion_size_comparison = compare_estimates_with_actual(
                            fusion_csv_path=fused_csv_path,
                            estimate_path=estimate_path,
                        )
                        comparisons = fusion_size_comparison.get("comparisons", {})
                        if comparisons:
                            print("[FUSION SIZE COMPARISON]")
                            for stage, comp in comparisons.items():
                                print(
                                    f"  {stage}: expected_rows={comp.get('expected_rows')} "
                                    f"actual_rows={comp.get('actual_rows')} "
                                    f"rows_pct_error={comp.get('rows_pct_error')}"
                                )
                    except Exception as compare_error:
                        print(f"[WARN] Could not compare expected vs actual fusion size: {compare_error}")
            else:
                execution_result = f"error: {result.stderr}"[:10000]
                print("Error: " + str(execution_result))
                if result.stdout:
                    print("[PIPELINE STDOUT]")
                    print(result.stdout)

        except Exception as e:
            execution_result = f"error: {str(e)}"

        self.logger.info("Pipeline execution result: " + execution_result)
        self.logger.info('Leaving execute_pipeline')

        return {
            "pipeline_execution_result": execution_result,
            "pipeline_execution_attempts": attempts,
            "pipeline_run_started_at": run_started_at,
            "pipeline_run_finished_at": time.time(),
            "fusion_size_comparison": fusion_size_comparison,
        }
    
    def cluster_analysis(self, state: SimpleModelAgentState) -> Dict[str, Any]:
        from helpers.correspondence_helpers import (
            collect_latest_correspondence_files as helper_collect_latest_correspondence_files,
            summarize_correspondence_entries as helper_summarize_correspondence_entries,
        )

        self._log_action("cluster_analysis", "start", "Analyze pairwise correspondences", "Supports investigator loop")
        self.logger.info("----------------------- Entering Cluster Analysis Helper -----------------------")
        print("[*] Running cluster analysis helper...")

        correspondence_files_to_process = helper_collect_latest_correspondence_files(state)
        if not correspondence_files_to_process:
            print("[-] No relevant correspondence files found for current run, skipping cluster analysis.")
            return {"cluster_analysis_result": {"warning": "stale_or_missing_correspondence_files", "_investigation": {"files": {}}}}

        print(f"[*] Found {len(correspondence_files_to_process)} pairwise correspondence files to analyze.")

        try:
            cluster_tester = ClusterTester(llm=self.base_model, verbose=True)
            report = cluster_tester.run(correspondence_files_to_process)
            if not isinstance(report, dict):
                report = {"_overall": {"recommended_strategy": "None", "parameters": {}}, "raw_report": report}
            report["_investigation"] = helper_summarize_correspondence_entries(correspondence_files_to_process)

            return {"cluster_analysis_result": report}
        except Exception as e:
            print(f"[-] Error during cluster analysis helper: {e}")
            self.logger.error(f"Cluster analysis helper failed: {traceback.format_exc()}")
            return {"cluster_analysis_result": {"error": str(e)}}
        
    def evaluation_adaption(self, state: SimpleModelAgentState):
        from helpers.evaluation_helpers import extract_python_code as helper_extract_python_code

        self._log_action("evaluation_adaption", "start", "Generate evaluation code", "Measures fusion quality")

        self.logger.info('----------------------- Entering evaluation_adaption -----------------------')
        try:
            from prompts.evaluation_prompt import EVALUATION_ROBUSTNESS_RULES_BLOCK
        except Exception:
            EVALUATION_ROBUSTNESS_RULES_BLOCK = (
                "EVALUATION ROBUSTNESS RULES (MANDATORY):\n"
                "- Use validation-set representation as the normalization target for evaluation.\n"
                "- Normalize fused and gold columns to the SAME representation before evaluating.\n"
                "- For country-like columns, infer and apply a shared normalize_country output_format from the evaluation set (alpha_2/alpha_3/numeric/name/official_name).\n"
                "- For free-text/list-like columns, avoid strict exact comparisons unless values are canonical identifiers.\n"
                "  Prefer tokenized_match with an explicit threshold (for example 0.7-0.9) instead of exact-only semantics.\n"
                "- If using set-based comparison on textual lists, first canonicalize list elements consistently across fused and gold."
            )
        
        example_eval_path = INPUT_DIR + "example_pipelines/example_evaluation.py"
        example_eval_code = open(example_eval_path).read()
    
        fused_output_path = "output/data_fusion/fusion_data.csv"
        force_test_eval = bool(state.get("_force_test_eval"))
        eval_testset_path = self._evaluation_testset_path(state, force_test=force_test_eval)
        eval_stage = self._evaluation_stage_label(state, force_test=force_test_eval)

        # Prepare first-row preview for evaluation set
        try:
            dataset = load_dataset(eval_testset_path) if eval_testset_path else None
        except Exception:
            dataset = None
        if dataset is not None and not dataset.empty:
            testset_preview = dataset.iloc[0].to_dict()
        else:
            testset_preview = "Failed to load or empty dataset"
    
        system_prompt = f"""
        You are a data scientist evaluating a data fusion pipeline.
    
        Example evaluation code:
        {example_eval_code}
    
        Generated integration pipeline:
        {state['integration_pipeline_code']}
    
        Dataset profiles:
        {json.dumps(state['data_profiles'], indent=2)}
    
        The fused output is located at:
        {fused_output_path}

        The evaluation stage is:
        {eval_stage}

        The evaluation set is located at:
        {eval_testset_path}

        The first row of the evaluation set looks like the following:
        {testset_preview}

        Normalization directives and report from previous steps:
        {json.dumps(state.get("normalization_directives", {}), indent=2)}
        {json.dumps(state.get("normalization_report", {}), indent=2)}
    
        Create evaluation code that:
        - Uses the correct fusion strategy
        - Loads the fused output
        - Loads the gold standard evaluation set (validation in sealed mode, otherwise test)
        - Prints structured evaluation metrics
        - Prints chosen evaluation functions in a compact one-line summary
        - If helper modules are imported from local files (e.g., list_normalization), use a robust fallback import pattern that works from output/code execution context.
        - Does NOT require exact matching everywhere by default.

        {EVALUATION_ROBUSTNESS_RULES_BLOCK}
        """

        evaluation_analysis = state.get("evaluation_analysis", None)
        if evaluation_analysis:
            system_prompt += f"""
            Evaluation reasoning from prior pipeline run:
            {evaluation_analysis}
            """

        ####### HUMAN PROMPT #######
        if not state.get("evaluation_execution_result"):
            print("[*] Adapting evaluation code")
            # First generation
            human_content = """
            Create the evaluation code.
            """
        else:
            # Fix broken evaluation
            print("[*] Fixing evaluation code")
            attempts = state.get("evaluation_execution_attempts", 0)
    
            if attempts >= 3:
                self.logger.info("Maximum evaluation fix attempts reached")
                return {"evaluation_execution_result": "error: max attempts reached"}
    
            eval_path = OUTPUT_DIR + "code/evaluation.py"
            with open(eval_path, "r", encoding="utf-8") as f:
                broken_code = f.read()
    
            error = state["evaluation_execution_result"]
    
            human_content = f"""
            You previously generated Python evaluation code.
            Executing this code caused the following error:
    
            {error}
    
            Here is the current evaluation code:
            {broken_code}
    
            Fix the code so that it executes successfully.
            Output ONLY the corrected Python code.
            """

        if "search_documentation" in self.tools and not state.get("evaluation_execution_result"):
            self.tools["search_documentation"].reset()

        # Rebuild prompt each attempt so latest execution error is always included.
        system_prompt += """
            **PROCESS:**
            1.  **THINK**: Analyze the provided integration pipeline code, dataset profiles, and any previous error reports.
            2.  **RESEARCH**: If you are unsure how to use a PyDI function or class for evaluation, you MUST use the `search_documentation` tool. You can call it multiple times based on given information such as, fusion strategy, data profiles, error messages etc. Ask specific questions (e.g., "How to evaluate a fusion output?", "What functions does PyDI provide for evaluation?").
            3.  **CODE**: Once you have gathered enough information, write the complete, executable Python code for the evaluation. **Your final output in this process must be only the Python code itself.**"""

        messages = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content)
        ]
        state["eval_messages"] = messages

        self.logger.info("Input Message:" + str(messages))

        result = self._invoke_with_usage(messages, "evaluation_adaption")
        messages.append(result)

        if result.tool_calls:
            tool_messages = []
            for tool_call in result.tool_calls:
                tool_name = tool_call.get("name", "")
                tool_args = tool_call.get("args", {})
                tool_id = tool_call.get("id")
                try:
                    if tool_name in self.tools:
                        tool_output = self.tools[tool_name].invoke(tool_args)
                    else:
                        tool_output = (
                            f"Tool '{tool_name}' not available. "
                            f"Available tools: {list(self.tools.keys())}"
                        )
                except Exception as tool_err:
                    tool_output = f"Tool '{tool_name}' execution error: {tool_err}"
                if tool_id:
                    tool_messages.append(
                        ToolMessage(content=str(tool_output), tool_call_id=tool_id)
                    )
            messages.extend(tool_messages)
            
            # After tool calls, invoke the model again to get the final code
            final_response = self._invoke_with_usage(messages, "evaluation_adaption")
            messages.append(final_response)
            result = final_response

        if hasattr(result, 'tool_calls') and result.tool_calls:
            # If still has tool calls after second invocation, recursively handle
            code = "Evaluation code not available - too many tool calls"
        else:
            code = result.content if hasattr(result, "content") else str(result)
            self.logger.info("RESULT:" + str(code))

            code = helper_extract_python_code(code)
            code = self._apply_evaluation_guardrails(code)
            with open(OUTPUT_DIR + "code/evaluation.py", "w") as f:
                f.write(code)

        self.logger.info('Leaving evaluation_adaption')
    
        return {"evaluation_code": code, "eval_messages": messages}

    def execute_evaluation(self, state: SimpleModelAgentState):
        self._log_action("execute_evaluation", "start", "Run evaluation", "Produces accuracy metrics", {"attempt": state.get("evaluation_execution_attempts", 0)+1})

        self.logger.info('----------------------- Entering execute_evaluation -----------------------')
    
        print("[*] Running generated evaluation")
    
        attempts = state.get("evaluation_execution_attempts", 0) + 1
        state["evaluation_execution_attempts"] = attempts
    
        evaluation_path = OUTPUT_DIR + "code/evaluation.py"
    
        try:
            result = subprocess.run(
                [sys.executable, evaluation_path],
                capture_output=True,
                text=True,
                timeout=3600
            )
    
            if result.returncode == 0:
                print("[+] Evaluation successfully completed")
                execution_result = "success"
                if result.stdout:
                    print("[EVALUATION STDOUT]")
                    print(result.stdout)
                if result.stderr:
                    print("[EVALUATION STDERR]")
                    print(result.stderr)
            else:
                print("[-] Evaluation could not be executed")
                execution_result = f"error: {result.stderr}"[:10000]
                print("Error: " + str(execution_result))
                if result.stdout:
                    print("[EVALUATION STDOUT]")
                    print(result.stdout)
    
        except Exception as e:
            execution_result = f"error: {str(e)}"
    
        self.logger.info("Evaluation execution result: " + execution_result)
        self.logger.info('Leaving execute_evaluation')
    
        return {
            "evaluation_execution_result": execution_result,
            "evaluation_execution_attempts": attempts
        }

    def integration_diagnostics(self, state: SimpleModelAgentState):
        from helpers.evaluation_helpers import extract_python_code as helper_extract_python_code

        self._log_action(
            "integration_diagnostics",
            "start",
            "Generate and run free-form integration diagnostics",
            "Produces issue report and concrete next actions",
        )
        print("[*] Running free integration diagnostics")

        os.makedirs(OUTPUT_DIR + "code/", exist_ok=True)
        os.makedirs("output/pipeline_evaluation", exist_ok=True)

        diagnostics_code_path = OUTPUT_DIR + "code/integration_diagnostics.py"
        report_json_path = "output/pipeline_evaluation/integration_diagnostics.json"
        report_md_path = "output/pipeline_evaluation/integration_diagnostics.md"

        context_payload = {
            "datasets": state.get("datasets", []),
            "fusion_testset": state.get("fusion_testset"),
            "validation_fusion_testset": state.get("validation_fusion_testset"),
            "evaluation_testset": self._evaluation_testset_path(state, force_test=bool(state.get("_force_test_eval"))),
            "evaluation_stage": self._evaluation_stage_label(state, force_test=bool(state.get("_force_test_eval"))),
            "matcher_mode": state.get("matcher_mode"),
            "evaluation_metrics": state.get("evaluation_metrics", {}),
            "auto_diagnostics": state.get("auto_diagnostics", {}),
            "normalization_execution_result": state.get("normalization_execution_result", ""),
            "normalization_attempts": state.get("normalization_attempts", 0),
            "normalization_report": state.get("normalization_report", {}),
            "normalization_directives": state.get("normalization_directives", {}),
            "investigator_action_plan": state.get("investigator_action_plan", []),
            "normalized_datasets": state.get("normalized_datasets", []),
            "fusion_size_comparison": state.get("fusion_size_comparison", {}),
            "cluster_analysis_result": state.get("cluster_analysis_result", {}),
            "output_paths": {
                "fused_csv": "output/data_fusion/fusion_data.csv",
                "evaluation_json": "output/pipeline_evaluation/pipeline_evaluation.json",
                "debug_jsonl": "output/pipeline_evaluation/debug_fusion_eval.jsonl",
                "fusion_size_estimate_json": "output/pipeline_evaluation/fusion_size_estimate.json",
                "correspondences_dir": "output/correspondences",
                "report_json": report_json_path,
                "report_md": report_md_path,
            },
        }

        system_prompt = """
        You are generating a standalone Python diagnostics script for a data-integration pipeline.
        Write ONLY executable Python code.

        Hard requirements:
        - Be dataset-agnostic (no dataset-specific hardcoding).
        - The diagnostics script must be generated from reasoning and execute its own analysis logic (no placeholder output).
        - Read available artifacts and detect integration issues robustly.
        - Focus on actionable findings: coverage gaps, over-clustering, noisy list fusion, and size-estimate drift.
        - Explicitly detect empty pairwise correspondence files and treat them as HIGH severity if matching config expected that pair.
        - Explicitly detect case-only mismatch patterns from debug_fusion_eval events.
        - Perform attribute-level source agreement analysis:
          * load fused output and source datasets
          * compare fused attribute values against source attribute values (for aligned rows where possible)
          * compute per-attribute/per-source agreement metrics (support_count, exact_ratio and/or similarity ratio)
          * identify attributes where one source strongly dominates agreement
        - From that analysis, generate machine-usable fusion policy suggestions (for example trust-based source preference for specific attributes).
        - Rank suggested improvements by expected impact and confidence, with concise evidence.

        - Explicitly check normalization-sensitive issues and report them as findings/recommendations:

          * country canonicalization mismatches (e.g., long-form vs short-form country names)

          * list-format inconsistencies (JSON-list strings vs scalar strings vs malformed list encodings)
        - Gracefully handle missing files (do not crash; record warnings).
        - Output TWO files:
          1) output/pipeline_evaluation/integration_diagnostics.json
          2) output/pipeline_evaluation/integration_diagnostics.md
        - JSON must contain at least:
          - summary
          - findings (list ordered by severity)
          - recommendations (list, concrete and generic)
          - source_attribute_agreement (attribute -> source metrics)
          - fusion_policy_recommendations (list of suggested strategy/trust actions with evidence)
          - each recommendation should include: action, target_attributes, evidence_summary, expected_impact, confidence

          - recommendation fields should include machine-usable hints when possible (e.g., target columns, suggested PyDI functions)
          - evidence (counts/ratios/paths)
          - created_at
        - Keep dependencies minimal (stdlib + pandas).
        """

        def _generate_code(feedback: str | None = None) -> str:
            human_content = f"""
            Context for diagnostics:
            {json.dumps(context_payload, indent=2)}

            Generate a Python script that inspects those artifacts, computes diagnostics, and writes:
            - {report_json_path}
            - {report_md_path}
            The script should include concrete computations for source-attribute agreement and not only text heuristics.
            """
            if feedback:
                human_content += f"""

                The previous diagnostics script failed with:
                {feedback}

                Fix the script and return corrected Python code only.
                """
            response = self.base_model.invoke(
                [
                    SystemMessage(content=system_prompt),
                    HumanMessage(content=human_content),
                ]
            )
            return helper_extract_python_code(response)

        diagnostics_code = _generate_code()
        execution_result = "error: diagnostics script not executed"
        report_payload: Dict[str, Any] = {}

        for attempt in range(1, 3):
            with open(diagnostics_code_path, "w", encoding="utf-8") as f:
                f.write(diagnostics_code)

            try:
                result = subprocess.run(
                    [sys.executable, diagnostics_code_path],
                    capture_output=True,
                    text=True,
                    timeout=1200,
                )
                if result.returncode == 0:
                    execution_result = "success"
                    if result.stdout:
                        print("[INTEGRATION DIAGNOSTICS STDOUT]")
                        print(result.stdout)
                    if result.stderr:
                        print("[INTEGRATION DIAGNOSTICS STDERR]")
                        print(result.stderr)
                    break

                execution_result = f"error: {result.stderr or result.stdout}"[:10000]
                print("[-] Integration diagnostics failed")
                print(execution_result)
            except Exception as e:
                execution_result = f"error: {str(e)}"
                print("[-] Integration diagnostics exception")
                print(execution_result)

            if attempt < 2:
                diagnostics_code = _generate_code(feedback=execution_result)

        if os.path.exists(report_json_path):
            try:
                with open(report_json_path, "r", encoding="utf-8") as f:
                    report_payload = json.load(f)
            except Exception as e:
                report_payload = {"error": f"could_not_read_report: {e}"}

        return {
            "integration_diagnostics_code": diagnostics_code,
            "integration_diagnostics_execution_result": execution_result,
            "integration_diagnostics_report": report_payload,
        }


    def human_review_export(self, state: SimpleModelAgentState):
        from helpers.evaluation_helpers import extract_python_code as helper_extract_python_code

        self._log_action(
            "human_review_export",
            "start",
            "Generate final human-review package",
            "Creates reviewer-friendly fusion/source/testset comparison artifacts",
        )
        print("[*] Building final human-review package")

        os.makedirs(OUTPUT_DIR + "code/", exist_ok=True)
        os.makedirs("output/human_review", exist_ok=True)

        review_code_path = OUTPUT_DIR + "code/human_review_export.py"
        review_summary_json = "output/human_review/human_review_summary.json"
        review_summary_md = "output/human_review/human_review_summary.md"
        fused_review_csv = "output/human_review/fused_review_table.csv"
        source_lineage_csv = "output/human_review/source_lineage_long.csv"
        diff_csv = "output/human_review/fusion_vs_testset_diff.csv"

        review_attributes: List[str] = []
        fused_csv_path = "output/data_fusion/fusion_data.csv"
        if os.path.exists(fused_csv_path):
            try:
                fused_preview_df = pd.read_csv(fused_csv_path, nrows=1)
                review_attributes = [
                    c
                    for c in fused_preview_df.columns
                    if not str(c).startswith("_fusion_") and str(c) not in {"_fusion_sources", "_fusion_source_datasets", "_fusion_confidence", "_fusion_metadata"}
                ]
            except Exception:
                review_attributes = []

        context_payload = {
            "datasets": state.get("datasets", []),
            "fusion_testset": state.get("fusion_testset"),
            "review_attributes": review_attributes,
            "evaluation_metrics": state.get("evaluation_metrics", {}),
            "auto_diagnostics": state.get("auto_diagnostics", {}),
            "integration_diagnostics_report": state.get("integration_diagnostics_report", {}),
            "output_paths": {
                "fused_csv": "output/data_fusion/fusion_data.csv",
                "fused_debug_jsonl": "output/data_fusion/debug_fusion_data.jsonl",
                "evaluation_json": "output/pipeline_evaluation/pipeline_evaluation.json",
                "review_summary_json": review_summary_json,
                "review_summary_md": review_summary_md,
                "fused_review_csv": fused_review_csv,
                "source_lineage_csv": source_lineage_csv,
                "diff_csv": diff_csv,
            },
        }

        system_prompt = """
        You are generating a standalone Python script that creates FINAL human-review outputs for a data-fusion run.
        Write ONLY executable Python code.

        Hard requirements:
        - Be dataset-agnostic (no hardcoded dataset-specific columns or IDs).
        - Use only standard library + pandas (optional: PyDI.io if available).
        - Read fused output from output/data_fusion/fusion_data.csv.
        - Load source datasets from the provided dataset paths and detect ID columns robustly.
        - Parse `_fusion_sources` robustly (JSON/list/string/empty) and map each source ID back to source rows.
        - Produce reviewer-friendly outputs:
          1) output/human_review/fused_review_table.csv
             - one row per fused entity in WIDE format
             - for EVERY attribute listed in context_payload.review_attributes, create EXACTLY these columns:
               <attribute>_test, <attribute>_fused, <attribute>_source_1, <attribute>_source_2, <attribute>_source_3
             - keep the attribute text as-is when forming column names (do not rename/sanitize)
             - if testset value is unavailable, leave <attribute>_test as empty string
             - if fewer than 3 sources are available, leave missing <attribute>_source_<n> cells empty
             - this wide-table schema is mandatory and must exist even when values are missing
          2) output/human_review/source_lineage_long.csv
             - long table: fused_id, source_id, source_dataset, source attribute values, fused attribute values
          3) output/human_review/fusion_vs_testset_diff.csv
             - if fusion_testset exists, compare overlapping columns against mapped fused rows and record per-attribute diffs
             - if unavailable, still create an empty CSV with columns and a note in summary
          4) output/human_review/human_review_summary.json
          5) output/human_review/human_review_summary.md
        - Summary JSON must include: summary, file_paths, counts, warnings, created_at.
        - Gracefully handle missing files and malformed rows; do not crash.
        """

        def _generate_code(feedback: str | None = None) -> str:
            human_content = f"""
            Context:
            {json.dumps(context_payload, indent=2)}

            Generate a Python script that builds the required human-review outputs.
            """
            if feedback:
                human_content += f"""

                Previous script failed with:
                {feedback}

                Fix it and return corrected Python code only.
                """

            response = self.base_model.invoke(
                [
                    SystemMessage(content=system_prompt),
                    HumanMessage(content=human_content),
                ]
            )
            return helper_extract_python_code(response)

        execution_result = "error: not_run"
        review_code = ""
        feedback = None

        def _validate_wide_review_columns(path: str, attributes: List[str]) -> tuple[bool, str]:
            if not os.path.exists(path):
                return False, f"missing required file: {path}"
            try:
                review_df = pd.read_csv(path, nrows=1, dtype=str)
            except Exception as e:
                return False, f"could not read {path}: {e}"

            if not attributes:
                return True, "no attributes discovered; skipped strict schema validation"

            cols = set(review_df.columns.tolist())
            missing: List[str] = []
            for attr in attributes:
                expected = [
                    f"{attr}_test",
                    f"{attr}_fused",
                    f"{attr}_source_1",
                    f"{attr}_source_2",
                    f"{attr}_source_3",
                ]
                for col in expected:
                    if col not in cols:
                        missing.append(col)

            if missing:
                preview = ", ".join(missing[:40])
                if len(missing) > 40:
                    preview += f", ... and {len(missing) - 40} more"
                return False, f"missing required wide review columns: {preview}"
            return True, "ok"

        for attempt in range(1, 4):
            review_code = _generate_code(feedback)
            with open(review_code_path, "w", encoding="utf-8") as f:
                f.write(review_code)

            try:
                run = subprocess.run(
                    [sys.executable, review_code_path],
                    capture_output=True,
                    text=True,
                    timeout=1800,
                )
                if run.returncode == 0:
                    schema_ok, schema_msg = _validate_wide_review_columns(fused_review_csv, review_attributes)
                    if not schema_ok:
                        feedback = (
                            "Script executed but fused_review_table.csv does not match required wide schema. "
                            + schema_msg
                            + " Use exact column pattern <attribute>_test/<attribute>_fused/<attribute>_source_1/<attribute>_source_2/<attribute>_source_3 for every attribute in context_payload.review_attributes."
                        )[:10000]
                        execution_result = f"error: {feedback}"[:10000]
                        print("[-] Human-review export schema validation failed")
                        continue

                    execution_result = "success"
                    print("[*] Human-review export completed")
                    if run.stdout:
                        print("[HUMAN REVIEW STDOUT]")
                        print(run.stdout)
                    if run.stderr:
                        print("[HUMAN REVIEW STDERR]")
                        print(run.stderr)
                    break
                feedback = (run.stderr or run.stdout or "unknown error")[:10000]
                execution_result = f"error: {feedback}"[:10000]
            except Exception as e:
                feedback = str(e)
                execution_result = f"error: {feedback}"[:10000]

        report_payload: Dict[str, Any] = {}
        if os.path.exists(review_summary_json):
            try:
                with open(review_summary_json, "r", encoding="utf-8") as f:
                    report_payload = json.load(f)
            except Exception as e:
                report_payload = {"error": f"could_not_read_human_review_summary: {e}"}

        return {
            "human_review_code": review_code,
            "human_review_execution_result": execution_result,
            "human_review_report": report_payload,
        }


    def sealed_final_test_evaluation(self, state: SimpleModelAgentState):
        self._log_action(
            "sealed_final_test_evaluation",
            "start",
            "Run one-time held-out test evaluation",
            "Prevents optimization on final test while still reporting final quality",
        )

        if not self._sealed_eval_active(state):
            print("[*] Sealed final-test evaluation not active (missing validation/test paths).")
            return {
                "final_test_evaluation_execution_result": "skipped",
                "final_test_evaluation_metrics": {},
            }

        print("[*] Running sealed final test evaluation on held-out test set")
        temp_state = dict(state)
        temp_state["_force_test_eval"] = True
        temp_state["evaluation_execution_result"] = ""
        temp_state["evaluation_execution_attempts"] = 0

        eval_updates = self.evaluation_adaption(temp_state)
        temp_state.update(eval_updates)

        exec_updates = self.execute_evaluation(temp_state)
        temp_state.update(exec_updates)

        eval_path = "output/pipeline_evaluation/pipeline_evaluation.json"
        final_metrics: Dict[str, Any] = {}
        if os.path.exists(eval_path):
            try:
                with open(eval_path, "r", encoding="utf-8") as f:
                    final_metrics = json.load(f)
            except Exception as e:
                final_metrics = {"error": f"could_not_read_final_test_metrics: {e}"}

        final_acc = final_metrics.get("overall_accuracy") if isinstance(final_metrics, dict) else None
        if final_acc is not None:
            try:
                print(f"[*] Sealed final test overall accuracy: {float(final_acc):.3%}")
            except Exception:
                pass

        return {
            "final_test_evaluation_execution_result": temp_state.get("evaluation_execution_result", ""),
            "final_test_evaluation_metrics": final_metrics,
        }


    def evaluation_decision(self, state: SimpleModelAgentState):
        self._log_action("evaluation_decision", "start", "Decide whether to iterate", "Drives improvement loop")

        self.logger.info('----------------------- Entering evaluation_decision -----------------------')
        print("[*] Reading evaluation metrics")

        attempts = state.get("evaluation_attempts", 0) + 1
    
        eval_path = "output/pipeline_evaluation/pipeline_evaluation.json"
    
        if not os.path.exists(eval_path):
            self.logger.warning("Evaluation file missing")
            metrics = {"error": "evaluation file missing"}
        else:
            with open(eval_path, "r", encoding="utf-8") as f:
                metrics = json.load(f)
    
        self.logger.info(f"Evaluation metrics: {metrics}")
        print(f"Evaluation metrics: {json.dumps(metrics)}")
    
        # Store metrics in the state
        state["evaluation_metrics"] = metrics

        eval_stage = self._evaluation_stage_label(state, force_test=False)
        try:
            overall_acc = float(metrics.get("overall_accuracy", 0.0))
        except Exception:
            overall_acc = 0.0

        auto_diagnostics = self._compute_auto_diagnostics(state, metrics)
        state["auto_diagnostics"] = auto_diagnostics

        problems: List[str] = []
        if overall_acc < 0.85:
            problems.append(f"overall_accuracy below target: {overall_acc:.3%} < 85.000%")

        low_acc_columns: List[str] = []
        if isinstance(metrics, dict):
            for key, value in metrics.items():
                if not (isinstance(key, str) and key.endswith("_accuracy") and key != "overall_accuracy"):
                    continue
                try:
                    v = float(value)
                except Exception:
                    continue
                if v < 0.5:
                    low_acc_columns.append(f"{key[:-9]}={v:.3%}")
        if low_acc_columns:
            problems.append("low attribute accuracy: " + ", ".join(sorted(low_acc_columns)[:8]))

        id_alignment = auto_diagnostics.get("id_alignment", {}) if isinstance(auto_diagnostics, dict) else {}
        if isinstance(id_alignment, dict):
            mapped_ratio = id_alignment.get("mapped_coverage_ratio")
            direct_ratio = id_alignment.get("direct_coverage_ratio")
            try:
                if mapped_ratio is not None and float(mapped_ratio) < 0.8:
                    problems.append(f"low mapped ID coverage: {float(mapped_ratio):.3%}")
            except Exception:
                pass
            try:
                if direct_ratio is not None and float(direct_ratio) < 0.5:
                    problems.append(f"low direct ID coverage: {float(direct_ratio):.3%}")
            except Exception:
                pass

        reason_ratios = auto_diagnostics.get("debug_reason_ratios", {}) if isinstance(auto_diagnostics, dict) else {}
        if isinstance(reason_ratios, dict):
            try:
                missing_ratio = float(reason_ratios.get("missing_fused_value", 0.0))
                if missing_ratio > 0.25:
                    problems.append(f"high missing_fused_value mismatch ratio: {missing_ratio:.3%}")
            except Exception:
                pass

        print("[EVALUATION REPORT]")
        print(f"  Stage: {eval_stage}")
        print(f"  Attempt: {attempts}/3")
        print(f"  Overall Accuracy: {overall_acc:.3%}")
        print("  Problems Detected:")
        if problems:
            for p in problems[:10]:
                print(f"    - {p}")
        else:
            print("    - none")
        print("  Planned Adaptation:")
        if overall_acc >= 0.85:
            print("    - quality target reached; continue to human review")
        elif attempts >= 3:
            print("    - max automatic iterations reached; stop adaptation loop")
        else:
            print("    - investigator runs diagnostics report + cluster evidence analysis")
            print("    - reasoning node proposes targeted pipeline/code changes")
            if any("coverage" in p for p in problems):
                print("    - prioritize ID alignment and singleton handling")
            if any("missing_fused_value" in p for p in problems):
                print("    - prioritize fusion strategy changes for sparse attributes")

        if auto_diagnostics:
            print("[*] Auto diagnostics:")
            print(json.dumps(auto_diagnostics, indent=2))

        if overall_acc >= 0.85 or attempts >= 3:
            self._print_total_usage()
    
        self.logger.info('Leaving evaluation_decision')

        return {
            "evaluation_metrics": metrics,
            "auto_diagnostics": auto_diagnostics,
            "fusion_size_comparison": state.get("fusion_size_comparison", {}),
            "evaluation_attempts": attempts,
            "pipeline_execution_result": "",
            "pipeline_execution_attempts": 0,
            "evaluation_execution_result": "",
            "evaluation_execution_attempts": 0
        }
    def evaluation_reasoning(self, state: SimpleModelAgentState):
        self._log_action("evaluation_reasoning", "start", "Analyze errors", "Suggests concrete fixes for next run")

        self.logger.info('----------------------- Entering evaluation_reasoning -----------------------')
    
        # Sync matching_config from disk so updated thresholds carry over
        matching_path = os.path.join(OUTPUT_DIR, "matching-evaluation", "matching_config.json")
        if os.path.exists(matching_path):
            with open(matching_path, "r", encoding="utf-8") as f:
                state["matching_config"] = json.load(f)

        debug_path = "output/pipeline_evaluation/debug_fusion_eval.jsonl"
        debug_events = []
    
        if os.path.exists(debug_path):
            with open(debug_path, "r", encoding="utf-8") as f:
                for line in f:
                    try:
                        debug_events.append(json.loads(line))
                    except Exception:
                        continue
    
        # Prepare system prompt
        system_prompt = """
        You are a data integration expert analyzing the evaluation results of a data integration pipeline.
    
        You are given:
        - Aggregate evaluation metrics
        - Detailed per-record debugging events from a fusion evaluation
        - Automatic diagnostics (ID coverage, mismatch reasons, size comparison)
        - The current integration pipeline code
        - The optimal blocking and matching configurations
        - Detailed Cluster Analysis report with improvement suggestions.
    
        Your task:
        1. Identify the dominant error types (false positives, false negatives, missed blocks, bad matches)
        2. Determine whether errors are more likely caused by:
           - Blocking being too restrictive or too loose
           - Matching thresholds or comparator choices
           - Schema or preprocessing issues
           - Logic in the current pipeline code
        3. Analyze the provided cluster analysis report to suggest improvements.
        4. Suggest concrete, actionable improvements for the next pipeline iteration

        5. If issues indicate normalization problems, explicitly recommend normalization actions with target columns.
           Prefer these capabilities when appropriate:
           - PyDI country normalization: normalize_country(value, output_format="name")
           - list formatting normalization via helper functions: detect_list_like_columns / normalize_list_like_columns

        IMPORTANT: The blocking and matching strategies have been determined earlier and have been already evaluated. Therefore, 
        focus on improving the fusion of the pipeline.
    
        Respond with concise, structured reasoning.
        Include a short section named `Normalization Recommendations` when relevant.
        """
    
        # Prepare human content
        human_content = f"""
        Evaluation metrics:
        {json.dumps(state.get("evaluation_metrics", {}), indent=2)}
    
        Debug fusion events (JSONL):
        {json.dumps(debug_events[:50], indent=2)}
    
        Current integration pipeline code:
        {state.get("integration_pipeline_code", "Pipeline code not available")}

        Current pipeline evaluation code:
        {state.get("evaluation_code", "Pipeline evaluation code not available")}
    
        Optimal blocking configuration:
        {json.dumps(state.get("blocking_config", {}), indent=2)}
    
        Optimal matching configuration:
        {json.dumps(state.get("matching_config", {}), indent=2)}

        Cluster Analysis Report:
        {json.dumps(state.get("cluster_analysis_result", {}), indent=2)}

        Auto diagnostics:
        {json.dumps(state.get("auto_diagnostics", {}), indent=2)}

        Fusion size comparison:
        {json.dumps(state.get("fusion_size_comparison", {}), indent=2)}

        Integration diagnostics report:
        {json.dumps(state.get("integration_diagnostics_report", {}), indent=2)}
        """
    
        # Model call
        message = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content)
        ]
    
        result = self.model.invoke(message)
        analysis = result.content if hasattr(result, "content") else str(result)
    
        self.logger.info("Evaluation reasoning produced")
        print("[*] Evaluation reasoning:\n" + analysis)
    
        return {"evaluation_analysis": analysis}
        
    def save_results(self, state: SimpleModelAgentState):
        self._log_action("save_results", "start", "Persist run artifacts", "Enables reproducibility")

        """Save comprehensive results to timestamped JSON file"""
        self.logger.info('----------------------- Entering save_results -----------------------')


        def _extract_query_response_pairs(messages):
            """
            Extract (query, response) pairs from LangChain message objects.
            """
            pairs = []

            # Step 1: collect tool_call_id -> query mapping
            tool_call_map = {}

            for msg in messages:
                if isinstance(msg, AIMessage) and msg.tool_calls:
                    for tool_call in msg.tool_calls:

                        call_id = tool_call.get("id")

                        query = None

                        # Case 1: args stored directly
                        if "args" in tool_call:
                            query = tool_call["args"].get("query")

                        # Case 2: arguments stored as JSON string
                        elif "function" in tool_call:
                            args_str = tool_call["function"].get("arguments", "{}")
                            try:
                                args = json.loads(args_str)
                                query = args.get("query")
                            except json.JSONDecodeError:
                                query = None

                        if call_id and query:
                            tool_call_map[call_id] = query

                # Step 2: match ToolMessage responses
                for msg in messages:
                    if isinstance(msg, ToolMessage):
                        tool_call_id = msg.tool_call_id

                        if tool_call_id in tool_call_map:
                            query = tool_call_map[tool_call_id]
                            response = msg.content

                            pairs.append({
                                "query": query,
                                "response": response
                            })

                return pairs

        from datetime import datetime

        # Create timestamp and ensure run metadata exists
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        results_dir = os.path.join(OUTPUT_DIR, "results")
        os.makedirs(results_dir, exist_ok=True)
        if not getattr(self, "run_id", ""):
            self.run_id = datetime.now().strftime("%Y%m%d_%H%M%S_%f")
        if not getattr(self, "run_output_root", ""):
            self.run_output_root = os.path.join(OUTPUT_DIR, "runs", self.run_id)
        os.makedirs(self.run_output_root, exist_ok=True)

        # Collect dataset information
        dataset_names = [os.path.splitext(os.path.basename(path))[0] for path in state.get("datasets", [])]

        # Collect blocking metrics
        blocking_metrics = {}
        blocking_strategies = state.get("blocking_config", {}).get("blocking_strategies", {})
        for pair_key, config in blocking_strategies.items():
            if isinstance(config, dict):
                blocking_metrics[pair_key] = {
                    "pair_completeness": config.get("pair_completeness", 0),
                    "num_candidates": config.get("num_candidates", 0),
                    "stategy": config.get("strategy", "unknown"),
                    "columns": config.get("columns", [])

                }

        # Collect matching metrics
        matching_metrics = {}
        matching_strategies = state.get("matching_config", {}).get("matching_strategies", {})
        for pair_key, config in matching_strategies.items():
            if isinstance(config, dict):
                matching_metrics[pair_key] = {
                    "f1_score": config.get("f1", 0)
                }

        # Collect evaluation metrics
        evaluation_metrics = state.get("evaluation_metrics", {})
        sealed_test_metrics_final = state.get("final_test_evaluation_metrics", {})

        # Collect pipeline execution info
        pipeline_info = {
            "evaluation_attempts": state.get("evaluation_attempts", 0),
            "matcher_mode": state.get("matcher_mode", "unknown"),
        }

        # Collect data profiles summary
        data_profiles_summary = {}
        data_profiles = state.get("data_profiles", {})
        for path, profile in data_profiles.items():
            if isinstance(profile, dict):
                dataset_name = os.path.splitext(os.path.basename(path))[0]
                data_profiles_summary[dataset_name] = {
                    "num_rows": profile.get("num_rows", 0),
                    "num_columns": profile.get("num_columns", 0),
                    "columns": list(profile.get("dtypes", {}).keys())[:10]  # First 10 columns
                }

        # Compile comprehensive results
        results = {
            "timestamp": timestamp,
            "run_id": self.run_id,
            "run_output_root": self.run_output_root,

            # Basic run information
            "datasets": dataset_names,
            "matcher_mode": state.get("matcher_mode", "unknown"),
            "fusion_testset": state.get("fusion_testset", "").split("/")[-1],
            "validation_fusion_testset": state.get("validation_fusion_testset", "").split("/")[-1] if state.get("validation_fusion_testset") else "",
            "sealed_evaluation_active": self._sealed_eval_active(state),

            # Performance metrics
            "blocking_metrics": blocking_metrics,
            "matching_metrics": matching_metrics,
            "evaluation_metrics": evaluation_metrics,
            "overall_accuracy": evaluation_metrics.get("overall_accuracy", 0),

            # Configurations used
            "blocking_config": state.get("blocking_config", {}),
            "matching_config": state.get("matching_config", {}),
            "fusion_size_comparison": state.get("fusion_size_comparison", {}),
            "auto_diagnostics": state.get("auto_diagnostics", {}),
            "normalization_execution_result": state.get("normalization_execution_result", ""),
            "normalization_attempts": state.get("normalization_attempts", 0),
            "normalization_report": state.get("normalization_report", {}),
            "normalization_directives": state.get("normalization_directives", {}),
            "investigator_action_plan": state.get("investigator_action_plan", []),
            "normalized_datasets": state.get("normalized_datasets", []),
            "integration_diagnostics_execution_result": state.get("integration_diagnostics_execution_result", ""),
            "integration_diagnostics_report": state.get("integration_diagnostics_report", {}),
            "investigator_action_plan": state.get("investigator_action_plan", []),
            "human_review_execution_result": state.get("human_review_execution_result", ""),
            "human_review_report": state.get("human_review_report", {}),
            "final_test_evaluation_execution_result": state.get("final_test_evaluation_execution_result", ""),
            "final_test_evaluation_metrics": state.get("final_test_evaluation_metrics", {}),
            "sealed_test_metrics_final": sealed_test_metrics_final,

            # Token usage
            "token_usage": self.token_usage.copy(),

            # Pipeline execution details
            "pipeline_info": pipeline_info,

            # Search tool responses
            "pipeline_search_tool_responses": _extract_query_response_pairs(state.get("messages", [])[2:-1]),
            "evaluation_search_tool_responses": _extract_query_response_pairs((state.get("eval_messages") or [])[2:-1]),

            # Code and execution
            "integration_pipeline_code_length": len(state.get("integration_pipeline_code", "")),
            "evaluation_code_length": len(state.get("evaluation_code", "")),
            "integration_diagnostics_code_length": len(state.get("integration_diagnostics_code", "")),
            "human_review_code_length": len(state.get("human_review_code", "")),

        }

        # Save to timestamped files
        results_file = os.path.join(results_dir, f"run_{timestamp}.json")
        run_audit_file = os.path.join(results_dir, f"run_audit_{timestamp}.json")
        run_report_file = os.path.join(results_dir, f"run_report_{timestamp}.md")

        results["run_audit_path"] = run_audit_file
        results["run_report_path"] = run_report_file

        with open(results_file, "w", encoding="utf-8") as f:
            json.dump(results, f, indent=2, ensure_ascii=False, default=str)

        with open(run_audit_file, "w", encoding="utf-8") as f:
            json.dump(results, f, indent=2, ensure_ascii=False, default=str)

        report_lines = [
            f"# Run Report ({timestamp})",
            "",
            f"- Run ID: `{self.run_id}`",
            f"- Run output root: `{self.run_output_root}`",
            f"- Validation overall (final): `{evaluation_metrics.get('overall_accuracy', 'n/a')}`",
            f"- Validation macro (final): `{evaluation_metrics.get('macro_accuracy', 'n/a')}`",
            f"- Sealed test overall (final): `{sealed_test_metrics_final.get('overall_accuracy', 'n/a')}`",
            f"- Sealed test macro (final): `{sealed_test_metrics_final.get('macro_accuracy', 'n/a')}`",
        ]
        with open(run_report_file, "w", encoding="utf-8") as f:
            f.write("\n".join(report_lines) + "\n")

        print(f"[+] Results saved to: {results_file}")

        self.logger.info(f"Results saved to {results_file}")
        self.logger.info("Leaving save_results")

        return {
            "run_id": self.run_id,
            "run_output_root": self.run_output_root,
            "run_audit_path": run_audit_file,
            "run_report_path": run_report_file,
            "sealed_test_metrics_final": sealed_test_metrics_final,
        }
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Invoke Pipeline

# %%
if USE_LLM == "gemini":
    llm = ChatGoogleGenerativeAI(
        model="gemini-2.0-flash",
        temperature=0,
        max_tokens=None,
        timeout=None,
        max_retries=2,
    )
elif USE_LLM == "groq":
    llm = ChatGroq(
        model="llama-3.3-70b-versatile",
        temperature=0.2
    )
elif USE_LLM == "gpt":
    llm = ChatOpenAI(
        model="gpt-5.2",
        temperature=0,
        max_tokens=None,
    )
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Company datasets

if "agent" in globals():
    del agent

SKIP_BLOCKING_TESTER = False
SKIP_MATCHING_TESTER = False

llm = ChatOpenAI(
    model="gpt-5.2",
    temperature=0,
    max_tokens=None,
    timeout=600,
    max_retries=5,
)

profile_tool = ProfileDatasetTool()
search_tool = SearchDocumentationTool()

agent = SimpleModelAgent(
    llm,
    tools={profile_tool.name: profile_tool, search_tool.name: search_tool},
)

print(type(agent).__name__)
print(hasattr(agent, "run_id"))
print(hasattr(agent, "run_output_root"))
print("save_results" in agent.graph.nodes)
print("sealed_final_test_evaluation" in agent.graph.nodes)

entity_matching_testsets = {
    ("forbes", "dbpedia"): INPUT_DIR + "datasets/companies/testsets/forbes_dbpedia_art.csv",
    ("forbes", "fullcontact"): INPUT_DIR + "datasets/companies/testsets/forbes_fullcontact_art.csv",
    ("fullcontact", "dbpedia"): INPUT_DIR + "datasets/companies/testsets/fullcontact_dbpedia_art.csv",
}

payload = {
    "datasets": [
        INPUT_DIR + "datasets/companies/forbes.csv",
        INPUT_DIR + "datasets/companies/dbpedia.xml",
        INPUT_DIR + "datasets/companies/fullcontact.xml",
    ],
    "original_datasets": [
        INPUT_DIR + "datasets/companies/forbes.csv",
        INPUT_DIR + "datasets/companies/dbpedia.xml",
        INPUT_DIR + "datasets/companies/fullcontact.xml",
    ],
    "normalized_datasets": [],
    "entity_matching_testsets": entity_matching_testsets,
    "fusion_testset": INPUT_DIR + "datasets/companies/testsets/test_set.xml",
    "validation_fusion_testset": INPUT_DIR + "datasets/companies/testsets/validation_set.xml",
    "matcher_mode": "rulebased",
    "evaluation_attempts": 0,
    "normalization_attempts": 0,
    "normalization_execution_result": "",
    "normalization_rework_required": False,
    "normalization_rework_reasons": [],
    "normalization_directives": {},
    "investigator_decision": "",
}

print("[*] Starting companies run...")
RESULT = agent.graph.invoke(payload, config={"recursion_limit": 200})
print("[*] Companies run complete")

summary = {
    "validation_overall_accuracy": (RESULT.get("evaluation_metrics") or {}).get("overall_accuracy"),
    "sealed_test_overall_accuracy": (RESULT.get("sealed_test_metrics_final") or {}).get("overall_accuracy"),
    "normalization_attempts": RESULT.get("normalization_attempts"),
    "evaluation_attempts": RESULT.get("evaluation_attempts"),
    "run_id": RESULT.get("run_id"),
    "run_output_root": RESULT.get("run_output_root"),
    "run_audit_path": RESULT.get("run_audit_path"),
    "run_report_path": RESULT.get("run_report_path"),
}

print(json.dumps(summary, indent=2, default=str))
# Out:
# [*] Starting companies run...
# [*] Running schema matching
# [*] Schema alignment columns:
#     forbes: ['name', 'Sector', 'industry', 'Continent', 'country', 'Market Value', 'Sales', 'Profits', 'assets', 'Rank', 'id']
#     dbpedia: ['id', 'name', 'founded', 'country', 'city', 'industry', 'keypeople_name', 'assets', 'Sales']
#     fullcontact: ['id', 'name', 'country', 'city', 'keypeople_name', 'founded']
# [*] Profiling datasets
# TOKEN USAGE (profile_data):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 285
#    Completion tokens: 80
#    Total tokens: 365
#    Estimated cost: $0.001156
# [*] Running normalization node
# [+] Normalization completed; using normalized datasets
# [*] Running BlockingTester
# [*] Loading dataset: forbes
# [*] Loading dataset: dbpedia
# [*] Loading dataset: fullcontact
# [*] Loading gold standard for forbes <-> dbpedia
#     Loaded 460 ground truth pairs (positives: 110, negatives/other: 350)
# [*] Loading gold standard for forbes <-> fullcontact
#     Loaded 500 ground truth pairs (positives: 150, negatives/other: 350)
# [*] Loading gold standard for fullcontact <-> dbpedia
#     Loaded 500 ground truth pairs (positives: 150, negatives/other: 350)
# [*] Adaptive max_candidates set to 69,375 (r=0.35%, median_pairs=19,476,066)
#
# ============================================================
# 🤖 BLOCKING: forbes <-> dbpedia
# ============================================================
# Gold pairs: 460, PC threshold: 0.9
# Candidate limit: 69,375 (hard: 79,781 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 2,000 × 10,086 = 20,172,000 potential pairs
# Common columns: ['industry', 'assets', 'name', 'country', 'Sales']
# Guardrails: strategies=['exact_match_multi', 'exact_match_single', 'token_blocking', 'semantic_similarity'], preferred_columns=['industry', 'country']
#
# --- Attempt 1/5 ---
# LLM chose: token_blocking on ['name']
#   Params: {'min_token_len': 5}
#   Reasoning: Need strong reduction from 20.2M pairs to <=69,375. Exact-match on name would miss many due to casin...
#     Token (name, len>=5): 93,724 candidates
#     ⛔ SKIPPING EVALUATION: 93,724 > 79,781 (hard limit)
#     💡 Try increasing min_token_len or ngram_size, or use a more selective column
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['name', 'country', 'industry']
#   Params: {'top_k': 15}
#   Reasoning: Exact/token blocking on name failed (PC=0) and exceeded candidate cap; names likely differ in form b...
#     Embedding (name+country+industry, k=15): 30,000 candidates
#     ✅ PC=1.0000, RR=0.9985
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: forbes <-> fullcontact
# ============================================================
# Gold pairs: 500, PC threshold: 0.9
# Candidate limit: 69,375 (hard: 79,781 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 2,000 × 1,931 = 3,862,000 potential pairs
# Common columns: ['name', 'country']
# Guardrails: strategies=['exact_match_multi', 'exact_match_single', 'token_blocking', 'sorted_neighbourhood', 'ngram_blocking', 'semantic_similarity'], preferred_columns=['country', 'name']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['country', 'name']
#   Params: {}
#   Reasoning: To keep candidates well under the 69,375 cap, use the most restrictive fast blocker: exact match on ...
#     Standard (country+name): 213 candidates
#     ⚠️ PC=0.6800, RR=0.9999
#
# --- Attempt 2/5 ---
# LLM chose: token_blocking on ['name']
#   Params: {'min_token_len': 5}
#   Reasoning: Exact match on (country,name) was too restrictive (PC=0.68). Company names vary by suffixes/abbrevia...
#     Token (name, len>=5): 21,475 candidates
#     ✅ PC=0.9267, RR=0.9944
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: fullcontact <-> dbpedia
# ============================================================
# Gold pairs: 500, PC threshold: 0.9
# Candidate limit: 69,375 (hard: 79,781 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 1,931 × 10,086 = 19,476,066 potential pairs
# Common columns: ['city', 'name', 'country', 'keypeople_name', 'founded']
# Guardrails: strategies=['exact_match_multi', 'exact_match_single', 'token_blocking', 'semantic_similarity'], preferred_columns=['founded', 'city', 'country']
#
# --- Attempt 1/5 ---
# LLM chose: semantic_similarity on ['name', 'city', 'country']
#   Params: {'top_k': 15}
#   Reasoning: Exact-match blocking on preferred columns (founded/city/country) would miss many true matches due to...
#     Embedding (name+city+country, k=15): 28,667 candidates
#     ✅ PC=0.9867, RR=0.9985
# ✅ Found acceptable strategy!
#
# ============================================================
# 📊 RESULTS SUMMARY: 3 pairs evaluated
# ============================================================
#   ✅ forbes_dbpedia: PC=1.0000, candidates=30,000, strategy=semantic_similarity
#   ✅ forbes_fullcontact: PC=0.9267, candidates=21,475, strategy=token_blocking
#   ✅ fullcontact_dbpedia: PC=0.9867, candidates=28,667, strategy=semantic_similarity
# [*] Blocking fused-size estimate: rows=11853, unique_ids=11853
# [*] Blocking estimate breakdown: matched_only_rows=2164, singleton_aware_rows=11853
# [*] Fused-size report updated: /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/pipeline_evaluation/fusion_size_estimate.json
#
# 💾 Config saved to: output/blocking-evaluation/blocking_config.json
# [*] Blocking config computed:
# {
#   "blocking_strategies": {
#     "forbes_dbpedia": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "country",
#         "industry"
#       ],
#       "params": {
#         "top_k": 15
#       },
#       "pair_completeness": 1.0,
#       "num_candidates": 30000,
#       "is_acceptable": true,
#       "failure_tags": [
#         "ok"
#       ]
#     },
#     "forbes_fullcontact": {
#       "strategy": "token_blocking",
#       "columns": [
#         "name"
#       ],
#       "params": {
#         "min_token_len": 5
#       },
#       "pair_completeness": 0.9266666666666666,
#       "num_candidates": 21475,
#       "is_acceptable": true,
#       "failure_tags": [
#         "ok"
#       ]
#     },
#     "fullcontact_dbpedia": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "city",
#         "country"
#       ],
#       "params": {
#         "top_k": 15
#       },
#       "pair_completeness": 0.9866666666666667,
#       "num_candidates": 28667,
#       "is_acceptable": true,
#       "failure_tags": [
#         "ok"
#       ]
#     }
#   },
#   "id_columns": {
#     "forbes": "id",
#     "dbpedia": "id",
#     "fullcontact": "id"
#   },
#   "dataset_signature": "dbpedia|forbes|fullcontact",
#   "dataset_names": [
#     "dbpedia",
#     "forbes",
#     "fullcontact"
#   ],
#   "pc_threshold": 0.9,
#   "max_candidates": 69375,
#   "candidate_tolerance": 0.15,
#   "llm_trace_path": "output/blocking-evaluation/llm_blocking_trace.jsonl",
#   "fusion_size_estimate": {
#     "stage": "blocking",
#     "dataset_signature": "dbpedia|forbes|fullcontact",
#     "datasets": [
#       "dbpedia",
#       "forbes",
#       "fullcontact"
#     ],
#     "method": "3-way inclusion-exclusion over pair estimates: E=E12+E13+E23-2*E123, with E123 estimated from per-dataset overlap probabilities; singleton-aware projection applied for final fused output (include_singletons=True assumption)",
#     "expected_rows": 11853,
#     "expected_unique_ids": 11853,
#     "expected_rows_range": [
#       8323,
#       11901
#     ],
#     "expected_unique_ids_range": [
#       8323,
#       11901
#     ],
#     "three_way_intersection": {
#       "enabled": true,
#       "datasets": [
#         "forbes",
#         "dbpedia",
#         "fullcontact"
#       ],
#       "pair_cluster_estimates": {
#         "forbes_dbpedia": 2000,
#         "forbes_fullcontact": 1789,
#         "dbpedia_fullcontact": 1905
#       },
#       "triple_intersection_estimates": {
#         "via_forbes": 1789.0,
#         "via_dbpedia": 377.75133848899463,
#         "via_fullcontact": 1764.91196271362,
#         "median_used": 1764.91196271362,
#         "final_triple_intersection": 1765,
#         "triple_intersection_range": [
#           0,
#           1789
#         ]
#       },
#       "expected_union_clusters": 2164,
#       "expected_union_range": [
#         2116,
#         5694
#       ],
#       "formula": "E_union = E12 + E13 + E23 - 2*E123"
#     },
#     "pair_estimates": [
#       {
#         "pair_key": "forbes_dbpedia",
#         "left_dataset": "forbes",
#         "right_dataset": "dbpedia",
#         "min_pair_size": 2000,
#         "pair_completeness": 1.0,
#         "expected_cluster_count": 2000
#       },
#       {
#         "pair_key": "forbes_fullcontact",
#         "left_dataset": "forbes",
#         "right_dataset": "fullcontact",
#         "min_pair_size": 1931,
#         "pair_completeness": 0.9266666666666666,
#         "expected_cluster_count": 1789
#       },
#       {
#         "pair_key": "fullcontact_dbpedia",
#         "left_dataset": "dbpedia",
#         "right_dataset": "fullcontact",
#         "min_pair_size": 1931,
#         "pair_completeness": 0.9866666666666667,
#         "expected_cluster_count": 1905
#       }
#     ],
#     "created_at": "2026-03-04T10:01:53.432306+00:00",
#     "expected_rows_matched_only": 2164,
#     "expected_unique_ids_matched_only": 2164,
#     "expected_rows_matched_only_range": [
#       2116,
#       5694
#     ],
#     "expected_unique_ids_matched_only_range": [
#       2116,
#       5694
#     ],
#     "expected_rows_singleton_aware": 11853,
#     "expected_unique_ids_singleton_aware": 11853,
#     "expected_rows_singleton_aware_range": [
#       8323,
#       11901
#     ],
#     "expected_unique_ids_singleton_aware_range": [
#       8323,
#       11901
#     ],
#     "singleton_assumption": {
#       "assumed_include_singletons": true,
#       "total_input_rows": 14017,
#       "formula": "E_final_rows = total_input_rows - E_matched_clusters",
#       "notes": "Conservative singleton-aware estimate: each expected matched cluster reduces the final row count by at least one."
#     }
#   }
# }
# [*] Using MatchingTester module: /Users/nickblazek/Desktop/Agent_Pipeline/agents/matching_tester.py
# [*] Running MatchingTester
# [*] Loading dataset: forbes
# [*] Loading dataset: dbpedia
# [*] Loading dataset: fullcontact
# [*] Normalized list-like columns for matching: keypeople_name
# [*] Loading matching gold standard for forbes <-> dbpedia
#     Loaded 460 ground truth pairs
# [*] Loading matching gold standard for forbes <-> fullcontact
#     Loaded 500 ground truth pairs
# [*] Loading matching gold standard for fullcontact <-> dbpedia
#     Loaded 500 ground truth pairs
#
# ==================================================
# MATCHING EVALUATION
# ==================================================
#
# ==================================================
# MATCHING: forbes <-> dbpedia
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'country', 'industry']
# Guardrails preferred columns: ['industry', 'country']
# Candidates: full=30,000, proxy_sample=30,000 (margin=0.015)
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'country:jaro_winkler', 'industry:cosine']
# Weights: [0.6, 0.25, 0.15]
# Threshold: 0.82
#     Reasoning: Use blocking columns as comparators: name is the strongest identifier and fully populated on both sides; country is low-null and helps disambiguate; industry is preferred but noisier/high-cardinality and partially null on dbpedia, so given lower weight and cosine for multi-token/category text. Exclude Sales/assets due to very high null rates on dbpedia.
#     Reasoning (100c): Use blocking columns as comparators: name is the strongest identifier and fully populated on both si
# SUCCESS: F1=0.8734
#
# ==================================================
# MATCHING: forbes <-> fullcontact
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name']
# Guardrails preferred columns: ['country', 'name']
# Candidates: full=21,475, proxy_sample=21,475 (margin=0.015)
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'country:jaro_winkler']
# Weights: [0.85, 0.15]
# Threshold: 0.88
#     Reasoning: Use blocking/primary identifier 'name' as the dominant signal with typo-tolerant Jaro-Winkler; include 'country' as a secondary consistency check despite higher nulls on the right.
#     Reasoning (100c): Use blocking/primary identifier 'name' as the dominant signal with typo-tolerant Jaro-Winkler; inclu
# F1=0.5361 < 0.75
#
# --- Attempt 2/4 ---
# Comparators: ['name:jaro_winkler', 'country:levenshtein']
# Weights: [0.85, 0.15]
# Threshold: 0.6
#     Reasoning: Prior config underperformed likely due to name variations/abbreviations; prioritize name heavily and use typo-tolerant jaro_winkler with normalization. Keep country as a weak secondary check (higher nulls on right) using levenshtein for minor spelling differences. Lower threshold to improve recall given limited shared fields.
#     Reasoning (100c): Prior config underperformed likely due to name variations/abbreviations; prioritize name heavily and
#     Proxy stage: F1=0.4413, required>=0.5511 -> skip full
#
# --- Attempt 3/4 ---
# Comparators: ['name:jaro_winkler', 'country:jaro_winkler']
# Weights: [0.85, 0.15]
# Threshold: 0.6
#     Reasoning: Only 'name' and 'country' are shared; prior cosine-based matching underperformed. Use Jaro-Winkler on normalized names to better handle short strings/typos/abbreviations, keep country as a weak corroborator due to higher nulls on the right, and lower the threshold to recover recall while relying mainly on the blocking/matching strength of 'name'.
#     Reasoning (100c): Only 'name' and 'country' are shared; prior cosine-based matching underperformed. Use Jaro-Winkler o
#     Proxy stage: F1=0.4413, required>=0.5511 -> skip full
# ⏹️ Early stop: repeated no-gain proxy outcomes
# Max attempts reached. Best F1=0.5361
#
# ==================================================
# MATCHING: fullcontact <-> dbpedia
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'city', 'country']
# Guardrails preferred columns: ['founded', 'city', 'country']
# Candidates: full=28,667, proxy_sample=28,667 (margin=0.015)
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'country:jaro_winkler', 'city:jaro_winkler', 'founded:3650']
# Weights: [0.55, 0.2, 0.15, 0.1]
# Threshold: 0.78
#     Reasoning: Use blocking columns (name/city/country) with typo-tolerant string matching; name is strongest identifier and non-null. Country and city add disambiguation despite moderate nulls on the left. Founded appears as ISO-like dates but is high-null on the left, so include as a soft date constraint with a generous window (10 years) and low weight.
#     Reasoning (100c): Use blocking columns (name/city/country) with typo-tolerant string matching; name is strongest ident
# F1=0.7178 < 0.75
#
# --- Attempt 2/4 ---
# Comparators: ['name:jaro_winkler', 'city:jaro_winkler', 'country:jaro_winkler', 'founded:730']
# Weights: [0.58, 0.14, 0.08, 0.2]
# Threshold: 0.75
#     Reasoning: Boost name importance with typo-tolerant Jaro-Winkler; keep city/country as lighter disambiguators due to higher nulls/low cardinality; treat founded as a date with a 2-year tolerance to handle default Jan-01 and minor discrepancies. Maintain 0.75 threshold to improve precision over prior 0.72.
#     Reasoning (100c): Boost name importance with typo-tolerant Jaro-Winkler; keep city/country as lighter disambiguators d
#     Proxy stage: F1=0.8280, required>=0.7328 -> run full
# SUCCESS: F1=0.8280
#
# 📊 Results: 3 pairs evaluated
#   OK forbes_dbpedia: F1=0.8734
#   WARN forbes_fullcontact: F1=0.5361
#   OK fullcontact_dbpedia: F1=0.8280, proxy=0.8280
# [*] Matching fused-size estimate: rows=11301, unique_ids=11301
# [*] Matching estimate breakdown: matched_only_rows=2716, singleton_aware_rows=11301
# [*] Fused-size report updated: /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/pipeline_evaluation/fusion_size_estimate.json
# Config saved to matching_config.json
# [*] Run report updated: output/results/run_audit_20260303_155056_report.md
# [*] Matching config computed:
# {
#   "id_columns": {
#     "forbes": "id",
#     "dbpedia": "id",
#     "fullcontact": "id"
#   },
#   "matching_strategies": {
#     "forbes_dbpedia": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "country",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "industry",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip"
#         }
#       ],
#       "weights": [
#         0.6,
#         0.25,
#         0.15
#       ],
#       "threshold": 0.82,
#       "f1": 0.8733624454148471,
#       "skipped_due_to_blocking_gate": false,
#       "proxy_f1": null,
#       "failure_tags": [
#         "ok"
#       ]
#     },
#     "forbes_fullcontact": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "country",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         }
#       ],
#       "weights": [
#         0.85,
#         0.15
#       ],
#       "threshold": 0.88,
#       "f1": 0.5360824742268041,
#       "skipped_due_to_blocking_gate": false,
#       "proxy_f1": null,
#       "failure_tags": [
#         "low_matching_quality"
#       ]
#     },
#     "fullcontact_dbpedia": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "city",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "country",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "date",
#           "column": "founded",
#           "max_days_difference": 730
#         }
#       ],
#       "weights": [
#         0.58,
#         0.14,
#         0.08,
#         0.2
#       ],
#       "threshold": 0.75,
#       "f1": 0.8280254777070064,
#       "skipped_due_to_blocking_gate": false,
#       "proxy_f1": 0.8280254777070064,
#       "failure_tags": [
#         "ok"
#       ]
#     }
#   },
#   "dataset_signature": "dbpedia|forbes|fullcontact",
#   "dataset_names": [
#     "dbpedia",
#     "forbes",
#     "fullcontact"
#   ],
#   "min_blocking_pc_for_matching": 0.9,
#   "proxy_f1_margin": 0.015,
#   "proxy_max_candidates": 60000,
#   "llm_trace_path": "output/matching-evaluation/llm_matching_trace.jsonl",
#   "fusion_size_estimate": {
#     "stage": "matching",
#     "dataset_signature": "dbpedia|forbes|fullcontact",
#     "datasets": [
#       "dbpedia",
#       "forbes",
#       "fullcontact"
#     ],
#     "method": "3-way inclusion-exclusion over pair estimates: E=E12+E13+E23-2*E123, with E123 estimated from per-dataset overlap probabilities; singleton-aware projection applied for final fused output (include_singletons=True assumption)",
#     "expected_rows": 11301,
#     "expected_unique_ids": 11301,
#     "expected_rows_range": [
#       9733,
#       11651
#     ],
#     "expected_unique_ids_range": [
#       9733,
#       11651
#     ],
#     "three_way_intersection": {
#       "enabled": true,
#       "datasets": [
#         "forbes",
#         "dbpedia",
#         "fullcontact"
#       ],
#       "pair_cluster_estimates": {
#         "forbes_dbpedia": 1747,
#         "forbes_fullcontact": 959,
#         "dbpedia_fullcontact": 1578
#       },
#       "triple_intersection_estimates": {
#         "via_forbes": 837.6865,
#         "via_dbpedia": 273.325996430696,
#         "via_fullcontact": 783.6882444329364,
#         "median_used": 783.6882444329364,
#         "final_triple_intersection": 784,
#         "triple_intersection_range": [
#           0,
#           959
#         ]
#       },
#       "expected_union_clusters": 2716,
#       "expected_union_range": [
#         2366,
#         4284
#       ],
#       "formula": "E_union = E12 + E13 + E23 - 2*E123"
#     },
#     "pair_estimates": [
#       {
#         "pair_key": "forbes_dbpedia",
#         "left_dataset": "forbes",
#         "right_dataset": "dbpedia",
#         "min_pair_size": 2000,
#         "pair_completeness": 1.0,
#         "f1": 0.8733624454148471,
#         "expected_cluster_count": 1747
#       },
#       {
#         "pair_key": "forbes_fullcontact",
#         "left_dataset": "forbes",
#         "right_dataset": "fullcontact",
#         "min_pair_size": 1931,
#         "pair_completeness": 0.9266666666666666,
#         "f1": 0.5360824742268041,
#         "expected_cluster_count": 959
#       },
#       {
#         "pair_key": "fullcontact_dbpedia",
#         "left_dataset": "dbpedia",
#         "right_dataset": "fullcontact",
#         "min_pair_size": 1931,
#         "pair_completeness": 0.9866666666666667,
#         "f1": 0.8280254777070064,
#         "expected_cluster_count": 1578
#       }
#     ],
#     "created_at": "2026-03-04T10:02:55.190044+00:00",
#     "expected_rows_matched_only": 2716,
#     "expected_unique_ids_matched_only": 2716,
#     "expected_rows_matched_only_range": [
#       2366,
#       4284
#     ],
#     "expected_unique_ids_matched_only_range": [
#       2366,
#       4284
#     ],
#     "expected_rows_singleton_aware": 11301,
#     "expected_unique_ids_singleton_aware": 11301,
#     "expected_rows_singleton_aware_range": [
#       9733,
#       11651
#     ],
#     "expected_unique_ids_singleton_aware_range": [
#       9733,
#       11651
#     ],
#     "singleton_assumption": {
#       "assumed_include_singletons": true,
#       "total_input_rows": 14017,
#       "formula": "E_final_rows = total_input_rows - E_matched_clusters",
#       "notes": "Conservative singleton-aware estimate: each expected matched cluster reduces the final row count by at least one."
#     }
#   },
#   "run_report_path": "output/results/run_audit_20260303_155056_report.md"
# }
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 14,566
#    Completion tokens: 1,999
#    Total tokens: 16,565
#    Estimated cost: $0.038198
# [*] Running generated pipeline
# Error: error:   File "/Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/pipeline.py", line 152
#     list_strategy=\"concatenate\",
#                    ^
# SyntaxError: unexpected character after line continuation character
#
# [*] Trying to fix pipeline
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 11,986
#    Completion tokens: 2,004
#    Total tokens: 13,990
#    Estimated cost: $0.035022
# [*] Running generated pipeline
# Error: error:   File "/Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/pipeline.py", line 152
#     list_strategy=\"concatenate\",
#                    ^
# SyntaxError: unexpected character after line continuation character
#
# [*] Trying to fix pipeline
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 11,991
#    Completion tokens: 2,060
#    Total tokens: 14,051
#    Estimated cost: $0.035589
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Normalized list-like columns: keypeople_name
# Performing Blocking
# Matching Entities
# Fusing Data
#
# [FUSION SIZE COMPARISON]
#   blocking: expected_rows=11853 actual_rows=989 rows_pct_error=0.9165612081329622
#   matching: expected_rows=11301 actual_rows=989 rows_pct_error=0.9124856207415273
# [*] Running consolidated evaluation node
# [EVALUATION EXECUTION] Attempt 1/3
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 7,756
#    Completion tokens: 43
#    Total tokens: 7,799
#    Estimated cost: $0.010125
# [SEARCH TOOL CALL 1]: Asking 'DataFusionEvaluator evaluate() usage example and available evaluation match functions tokenized_match year_only_match set_equality_match numeric_tolerance_match'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 9,277
#    Completion tokens: 2,835
#    Total tokens: 12,112
#    Estimated cost: $0.039946
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [LIST NORMALIZATION] columns=['keypeople_name']
# [COUNTRY NORMALIZATION] output_format=name, columns=['country']
# [ID ALIGNMENT] direct _id coverage: 0/25
# [ID ALIGNMENT] mapped eval_id coverage: 12/25
# [EVAL FUNCTIONS] assets:numeric_tolerance_match(tolerance=1e-06) | city:tokenized_match(threshold=0.8) | country:tokenized_match(threshold=0.8) | founded:year_only_match | keypeople_name:set_equality_match | name:tokenized_match(threshold=0.85)
# [EVALUATION RESULTS]
# {
#   "overall_accuracy": 0.2878787878787879,
#   "macro_accuracy": 0.32190476190476186,
#   "num_evaluated_records": 25,
#   "num_evaluated_attributes": 6,
#   "total_evaluations": 132,
#   "total_correct": 38,
#   "assets_accuracy": 0.0,
#   "assets_count": 25,
#   "country_accuracy": 0.44,
#   "country_count": 25,
#   "keypeople_name_accuracy": 0.5714285714285714,
#   "keypeople_name_count": 7,
#   "name_accuracy": 0.32,
#   "name_count": 25,
#   "founded_accuracy": 0.36,
#   "founded_count": 25,
#   "city_accuracy": 0.24,
#   "city_count": 25
# }
#
# [EVALUATION STDERR]
# Missing 13 expected/reference records in fused dataset: http://www.forbes.com/companies/deutsche-telekom/, http://www.forbes.com/companies/prudential/, http://www.forbes.com/companies/byd/, http://www.forbes.com/companies/dongbu-insurance/, http://www.forbes.com/companies/yamaha-motor/, ...
#
# [EVALUATION EXECUTION] Status: success
# [*] Running consolidated investigator node
# [*] Running free integration diagnostics
# TOKEN USAGE (integration_diagnostics_generation):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 3,542
#    Completion tokens: 13,813
#    Total tokens: 17,355
#    Estimated cost: $0.142558
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.2878787878787879, "macro_accuracy": 0.32190476190476186, "num_evaluated_records": 25, "num_evaluated_attributes": 6, "total_evaluations": 132, "total_correct": 38, "assets_accuracy": 0.0, "assets_count": 25, "country_accuracy": 0.44, "country_count": 25, "keypeople_name_accuracy": 0.5714285714285714, "keypeople_name_count": 7, "name_accuracy": 0.32, "name_count": 25, "founded_accuracy": 0.36, "founded_count": 25, "city_accuracy": 0.24, "city_count": 25}
# [EVALUATION REPORT]
#   Stage: validation
#   Attempt: 1/3
#   Overall Accuracy: 28.788%
#   Problems Detected:
#     - overall_accuracy below target: 28.788% < 85.000%
#     - low attribute accuracy: assets=0.000%, city=24.000%, country=44.000%, founded=36.000%, macro=32.190%, name=32.000%
#     - low mapped ID coverage: 48.000%
#     - low direct ID coverage: 0.000%
#     - high missing_fused_value mismatch ratio: 71.277%
#   Planned Adaptation:
#     - investigator runs diagnostics report + cluster evidence analysis
#     - reasoning node proposes targeted pipeline/code changes
#     - prioritize ID alignment and singleton handling
#     - prioritize fusion strategy changes for sparse attributes
# [*] Auto diagnostics:
# {
#   "debug_reason_counts": {
#     "mismatch": 27,
#     "missing_fused_value": 67
#   },
#   "debug_reason_ratios": {
#     "mismatch": 0.2872340425531915,
#     "missing_fused_value": 0.7127659574468085
#   },
#   "evaluation_stage": "validation",
#   "evaluation_testset_path": "input/datasets/companies/testsets/validation_set.xml",
#   "id_alignment": {
#     "gold_count": 25,
#     "direct_coverage": 0,
#     "direct_coverage_ratio": 0.0,
#     "mapped_coverage": 12,
#     "mapped_coverage_ratio": 0.48,
#     "missing_gold_ids": [
#       "http://www.forbes.com/companies/banca-popolare-di-milano/",
#       "http://www.forbes.com/companies/byd/",
#       "http://www.forbes.com/companies/china-communications-services/",
#       "http://www.forbes.com/companies/crown-resorts/",
#       "http://www.forbes.com/companies/deutsche-telekom/",
#       "http://www.forbes.com/companies/dongbu-insurance/",
#       "http://www.forbes.com/companies/herbalife/",
#       "http://www.forbes.com/companies/level-3-communications/",
#       "http://www.forbes.com/companies/nabors-industries/",
#       "http://www.forbes.com/companies/prudential/",
#       "http://www.forbes.com/companies/shoprite-holdings/",
#       "http://www.forbes.com/companies/tdc/",
#       "http://www.forbes.com/companies/yamaha-motor/"
#     ]
#   },
#   "fusion_size_comparison": {
#     "estimate_path": "output/pipeline_evaluation/fusion_size_estimate.json",
#     "actual": {
#       "rows": 989,
#       "unique_ids": 989
#     },
#     "comparisons": {
#       "blocking": {
#         "expected_rows": 11853,
#         "actual_rows": 989,
#         "rows_abs_error": 10864,
#         "rows_pct_error": 0.9165612081329622,
#         "expected_rows_matched_only": 2164,
#         "expected_rows_singleton_aware": 11853,
#         "rows_pct_error_matched_only": 0.5429759704251387,
#         "rows_pct_error_singleton_aware": 0.9165612081329622,
#         "better_variant": "matched_only",
#         "expected_unique_ids": 11853,
#         "actual_unique_ids": 989,
#         "unique_ids_abs_error": 10864,
#         "unique_ids_pct_error": 0.9165612081329622,
#         "reasoning": "Estimate deviates strongly; blocking/matching assumptions are likely not representative of fusion behavior. Blocking likely generated broader candidate space than what matching+fusion accepted.",
#         "compared_at": "2026-03-04T10:04:36.885521+00:00"
#       },
#       "matching": {
#         "expected_rows": 11301,
#         "actual_rows": 989,
#         "rows_abs_error": 10312,
#         "rows_pct_error": 0.9124856207415273,
#         "expected_rows_matched_only": 2716,
#         "expected_rows_singleton_aware": 11301,
#         "rows_pct_error_matched_only": 0.635861561119293,
#         "rows_pct_error_singleton_aware": 0.9124856207415273,
#         "better_variant": "matched_only",
#         "expected_unique_ids": 11301,
#         "actual_unique_ids": 989,
#         "unique_ids_abs_error": 10312,
#         "unique_ids_pct_error": 0.9124856207415273,
#         "reasoning": "Estimate deviates strongly; blocking/matching assumptions are likely not representative of fusion behavior. Matching estimate seems optimistic; thresholds or fusion constraints likely reduced surviving clusters.",
#         "compared_at": "2026-03-04T10:04:36.885622+00:00"
#       }
#     }
#   },
#   "overall_accuracy": 0.2878787878787879
# }
# [*] Running cluster analysis helper...
# [-] No relevant correspondence files found for current run, skipping cluster analysis.
# TOKEN USAGE (evaluation_reasoning):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 16,524
#    Completion tokens: 1,977
#    Total tokens: 18,501
#    Estimated cost: $0.040425
# [*] Evaluation reasoning:
# ## 1) Dominant error types
#
# ### A. **Missing fused values (dominant)**
# - Auto diagnostics: **67/94 (71.3%)** of debug events are `missing_fused_value`.
# - ID alignment: only **12/25 gold IDs mapped (48%)** into the fused output view; **13/25 missing**.
#   Those missing gold entities then show up as missing for *all* attributes (assets/country/name/etc.).
#
# **Interpretation:** the primary problem is not “wrong value chosen” but **the record/cluster for that gold entity is absent from the fused output** (or cannot be mapped to it due to broken provenance metadata).
#
# ### B. **Value mismatches (secondary)**
# - **27/94 (28.7%)** are `mismatch`.
# - The most extreme systematic mismatches are on **assets**:
#   - Fused assets like `37.6`, `8.8`, `21.75`, `70.7` vs gold `"39900000000"`, `"8800000000"`, `"31200000000"`, `"70700000000"`, etc.
#   - This is a **unit/scale problem** (billions vs absolute) and/or wrong source chosen.
#
# ### C. **Fusion policy errors**
# - **Strings fused with `longest_string`** cause wrong canonical names:
#   - e.g., `Schlumberger` expected, fused `schlumberger limited` (longer string wins).
#   - `Westfield Group` expected, fused `westfield retail trust`.
# - **Dates fused with `most_recent`** is risky for `founded` (should usually be *earliest* / most plausible year, not latest).
#
# ### D. **List fusion partially missing**
# - `keypeople_name` mismatch shows incomplete union (expected 2 names, fused 1). This can happen if:
#   - the other source record didn’t make it into the cluster (upstream linkage/coverage issue), or
#   - list parsing/encoding is broken so `union` doesn’t see both lists as lists.
#
# ---
#
# ## 2) Likely root causes (blocking/matching vs fusion vs preprocessing vs code)
#
# ### Blocking / matching?
# - You stated blocking+matching configs are “optimal” and already evaluated; blocking PC is high (0.93–1.0) and matching F1 is decent for 2/3 pairs.
# - The failure pattern here is **not classic false positives/false negatives evidence** from matcher debug; it’s mostly **fusion output coverage + fusion value selection + representation**.
#
# So: **errors are more likely caused by fusion/provenance/preprocessing and pipeline logic**, not the blocking/matching strategies themselves.
#
# ### Fusion/provenance & pipeline logic issues (major)
# 1. **`include_singletons=False`**
#    - This alone can explain the very small fused output:
#      - Actual fused rows: **989**
#      - Expected “matched_only” clusters: **~2716**
#    - Excluding singletons should not drop matched clusters, but it *will* drop every entity that fails to match—which directly creates `missing_fused_value` for many gold IDs.
#    - Given gold IDs are Forbes URLs, any Forbes entity that doesn’t successfully match into a cluster is **dropped**.
#
# 2. **Broken provenance columns `_fusion_sources` / `_fusion_source_datasets`**
#    - Integration diagnostics: both are **“json_malformed” in 800/800 samples**.
#    - Your evaluation relies on `_fusion_sources` to map fused clusters back to gold IDs (`build_eval_view()`).
#    - If `_fusion_sources` is malformed, **mapping fails**, producing `fused_id = NaN` and lots of “missing” even when the entity might exist in fused output.
#
# 3. **Assets scale/units not normalized + wrong numeric fuser**
#    - Using `median` for `assets` is fine only if values are commensurate.
#    - Here they are not (billions vs absolute), so median produces nonsense relative to gold.
#
# 4. **Bad string fuser choice for canonical fields**
#    - `longest_string(name/city/country)` is not a reliable canonicalization rule and directly produces wrong names/countries when longer aliases exist.
#
# ### Schema / preprocessing issues (major)
# - Diagnostics show **list-format inconsistencies** in: `city`, `country`, `name` (mixed scalar vs delimited lists) and **malformed JSON** for `keypeople_name` and provenance columns.
# - That breaks both:
#   - fusion functions like `union`, and
#   - evaluation ID mapping via `_fusion_sources`.
#
# ---
#
# ## 3) Cluster Analysis report implications
# - Cluster report is essentially empty: `stale_or_missing_correspondence_files`.
# - This strongly suggests the cluster analysis tooling couldn’t find/consume the correspondences artifacts at expected locations (your pipeline writes blockers to `output/blocking-evaluation` but doesn’t show writing correspondences to `output/correspondences`).
# - Net: you’re missing a key diagnostic feedback loop; but the provided integration diagnostics already points to the big issues: provenance/list encoding + ID alignment.
#
# ---
#
# ## 4) Concrete, actionable improvements for next iteration (focus: fusion)
#
# ### Priority 1 — Fix coverage & evaluation mapping
# 1. **Set `include_singletons=True`**
#    - This will ensure every Forbes gold entity appears in fused output even if it doesn’t match.
#    - Expected immediate impact: big reduction in `missing_fused_value` for `name/country/city/assets`.
#
# 2. **Repair how `_fusion_sources` is generated/serialized**
#    - Since the fused CSV shows malformed JSON lists, ensure these columns are written as valid JSON arrays or as proper Python lists before `.to_csv()`.
#    - Practical approach:
#      - After fusion, explicitly coerce provenance columns to JSON strings with `json.dumps(list_value)` if they are lists.
#      - Or avoid CSV for these meta-columns (Parquet), but if you must keep CSV: enforce strict JSON encoding.
#
# 3. **Ensure fused output has a stable, evaluable ID**
#    - If your gold IDs are Forbes IDs, consider adding a dedicated column like `forbes_id` during fusion (picked from sources) so evaluation can join directly without parsing `_fusion_sources`.
#
# ### Priority 2 — Fix fusion policy (pick better fusers per attribute)
# 4. **Replace `longest_string` for canonical identifiers**
#    - For `name`: prefer *most frequent across sources*, or prefer a trusted source priority (often Forbes > FullContact > DBpedia) for “display name”.
#    - For `country`/`city`: similarly prefer trusted source or consensus, not longest.
#
# 5. **Fix `founded` fuser**
#    - Replace `most_recent` with **earliest** (or “most plausible year”).
#    - If PyDI has `min`/`earliest` fuser use that; otherwise implement a small custom fuser: parse years, take minimum non-null.
#
# 6. **Assets: normalize units, then fuse**
#    - Convert all assets values into the same unit (absolute number) before fusion.
#    - Then use `median` or (better) “source-priority numeric” if one source is known to be authoritative.
#
# ### Priority 3 — Fix list-like normalization before fusion
# 7. **Normalize list-like columns in the *inputs* more aggressively**
#    - You already call `detect_list_like_columns` + `normalize_list_like_columns`, but diagnostics show problems persist in fused output, including in `keypeople_name`.
#    - Ensure `keypeople_name` is a real Python list in each source dataframe prior to fusion (not a malformed JSON string).
#
# ---
#
# ## Normalization Recommendations
#
# 1. **Country normalization (inputs, before matching+fusion)**
#    - Apply `normalize_country(value, output_format="name")` on:
#      - `forbes.country`, `dbpedia.country`, `fullcontact.country`
#    - This will reduce wrong-country fusions and improve match stability (even though matching is “fixed”, it helps fusion consensus too).
#
# 2. **List formatting normalization**
#    - Use `detect_list_like_columns` / `normalize_list_like_columns` on **source datasets**, explicitly ensuring these become proper lists:
#      - `keypeople_name` (primary)
#      - also check: `city`, `country`, `name` (diagnostics found mixed scalar/delimited representations in fused output—this usually originates upstream)
#    - Additionally: enforce that `_fusion_sources` and `_fusion_source_datasets` are emitted as valid JSON list strings when writing CSV (post-fusion serialization step).
#
# 3. **Numeric normalization for `assets`**
#    - Normalize to a single scale (absolute) prior to fusion:
#      - If values look like small floats (e.g., 37.6) treat as “billions” and multiply by 1e9.
#      - If values are large integers/strings already, parse as int.
#    - Target column: `assets` in all three sources (where present).
#
# ---
#
# ### What to do next (minimal change set with biggest payoff)
# 1. Change fusion run to `include_singletons=True`.
# 2. Fix provenance serialization so `_fusion_sources` is valid JSON (or add a direct `forbes_id` column).
# 3. Normalize `assets` units before fusion.
# 4. Replace `longest_string` for `name` (and ideally for `country/city`) with a trust/consensus-based fuser.
# TOKEN USAGE (investigator_normalization_assessment):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 5,839
#    Completion tokens: 385
#    Total tokens: 6,224
#    Estimated cost: $0.011149
# [*] Investigator decision: rerun normalization before next pipeline iteration
# [INVESTIGATION REPORT]
#   - overall_accuracy=28.788%, evaluation_attempt=1/3
#   - probes: reason_distribution: missing_fused_value=0.71, mismatch=0.29 | worst_attributes: assets_accuracy=0.00, city_accuracy=0.24, overall_accuracy=0.29, name_accuracy=0.32, macro_accuracy=0.32 | recent_mismatches: reasons[missing_fused_value:67, mismatch:27] attrs[assets:25, city:19, name:17] | directive_coverage: forbes: keypeople_name
#   - objective: composite=0.0 worst_pressure=1.0 missing_penalty=0.712766
#   - normalization acceptance: None (delta=None, required=None)
#   - routing score=1.315264 threshold=0.72 blocked_action_plan=False blocked_regret=False
# [*] Running normalization node
# [+] Normalization completed; using normalized datasets
# [*] Blocking config already present in state; skipping BlockingTester
# [*] Matching config already present in state; skipping MatchingTester
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 21,814
#    Completion tokens: 191
#    Total tokens: 22,005
#    Estimated cost: $0.029177
# [SEARCH TOOL CALL 1]: Asking 'PyDI.fusion available built-in fusers for strings and ids: is there 'shortest_string', 'most_complete', 'earliest', 'prefer_higher_trust' and how to use trust_map with DataFusionStrategy.add_attribute_fuser?'
# [SEARCH TOOL CALL 2]: Asking 'PyDI DataFusionEngine output provenance columns names and types: _fusion_sources and _fusion_source_datasets - are they lists, dicts, how to ensure valid JSON when writing to CSV?'
# [SEARCH TOOL CALL 3]: Asking 'PyDI.entitymatching post-clustering utilities: MaximumBipartiteMatching / HierarchicalClusterer / StableMatching usage with correspondences dataframe. What columns expected and how to call .cluster()?'
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 26,278
#    Completion tokens: 3,320
#    Total tokens: 29,598
#    Estimated cost: $0.066047
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Normalized list-like columns (helper): city, country, keypeople_name, name
# Performing Blocking
# Matching Entities
# Fusing Data
#
# [FUSION SIZE COMPARISON]
#   blocking: expected_rows=11853 actual_rows=12893 rows_pct_error=0.08774150004218341
#   matching: expected_rows=11301 actual_rows=12893 rows_pct_error=0.1408724891602513
# [*] Running consolidated evaluation node
# [EVALUATION EXECUTION] Attempt 1/3
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 12,574
#    Completion tokens: 150
#    Total tokens: 12,724
#    Estimated cost: $0.017218
# [SEARCH TOOL CALL 1]: Asking 'PyDI DataFusionEvaluator evaluate() usage example and expected output structure; how to print metrics'
# [SEARCH TOOL CALL 2]: Asking 'PyDI fusion evaluation functions tokenized_match year_only_match set_equality_match numeric_tolerance_match parameters'
# [SEARCH TOOL CALL 3]: Asking 'PyDI io.load_xml nested_handling='aggregate' meaning and how gold standard testsets are structured (id column, provenance columns)'
# [SEARCH TOOL CALL 4]: Asking 'PyDI normalize_country function signature and output_format options'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 19,685
#    Completion tokens: 2,849
#    Total tokens: 22,534
#    Estimated cost: $0.053096
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [LIST NORMALIZATION] columns=['city', 'country', 'keypeople_name', 'name']
# [COUNTRY NORMALIZATION] output_format=name, columns=['country']
# [ID ALIGNMENT] direct _id coverage: 14/25
# [ID ALIGNMENT] mapped eval_id coverage: 25/25
# [EVAL FUNCTIONS] Market Value:numeric_tolerance_match(tolerance=1000000.0) | Profits:numeric_tolerance_match(tolerance=1000000.0) | Rank:numeric_tolerance_match(tolerance=0.0) | Sales:numeric_tolerance_match(tolerance=1000000.0) | assets:numeric_tolerance_match(tolerance=1000000.0) | city:tokenized_match(threshold=0.8) | country:tokenized_match(threshold=0.8) | founded:year_only_match | industry:tokenized_match(threshold=0.75) | keypeople_name:set_equality_match | name:tokenized_match(threshold=0.85)
#
# [EVALUATION METRICS]
# {
#   "overall_accuracy": 0.5303030303030303,
#   "macro_accuracy": 0.518095238095238,
#   "num_evaluated_records": 25,
#   "num_evaluated_attributes": 6,
#   "total_evaluations": 132,
#   "total_correct": 70,
#   "city_accuracy": 0.36,
#   "city_count": 25,
#   "assets_accuracy": 0.0,
#   "assets_count": 25,
#   "name_accuracy": 1.0,
#   "name_count": 25,
#   "keypeople_name_accuracy": 0.42857142857142855,
#   "keypeople_name_count": 7,
#   "country_accuracy": 0.96,
#   "country_count": 25,
#   "founded_accuracy": 0.36,
#   "founded_count": 25
# }
#
# [EVALUATION EXECUTION] Status: success
# [*] Running consolidated investigator node
# [*] Running free integration diagnostics
# TOKEN USAGE (integration_diagnostics_generation):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 6,454
#    Completion tokens: 13,966
#    Total tokens: 20,420
#    Estimated cost: $0.147728
# [*] Reading evaluation metrics
# [EVALUATION GUARD] Rejected regressive validation metrics; keeping best-known validation metrics
# Evaluation metrics: {"overall_accuracy": 0.2878787878787879, "macro_accuracy": 0.32190476190476186, "num_evaluated_records": 25, "num_evaluated_attributes": 6, "total_evaluations": 132, "total_correct": 38, "assets_accuracy": 0.0, "assets_count": 25, "country_accuracy": 0.44, "country_count": 25, "keypeople_name_accuracy": 0.5714285714285714, "keypeople_name_count": 7, "name_accuracy": 0.32, "name_count": 25, "founded_accuracy": 0.36, "founded_count": 25, "city_accuracy": 0.24, "city_count": 25}
# [EVALUATION REPORT]
#   Stage: validation
#   Attempt: 2/3
#   Overall Accuracy: 28.788%
#   Problems Detected:
#     - overall_accuracy below target: 28.788% < 85.000%
#     - low attribute accuracy: assets=0.000%, city=24.000%, country=44.000%, founded=36.000%, macro=32.190%, name=32.000%
#     - regression guard rejected latest candidate: overall_drop=-0.242424, macro_drop=-0.19619, top_attribute_drops={'keypeople_name': 0.142857}
#     - high missing_fused_value mismatch ratio: 50.000%
#   Planned Adaptation:
#     - investigator runs diagnostics report + cluster evidence analysis
#     - reasoning node proposes targeted pipeline/code changes
#     - prioritize fusion strategy changes for sparse attributes
# [*] Auto diagnostics:
# {
#   "debug_reason_counts": {
#     "mismatch": 31,
#     "missing_fused_value": 31
#   },
#   "debug_reason_ratios": {
#     "mismatch": 0.5,
#     "missing_fused_value": 0.5
#   },
#   "evaluation_stage": "validation",
#   "evaluation_testset_path": "input/datasets/companies/testsets/validation_set.xml",
#   "id_alignment": {
#     "gold_count": 25,
#     "direct_coverage": 14,
#     "direct_coverage_ratio": 0.56,
#     "mapped_coverage": 25,
#     "mapped_coverage_ratio": 1.0,
#     "missing_gold_ids": []
#   },
#   "fusion_size_comparison": {
#     "estimate_path": "output/pipeline_evaluation/fusion_size_estimate.json",
#     "actual": {
#       "rows": 12893,
#       "unique_ids": 12893
#     },
#     "comparisons": {
#       "blocking": {
#         "expected_rows": 11853,
#         "actual_rows": 12893,
#         "rows_abs_error": 1040,
#         "rows_pct_error": 0.08774150004218341,
#         "expected_rows_matched_only": 2164,
#         "expected_rows_singleton_aware": 11853,
#         "rows_pct_error_matched_only": 4.957948243992607,
#         "rows_pct_error_singleton_aware": 0.08774150004218341,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 11853,
#         "actual_unique_ids": 12893,
#         "unique_ids_abs_error": 1040,
#         "unique_ids_pct_error": 0.08774150004218341,
#         "reasoning": "Estimate is close to actual fused size. Blocking estimate was conservative; downstream matching/fusion retained more entities than expected.",
#         "compared_at": "2026-03-04T10:12:10.698796+00:00"
#       },
#       "matching": {
#         "expected_rows": 11301,
#         "actual_rows": 12893,
#         "rows_abs_error": 1592,
#         "rows_pct_error": 0.1408724891602513,
#         "expected_rows_matched_only": 2716,
#         "expected_rows_singleton_aware": 11301,
#         "rows_pct_error_matched_only": 3.7470544918998527,
#         "rows_pct_error_singleton_aware": 0.1408724891602513,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 11301,
#         "actual_unique_ids": 12893,
#         "unique_ids_abs_error": 1592,
#         "unique_ids_pct_error": 0.1408724891602513,
# ...
# Implement a preprocessing normalization step before fusion:
# - Detect if a value looks like “billions” (e.g., `value < 1e6` but non-trivial like 2.5, 162.8) and upscale to absolute:
#   - `assets *= 1e9` (if the dataset uses billions)
# - Or more robust: keep per-source metadata (“assets_unit”) and convert accordingly.
#
# **Outcome:** should move `assets_accuracy` from 0% to meaningful levels immediately.
#
# ---
#
# ### (2) Replace `prefer_higher_trust` with “prefer higher trust non-empty, else fallback”
# Current issue pattern (many nulls) strongly suggests the fuser is selecting empty from the highest-trust source.
#
# Action:
# - Create a custom fuser for `name/country/city/industry` that:
#   1) filters out missing/empty/[] values,
#   2) chooses the highest-trust remaining,
#   3) if multiple remain from same trust, pick shortest_string or most frequent (consensus).
#
# **Outcome:** reduces `missing_fused_value` for city/founded/keypeople_name substantially.
#
# ---
#
# ### (3) Founded: ensure parsing to real dates + robust earliest selection
# Even with `earliest`, you can still miss if one source is string and another is datetime, or if empty lists appear.
#
# Action:
# - Normalize `founded` into a consistent datetime (or year-int) in **all three inputs** before fusion.
# - If only year is available, coerce to `YYYY-01-01`.
#
# **Outcome:** fewer missing founded values + fewer wrong-year picks.
#
# ---
#
# ### (4) Stop serializing core attributes as JSON list strings unless required
# Right now you:
# - parse list-like columns into lists,
# - fuse,
# - then serialize `"name/country/city/keypeople_name"` back to JSON strings.
#
# This is convenient for CSV storage but harms downstream comparators/evaluators and increases risk of `"[]"` vs `[]` mishandling.
#
# Action options:
# - Option A (recommended): **keep them as Python lists in-memory**; only serialize at the final write step, but ensure evaluation reads and parses them reliably.
# - Option B: for scalar-ish fields (`city`, `country`, `name`), **store as scalar strings** (not list) after fusion; keep lists only for truly multi-valued attributes (`keypeople_name`).
#
# **Outcome:** improves `country` and `city` scoring and reduces string/list friction.
#
# ---
#
# ### (5) `keypeople_name`: union with cleanup + de-dup + canonicalization
# Union is correct, but inputs likely contain:
# - empty lists due to parsing,
# - inconsistent casing/punctuation.
#
# Action:
# - Normalize each person name: lower/strip, remove duplicate whitespace, drop empty tokens.
# - Consider splitting delimiters inside a single string item (e.g., `"A; B"`).
#
# **Outcome:** improves set equality accuracy and reduces partial-list misses.
#
# ---
#
# ## Normalization Recommendations
#
# ### Country
# - Apply **PyDI country normalization** *before fusion* on: **`country`**
#   - `normalize_country(value, output_format="name")`
# - Do this on each dataset after list parsing:
#   - if `country` is a list, normalize each element; then de-dup.
#
# ### List-like columns (critical because you currently have `"[]"` showing up)
# - Use `detect_list_like_columns` / `normalize_list_like_columns` on:
#   - `name`, `country`, `city`, `keypeople_name`, `_fusion_sources`
# - Additionally, tighten `_parse_listish` behavior:
#   - treat the literal strings `"[]"`, `"['']"`, `"[\"\"]"` as empty list.
#
# ### Assets (and other financials)
# - Normalize numeric scale for **`assets`** (and likely `Sales`, `Market Value`, `Profits`) to a single unit (absolute).
# - If Forbes values are in billions and gold expects absolute, multiply Forbes-side by `1e9` (or apply per-source rule).
#
# ---
#
# ## Bottom line diagnosis
# - **#1 dominant failure is fusion/preprocessing, not blocking/matching**: assets unit mismatch and missing attribute values due to trust-first selection + list/string parsing issues.
# - Secondary contributor: **some over-clustering in forbes↔dbpedia** can cause wrong city/founded values, but it can be partially mitigated in fusion via better conflict resolution and “non-empty fallback” policies.
# TOKEN USAGE (investigator_normalization_assessment):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 10,884
#    Completion tokens: 483
#    Total tokens: 11,367
#    Estimated cost: $0.018435
# [*] Investigator decision: rerun normalization before next pipeline iteration
# [INVESTIGATION REPORT]
#   - overall_accuracy=28.788%, evaluation_attempt=2/3
#   - probes: reason_distribution: mismatch=0.50, missing_fused_value=0.50 | worst_attributes: assets_accuracy=0.00, city_accuracy=0.24, overall_accuracy=0.29, name_accuracy=0.32, macro_accuracy=0.32 | recent_mismatches: reasons[mismatch:31, missing_fused_value:31] attrs[assets:25, city:16, founded:16] | directive_coverage: forbes: city, keypeople_name
#   - objective: composite=0.0 worst_pressure=1.0 missing_penalty=0.5
#   - normalization acceptance: None (delta=None, required=None)
#   - routing score=1.340226 threshold=0.72 blocked_action_plan=False blocked_regret=False
# [*] Running normalization node
# [+] Normalization completed; using normalized datasets
# [*] Blocking config already present in state; skipping BlockingTester
# [*] Matching config already present in state; skipping MatchingTester
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 31,678
#    Completion tokens: 4,595
#    Total tokens: 36,273
#    Estimated cost: $0.085547
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Normalized list-like columns (helper): city, country, keypeople_name, name
# Performing Blocking
# Matching Entities
# Fusing Data
#
# [FUSION SIZE COMPARISON]
#   blocking: expected_rows=11853 actual_rows=12891 rows_pct_error=0.08757276638825613
#   matching: expected_rows=11301 actual_rows=12891 rows_pct_error=0.14069551367135652
# [*] Running consolidated evaluation node
# [EVALUATION EXECUTION] Attempt 1/3
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 14,146
#    Completion tokens: 155
#    Total tokens: 14,301
#    Estimated cost: $0.019232
# [SEARCH TOOL CALL 1]: Asking 'DataFusionEvaluator usage: required columns, return format, and how to print metrics summary'
# [SEARCH TOOL CALL 2]: Asking 'DataFusionStrategy.add_evaluation_function signature and available evaluation functions like tokenized_match, year_only_match, set_equality_match, numeric_tolerance_match'
# [SEARCH TOOL CALL 3]: Asking 'normalize_country function: supported output_format values and behavior'
# [SEARCH TOOL CALL 4]: Asking 'detect_list_like_columns and normalize_list_like_columns helper: expected inputs/outputs and how it parses list-like strings'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 20,572
#    Completion tokens: 3,423
#    Total tokens: 23,995
#    Estimated cost: $0.059945
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [LIST NORMALIZATION] columns=['city', 'country', 'keypeople_name', 'name']
# [COUNTRY NORMALIZATION] output_format=name, columns=['country']
# [ID ALIGNMENT] direct _id coverage: 13/25
# [ID ALIGNMENT] mapped eval_id coverage: 25/25
#
# [EVAL FUNCTIONS] assets:numeric_tolerance_match(tolerance=1000000.0) | city:tokenized_match(threshold=0.8) | country:tokenized_match(threshold=0.85) | founded:year_only_match | keypeople_name:set_equality_match | name:tokenized_match(threshold=0.85)
#
# === PIPELINE EVALUATION (STRUCTURED) ===
#
# [EVALUATION EXECUTION] Status: success
# [*] Running consolidated investigator node
# [*] Running free integration diagnostics
# TOKEN USAGE (integration_diagnostics_generation):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 9,755
#    Completion tokens: 14,288
#    Total tokens: 24,043
#    Estimated cost: $0.155074
# [INTEGRATION DIAGNOSTICS STDOUT]
# Wrote: output/pipeline_evaluation/integration_diagnostics.json
# Wrote: output/pipeline_evaluation/integration_diagnostics.md
#
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.6666666666666666, "macro_accuracy": 0.6552380952380952, "num_evaluated_records": 25, "num_evaluated_attributes": 6, "total_evaluations": 132, "total_correct": 88, "city_accuracy": 0.36, "city_count": 25, "name_accuracy": 0.88, "name_count": 25, "assets_accuracy": 0.8, "assets_count": 25, "keypeople_name_accuracy": 0.5714285714285714, "keypeople_name_count": 7, "founded_accuracy": 0.36, "founded_count": 25, "country_accuracy": 0.96, "country_count": 25}
# [EVALUATION REPORT]
#   Stage: validation
#   Attempt: 3/3
#   Overall Accuracy: 66.667%
#   Problems Detected:
#     - overall_accuracy below target: 66.667% < 85.000%
#     - low attribute accuracy: city=36.000%, founded=36.000%
#     - high missing_fused_value mismatch ratio: 63.636%
#   Planned Adaptation:
#     - max automatic iterations reached; stop adaptation loop
# [*] Auto diagnostics:
# {
#   "debug_reason_counts": {
#     "mismatch": 16,
#     "missing_fused_value": 28
#   },
#   "debug_reason_ratios": {
#     "mismatch": 0.36363636363636365,
#     "missing_fused_value": 0.6363636363636364
#   },
#   "evaluation_stage": "validation",
#   "evaluation_testset_path": "input/datasets/companies/testsets/validation_set.xml",
#   "id_alignment": {
#     "gold_count": 25,
#     "direct_coverage": 13,
#     "direct_coverage_ratio": 0.52,
#     "mapped_coverage": 25,
#     "mapped_coverage_ratio": 1.0,
#     "missing_gold_ids": []
#   },
#   "fusion_size_comparison": {
#     "estimate_path": "output/pipeline_evaluation/fusion_size_estimate.json",
#     "actual": {
#       "rows": 12891,
#       "unique_ids": 12891
#     },
#     "comparisons": {
#       "blocking": {
#         "expected_rows": 11853,
#         "actual_rows": 12891,
#         "rows_abs_error": 1038,
#         "rows_pct_error": 0.08757276638825613,
#         "expected_rows_matched_only": 2164,
#         "expected_rows_singleton_aware": 11853,
#         "rows_pct_error_matched_only": 4.957024029574861,
#         "rows_pct_error_singleton_aware": 0.08757276638825613,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 11853,
#         "actual_unique_ids": 12891,
#         "unique_ids_abs_error": 1038,
#         "unique_ids_pct_error": 0.08757276638825613,
#         "reasoning": "Estimate is close to actual fused size. Blocking estimate was conservative; downstream matching/fusion retained more entities than expected.",
#         "compared_at": "2026-03-04T10:22:34.827191+00:00"
#       },
#       "matching": {
#         "expected_rows": 11301,
#         "actual_rows": 12891,
#         "rows_abs_error": 1590,
#         "rows_pct_error": 0.14069551367135652,
#         "expected_rows_matched_only": 2716,
#         "expected_rows_singleton_aware": 11301,
#         "rows_pct_error_matched_only": 3.746318114874816,
#         "rows_pct_error_singleton_aware": 0.14069551367135652,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 11301,
#         "actual_unique_ids": 12891,
#         "unique_ids_abs_error": 1590,
#         "unique_ids_pct_error": 0.14069551367135652,
#         "reasoning": "Estimate is moderately off; candidate generation and matching quality likely explain the gap. Matching estimate seems conservative; matcher/fusion retained more clusters than projected.",
#         "compared_at": "2026-03-04T10:22:34.827284+00:00"
#       }
#     }
#   },
#   "overall_accuracy": 0.6666666666666666
# }
# TOTAL TOKEN USAGE:
#    Prompt tokens: 1,810,149
#    Completion tokens: 455,055
#    Total tokens: 2,265,204
#    Estimated cost: $6.813236
# [*] Investigator decision: proceed to human review
# [INVESTIGATION REPORT]
#   - overall_accuracy=66.667%, evaluation_attempt=3/3
#   - probes: reason_distribution: missing_fused_value=0.64, mismatch=0.36 | worst_attributes: city_accuracy=0.36, founded_accuracy=0.36, keypeople_name_accuracy=0.57, macro_accuracy=0.66, overall_accuracy=0.67 | recent_mismatches: reasons[missing_fused_value:28, mismatch:16] attrs[city:16, founded:16, assets:5] | directive_coverage: forbes: city, keypeople_name
#   - objective: composite=0.028303 worst_pressure=0.64 missing_penalty=0.636364
#   - normalization acceptance: None (delta=None, required=None)
# [*] Building final human-review package
# TOKEN USAGE (human_review_export_generation):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 6,020
#    Completion tokens: 6,387
#    Total tokens: 12,407
#    Estimated cost: $0.071395
# [*] Human-review export completed
# [*] Running sealed final test evaluation on held-out test set
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 14,106
#    Completion tokens: 137
#    Total tokens: 14,243
#    Estimated cost: $0.019002
# [SEARCH TOOL CALL 1]: Asking 'PyDI DataFusionEvaluator evaluate usage example and expected output structure'
# [SEARCH TOOL CALL 2]: Asking 'PyDI.fusion evaluation functions tokenized_match year_only_match set_equality_match numeric_tolerance_match parameters'
# [SEARCH TOOL CALL 3]: Asking 'PyDI.io load_xml parameters nested_handling aggregate'
# [SEARCH TOOL CALL 4]: Asking 'PyDI.normalization normalize_country output_format options alpha_2 alpha_3 numeric name official_name'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 21,208
#    Completion tokens: 2,955
#    Total tokens: 24,163
#    Estimated cost: $0.056060
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [LIST NORMALIZATION] columns=['city', 'country', 'keypeople_name', 'name']
# [COUNTRY NORMALIZATION] output_format=name, columns=['country']
# [ID ALIGNMENT] direct _id coverage: 5/18
# [ID ALIGNMENT] mapped eval_id coverage: 18/18
# [EVAL FUNCTIONS] Continent:tokenized_match(threshold=0.9) | Market Value:numeric_tolerance_match(tolerance=1.0) | Profits:numeric_tolerance_match(tolerance=1.0) | Rank:numeric_tolerance_match(tolerance=0.0) | Sales:numeric_tolerance_match(tolerance=1.0) | Sector:tokenized_match(threshold=0.7) | assets:numeric_tolerance_match(tolerance=1.0) | city:tokenized_match(threshold=0.75) | country:tokenized_match(threshold=0.75) | founded:year_only_match | industry:tokenized_match(threshold=0.7) | keypeople_name:tokenized_match(threshold=0.75) | name:tokenized_match(threshold=0.85)
# [EVALUATION RESULTS]
# {
#   "overall_accuracy": 0.7272727272727273,
#   "macro_accuracy": 0.7222222222222222,
#   "num_evaluated_records": 18,
#   "num_evaluated_attributes": 6,
#   "total_evaluations": 99,
#   "total_correct": 72,
#   "founded_accuracy": 0.6666666666666666,
#   "founded_count": 18,
#   "name_accuracy": 0.8333333333333334,
#   "name_count": 18,
#   "country_accuracy": 0.8888888888888888,
#   "country_count": 18,
#   "keypeople_name_accuracy": 0.6666666666666666,
#   "keypeople_name_count": 9,
#   "assets_accuracy": 0.6666666666666666,
#   "assets_count": 18,
#   "city_accuracy": 0.6111111111111112,
#   "city_count": 18
# }
#
# [*] Sealed final test overall accuracy: 72.727%
# [+] Results saved to: output/results/run_20260304_113020.json
# [+] Run audit saved to: output/results/run_audit_20260304_113020.json
# [+] Run report saved to: output/results/run_report_20260304_113020.md
# [*] Companies run complete
# {
#   "validation_overall_accuracy": 0.6666666666666666,
#   "sealed_test_overall_accuracy": 0.7272727272727273,
#   "normalization_attempts": 3,
#   "evaluation_attempts": 3,
#   "run_id": "20260303_125833_844806",
#   "run_output_root": "output/runs/20260303_125833_844806",
#   "run_audit_path": "output/results/run_audit_20260304_113020.json",
#   "run_report_path": "output/results/run_report_20260304_113020.md"
# }
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Short runner for Games (assumes `agent` and `INPUT_DIR` already exist in notebook)

entity_matching_testsets = {
    ("dbpedia", "sales"): INPUT_DIR + "datasets/games/testsets/dbpedia_2_sales_test.csv",
    ("metacritic", "dbpedia"): INPUT_DIR + "datasets/games/testsets/metacritic_2_dbpedia_test.csv",
    ("metacritic", "sales"): INPUT_DIR + "datasets/games/testsets/metacritic_2_sales_test.csv",
}


payload = {
    "datasets": [
        INPUT_DIR + "datasets/games/dbpedia.xml",
        INPUT_DIR + "datasets/games/metacritic.xml",
        INPUT_DIR + "datasets/games/sales.xml",
    ],
    "original_datasets": [
        INPUT_DIR + "datasets/games/dbpedia.xml",
        INPUT_DIR + "datasets/games/metacritic.xml",
        INPUT_DIR + "datasets/games/sales.xml",
    ],
    "normalized_datasets": [],
    "entity_matching_testsets": entity_matching_testsets,
    "fusion_testset": INPUT_DIR + "datasets/games/testsets/test_set.xml",
    # include only if this file exists in your setup:
    "validation_fusion_testset": INPUT_DIR + "datasets/games/testsets/validation_set.xml",
    "matcher_mode": "rulebased",
    "evaluation_attempts": 0,
    "normalization_attempts": 0,
    "normalization_execution_result": "",
    "normalization_rework_required": False,
    "normalization_rework_reasons": [],
    "normalization_directives": {},
    "investigator_decision": "",
}

print("[*] Starting games run...")
RESULT = agent.graph.invoke(payload, config={"recursion_limit": 200})
print("[*] Games run complete")

print(json.dumps({
    "validation_overall_accuracy": (RESULT.get("evaluation_metrics") or {}).get("overall_accuracy"),
    "sealed_test_overall_accuracy": (RESULT.get("sealed_test_metrics_final") or {}).get("overall_accuracy"),
    "normalization_attempts": RESULT.get("normalization_attempts"),
    "evaluation_attempts": RESULT.get("evaluation_attempts"),
    "run_id": RESULT.get("run_id"),
    "run_output_root": RESULT.get("run_output_root"),
    "run_audit_path": RESULT.get("run_audit_path"),
    "run_report_path": RESULT.get("run_report_path"),
}, indent=2, default=str))
# Out:
# [*] Starting games run...
# [*] Running schema matching
# [*] Schema alignment columns:
#     dbpedia: ['id', 'name', 'releaseYear', 'developer', 'platform', 'series']
#     metacritic: ['id', 'name', 'releaseYear', 'developer', 'platform', 'criticScore', 'userScore', 'ESRB']
#     sales: ['id', 'name', 'releaseYear', 'developer', 'publisher', 'platform', 'criticScore', 'userScore', 'ESRB', 'globalSales']
# [*] Profiling datasets
# TOKEN USAGE (profile_data):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 285
#    Completion tokens: 80
#    Total tokens: 365
#    Estimated cost: $0.001156
# [*] Running normalization node
# [+] Normalization completed; using normalized datasets
# [*] Running BlockingTester
# [*] Loading dataset: dbpedia
# [*] Loading dataset: metacritic
# [*] Loading dataset: sales
# [*] Loading gold standard for dbpedia <-> sales
#     Loaded 596 ground truth pairs (positives: 206, negatives/other: 390)
# [*] Loading gold standard for metacritic <-> dbpedia
#     Loaded 579 ground truth pairs (positives: 187, negatives/other: 392)
# [*] Loading gold standard for metacritic <-> sales
#     Loaded 582 ground truth pairs (positives: 135, negatives/other: 447)
# [*] Adaptive max_candidates set to 2,071,389 (r=0.35%, median_pairs=366,910,660)
#
# ============================================================
# 🤖 BLOCKING: dbpedia <-> sales
# ============================================================
# Gold pairs: 596, PC threshold: 0.9
# Candidate limit: 2,071,389 (hard: 2,382,097 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 46,580 × 7,877 = 366,910,660 potential pairs
# Common columns: ['platform', 'releaseYear', 'developer', 'name']
# Guardrails: strategies=['exact_match_multi', 'exact_match_single', 'semantic_similarity'], preferred_columns=['developer', 'releaseYear', 'platform', 'name']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['name', 'releaseYear', 'platform']
#   Params: {}
#   Reasoning: Very large pair space (~367M) requires a fast, highly restrictive block to stay under the 2.07M cand...
#     Standard (name+releaseYear+platform): 3,122 candidates
#     ⚠️ PC=0.8641, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['name', 'developer', 'releaseYear']
#   Params: {'top_k': 20}
#   Reasoning: Previous exact_match_multi on (name, releaseYear, platform) was too restrictive (PC=0.864). To raise...
#     Embedding (name+developer+releaseYear, k=20): 931,501 candidates
#     ✅ PC=0.9126, RR=0.9975
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: metacritic <-> dbpedia
# ============================================================
# Gold pairs: 579, PC threshold: 0.9
# Candidate limit: 2,071,389 (hard: 2,382,097 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 20,494 × 46,580 = 954,610,520 potential pairs
# Common columns: ['platform', 'releaseYear', 'developer', 'name']
# Guardrails: strategies=['exact_match_multi', 'exact_match_single', 'semantic_similarity'], preferred_columns=['developer', 'releaseYear', 'platform', 'name']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['name', 'releaseYear']
#   Params: {}
#   Reasoning: Given the very large Cartesian space (~955M) and the allowed strategies, multi-column exact blocking...
#     Standard (name+releaseYear): 21,005 candidates
#     ⚠️ PC=0.8503, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['name', 'developer', 'releaseYear']
#   Params: {'top_k': 20}
#   Reasoning: Previous exact_match_multi on (name, releaseYear) was too restrictive (PC=0.85). Use semantic_simila...
#     Embedding (name+developer+releaseYear, k=20): 409,855 candidates
#     ✅ PC=0.9679, RR=0.9996
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: metacritic <-> sales
# ============================================================
# Gold pairs: 582, PC threshold: 0.9
# Candidate limit: 2,071,389 (hard: 2,382,097 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 20,494 × 7,877 = 161,431,238 potential pairs
# Common columns: ['criticScore', 'userScore', 'ESRB', 'platform', 'releaseYear', 'developer', 'name']
# Guardrails: strategies=['exact_match_multi', 'exact_match_single', 'semantic_similarity'], preferred_columns=['userScore', 'ESRB', 'releaseYear', 'criticScore']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['platform', 'releaseYear', 'developer']
#   Params: {}
#   Reasoning: Very large Cartesian space (161M) requires highly restrictive blocking. Single-column exact matches ...
#     Standard (platform+releaseYear+developer): 11,329 candidates
#     ⚠️ PC=0.8222, RR=0.9999
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['name', 'platform', 'releaseYear']
#   Params: {'top_k': 20}
#   Reasoning: Previous exact_match_multi on (platform, releaseYear, developer) was too restrictive (PC=0.822). To ...
#     Embedding (name+platform+releaseYear, k=20): 409,504 candidates
#     ✅ PC=1.0000, RR=0.9975
# ✅ Found acceptable strategy!
#
# ============================================================
# 📊 RESULTS SUMMARY: 3 pairs evaluated
# ============================================================
#   ✅ dbpedia_sales: PC=0.9126, candidates=931,501, strategy=semantic_similarity
#   ✅ metacritic_dbpedia: PC=0.9679, candidates=409,855, strategy=semantic_similarity
#   ✅ metacritic_sales: PC=1.0000, candidates=409,504, strategy=semantic_similarity
# [*] Blocking fused-size estimate: rows=54427, unique_ids=54427
# [*] Blocking estimate breakdown: matched_only_rows=20524, singleton_aware_rows=54427
# [*] Fused-size report updated: /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/pipeline_evaluation/fusion_size_estimate.json
#
# 💾 Config saved to: output/blocking-evaluation/blocking_config.json
# [*] Blocking config computed:
# {
#   "blocking_strategies": {
#     "dbpedia_sales": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "developer",
#         "releaseYear"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.912621359223301,
#       "num_candidates": 931501,
#       "is_acceptable": true,
#       "failure_tags": [
#         "ok"
#       ]
#     },
#     "metacritic_dbpedia": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "developer",
#         "releaseYear"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.9679144385026738,
#       "num_candidates": 409855,
#       "is_acceptable": true,
#       "failure_tags": [
#         "ok"
#       ]
#     },
#     "metacritic_sales": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "platform",
#         "releaseYear"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 1.0,
#       "num_candidates": 409504,
#       "is_acceptable": true,
#       "failure_tags": [
#         "ok"
#       ]
#     }
#   },
#   "id_columns": {
#     "dbpedia": "id",
#     "metacritic": "id",
#     "sales": "id"
#   },
#   "dataset_signature": "dbpedia|metacritic|sales",
#   "dataset_names": [
#     "dbpedia",
#     "metacritic",
#     "sales"
#   ],
#   "pc_threshold": 0.9,
#   "max_candidates": 2071389,
#   "candidate_tolerance": 0.15,
#   "llm_trace_path": "output/blocking-evaluation/llm_blocking_trace.jsonl",
#   "fusion_size_estimate": {
#     "stage": "blocking",
#     "dataset_signature": "dbpedia|metacritic|sales",
#     "datasets": [
#       "dbpedia",
#       "metacritic",
#       "sales"
#     ],
#     "method": "3-way inclusion-exclusion over pair estimates: E=E12+E13+E23-2*E123, with E123 estimated from per-dataset overlap probabilities; singleton-aware projection applied for final fused output (include_singletons=True assumption)",
#     "expected_rows": 54427,
#     "expected_unique_ids": 54427,
#     "expected_rows_range": [
#       40049,
#       54427
#     ],
#     "expected_unique_ids_range": [
#       40049,
#       54427
#     ],
#     "three_way_intersection": {
#       "enabled": true,
#       "datasets": [
#         "dbpedia",
#         "metacritic",
#         "sales"
#       ],
#       "pair_cluster_estimates": {
#         "dbpedia_metacritic": 19836,
#         "dbpedia_sales": 7189,
#         "metacritic_sales": 7877
#       },
#       "triple_intersection_estimates": {
#         "via_dbpedia": 3061.42129669386,
#         "via_metacritic": 7624.093490777788,
#         "via_sales": 7189.0,
#         "median_used": 7189.0,
#         "final_triple_intersection": 7189,
#         "triple_intersection_range": [
#           0,
#           7189
#         ]
#       },
#       "expected_union_clusters": 20524,
#       "expected_union_range": [
#         20524,
#         34902
#       ],
#       "formula": "E_union = E12 + E13 + E23 - 2*E123"
#     },
#     "pair_estimates": [
#       {
#         "pair_key": "dbpedia_sales",
#         "left_dataset": "dbpedia",
#         "right_dataset": "sales",
#         "min_pair_size": 7877,
#         "pair_completeness": 0.912621359223301,
#         "expected_cluster_count": 7189
#       },
#       {
#         "pair_key": "metacritic_dbpedia",
#         "left_dataset": "dbpedia",
#         "right_dataset": "metacritic",
#         "min_pair_size": 20494,
#         "pair_completeness": 0.9679144385026738,
#         "expected_cluster_count": 19836
#       },
#       {
#         "pair_key": "metacritic_sales",
#         "left_dataset": "metacritic",
#         "right_dataset": "sales",
#         "min_pair_size": 7877,
#         "pair_completeness": 1.0,
#         "expected_cluster_count": 7877
#       }
#     ],
#     "created_at": "2026-03-04T10:35:45.302561+00:00",
#     "expected_rows_matched_only": 20524,
#     "expected_unique_ids_matched_only": 20524,
#     "expected_rows_matched_only_range": [
#       20524,
#       34902
#     ],
#     "expected_unique_ids_matched_only_range": [
#       20524,
#       34902
#     ],
#     "expected_rows_singleton_aware": 54427,
#     "expected_unique_ids_singleton_aware": 54427,
#     "expected_rows_singleton_aware_range": [
#       40049,
#       54427
#     ],
#     "expected_unique_ids_singleton_aware_range": [
#       40049,
#       54427
#     ],
#     "singleton_assumption": {
#       "assumed_include_singletons": true,
#       "total_input_rows": 74951,
#       "formula": "E_final_rows = total_input_rows - E_matched_clusters",
#       "notes": "Conservative singleton-aware estimate: each expected matched cluster reduces the final row count by at least one."
#     }
#   }
# }
# [*] Using MatchingTester module: /Users/nickblazek/Desktop/Agent_Pipeline/agents/matching_tester.py
# [*] Running MatchingTester
# [*] Loading dataset: dbpedia
# [*] Loading dataset: metacritic
# [*] Loading dataset: sales
# [*] Loading matching gold standard for dbpedia <-> sales
#     Loaded 596 ground truth pairs
# [*] Loading matching gold standard for metacritic <-> dbpedia
#     Loaded 579 ground truth pairs
# [*] Loading matching gold standard for metacritic <-> sales
#     Loaded 582 ground truth pairs
#
# ==================================================
# MATCHING EVALUATION
# ==================================================
#
# ==================================================
# MATCHING: dbpedia <-> sales
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'developer', 'releaseYear']
# Guardrails preferred columns: ['developer', 'releaseYear', 'platform']
# Candidates: full=931,501, proxy_sample=60,000 (margin=0.015)
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'developer:jaro_winkler', 'platform:jaro_winkler', 'releaseYear:366']
# Weights: [0.55, 0.2, 0.1, 0.15]
# Threshold: 0.78
#     Reasoning: Use blocking columns (name, developer, releaseYear) as primary signals; name is highly unique and best for matching with minor typos, developer adds confirmation, release year is a strong temporal constraint with small tolerance, and platform helps disambiguate duplicates across systems.
#     Reasoning (100c): Use blocking columns (name, developer, releaseYear) as primary signals; name is highly unique and be
#     Proxy stage: F1=0.0822, required>=0.0300 -> run full
# SUCCESS: F1=0.8086
#
# ==================================================
# MATCHING: metacritic <-> dbpedia
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'developer', 'releaseYear']
# Guardrails preferred columns: ['releaseYear', 'developer', 'platform', 'name']
# Candidates: full=409,855, proxy_sample=60,000 (margin=0.015)
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'developer:jaro_winkler', 'releaseYear:366', 'platform:cosine']
# Weights: [0.55, 0.2, 0.2, 0.05]
# Threshold: 0.78
#     Reasoning: Use all blocking columns: name is the strongest identifier (typo-tolerant Jaro-Winkler), developer adds disambiguation, and releaseYear provides strong temporal consistency with small tolerance for date parsing/offsets. Platform is lower weight due to many variants and differing granularity between sources, so cosine on normalized text is a light supporting signal. Higher threshold favors precision given strong identifiers and some noise in developer/platform.
#     Reasoning (100c): Use all blocking columns: name is the strongest identifier (typo-tolerant Jaro-Winkler), developer a
#     Proxy stage: F1=0.3097, required>=0.0300 -> run full
# SUCCESS: F1=0.9031
#
# ==================================================
# MATCHING: metacritic <-> sales
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'platform', 'releaseYear']
# Guardrails preferred columns: ['userScore', 'releaseYear', 'criticScore', 'ESRB', 'developer']
# Candidates: full=409,504, proxy_sample=60,000 (margin=0.015)
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'platform:jaro_winkler', 'releaseYear:366', 'developer:cosine', 'criticScore:5.0', 'userScore:1.0', 'ESRB:jaro_winkler']
# Weights: [0.4, 0.15, 0.15, 0.1, 0.08, 0.07, 0.05]
# Threshold: 0.78
#     Reasoning: Use blocking columns (name/platform/releaseYear) as primary evidence: name is the strongest identifier; platform and release year disambiguate editions/ports. Developer provides additional disambiguation with many unique values. CriticScore/userScore help but can vary across sources and have some missingness (userScore), so lower weights with moderate numeric tolerances. ESRB has low cardinality so smallest weight. Higher threshold favors precision given strong identifiers and generally low null rates.
#     Reasoning (100c): Use blocking columns (name/platform/releaseYear) as primary evidence: name is the strongest identifi
#     Proxy stage: F1=0.2545, required>=0.0300 -> run full
# SUCCESS: F1=0.8375
#
# 📊 Results: 3 pairs evaluated
#   OK dbpedia_sales: F1=0.8086, proxy=0.0822
#   OK metacritic_dbpedia: F1=0.9031, proxy=0.3097
#   OK metacritic_sales: F1=0.8375, proxy=0.2545
# [*] Matching fused-size estimate: rows=54363, unique_ids=54363
# [*] Matching estimate breakdown: matched_only_rows=20588, singleton_aware_rows=54363
# [*] Fused-size report updated: /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/pipeline_evaluation/fusion_size_estimate.json
# Config saved to matching_config.json
# [*] Run report updated: output/results/run_audit_20260304_113020_report.md
# [*] Matching config computed:
# {
#   "id_columns": {
#     "dbpedia": "id",
#     "metacritic": "id",
#     "sales": "id"
#   },
#   "matching_strategies": {
#     "dbpedia_sales": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "developer",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "platform",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "date",
#           "column": "releaseYear",
#           "max_days_difference": 366
#         }
#       ],
#       "weights": [
#         0.55,
#         0.2,
#         0.1,
#         0.15
#       ],
#       "threshold": 0.78,
#       "f1": 0.8086021505376344,
#       "skipped_due_to_blocking_gate": false,
#       "proxy_f1": 0.08219178082191782,
#       "failure_tags": [
#         "ok"
#       ]
#     },
#     "metacritic_dbpedia": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "developer",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "date",
#           "column": "releaseYear",
#           "max_days_difference": 366
#         },
#         {
#           "type": "string",
#           "column": "platform",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip"
#         }
#       ],
#       "weights": [
#         0.55,
#         0.2,
#         0.2,
#         0.05
#       ],
#       "threshold": 0.78,
#       "f1": 0.9030612244897959,
#       "skipped_due_to_blocking_gate": false,
#       "proxy_f1": 0.30973451327433627,
#       "failure_tags": [
#         "ok"
#       ]
#     },
#     "metacritic_sales": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "platform",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "date",
#           "column": "releaseYear",
#           "max_days_difference": 366
#         },
#         {
#           "type": "string",
#           "column": "developer",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "numeric",
#           "column": "criticScore",
#           "max_difference": 5.0
#         },
#         {
#           "type": "numeric",
#           "column": "userScore",
#           "max_difference": 1.0
#         },
#         {
#           "type": "string",
#           "column": "ESRB",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         }
#       ],
#       "weights": [
#         0.4,
#         0.15,
#         0.15,
#         0.1,
#         0.08,
#         0.07,
#         0.05
#       ],
#       "threshold": 0.78,
#       "f1": 0.8375,
#       "skipped_due_to_blocking_gate": false,
#       "proxy_f1": 0.2545454545454545,
#       "failure_tags": [
#         "ok"
#       ]
#     }
#   },
#   "dataset_signature": "dbpedia|metacritic|sales",
#   "dataset_names": [
#     "dbpedia",
#     "metacritic",
#     "sales"
#   ],
#   "min_blocking_pc_for_matching": 0.9,
#   "proxy_f1_margin": 0.015,
#   "proxy_max_candidates": 60000,
#   "llm_trace_path": "output/matching-evaluation/llm_matching_trace.jsonl",
#   "fusion_size_estimate": {
#     "stage": "matching",
#     "dataset_signature": "dbpedia|metacritic|sales",
#     "datasets": [
#       "dbpedia",
#       "metacritic",
#       "sales"
#     ],
#     "method": "3-way inclusion-exclusion over pair estimates: E=E12+E13+E23-2*E123, with E123 estimated from per-dataset overlap probabilities; singleton-aware projection applied for final fused output (include_singletons=True assumption)",
#     "expected_rows": 54363,
#     "expected_unique_ids": 54363,
#     "expected_rows_range": [
#       44627,
#       56253
#     ],
#     "expected_unique_ids_range": [
#       44627,
#       56253
#     ],
#     "three_way_intersection": {
#       "enabled": true,
#       "datasets": [
#         "dbpedia",
#         "metacritic",
#         "sales"
#       ],
#       "pair_cluster_estimates": {
#         "dbpedia_metacritic": 17914,
#         "dbpedia_sales": 5813,
#         "metacritic_sales": 6597
#       },
#       "triple_intersection_estimates": {
#         "via_dbpedia": 2235.596436238729,
#         "via_metacritic": 5766.500341563385,
#         "via_sales": 4868.396724641361,
#         "median_used": 4868.396724641361,
#         "final_triple_intersection": 4868,
#         "triple_intersection_range": [
#           0,
#           5813
#         ]
#       },
#       "expected_union_clusters": 20588,
#       "expected_union_range": [
#         18698,
#         30324
#       ],
#       "formula": "E_union = E12 + E13 + E23 - 2*E123"
#     },
#     "pair_estimates": [
#       {
#         "pair_key": "dbpedia_sales",
#         "left_dataset": "dbpedia",
#         "right_dataset": "sales",
#         "min_pair_size": 7877,
#         "pair_completeness": 0.912621359223301,
#         "f1": 0.8086021505376344,
#         "expected_cluster_count": 5813
#       },
#       {
#         "pair_key": "metacritic_dbpedia",
#         "left_dataset": "dbpedia",
#         "right_dataset": "metacritic",
#         "min_pair_size": 20494,
#         "pair_completeness": 0.9679144385026738,
#         "f1": 0.9030612244897959,
#         "expected_cluster_count": 17914
#       },
#       {
#         "pair_key": "metacritic_sales",
#         "left_dataset": "metacritic",
#         "right_dataset": "sales",
#         "min_pair_size": 7877,
#         "pair_completeness": 1.0,
#         "f1": 0.8375,
#         "expected_cluster_count": 6597
#       }
#     ],
#     "created_at": "2026-03-04T10:47:19.363392+00:00",
#     "expected_rows_matched_only": 20588,
#     "expected_unique_ids_matched_only": 20588,
#     "expected_rows_matched_only_range": [
#       18698,
#       30324
#     ],
#     "expected_unique_ids_matched_only_range": [
#       18698,
#       30324
#     ],
#     "expected_rows_singleton_aware": 54363,
#     "expected_unique_ids_singleton_aware": 54363,
#     "expected_rows_singleton_aware_range": [
#       44627,
#       56253
#     ],
#     "expected_unique_ids_singleton_aware_range": [
#       44627,
#       56253
#     ],
#     "singleton_assumption": {
#       "assumed_include_singletons": true,
#       "total_input_rows": 74951,
#       "formula": "E_final_rows = total_input_rows - E_matched_clusters",
#       "notes": "Conservative singleton-aware estimate: each expected matched cluster reduces the final row count by at least one."
#     }
#   },
#   "run_report_path": "output/results/run_audit_20260304_113020_report.md"
# }
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 14,358
#    Completion tokens: 3,002
#    Total tokens: 17,360
#    Estimated cost: $0.047968
# [*] Running generated pipeline
# Error: error:   File "/Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/pipeline.py", line 255
#     list_strategy=\"average\",
#                    ^
# SyntaxError: unexpected character after line continuation character
#
# [*] Trying to fix pipeline
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 12,834
#    Completion tokens: 3,014
#    Total tokens: 15,848
#    Estimated cost: $0.046183
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Performing Blocking
# Matching Entities
# Fusing Data
#
# [FUSION SIZE COMPARISON]
#   blocking: expected_rows=54427 actual_rows=55723 rows_pct_error=0.023811711099270584
#   matching: expected_rows=54363 actual_rows=55723 rows_pct_error=0.025017015249342384
# [*] Running consolidated evaluation node
# [EVALUATION EXECUTION] Attempt 1/3
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 8,253
#    Completion tokens: 125
#    Total tokens: 8,378
#    Estimated cost: $0.011566
# [SEARCH TOOL CALL 1]: Asking 'How do I use PyDI DataFusionEvaluator to evaluate fused_df against a gold_df? What is the expected format of evaluation_results and how to print metrics?'
# [SEARCH TOOL CALL 2]: Asking 'PyDI DataFusionStrategy: how to register evaluation functions for columns (add_evaluation_function) and what built-in match functions exist (tokenized_match, year_only_match, numeric_tolerance_match, set_equality_match)?'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 11,584
#    Completion tokens: 2,989
#    Total tokens: 14,573
#    Estimated cost: $0.044370
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# {
#   "id_alignment": {
#     "direct__id_coverage": [
#       0,
#       15
#     ],
#     "mapped_eval_id_coverage": [
#       15,
#       15
#     ]
#   }
# }
# [EVAL_FUNCTIONS] ESRB:tokenized_match(threshold=0.9) | criticScore:numeric_tolerance_match(tolerance=5.0) | developer:tokenized_match(threshold=0.75) | genres_genre:tokenized_match(threshold=0.75) | globalSales:numeric_tolerance_match(tolerance=0.5) | name:tokenized_match(threshold=0.85) | platform:tokenized_match(threshold=0.8) | publisher:tokenized_match(threshold=0.8) | releaseYear:year_only_match | userScore:numeric_tolerance_match(tolerance=1.0)
# {
#   "ESRB_accuracy": 0.6666666666666666,
#   "ESRB_count": 15.0,
#   "criticScore_accuracy": 0.7333333333333333,
#   "criticScore_count": 15.0,
#   "developer_accuracy": 0.6,
#   "developer_count": 15.0,
#   "macro_accuracy": 0.7220238095238095,
#   "name_accuracy": 0.9333333333333333,
#   "name_count": 15.0,
#   "num_evaluated_attributes": 8.0,
#   "num_evaluated_records": 15.0,
#   "overall_accuracy": 0.7226890756302521,
#   "platform_accuracy": 0.5333333333333333,
#   "platform_count": 15.0,
#   "publisher_accuracy": 0.8,
#   "publisher_count": 15.0,
#   "releaseYear_accuracy": 0.8666666666666667,
#   "releaseYear_count": 15.0,
#   "total_correct": 86.0,
#   "total_evaluations": 119.0,
#   "userScore_accuracy": 0.6428571428571429,
#   "userScore_count": 14.0
# }
#
# [EVALUATION STDERR]
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/evaluation.py:242: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   fused = pd.read_csv(FUSED_PATH)
#
# [EVALUATION EXECUTION] Status: success
# [*] Running consolidated investigator node
# [*] Running free integration diagnostics
# TOKEN USAGE (integration_diagnostics_generation):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 3,235
#    Completion tokens: 12,851
#    Total tokens: 16,086
#    Estimated cost: $0.132554
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.7226890756302521, "macro_accuracy": 0.7220238095238095, "num_evaluated_records": 15, "num_evaluated_attributes": 8, "total_evaluations": 119, "total_correct": 86, "criticScore_accuracy": 0.7333333333333333, "criticScore_count": 15, "name_accuracy": 0.9333333333333333, "name_count": 15, "publisher_accuracy": 0.8, "publisher_count": 15, "platform_accuracy": 0.5333333333333333, "platform_count": 15, "developer_accuracy": 0.6, "developer_count": 15, "userScore_accuracy": 0.6428571428571429, "userScore_count": 14, "ESRB_accuracy": 0.6666666666666666, "ESRB_count": 15, "releaseYear_accuracy": 0.8666666666666667, "releaseYear_count": 15}
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/helpers/evaluation_helpers.py:110: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   fused_df = pd.read_csv(fused_path)
# [EVALUATION REPORT]
#   Stage: test
#   Attempt: 1/3
#   Overall Accuracy: 72.269%
#   Problems Detected:
#     - overall_accuracy below target: 72.269% < 85.000%
#     - low direct ID coverage: 0.000%
#   Planned Adaptation:
#     - investigator runs diagnostics report + cluster evidence analysis
#     - reasoning node proposes targeted pipeline/code changes
#     - prioritize ID alignment and singleton handling
# [*] Auto diagnostics:
# {
#   "debug_reason_counts": {
#     "mismatch": 33
#   },
#   "debug_reason_ratios": {
#     "mismatch": 1.0
#   },
#   "evaluation_stage": "test",
#   "evaluation_testset_path": "input/datasets/games/testsets/test_set.xml",
#   "id_alignment": {
#     "gold_count": 15,
#     "direct_coverage": 0,
#     "direct_coverage_ratio": 0.0,
#     "mapped_coverage": 15,
#     "mapped_coverage_ratio": 1.0,
#     "missing_gold_ids": []
#   },
#   "fusion_size_comparison": {
#     "estimate_path": "output/pipeline_evaluation/fusion_size_estimate.json",
#     "actual": {
#       "rows": 55723,
#       "unique_ids": 55723
#     },
#     "comparisons": {
#       "blocking": {
#         "expected_rows": 54427,
#         "actual_rows": 55723,
#         "rows_abs_error": 1296,
#         "rows_pct_error": 0.023811711099270584,
#         "expected_rows_matched_only": 20524,
#         "expected_rows_singleton_aware": 54427,
#         "rows_pct_error_matched_only": 1.7150165659715455,
#         "rows_pct_error_singleton_aware": 0.023811711099270584,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 54427,
#         "actual_unique_ids": 55723,
#         "unique_ids_abs_error": 1296,
#         "unique_ids_pct_error": 0.023811711099270584,
#         "reasoning": "Estimate is close to actual fused size. Blocking estimate was conservative; downstream matching/fusion retained more entities than expected.",
#         "compared_at": "2026-03-04T10:54:23.866698+00:00"
#       },
#       "matching": {
#         "expected_rows": 54363,
#         "actual_rows": 55723,
#         "rows_abs_error": 1360,
#         "rows_pct_error": 0.025017015249342384,
#         "expected_rows_matched_only": 20588,
#         "expected_rows_singleton_aware": 54363,
#         "rows_pct_error_matched_only": 1.7065766465902468,
#         "rows_pct_error_singleton_aware": 0.025017015249342384,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 54363,
#         "actual_unique_ids": 55723,
#         "unique_ids_abs_error": 1360,
#         "unique_ids_pct_error": 0.025017015249342384,
#         "reasoning": "Estimate is close to actual fused size. Matching estimate seems conservative; matcher/fusion retained more clusters than projected.",
#         "compared_at": "2026-03-04T10:54:23.866726+00:00"
#       }
#     }
#   },
#   "overall_accuracy": 0.7226890756302521
# }
# [*] Running cluster analysis helper...
# [*] Found 3 pairwise correspondence files to analyze.
#
#
# ===================
#  CLUSTER ANALYSIS
# ===================
# [*] Analyzing clusters from correspondences_dbpedia_sales.csv
#     Metrics: clusters=2284, max_size=477, small=33.98%, large=31.04%, one_to_many=74.76%
#     Recommended Strategy: AdjustMatchingConfig
# [*] Analyzing clusters from correspondences_metacritic_dbpedia.csv
#     Metrics: clusters=4759, max_size=200, small=33.28%, large=29.90%, one_to_many=69.22%
#     Recommended Strategy: AdjustMatchingConfig
# [*] Analyzing clusters from correspondences_metacritic_sales.csv
#     Metrics: clusters=5038, max_size=87, small=74.35%, large=9.15%, one_to_many=41.79%
#     Recommended Strategy: AdjustMatchingConfig
#     Overall: recommended_strategy=AdjustMatchingConfig, unhealthy_files=3
#
#     Aggregated cluster analysis report saved to output/cluster-evaluation/cluster_analysis_report.json
# TOKEN USAGE (evaluation_reasoning):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 25,850
#    Completion tokens: 2,127
#    Total tokens: 27,977
#    Estimated cost: $0.053582
# [*] Evaluation reasoning:
# ## 1) Dominant error types (from fusion evaluation debug)
#
# All 33 debug events are **attribute-level mismatches** (no missing-ID coverage issues: mapped coverage 15/15). So the dominant errors are **wrong fused attribute values inside otherwise correctly aligned clusters**.
#
# By attribute, the biggest contributors (from the JSONL list) are:
#
# - **platform**: 7 mismatches (accuracy 0.533)
#   Examples: fused `pc/ps2/3ds/ps4` when expected `PS3/PS4/Wii`.
# - **developer**: 6 mismatches (accuracy 0.6)
#   Example: fused `ios` as developer (clear schema/value leakage).
# - **userScore**: 5 mismatches (accuracy ~0.643)
#   Values are often far from expected, not just slight noise.
# - **ESRB**: 5 mismatches (accuracy 0.667)
#   Often fused as `"m"` when expected `T/E10+/AO/M17+`.
# - **criticScore**: 4 mismatches (accuracy 0.733)
# - **publisher**: 3 mismatches (accuracy 0.8)
# - **name**: 1 mismatch (but very severe: “PGA Tour 09” vs expected “10”)
# - **releaseYear**: 2 mismatches (off by 1–2 years)
#
# **Interpretation:** this looks like **cluster contamination / over-merging**: attributes are being pulled from the wrong game record within a cluster, not just normalization/formatting disagreements.
#
# ---
#
# ## 2) Most likely root causes (blocking/matching vs fusion)
#
# Per your instruction, blocking+matching configs are “already determined”; still, the evidence points to the fusion stage receiving **correspondence/cluster structures that contain multiple distinct real-world entities**, and then the fusion policy (shortest_string / median / earliest) selects values that are *internally consistent for the wrong entity*.
#
# ### Evidence that the problem is NOT blocking being too restrictive
# - Blocking pair completeness is high (0.91–1.0). Not a missed-block / false negative signature.
#
# ### Evidence that the problem is over-matching / bad correspondences feeding fusion
# - Cluster Analysis: extremely high **one-to-many ratios**
#   - dbpedia_sales: **0.7476** (very unhealthy), max cluster size **477**
#   - metacritic_dbpedia: **0.6922**, max cluster size **200**
#   - metacritic_sales: **0.4179**, max cluster size **87**
# - Those huge clusters strongly suggest ambiguous matches and entity conflation (e.g., same franchise name across platforms/years).
#
# ### Fusion-policy-specific issues amplifying the damage
# Even if correspondences are imperfect, the current fusers make wrong picks more likely:
# - `platform`, `ESRB`, `developer`, `publisher`, `name` use **`shortest_string`**
#   This is a weak canonicalization heuristic:
#   - platform: `"pc"` will often beat `"playstation 3"` by being shorter
#   - ESRB: `"m"` beats `"M17+"` / `"Teen"` etc.
#   - publisher/developer: abbreviations or generic short tokens can dominate
# - `releaseYear` uses **`earliest`**
#   If a cluster mistakenly contains entries from multiple editions/ports/sequels, earliest year will often be wrong (matches your 2008 vs expected 2009/2010 failures).
# - `criticScore`/`userScore` use **median**
#   If cluster contains multiple games, median produces plausible-but-wrong scores (matches your large deltas like 7.65 vs 4.8).
#
# ### Clear schema/preprocessing red flag
# - Developer fused as `"ios"`: that’s not a developer; that’s a **platform** value leaking into developer, or a dataset has developer column polluted.
#
# **Conclusion:** Errors are primarily caused by **fusion receiving polluted clusters** (stemming from over-matching/ambiguous correspondences) *and* a **fusion policy that picks “short”/“early” values which are systematically biased toward wrong representatives** in mixed clusters.
#
# ---
#
# ## 3) Cluster Analysis Report → what to change (focusing on fusion)
#
# The report recommends raising thresholds, but you asked to focus on fusion improvements. Given unhealthy cluster structures, fusion needs **(a) safer selection rules and (b) conflict-aware voting** so a single short token doesn’t dominate.
#
# Key cluster-analysis implications for fusion:
# - Large clusters mean you should not use “single-value heuristic” fusers (shortest/earliest) blindly.
# - One-to-many suggests many correspondences are ambiguous; fusion should prefer **source-priority or agreement-based** decisions.
#
# ---
#
# ## 4) Concrete, actionable improvements for next iteration (fusion-focused)
#
# ### A. Replace `shortest_string` with agreement/majority + trusted-source tie-breaks
# For **platform, ESRB, developer, publisher, name**:
# - Prefer **most frequent non-null value** across sources (mode/majority vote).
# - If tied, use a **source priority** (e.g., metacritic for scores/ESRB/platform; dbpedia for series/publisher; sales for globalSales).
# - Only then fall back to shortest/longest.
#
# If PyDI doesn’t ship a “mode” fuser, implement a small custom fuser in the pipeline (rule-based aggregation over the cluster’s input values) and register it via `strategy.add_attribute_fuser`.
#
# **Why it helps:** prevents `"m"`, `"pc"`, `"ps2"` from winning just because they’re short.
#
# ### B. Make platform and ESRB *normalized categorical* before fusing, then fuse by majority
# - Normalize platforms to a canonical set: `PS3, PS4, Wii, PC, 3DS, PS2, ...`
# - Normalize ESRB to canonical set: `E, E10+, T, M, AO` (and map `M17+ → M`, etc.)
# Then fuse categoricals by majority vote.
#
# **Why it helps:** reduces superficial variation so “agreement” becomes detectable.
#
# ### C. Stop using `earliest` for `releaseYear` in a multi-edition domain
# Use a more robust choice:
# - **majority year** (mode on year component), or
# - if only two sources disagree, prefer a trusted source (often sales/metacritic over dbpedia depending on dataset quality), or
# - **median year** (less sensitive than earliest when clusters are contaminated)
#
# **Why it helps:** your observed errors are “too early”, consistent with `earliest` bias.
#
# ### D. Scores: don’t fuse by median unless you first ensure the cluster is clean
# Given cluster contamination signals, scores should be:
# - **source-priority** (e.g., metacritic scores from metacritic if present), else
# - **agreement-based** (if values within tolerance across sources, average/median; if not, pick from priority source and mark low confidence)
#
# Also consider scaling consistency checks (e.g., if some source uses 0–10 vs 0–100); your large score deltas could be cross-entity, but scaling mismatches are also common.
#
# ### E. Add fusion-time “cluster sanity checks” and confidence penalties
# When a cluster has contradictory categorical values:
# - if it contains >N distinct platforms or >N distinct years, mark `_fusion_confidence` low, and/or
# - optionally **split** cluster is not available in simple fusion, but you can at least avoid taking extreme heuristics (earliest/shortest) and prefer trusted source.
#
# ### F. Fix the obvious column pollution (“developer” contains platform tokens)
# Before fusion, apply a rule:
# - if `developer` value is in a platform vocabulary (`ios`, `android`, `pc`, `ps3`, etc.), set it to null (or move it to platform if platform missing and you’re confident).
#
# This single rule likely fixes the `developer=ios` mismatch class.
#
# ---
#
# ## Normalization Recommendations
#
# These mismatches show strong categorical-normalization needs (not country/list-related in this task).
#
# 1) **platform** (all datasets): normalize to canonical tokens
#    - Target columns: `platform`
#    - Actions:
#      - uppercase, strip, map synonyms: `playstation 3|ps-3|ps3 → PS3`, `wii u → Wii U`, etc.
#      - if list-like platforms exist, normalize list elements then fuse by majority.
#
# 2) **ESRB** (all datasets): normalize ratings to canonical set
#    - Target columns: `ESRB`
#    - Actions:
#      - map: `mature|m17+|mature 17+|m → M`, `teen|t → T`, `everyone 10+|e10 → E10+`, etc.
#      - keep as categorical; fuse via majority vote / trusted-source priority.
#
# 3) **developer / publisher**: normalize organization names + abbreviations
#    - Target columns: `developer`, `publisher`
#    - Actions:
#      - map common aliases: `SCEA → Sony Computer Entertainment`, `TT Games → Traveller's Tales` (or pick one canonical)
#      - remove platform-like contaminants from developer (`ios`, etc.)
#
# 4) **list formatting normalization (if genres/series become list-like in other runs)**
#    - You already use `detect_list_like_columns / normalize_list_like_columns`; keep it enabled and ensure `platform` isn’t accidentally treated as list-concatenated text during fusion if it becomes list-like.
#
# (No country normalization needed here; no country signals in diagnostics.)
#
# ---
#
# ### Priority next-step (highest ROI)
# 1. Replace `shortest_string` for `platform`, `ESRB`, `developer`, `publisher`, `name` with **majority vote + source priority**.
# 2. Replace `earliest(releaseYear)` with **mode/median year** or **source-priority year**.
# 3. Add a preprocessing guard to null out `developer` values that look like platforms (e.g., `ios`).
#
# These changes directly target the attributes with the worst accuracies and the exact mismatch patterns shown in the debug events.
# TOKEN USAGE (investigator_normalization_assessment):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 7,761
#    Completion tokens: 391
#    Total tokens: 8,152
#    Estimated cost: $0.013611
# [*] Investigator decision: rerun normalization before next pipeline iteration
# [INVESTIGATION REPORT]
#   - overall_accuracy=72.269%, evaluation_attempt=1/3
#   - probes: reason_distribution: mismatch=1.00 | worst_attributes: platform_accuracy=0.53, developer_accuracy=0.60, userScore_accuracy=0.64, ESRB_accuracy=0.67, macro_accuracy=0.72
#   - objective: composite=0.466022 worst_pressure=0.466667 missing_penalty=0.0
#   - normalization acceptance: None (delta=None, required=None)
#   - routing score=1.058138 threshold=0.72 blocked_action_plan=False blocked_regret=False
# [*] Running normalization node
# [+] Normalization completed; using normalized datasets
# [*] Blocking config already present in state; skipping BlockingTester
# [*] Matching config already present in state; skipping MatchingTester
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 32,315
#    Completion tokens: 70
#    Total tokens: 32,385
#    Estimated cost: $0.041094
# [SEARCH TOOL CALL 1]: Asking 'PyDI fusion built-in functions list: longest_string, shortest_string, most_complete, prefer_higher_trust, union, intersection, average, median, earliest, most_recent. Is there a built-in mode/majority fuser or voting-based fuser?'
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 33,580
#    Completion tokens: 4,689
#    Total tokens: 38,269
#    Estimated cost: $0.088865
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Performing Blocking
# Matching Entities
# Fusing Data
#
# [FUSION SIZE COMPARISON]
#   blocking: expected_rows=54427 actual_rows=55749 rows_pct_error=0.024289415179965825
#   matching: expected_rows=54363 actual_rows=55749 rows_pct_error=0.02549528171734452
# [*] Running consolidated evaluation node
# [EVALUATION EXECUTION] Attempt 1/3
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 13,459
#    Completion tokens: 123
#    Total tokens: 13,582
#    Estimated cost: $0.018054
# [SEARCH TOOL CALL 1]: Asking 'How do I use PyDI.fusion.DataFusionEvaluator to evaluate a fused dataframe against a gold standard? What is the expected structure of evaluation_results?'
# [SEARCH TOOL CALL 2]: Asking 'What evaluation/match functions are available in PyDI.fusion for DataFusionStrategy.add_evaluation_function (e.g., tokenized_match, year_only_match, numeric_tolerance_match, set_equality_match) and their parameters?'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 17,197
#    Completion tokens: 2,725
#    Total tokens: 19,922
#    Estimated cost: $0.048746
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [LIST NORMALIZATION] columns: genres_genre
# [ID ALIGNMENT] direct _id coverage: 0/15
# [ID ALIGNMENT] mapped eval_id coverage: 15/15
# [EVAL FUNCTIONS] ESRB:tokenized_match(threshold=0.8) | criticScore:numeric_tolerance_match(tolerance=5.0) | developer:tokenized_match(threshold=0.75) | genres_genre:set_equality_match | globalSales:numeric_tolerance_match(tolerance=0.1) | name:tokenized_match(threshold=0.85) | platform:tokenized_match(threshold=0.75) | publisher:tokenized_match(threshold=0.8) | releaseYear:year_only_match | userScore:numeric_tolerance_match(tolerance=0.5)
#
# === FUSION EVALUATION METRICS (structured) ===
# {
#   "ESRB_accuracy": 0.8,
#   "ESRB_count": 15,
#   "criticScore_accuracy": 0.7333333333333333,
#   "criticScore_count": 15,
#   "developer_accuracy": 0.7333333333333333,
#   "developer_count": 15,
#   "macro_accuracy": 0.7541666666666667,
#   "name_accuracy": 0.6,
#   "name_count": 15,
#   "num_evaluated_attributes": 8,
#   "num_evaluated_records": 15,
#   "overall_accuracy": 0.7563025210084033,
#   "platform_accuracy": 0.8,
#   "platform_count": 15,
#   "publisher_accuracy": 0.8666666666666667,
#   "publisher_count": 15,
#   "releaseYear_accuracy": 1.0,
#   "releaseYear_count": 15,
#   "total_correct": 90,
#   "total_evaluations": 119,
#   "userScore_accuracy": 0.5,
#   "userScore_count": 14
# }
#
# [EVALUATION STDERR]
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/evaluation.py:201: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   fused = pd.read_csv(FUSED_PATH)
#
# [EVALUATION EXECUTION] Status: success
# [*] Running consolidated investigator node
# [*] Running free integration diagnostics
# TOKEN USAGE (integration_diagnostics_generation):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 13,434
#    Completion tokens: 12,620
#    Total tokens: 26,054
#    Estimated cost: $0.142992
# [*] Reading evaluation metrics
# [EVALUATION GUARD] Rejected regressive validation metrics; keeping best-known validation metrics
# Evaluation metrics: {"overall_accuracy": 0.7226890756302521, "macro_accuracy": 0.7220238095238095, "num_evaluated_records": 15, "num_evaluated_attributes": 8, "total_evaluations": 119, "total_correct": 86, "criticScore_accuracy": 0.7333333333333333, "criticScore_count": 15, "name_accuracy": 0.9333333333333333, "name_count": 15, "publisher_accuracy": 0.8, "publisher_count": 15, "platform_accuracy": 0.5333333333333333, "platform_count": 15, "developer_accuracy": 0.6, "developer_count": 15, "userScore_accuracy": 0.6428571428571429, "userScore_count": 14, "ESRB_accuracy": 0.6666666666666666, "ESRB_count": 15, "releaseYear_accuracy": 0.8666666666666667, "releaseYear_count": 15}
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/helpers/evaluation_helpers.py:110: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   fused_df = pd.read_csv(fused_path)
# [EVALUATION REPORT]
#   Stage: test
#   Attempt: 2/3
#   Overall Accuracy: 72.269%
#   Problems Detected:
#     - overall_accuracy below target: 72.269% < 85.000%
#     - regression guard rejected latest candidate: overall_drop=-0.033613, macro_drop=-0.032143, top_attribute_drops={'name': 0.333333, 'userScore': 0.142857}
#     - low direct ID coverage: 0.000%
#   Planned Adaptation:
#     - investigator runs diagnostics report + cluster evidence analysis
#     - reasoning node proposes targeted pipeline/code changes
#     - prioritize ID alignment and singleton handling
# [*] Auto diagnostics:
# {
#   "debug_reason_counts": {
#     "mismatch": 29
#   },
#   "debug_reason_ratios": {
#     "mismatch": 1.0
#   },
#   "evaluation_stage": "test",
#   "evaluation_testset_path": "input/datasets/games/testsets/test_set.xml",
#   "id_alignment": {
#     "gold_count": 15,
#     "direct_coverage": 0,
#     "direct_coverage_ratio": 0.0,
#     "mapped_coverage": 15,
#     "mapped_coverage_ratio": 1.0,
#     "missing_gold_ids": []
#   },
#   "fusion_size_comparison": {
#     "estimate_path": "output/pipeline_evaluation/fusion_size_estimate.json",
#     "actual": {
#       "rows": 55749,
#       "unique_ids": 55749
#     },
#     "comparisons": {
#       "blocking": {
#         "expected_rows": 54427,
#         "actual_rows": 55749,
#         "rows_abs_error": 1322,
#         "rows_pct_error": 0.024289415179965825,
#         "expected_rows_matched_only": 20524,
#         "expected_rows_singleton_aware": 54427,
#         "rows_pct_error_matched_only": 1.7162833755603197,
#         "rows_pct_error_singleton_aware": 0.024289415179965825,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 54427,
#         "actual_unique_ids": 55749,
#         "unique_ids_abs_error": 1322,
#         "unique_ids_pct_error": 0.024289415179965825,
#         "reasoning": "Estimate is close to actual fused size. Blocking estimate was conservative; downstream matching/fusion retained more entities than expected.",
#         "compared_at": "2026-03-04T11:07:56.507969+00:00"
#       },
#       "matching": {
#         "expected_rows": 54363,
#         "actual_rows": 55749,
#         "rows_abs_error": 1386,
#         "rows_pct_error": 0.02549528171734452,
#         "expected_rows_matched_only": 20588,
#         "expected_rows_singleton_aware": 54363,
#         "rows_pct_error_matched_only": 1.7078395181659218,
#         "rows_pct_error_singleton_aware": 0.02549528171734452,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 54363,
#         "actual_unique_ids": 55749,
#         "unique_ids_abs_error": 1386,
# ...
#    - Prefer pairs with highest score
#    - Enforce at most one node per dataset (dbpedia/metacritic/sales) in the final fused group
#    - If multiple candidates from same dataset exist, keep the one that best agrees on:
#      - platform (exact/canonical match)
#      - releaseYear (same year)
#      - high name similarity (token Jaccard/Jaro)
#
# Outcome: you keep your matchers, but prevent “A matches B1 and B2; B2 matches C” from creating a polluted 3-way cluster.
#
# ### B. Make fusion conditional on agreement (“inlier voting”), not raw voting
# For attributes most harmed by contamination:
# - **platform, ESRB, releaseYear, scores**
# Use a rule like:
# - compute consensus subset = records within cluster whose (platform, year) match the modal (platform, year)
# - fuse only across that subset
# If no subset reaches a minimum support (e.g., ≥2 sources or ≥60% of members), fall back to:
# - single best source (metacritic for scores; sales for globalSales)
# - or keep null rather than wrong value
#
# ### C. Safer title fusion
# Replace `name = most_complete` with a “best-supported name” strategy:
# - choose the name with **highest average similarity to other names in the cluster** (medoid-like)
# - tie-break by non-null + length
# This avoids picking a long but unrelated title.
#
# ### D. Fix score fusion amplification
# Keep `favour_sources`, but only if the chosen source row is consistent with cluster disambiguators:
# - If metacritic row’s platform/year disagrees with modal platform/year, **do not favour it**; use median of consistent subset.
#
# ### E. Canonicalize org abbreviations (developer/publisher) before fusion
# Add lightweight mapping tables (domain-specific, small but impactful):
# - publisher: `SCEA -> Sony Computer Entertainment`, `SCE -> Sony Computer Entertainment`, etc.
# - developer: `TT Fusion -> Traveller's Tales` (or normalize both to a canonical label)
# This will raise developer/publisher accuracies *when clusters are correct*.
#
# ### F. Ensure `_fusion_sources` and `_fusion_source_datasets` are valid JSON arrays
# This is critical for auditing and for future “inlier” fusion logic that depends on reliable lineage.
# - Store these fields as `json.dumps(list_of_ids)` / `json.dumps(list_of_dataset_names)` consistently.
#
# ---
#
# ## Normalization Recommendations
#
# 1) **List formatting normalization (mandatory for lineage/auditing)**
# - Target columns (from diagnostics): **`_fusion_sources`**, **`_fusion_source_datasets`**
# - Action: ensure they are emitted as proper JSON arrays (not malformed strings). If you post-process, use `detect_list_like_columns / normalize_list_like_columns` on the fused output (or better: fix at creation time).
#
# 2) **Organization name normalization**
# - Target columns: **`publisher`**, **`developer`**
# - Action: apply canonical mapping for common abbreviations/aliases:
#   - `SCEA` ↔ `Sony Computer Entertainment`
#   - `Koei` ↔ `Tecmo Koei` (decide one canonical)
#   - `TT Fusion` ↔ `Traveller's Tales`
#   - Strip region/division qualifiers where needed (e.g., “SCEE London Studio” → “London Studio”) via regex rules.
#
# 3) **ESRB normalization tightening**
# - Target column: **`ESRB`**
# - Your `_norm_esrb_value` maps `m17+ -> M`, but gold sometimes contains `M17+`.
# - Decide on one canonical representation aligned to gold (if gold uses `M17+`, keep it instead of collapsing to `M`). This is a pure normalization win independent of matching.
#
# (There are no country columns here; `normalize_country` is not relevant for this pipeline.)
#
# ---
#
# ### Net assessment
# - **Dominant error type:** false positives/over-clustering leading to wrong-entity fusion (cross-title/platform/score swaps).
# - **Most likely root cause:** correspondence graph induces impure multi-entity clusters (transitive effects across pairwise MBM), and fusion rules (voting/most_complete/favour_sources) amplify those mistakes.
# - **Next iteration priority:** add **fusion-stage cluster purification + consistency-gated fusion**, and fix lineage list encoding for auditability.
# TOKEN USAGE (investigator_normalization_assessment):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 12,946
#    Completion tokens: 310
#    Total tokens: 13,256
#    Estimated cost: $0.019283
# [*] Investigator decision: rerun normalization before next pipeline iteration
# [INVESTIGATION REPORT]
#   - overall_accuracy=72.269%, evaluation_attempt=2/3
#   - probes: reason_distribution: mismatch=1.00 | worst_attributes: platform_accuracy=0.53, developer_accuracy=0.60, userScore_accuracy=0.64, ESRB_accuracy=0.67, macro_accuracy=0.72 | recent_mismatches: reasons[mismatch:29] attrs[userScore:7, name:6, criticScore:4] | directive_coverage: dbpedia: esrb, publisher; metacritic: publisher
#   - objective: composite=0.466022 worst_pressure=0.466667 missing_penalty=0.0
#   - normalization acceptance: None (delta=None, required=None)
#   - routing score=1.033638 threshold=0.72 blocked_action_plan=False blocked_regret=False
# [*] Running normalization node
# [+] Normalization completed; using normalized datasets
# [*] Blocking config already present in state; skipping BlockingTester
# [*] Matching config already present in state; skipping MatchingTester
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 38,993
#    Completion tokens: 42
#    Total tokens: 39,035
#    Estimated cost: $0.049161
# [SEARCH TOOL CALL 1]: Asking 'PyDI.fusion favour_sources usage: expected signature and how it selects values; how sources list is interpreted (dataset name?)'
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 40,409
#    Completion tokens: 5,826
#    Total tokens: 46,235
#    Estimated cost: $0.108771
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Performing Blocking
# Matching Entities
# Fusing Data
#
# [PIPELINE STDERR]
# '(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')), '(Request ID: 1c0a3c34-5d5b-4b25-b035-b8cce9d7f896)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/./modules.json
# Retrying in 1s [Retry 1/5].
#
# [FUSION SIZE COMPARISON]
#   blocking: expected_rows=54427 actual_rows=55745 rows_pct_error=0.02421592224447425
#   matching: expected_rows=54363 actual_rows=55745 rows_pct_error=0.025421702260728804
# [*] Running consolidated evaluation node
# [EVALUATION EXECUTION] Attempt 1/3
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 14,173
#    Completion tokens: 177
#    Total tokens: 14,350
#    Estimated cost: $0.019486
# [SEARCH TOOL CALL 1]: Asking 'DataFusionEvaluator usage: expected format of evaluation_results and how to print metrics; how to add evaluation functions with DataFusionStrategy.add_evaluation_function'
# [SEARCH TOOL CALL 2]: Asking 'tokenized_match, year_only_match, numeric_tolerance_match, set_equality_match: signatures and recommended kwargs (threshold etc.)'
# [SEARCH TOOL CALL 3]: Asking 'PyDI.io.load_xml parameters for test_set.xml and how nested_handling='aggregate' structures list-like columns'
# [SEARCH TOOL CALL 4]: Asking 'DataFusionStrategy vs DataFusionEngine: how to ensure correct fusion strategy name for evaluation; any requirement to match fusers?'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 21,093
#    Completion tokens: 2,706
#    Total tokens: 23,799
#    Estimated cost: $0.053426
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [ID ALIGNMENT] direct _id coverage: 0/15
# [ID ALIGNMENT] mapped eval_id coverage: 15/15
# [EVAL FUNCTIONS] ESRB:tokenized_match(threshold=0.9) | criticScore:numeric_tolerance_match(tolerance=5.0) | developer:tokenized_match(threshold=0.8) | genres_genre:set_equality_match | globalSales:numeric_tolerance_match(tolerance=1.0) | name:tokenized_match(threshold=0.85) | platform:tokenized_match(threshold=0.9) | publisher:tokenized_match(threshold=0.8) | releaseYear:year_only_match | series:tokenized_match(threshold=0.8) | userScore:numeric_tolerance_match(tolerance=0.5)
#
# === Data Fusion Evaluation Metrics ===
# overall_accuracy: 0.6302521008403361
# macro_accuracy: 0.6285714285714286
# ESRB_accuracy: 0.8
# ESRB_count: 15
# criticScore_accuracy: 0.6666666666666666
# criticScore_count: 15
# developer_accuracy: 0.6
# developer_count: 15
# name_accuracy: 0.7333333333333333
# name_count: 15
# num_evaluated_attributes: 8
# num_evaluated_records: 15
# platform_accuracy: 0.9333333333333333
# platform_count: 15
# publisher_accuracy: 0.8666666666666667
# publisher_count: 15
# releaseYear_accuracy: 0.0
# releaseYear_count: 15
# total_correct: 75
# total_evaluations: 119
# userScore_accuracy: 0.42857142857142855
# userScore_count: 14
# =====================================
#
#
# [EVALUATION STDERR]
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/evaluation.py:197: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   fused = pd.read_csv(FUSED_PATH)
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/evaluation.py:159: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   fused_df[c] = pd.to_numeric(fused_df[c], errors="ignore")
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/evaluation.py:161: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   gold_df[c] = pd.to_numeric(gold_df[c], errors="ignore")
#
# [EVALUATION EXECUTION] Status: success
# [*] Running consolidated investigator node
# [*] Running free integration diagnostics
# TOKEN USAGE (integration_diagnostics_generation):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 13,215
#    Completion tokens: 13,527
#    Total tokens: 26,742
#    Estimated cost: $0.151789
# [*] Reading evaluation metrics
# [EVALUATION GUARD] Rejected regressive validation metrics; keeping best-known validation metrics
# Evaluation metrics: {"overall_accuracy": 0.7226890756302521, "macro_accuracy": 0.7220238095238095, "num_evaluated_records": 15, "num_evaluated_attributes": 8, "total_evaluations": 119, "total_correct": 86, "criticScore_accuracy": 0.7333333333333333, "criticScore_count": 15, "name_accuracy": 0.9333333333333333, "name_count": 15, "publisher_accuracy": 0.8, "publisher_count": 15, "platform_accuracy": 0.5333333333333333, "platform_count": 15, "developer_accuracy": 0.6, "developer_count": 15, "userScore_accuracy": 0.6428571428571429, "userScore_count": 14, "ESRB_accuracy": 0.6666666666666666, "ESRB_count": 15, "releaseYear_accuracy": 0.8666666666666667, "releaseYear_count": 15}
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/helpers/evaluation_helpers.py:110: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   fused_df = pd.read_csv(fused_path)
# [EVALUATION REPORT]
#   Stage: test
#   Attempt: 3/3
#   Overall Accuracy: 72.269%
#   Problems Detected:
#     - overall_accuracy below target: 72.269% < 85.000%
#     - regression guard rejected latest candidate: overall_drop=0.092437, macro_drop=0.093452, top_attribute_drops={'releaseYear': 0.866667, 'userScore': 0.214286, 'name': 0.2, 'criticScore': 0.066667}
#     - low direct ID coverage: 0.000%
#     - high missing_fused_value mismatch ratio: 34.091%
#   Planned Adaptation:
#     - max automatic iterations reached; stop adaptation loop
# [*] Auto diagnostics:
# {
#   "debug_reason_counts": {
#     "mismatch": 29,
#     "missing_fused_value": 15
#   },
#   "debug_reason_ratios": {
#     "mismatch": 0.6590909090909091,
#     "missing_fused_value": 0.3409090909090909
#   },
#   "evaluation_stage": "test",
#   "evaluation_testset_path": "input/datasets/games/testsets/test_set.xml",
#   "id_alignment": {
#     "gold_count": 15,
#     "direct_coverage": 0,
#     "direct_coverage_ratio": 0.0,
#     "mapped_coverage": 15,
#     "mapped_coverage_ratio": 1.0,
#     "missing_gold_ids": []
#   },
#   "fusion_size_comparison": {
#     "estimate_path": "output/pipeline_evaluation/fusion_size_estimate.json",
#     "actual": {
#       "rows": 55745,
#       "unique_ids": 55745
#     },
#     "comparisons": {
#       "blocking": {
#         "expected_rows": 54427,
#         "actual_rows": 55745,
#         "rows_abs_error": 1318,
#         "rows_pct_error": 0.02421592224447425,
#         "expected_rows_matched_only": 20524,
#         "expected_rows_singleton_aware": 54427,
#         "rows_pct_error_matched_only": 1.7160884817774313,
#         "rows_pct_error_singleton_aware": 0.02421592224447425,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 54427,
#         "actual_unique_ids": 55745,
#         "unique_ids_abs_error": 1318,
#         "unique_ids_pct_error": 0.02421592224447425,
#         "reasoning": "Estimate is close to actual fused size. Blocking estimate was conservative; downstream matching/fusion retained more entities than expected.",
#         "compared_at": "2026-03-04T11:39:37.750087+00:00"
#       },
#       "matching": {
#         "expected_rows": 54363,
#         "actual_rows": 55745,
#         "rows_abs_error": 1382,
#         "rows_pct_error": 0.025421702260728804,
#         "expected_rows_matched_only": 20588,
#         "expected_rows_singleton_aware": 54363,
#         "rows_pct_error_matched_only": 1.7076452302312026,
#         "rows_pct_error_singleton_aware": 0.025421702260728804,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 54363,
#         "actual_unique_ids": 55745,
#         "unique_ids_abs_error": 1382,
#         "unique_ids_pct_error": 0.025421702260728804,
#         "reasoning": "Estimate is close to actual fused size. Matching estimate seems conservative; matcher/fusion retained more clusters than projected.",
#         "compared_at": "2026-03-04T11:39:37.750101+00:00"
#       }
#     }
#   },
#   "overall_accuracy": 0.7226890756302521
# }
# TOTAL TOKEN USAGE:
#    Prompt tokens: 2,218,523
#    Completion tokens: 533,926
#    Total tokens: 2,752,449
#    Estimated cost: $8.112414
# [*] Investigator decision: proceed to human review
# [INVESTIGATION REPORT]
#   - overall_accuracy=72.269%, evaluation_attempt=3/3
#   - probes: reason_distribution: mismatch=0.66, missing_fused_value=0.34 | worst_attributes: platform_accuracy=0.53, developer_accuracy=0.60, userScore_accuracy=0.64, ESRB_accuracy=0.67, macro_accuracy=0.72
#   - objective: composite=0.312613 worst_pressure=0.466667 missing_penalty=0.340909
#   - normalization acceptance: None (delta=None, required=None)
# [*] Building final human-review package
# TOKEN USAGE (human_review_export_generation):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 8,158
#    Completion tokens: 6,332
#    Total tokens: 14,490
#    Estimated cost: $0.073517
# [*] Human-review export completed
# [+] Results saved to: output/results/run_20260304_124400.json
# [+] Run audit saved to: output/results/run_audit_20260304_124400.json
# [+] Run report saved to: output/results/run_report_20260304_124400.md
# [*] Games run complete
# {
#   "validation_overall_accuracy": 0.7226890756302521,
#   "sealed_test_overall_accuracy": null,
#   "normalization_attempts": 3,
#   "evaluation_attempts": 3,
#   "run_id": "20260303_125833_844806",
#   "run_output_root": "output/runs/20260303_125833_844806",
#   "run_audit_path": "output/results/run_audit_20260304_124400.json",
#   "run_report_path": "output/results/run_report_20260304_124400.md"
# }
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Run Music use case (assumes `agent` is already created)

import json

INPUT_DIR = globals().get("INPUT_DIR", "input/")

entity_matching_testsets = {
    ("discogs", "lastfm"): INPUT_DIR + "datasets/music/testsets/discogs_lastfm_goldstandard_blocking.csv",
    ("discogs", "musicbrainz"): INPUT_DIR + "datasets/music/testsets/discogs_musicbrainz_goldstandard_blocking.csv",
    ("musicbrainz", "lastfm"): INPUT_DIR + "datasets/music/testsets/musicbrainz_lastfm_goldstandard_blocking.csv",
}

datasets = [
    INPUT_DIR + "datasets/music/discogs.xml",
    INPUT_DIR + "datasets/music/lastfm.xml",
    INPUT_DIR + "datasets/music/musicbrainz.xml",
]

fusion_testset = INPUT_DIR + "datasets/music/testsets/test_set.xml"
validation_fusion_testset = INPUT_DIR + "datasets/music/testsets/validation_set.xml"

SKIP_BLOCKING_TESTER = False
SKIP_MATCHING_TESTER = False

payload = {
    "datasets": datasets,
    "original_datasets": list(datasets),
    "normalized_datasets": [],
    "entity_matching_testsets": entity_matching_testsets,
    "fusion_testset": fusion_testset,
    "validation_fusion_testset": validation_fusion_testset,
    "matcher_mode": "rulebased",
    "evaluation_attempts": 0,
    "normalization_attempts": 0,
    "normalization_execution_result": "",
    "normalization_rework_required": False,
    "normalization_rework_reasons": [],
    "normalization_directives": {},
    "investigator_decision": "",
}

print("[*] Starting music run...")
RESULT = agent.graph.invoke(payload, config={"recursion_limit": 200})
print("[*] Music run complete")

print(json.dumps({
    "investigator_decision": RESULT.get("investigator_decision"),
    "validation_overall_accuracy": (RESULT.get("evaluation_metrics") or {}).get("overall_accuracy"),
    "sealed_test_overall_accuracy": (RESULT.get("sealed_test_metrics_final") or {}).get("overall_accuracy"),
    "normalization_attempts": RESULT.get("normalization_attempts"),
    "evaluation_attempts": RESULT.get("evaluation_attempts"),
    "run_id": RESULT.get("run_id"),
    "run_output_root": RESULT.get("run_output_root"),
    "run_audit_path": RESULT.get("run_audit_path"),
    "run_report_path": RESULT.get("run_report_path"),
}, indent=2, default=str))
# Out:
# [*] Starting music run...
# [*] Running schema matching
# [*] Schema alignment columns:
#     discogs: ['id', 'name', 'artist', 'release-date', 'release-country', 'duration', 'label', 'genre', 'tracks_track_name', 'tracks_track_position', 'tracks_track_duration']
#     lastfm: ['id', 'name', 'artist', 'duration', 'tracks_track_name', 'tracks_track_duration', 'tracks_track_position']
#     musicbrainz: ['id', 'name', 'artist', 'release-date', 'release-country', 'duration', 'tracks_track_name', 'tracks_track_duration', 'tracks_track_position']
# [*] Profiling datasets
# TOKEN USAGE (profile_data):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 287
#    Completion tokens: 82
#    Total tokens: 369
#    Estimated cost: $0.001179
# [*] Running normalization node
# [+] Normalization completed; using normalized datasets
# [*] Running BlockingTester
# [*] Loading dataset: discogs
# [*] Loading dataset: lastfm
# [*] Loading dataset: musicbrainz
# [*] Loading gold standard for discogs <-> lastfm
#     Loaded 100 ground truth pairs (positives: 56, negatives/other: 44)
# [*] Loading gold standard for discogs <-> musicbrainz
#     Loaded 100 ground truth pairs (positives: 80, negatives/other: 20)
# [*] Loading gold standard for musicbrainz <-> lastfm
#     Loaded 100 ground truth pairs (positives: 79, negatives/other: 21)
# [*] Adaptive max_candidates set to 542,856 (r=0.35%, median_pairs=107,772,401)
#
# ============================================================
# 🤖 BLOCKING: discogs <-> lastfm
# ============================================================
# Gold pairs: 100, PC threshold: 0.9
# Candidate limit: 542,856 (hard: 624,284 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 22,627 × 9,865 = 223,215,355 potential pairs
# Common columns: ['tracks_track_position', 'name', 'duration', 'tracks_track_name', 'artist', 'tracks_track_duration']
# Guardrails: strategies=['exact_match_multi', 'exact_match_single', 'semantic_similarity'], preferred_columns=['name', 'duration', 'artist', 'tracks_track_name']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['artist', 'name']
#   Params: {}
#   Reasoning: N×M is very large (223M) with a strict max-candidates cap (~543k), so we need a very restrictive blo...
#     Standard (artist+name): 1,241 candidates
#     ⚠️ PC=0.3571, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['artist', 'name', 'tracks_track_name']
#   Params: {'top_k': 20}
#   Reasoning: Exact match on ['artist','name'] was too restrictive (PC=0.357). For Discogs↔Last.fm, titles often i...
#     Embedding (artist+name+tracks_track_name, k=20): 452,045 candidates
#     ⚠️ PC=0.7143, RR=0.9980
#
# --- Attempt 3/5 ---
# LLM chose: semantic_similarity on ['name', 'artist', 'tracks_track_duration']
#   Params: {'top_k': 20}
#   Reasoning: Previous semantic_similarity on (artist,name,tracks_track_name) reached PC=0.714 with candidates wit...
#     Embedding (name+artist+tracks_track_duration, k=20): 452,105 candidates
#     ⚠️ PC=0.8929, RR=0.9980
#
# --- Attempt 4/5 ---
# LLM chose: semantic_similarity on ['name', 'artist', 'duration']
#   Params: {'top_k': 20}
#   Reasoning: Exact matching was far too restrictive (PC=0.357). Prior semantic runs got close (PC=0.893) using tr...
#     Embedding (name+artist+duration, k=20): 451,490 candidates
#     ✅ PC=0.9643, RR=0.9980
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: discogs <-> musicbrainz
# ============================================================
# Gold pairs: 100, PC threshold: 0.9
# Candidate limit: 542,856 (hard: 624,284 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 22,627 × 4,763 = 107,772,401 potential pairs
# Common columns: ['tracks_track_position', 'name', 'release-date', 'duration', 'tracks_track_name', 'release-country', 'artist', 'tracks_track_duration']
# Guardrails: strategies=['exact_match_multi', 'exact_match_single', 'semantic_similarity'], preferred_columns=['release-date', 'release-country', 'tracks_track_position', 'name']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['name', 'artist', 'release-date']
#   Params: {}
#   Reasoning: With 107.8M possible pairs and a 542,856 max-candidate cap, we need a very restrictive blocker. Exac...
#     Standard (name+artist+release-date): 1,340 candidates
#     ⚠️ PC=0.3375, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['name', 'artist', 'release-date']
#   Params: {'top_k': 20}
#   Reasoning: Exact match on (name, artist, release-date) was too restrictive (PC=0.338). Use semantic_similarity ...
#     Embedding (name+artist+release-date, k=20): 450,711 candidates
#     ✅ PC=0.9500, RR=0.9958
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: musicbrainz <-> lastfm
# ============================================================
# Gold pairs: 100, PC threshold: 0.9
# Candidate limit: 542,856 (hard: 624,284 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 4,763 × 9,865 = 46,986,995 potential pairs
# Common columns: ['tracks_track_position', 'name', 'duration', 'tracks_track_name', 'artist', 'tracks_track_duration']
# Guardrails: strategies=['exact_match_multi', 'exact_match_single', 'token_blocking', 'semantic_similarity'], preferred_columns=['name', 'duration', 'tracks_track_name', 'tracks_track_duration']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['artist', 'name']
#   Params: {}
#   Reasoning: N×M (~47M) is large with a tight candidate cap (~543k), so we need a restrictive fast block. Exact m...
#     Standard (artist+name): 748 candidates
#     ⚠️ PC=0.4177, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['name', 'artist', 'duration']
#   Params: {'top_k': 20}
#   Reasoning: Exact match on (artist,name) was too restrictive (low PC). To capture fuzzy variations like prefixes...
#     Embedding (name+artist+duration, k=20): 95,134 candidates
#     ✅ PC=0.9367, RR=0.9980
# ✅ Found acceptable strategy!
#
# ============================================================
# 📊 RESULTS SUMMARY: 3 pairs evaluated
# ============================================================
#   ✅ discogs_lastfm: PC=0.9643, candidates=451,490, strategy=semantic_similarity
#   ✅ discogs_musicbrainz: PC=0.9500, candidates=450,711, strategy=semantic_similarity
#   ✅ musicbrainz_lastfm: PC=0.9367, candidates=95,134, strategy=semantic_similarity
# [*] Blocking fused-size estimate: rows=27233, unique_ids=27233
# [*] Blocking estimate breakdown: matched_only_rows=10022, singleton_aware_rows=27233
# [*] Fused-size report updated: /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/pipeline_evaluation/fusion_size_estimate.json
#
# 💾 Config saved to: output/blocking-evaluation/blocking_config.json
# [*] Blocking config computed:
# {
#   "blocking_strategies": {
#     "discogs_lastfm": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "artist",
#         "duration"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.9642857142857143,
#       "num_candidates": 451490,
#       "is_acceptable": true,
#       "failure_tags": [
#         "ok"
#       ]
#     },
#     "discogs_musicbrainz": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "artist",
#         "release-date"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.95,
#       "num_candidates": 450711,
#       "is_acceptable": true,
#       "failure_tags": [
#         "ok"
#       ]
#     },
#     "musicbrainz_lastfm": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "artist",
#         "duration"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.9367088607594937,
#       "num_candidates": 95134,
#       "is_acceptable": true,
#       "failure_tags": [
#         "ok"
#       ]
#     }
#   },
#   "id_columns": {
#     "discogs": "id",
#     "lastfm": "id",
#     "musicbrainz": "id"
#   },
#   "dataset_signature": "discogs|lastfm|musicbrainz",
#   "dataset_names": [
#     "discogs",
#     "lastfm",
#     "musicbrainz"
#   ],
#   "pc_threshold": 0.9,
#   "max_candidates": 542856,
#   "candidate_tolerance": 0.15,
#   "llm_trace_path": "output/blocking-evaluation/llm_blocking_trace.jsonl",
#   "fusion_size_estimate": {
#     "stage": "blocking",
#     "dataset_signature": "discogs|lastfm|musicbrainz",
#     "datasets": [
#       "discogs",
#       "lastfm",
#       "musicbrainz"
#     ],
#     "method": "3-way inclusion-exclusion over pair estimates: E=E12+E13+E23-2*E123, with E123 estimated from per-dataset overlap probabilities; singleton-aware projection applied for final fused output (include_singletons=True assumption)",
#     "expected_rows": 27233,
#     "expected_unique_ids": 27233,
#     "expected_rows_range": [
#       18755,
#       27679
#     ],
#     "expected_unique_ids_range": [
#       18755,
#       27679
#     ],
#     "three_way_intersection": {
#       "enabled": true,
#       "datasets": [
#         "discogs",
#         "lastfm",
#         "musicbrainz"
#       ],
#       "pair_cluster_estimates": {
#         "discogs_lastfm": 9513,
#         "discogs_musicbrainz": 4525,
#         "lastfm_musicbrainz": 4462
#       },
#       "triple_intersection_estimates": {
#         "via_discogs": 1902.4318292305652,
#         "via_lastfm": 4302.788241256969,
#         "via_musicbrainz": 4239.040520680243,
#         "median_used": 4239.040520680243,
#         "final_triple_intersection": 4239,
#         "triple_intersection_range": [
#           0,
#           4462
#         ]
#       },
#       "expected_union_clusters": 10022,
#       "expected_union_range": [
#         9576,
#         18500
#       ],
#       "formula": "E_union = E12 + E13 + E23 - 2*E123"
#     },
#     "pair_estimates": [
#       {
#         "pair_key": "discogs_lastfm",
#         "left_dataset": "discogs",
#         "right_dataset": "lastfm",
#         "min_pair_size": 9865,
#         "pair_completeness": 0.9642857142857143,
#         "expected_cluster_count": 9513
#       },
#       {
#         "pair_key": "discogs_musicbrainz",
#         "left_dataset": "discogs",
#         "right_dataset": "musicbrainz",
#         "min_pair_size": 4763,
#         "pair_completeness": 0.95,
#         "expected_cluster_count": 4525
#       },
#       {
#         "pair_key": "musicbrainz_lastfm",
#         "left_dataset": "lastfm",
#         "right_dataset": "musicbrainz",
#         "min_pair_size": 4763,
#         "pair_completeness": 0.9367088607594937,
#         "expected_cluster_count": 4462
#       }
#     ],
#     "created_at": "2026-03-04T11:50:53.610042+00:00",
#     "expected_rows_matched_only": 10022,
#     "expected_unique_ids_matched_only": 10022,
#     "expected_rows_matched_only_range": [
#       9576,
#       18500
#     ],
#     "expected_unique_ids_matched_only_range": [
#       9576,
#       18500
#     ],
#     "expected_rows_singleton_aware": 27233,
#     "expected_unique_ids_singleton_aware": 27233,
#     "expected_rows_singleton_aware_range": [
#       18755,
#       27679
#     ],
#     "expected_unique_ids_singleton_aware_range": [
#       18755,
#       27679
#     ],
#     "singleton_assumption": {
#       "assumed_include_singletons": true,
#       "total_input_rows": 37255,
#       "formula": "E_final_rows = total_input_rows - E_matched_clusters",
#       "notes": "Conservative singleton-aware estimate: each expected matched cluster reduces the final row count by at least one."
#     }
#   }
# }
# [*] Using MatchingTester module: /Users/nickblazek/Desktop/Agent_Pipeline/agents/matching_tester.py
# [*] Running MatchingTester
# [*] Loading dataset: discogs
# [*] Loading dataset: lastfm
# [*] Loading dataset: musicbrainz
# [*] Normalized list-like columns for matching: tracks_track_duration, tracks_track_name, tracks_track_position
# [*] Loading matching gold standard for discogs <-> lastfm
#     Loaded 100 ground truth pairs
# [*] Loading matching gold standard for discogs <-> musicbrainz
#     Loaded 100 ground truth pairs
# [*] Loading matching gold standard for musicbrainz <-> lastfm
#     Loaded 100 ground truth pairs
#
# ==================================================
# MATCHING EVALUATION
# ==================================================
#
# ==================================================
# MATCHING: discogs <-> lastfm
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'artist', 'duration']
# Guardrails preferred columns: ['name', 'duration', 'artist']
# Candidates: full=451,490, proxy_sample=60,000 (margin=0.015)
#
# --- Attempt 1/4 ---
# Comparators: ['name:cosine', 'artist:jaro_winkler', 'duration:5.0']
# Weights: [0.5, 0.3, 0.2]
# Threshold: 0.72
#     Reasoning: Use all blocking/preferred scalar columns. Name is most informative but may include artist text, so token-based cosine with lowercase/strip helps. Artist is short and benefits from typo-tolerant Jaro-Winkler. Duration is numeric but has high nulls on the right, so keep a small weight and tight tolerance.
#     Reasoning (100c): Use all blocking/preferred scalar columns. Name is most informative but may include artist text, so
#     Proxy stage: F1=0.1639, required>=0.0300 -> run full
# SUCCESS: F1=0.8163
#
# ==================================================
# MATCHING: discogs <-> musicbrainz
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'artist', 'release-date']
# Guardrails preferred columns: ['release-date', 'release-country']
# Candidates: full=450,711, proxy_sample=60,000 (margin=0.015)
#
# --- Attempt 1/4 ---
# Comparators: ['name:cosine', 'artist:jaro_winkler', 'release-date:365', 'release-country:jaro_winkler']
# Weights: [0.4, 0.3, 0.2, 0.1]
# Threshold: 0.75
#     Reasoning: Use blocking identifiers (name, artist, release-date) as primary signals: name benefits from token-based cosine for longer titles, artist from typo-tolerant jaro_winkler. Release-date (preferred + blocking) anchors matches within 1 year to handle partial/approximate dates. Release-country (preferred) is a light disambiguator due to higher nulls and limited cardinality.
#     Reasoning (100c): Use blocking identifiers (name, artist, release-date) as primary signals: name benefits from token-b
#     Proxy stage: F1=0.2418, required>=0.0300 -> run full
# SUCCESS: F1=0.8732
#
# ==================================================
# MATCHING: musicbrainz <-> lastfm
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'artist', 'duration']
# Guardrails preferred columns: ['name']
# Candidates: full=94,519, proxy_sample=60,000 (margin=0.015)
#
# --- Attempt 1/4 ---
# Comparators: ['name:cosine', 'artist:jaro_winkler']
# Weights: [0.7, 0.3]
# Threshold: 0.78
#     Reasoning: Use preferred/blocking columns. Track 'name' can contain longer text and sometimes includes artist, so cosine on normalized text is robust; 'artist' is short and benefits from typo-tolerant jaro_winkler. Both columns are non-null and informative; a moderately high threshold favors precision.
#     Reasoning (100c): Use preferred/blocking columns. Track 'name' can contain longer text and sometimes includes artist,
#     Proxy stage: F1=0.6723, required>=0.0300 -> run full
# SUCCESS: F1=0.8714
#
# 📊 Results: 3 pairs evaluated
#   OK discogs_lastfm: F1=0.8163, proxy=0.1639
#   OK discogs_musicbrainz: F1=0.8732, proxy=0.2418
#   OK musicbrainz_lastfm: F1=0.8714, proxy=0.6723
# [*] Matching fused-size estimate: rows=27771, unique_ids=27771
# [*] Matching estimate breakdown: matched_only_rows=9484, singleton_aware_rows=27771
# [*] Fused-size report updated: /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/pipeline_evaluation/fusion_size_estimate.json
# Config saved to matching_config.json
# [*] Run report updated: output/results/run_audit_20260304_124400_report.md
# [*] Matching config computed:
# {
#   "id_columns": {
#     "discogs": "id",
#     "lastfm": "id",
#     "musicbrainz": "id"
#   },
#   "matching_strategies": {
#     "discogs_lastfm": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "artist",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "numeric",
#           "column": "duration",
#           "max_difference": 5.0
#         }
#       ],
#       "weights": [
#         0.5,
#         0.3,
#         0.2
#       ],
#       "threshold": 0.72,
#       "f1": 0.8163265306122449,
#       "skipped_due_to_blocking_gate": false,
#       "proxy_f1": 0.1639344262295082,
#       "failure_tags": [
#         "ok"
#       ]
#     },
#     "discogs_musicbrainz": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "artist",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "date",
#           "column": "release-date",
#           "max_days_difference": 365
#         },
#         {
#           "type": "string",
#           "column": "release-country",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         }
#       ],
#       "weights": [
#         0.4,
#         0.3,
#         0.2,
#         0.1
#       ],
#       "threshold": 0.75,
#       "f1": 0.8732394366197184,
#       "skipped_due_to_blocking_gate": false,
#       "proxy_f1": 0.2417582417582418,
#       "failure_tags": [
#         "ok"
#       ]
#     },
#     "musicbrainz_lastfm": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "artist",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         }
#       ],
#       "weights": [
#         0.7,
#         0.3
#       ],
#       "threshold": 0.78,
#       "f1": 0.8714285714285713,
#       "skipped_due_to_blocking_gate": false,
#       "proxy_f1": 0.6722689075630253,
#       "failure_tags": [
#         "ok"
#       ]
#     }
#   },
#   "dataset_signature": "discogs|lastfm|musicbrainz",
#   "dataset_names": [
#     "discogs",
#     "lastfm",
#     "musicbrainz"
#   ],
#   "min_blocking_pc_for_matching": 0.9,
#   "proxy_f1_margin": 0.015,
#   "proxy_max_candidates": 60000,
#   "llm_trace_path": "output/matching-evaluation/llm_matching_trace.jsonl",
#   "fusion_size_estimate": {
#     "stage": "matching",
#     "dataset_signature": "discogs|lastfm|musicbrainz",
#     "datasets": [
#       "discogs",
#       "lastfm",
#       "musicbrainz"
#     ],
#     "method": "3-way inclusion-exclusion over pair estimates: E=E12+E13+E23-2*E123, with E123 estimated from per-dataset overlap probabilities; singleton-aware projection applied for final fused output (include_singletons=True assumption)",
#     "expected_rows": 27771,
#     "expected_unique_ids": 27771,
#     "expected_rows_range": [
#       21651,
#       29427
#     ],
#     "expected_unique_ids_range": [
#       21651,
#       29427
#     ],
#     "three_way_intersection": {
#       "enabled": true,
#       "datasets": [
#         "discogs",
#         "lastfm",
#         "musicbrainz"
#       ],
#       "pair_cluster_estimates": {
#         "discogs_lastfm": 7765,
#         "discogs_musicbrainz": 3951,
#         "lastfm_musicbrainz": 3888
#       },
#       "triple_intersection_estimates": {
#         "via_discogs": 1355.8808061165864,
#         "via_lastfm": 3060.3466801824634,
#         "via_musicbrainz": 3225.1706907411294,
#         "median_used": 3060.3466801824634,
#         "final_triple_intersection": 3060,
#         "triple_intersection_range": [
#           0,
#           3888
#         ]
#       },
#       "expected_union_clusters": 9484,
#       "expected_union_range": [
#         7828,
#         15604
#       ],
#       "formula": "E_union = E12 + E13 + E23 - 2*E123"
#     },
#     "pair_estimates": [
#       {
#         "pair_key": "discogs_lastfm",
#         "left_dataset": "discogs",
#         "right_dataset": "lastfm",
#         "min_pair_size": 9865,
#         "pair_completeness": 0.9642857142857143,
#         "f1": 0.8163265306122449,
#         "expected_cluster_count": 7765
#       },
#       {
#         "pair_key": "discogs_musicbrainz",
#         "left_dataset": "discogs",
#         "right_dataset": "musicbrainz",
#         "min_pair_size": 4763,
#         "pair_completeness": 0.95,
#         "f1": 0.8732394366197184,
#         "expected_cluster_count": 3951
#       },
#       {
#         "pair_key": "musicbrainz_lastfm",
#         "left_dataset": "lastfm",
#         "right_dataset": "musicbrainz",
#         "min_pair_size": 4763,
#         "pair_completeness": 0.9367088607594937,
#         "f1": 0.8714285714285713,
#         "expected_cluster_count": 3888
#       }
#     ],
#     "created_at": "2026-03-04T11:55:16.709686+00:00",
#     "expected_rows_matched_only": 9484,
#     "expected_unique_ids_matched_only": 9484,
#     "expected_rows_matched_only_range": [
#       7828,
#       15604
#     ],
#     "expected_unique_ids_matched_only_range": [
#       7828,
#       15604
#     ],
#     "expected_rows_singleton_aware": 27771,
#     "expected_unique_ids_singleton_aware": 27771,
#     "expected_rows_singleton_aware_range": [
#       21651,
#       29427
#     ],
#     "expected_unique_ids_singleton_aware_range": [
#       21651,
#       29427
#     ],
#     "singleton_assumption": {
#       "assumed_include_singletons": true,
#       "total_input_rows": 37255,
#       "formula": "E_final_rows = total_input_rows - E_matched_clusters",
#       "notes": "Conservative singleton-aware estimate: each expected matched cluster reduces the final row count by at least one."
#     }
#   },
#   "run_report_path": "output/results/run_audit_20260304_124400_report.md"
# }
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 16,166
#    Completion tokens: 3,122
#    Total tokens: 19,288
#    Estimated cost: $0.051428
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Normalized list-like columns: tracks_track_duration, tracks_track_name, tracks_track_position
# Performing Blocking
# Matching Entities
# Fusing Data
#
# [FUSION SIZE COMPARISON]
#   blocking: expected_rows=27233 actual_rows=30294 rows_pct_error=0.11240039657768149
#   matching: expected_rows=27771 actual_rows=30294 rows_pct_error=0.09085016744085557
# [*] Running consolidated evaluation node
# [EVALUATION EXECUTION] Attempt 1/3
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 9,430
#    Completion tokens: 148
#    Total tokens: 9,578
#    Estimated cost: $0.013267
# [SEARCH TOOL CALL 1]: Asking 'DataFusionEvaluator evaluate() usage: required columns/parameters and expected output structure'
# [SEARCH TOOL CALL 2]: Asking 'DataFusionStrategy add_evaluation_function signature and available evaluation match functions (tokenized_match, year_only_match, numeric_tolerance_match, set_equality_match)'
# [SEARCH TOOL CALL 3]: Asking 'normalize_country function: supported output_format values and behavior'
# [SEARCH TOOL CALL 4]: Asking 'detect_list_like_columns and normalize_list_like_columns helper: expected inputs/outputs'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 16,128
#    Completion tokens: 2,976
#    Total tokens: 19,104
#    Estimated cost: $0.049920
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [COUNTRY NORMALIZATION] output_format=name, columns=['release-country']
# [ID ALIGNMENT] direct _id coverage: 3/25
# [ID ALIGNMENT] mapped eval_id coverage: 25/25
#
# [EVAL FUNCTIONS] artist=tokenized_match(threshold=0.75) | duration=numeric_tolerance_match(tolerance=5.0) | genre=tokenized_match(threshold=0.7) | label=tokenized_match(threshold=0.85) | name=tokenized_match(threshold=0.85) | release-country=tokenized_match(threshold=0.65) | release-date=year_only_match | tracks_track_duration=tokenized_match(threshold=0.85) | tracks_track_name=tokenized_match(threshold=0.65) | tracks_track_position=tokenized_match(threshold=0.9)
#
# Data Fusion Evaluation (validation set)
# ---------------------------------------
# {
#   "artist_accuracy": 0.92,
#   "artist_count": 25,
#   "duration_accuracy": 0.6,
#   "duration_count": 25,
#   "genre_accuracy": 0.76,
#   "genre_count": 25,
#   "label_accuracy": 0.76,
#   "label_count": 25,
#   "macro_accuracy": 0.5319999999999999,
#   "name_accuracy": 0.92,
#   "name_count": 25,
#   "num_evaluated_attributes": 10,
#   "num_evaluated_records": 25,
#   "overall_accuracy": 0.532,
#   "release-country_accuracy": 0.16,
#   "release-country_count": 25,
#   "release-date_accuracy": 0.12,
#   "release-date_count": 25,
#   "total_correct": 133,
#   "total_evaluations": 250,
#   "tracks_track_duration_accuracy": 0.24,
#   "tracks_track_duration_count": 25,
#   "tracks_track_name_accuracy": 0.44,
#   "tracks_track_name_count": 25,
#   "tracks_track_position_accuracy": 0.4,
#   "tracks_track_position_count": 25
# }
#
# [EVALUATION EXECUTION] Status: success
# [*] Running consolidated investigator node
# [*] Running free integration diagnostics
# TOKEN USAGE (integration_diagnostics_generation):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 3,877
#    Completion tokens: 13,284
#    Total tokens: 17,161
#    Estimated cost: $0.137686
# [INTEGRATION DIAGNOSTICS STDOUT]
# Wrote: output/pipeline_evaluation/integration_diagnostics.json
# Wrote: output/pipeline_evaluation/integration_diagnostics.md
# Findings: 1 (HIGH=0, MEDIUM=1, LOW=0, INFO=0)
# Recommendations: 1; Fusion policy recs: 0
#
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.532, "macro_accuracy": 0.5319999999999999, "num_evaluated_records": 25, "num_evaluated_attributes": 10, "total_evaluations": 250, "total_correct": 133, "duration_accuracy": 0.6, "duration_count": 25, "label_accuracy": 0.76, "label_count": 25, "artist_accuracy": 0.92, "artist_count": 25, "release-country_accuracy": 0.16, "release-country_count": 25, "name_accuracy": 0.92, "name_count": 25, "tracks_track_name_accuracy": 0.44, "tracks_track_name_count": 25, "tracks_track_duration_accuracy": 0.24, "tracks_track_duration_count": 25, "tracks_track_position_accuracy": 0.4, "tracks_track_position_count": 25, "release-date_accuracy": 0.12, "release-date_count": 25, "genre_accuracy": 0.76, "genre_count": 25}
# [EVALUATION REPORT]
#   Stage: validation
#   Attempt: 1/3
#   Overall Accuracy: 53.200%
#   Problems Detected:
#     - overall_accuracy below target: 53.200% < 85.000%
#     - low attribute accuracy: release-country=16.000%, release-date=12.000%, tracks_track_duration=24.000%, tracks_track_name=44.000%, tracks_track_position=40.000%
#     - low direct ID coverage: 12.000%
#     - high missing_fused_value mismatch ratio: 28.205%
#   Planned Adaptation:
#     - investigator runs diagnostics report + cluster evidence analysis
#     - reasoning node proposes targeted pipeline/code changes
#     - prioritize ID alignment and singleton handling
#     - prioritize fusion strategy changes for sparse attributes
# [*] Auto diagnostics:
# {
#   "debug_reason_counts": {
#     "mismatch": 84,
#     "missing_fused_value": 33
#   },
#   "debug_reason_ratios": {
#     "mismatch": 0.717948717948718,
#     "missing_fused_value": 0.28205128205128205
#   },
#   "evaluation_stage": "validation",
#   "evaluation_testset_path": "input/datasets/music/testsets/validation_set.xml",
#   "id_alignment": {
#     "gold_count": 25,
#     "direct_coverage": 3,
#     "direct_coverage_ratio": 0.12,
#     "mapped_coverage": 25,
#     "mapped_coverage_ratio": 1.0,
#     "missing_gold_ids": []
#   },
#   "fusion_size_comparison": {
#     "estimate_path": "output/pipeline_evaluation/fusion_size_estimate.json",
#     "actual": {
#       "rows": 30294,
#       "unique_ids": 30294
#     },
#     "comparisons": {
#       "blocking": {
#         "expected_rows": 27233,
#         "actual_rows": 30294,
#         "rows_abs_error": 3061,
#         "rows_pct_error": 0.11240039657768149,
#         "expected_rows_matched_only": 10022,
#         "expected_rows_singleton_aware": 27233,
#         "rows_pct_error_matched_only": 2.0227499501097586,
#         "rows_pct_error_singleton_aware": 0.11240039657768149,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 27233,
#         "actual_unique_ids": 30294,
#         "unique_ids_abs_error": 3061,
#         "unique_ids_pct_error": 0.11240039657768149,
#         "reasoning": "Estimate is moderately off; candidate generation and matching quality likely explain the gap. Blocking estimate was conservative; downstream matching/fusion retained more entities than expected.",
#         "compared_at": "2026-03-04T11:59:03.145007+00:00"
#       },
#       "matching": {
#         "expected_rows": 27771,
#         "actual_rows": 30294,
#         "rows_abs_error": 2523,
#         "rows_pct_error": 0.09085016744085557,
#         "expected_rows_matched_only": 9484,
#         "expected_rows_singleton_aware": 27771,
#         "rows_pct_error_matched_only": 2.1942218473218054,
#         "rows_pct_error_singleton_aware": 0.09085016744085557,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 27771,
#         "actual_unique_ids": 30294,
#         "unique_ids_abs_error": 2523,
#         "unique_ids_pct_error": 0.09085016744085557,
#         "reasoning": "Estimate is close to actual fused size. Matching estimate seems conservative; matcher/fusion retained more clusters than projected.",
#         "compared_at": "2026-03-04T11:59:03.145061+00:00"
#       }
#     }
#   },
#   "overall_accuracy": 0.532
# }
# [*] Running cluster analysis helper...
# [*] Found 3 pairwise correspondence files to analyze.
#
#
# ===================
#  CLUSTER ANALYSIS
# ===================
# [*] Analyzing clusters from correspondences_discogs_lastfm.csv
#     Metrics: clusters=1978, max_size=21, small=84.88%, large=2.17%, one_to_many=15.22%
#     Recommended Strategy: AdjustMatchingConfig
# [*] Analyzing clusters from correspondences_discogs_musicbrainz.csv
#     Metrics: clusters=2811, max_size=13, small=82.96%, large=0.75%, one_to_many=17.36%
#     Recommended Strategy: None
# [*] Analyzing clusters from correspondences_musicbrainz_lastfm.csv
#     Metrics: clusters=2421, max_size=62, small=85.58%, large=5.25%, one_to_many=23.92%
#     Recommended Strategy: AdjustMatchingConfig
#     Overall: recommended_strategy=AdjustMatchingConfig, unhealthy_files=2
#
#     Aggregated cluster analysis report saved to output/cluster-evaluation/cluster_analysis_report.json
# TOKEN USAGE (evaluation_reasoning):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 23,586
#    Completion tokens: 2,466
#    Total tokens: 26,052
#    Estimated cost: $0.054143
# [*] Evaluation reasoning:
# ## 1) Dominant error types (from metrics + debug events)
#
# ### A. Fusion-policy errors (dominant)
# These are not “blocking/matching missed pairs” problems; they are “picked the wrong value / wrong aggregation” problems during fusion.
#
# - **`release-country` extremely poor (0.16 accuracy)**
#   Debug shows systematic wrong picks like **“Uganda”**, **“europe”**, **“uk & europe”**, **“United States”** when gold expects a specific country (UK/France/Germany/Luxembourg/etc.).
#   This pattern is classic **voting on dirty / non-canonical values** + **no source trust weighting** + **region/multi-country strings** being treated as countries.
#
# - **Track fields are very poor**
#   - `tracks_track_name` 0.44
#   - `tracks_track_duration` 0.24
#   - `tracks_track_position` 0.40
#   Debug shows the fused track-name list often becomes a **bloated union of variants** (duplicates, encoding variants like `â€™`, bracket/parenthesis variants, “bonus tracks”, “encore”, etc.). This indicates the current **`union` fuser is inflating lists** without canonicalization/deduplication, harming evaluation.
#
# - **`release-date` very poor (0.12)**
#   You fuse with `median` over datetimes (often with NaTs and “year-only” coercions). If sources disagree (reissues vs originals) or one source defaults to Jan-01, median can land on a non-gold year/date. Evaluation uses `year_only_match`, but you still get many misses, suggesting fusion is often choosing the *wrong year*, not merely the wrong day.
#
# - **`duration` moderate (0.6)** with multiple mismatches slightly above tolerance
#   Many duration mismatches are far beyond ±5 seconds (e.g., 1125.5 vs 1882). That’s not “rounding”; it’s likely **wrong cluster membership** (over-matching) *or* mixing album duration vs track duration-like fields across sources. But given name/artist are high, this is less dominant than the country/track/date issues.
#
# ### B. Missing fused values (secondary but important)
# Auto diagnostics: **33/117 mismatches are `missing_fused_value` (~28%)**.
# Examples: `label` missing even though gold expects a value. With `most_complete`, missing values usually mean **no source in the cluster had that attribute populated** *or* the attribute didn’t normalize into the expected column (schema/preprocessing issue).
#
# ### C. Over-clustering / bad correspondences (contributes to wrong values)
# Cluster analysis flags:
# - **discogs_lastfm** unhealthy distribution; max cluster size 21; not long-tail
# - **musicbrainz_lastfm** unhealthy; max cluster size 62; high one-to-many ratio (0.239)
#
# Even though you run **MaximumBipartiteMatching (pairwise)**, you then **concatenate the three pairwise refined correspondences** and feed them to fusion. That can still create **multi-hop cluster merges** (A–B and B–C implies A–C) and can balloon clusters even if each pairwise step is 1–1. This is a common source of “wrong country/duration/tracklist” because you’re mixing multiple real-world releases.
#
# ## 2) Likely root causes (where errors come from)
#
# ### Blocking: not the main issue
# Optimal blocking PC is high (0.94–0.96) and “ok”. No evidence of dominant missed blocks in the fusion debug (which is attribute-level).
#
# ### Matching thresholds/comparators: contributes, but you asked to focus on fusion
# Cluster analysis suggests **over-matching** for discogs_lastfm and musicbrainz_lastfm. That will poison fusion inputs. However, your instruction says blocking/matching configs are already “determined earlier”; so treat this as **upstream noise we must make fusion robust to**.
#
# ### Schema / preprocessing issues: clearly present
# - **Country values are not normalized to canonical single-country names** prior to fusion; you only normalize in the *evaluation code*, not in the *pipeline*. So the fuser is voting over dirty tokens like “europe”.
# - **Text encoding/Unicode normalization issues** (`Sheâ€™s`, `youâ€™ll`, etc.) are propagating into track lists and names.
# - **List-like normalization exists**, but after that you use **`union`** which preserves noisy variants and duplicates.
#
# ### Fusion logic / policy: primary cause
# - `release-country` uses **`voting`** (unweighted, no canonicalization, no region handling) → consistently wrong.
# - Track columns use **`union`** → list inflation, duplicates, variant spellings, and garbage tokens survive.
# - `label` uses `most_complete` → fine in principle, but if over-clustering occurs, “most_complete” can select a wrong-but-non-null value; and if clusters are single-source or missing label in the chosen source, you get nulls.
#
# ## 3) What the Cluster Analysis Report implies (and how to use it for fusion)
#
# The report recommends increasing thresholds to reduce over-matching. Even if you keep matching fixed, its **practical implication for fusion** is:
#
# - Expect **ambiguous clusters** especially involving lastfm ↔ others.
# - Therefore, fusion should be **source-aware and conflict-aware**, not purely “most_complete/union/voting”.
#
# Concretely, you should:
# - **Prefer MusicBrainz for “release-country”, “release-date”, track metadata** (it’s typically more curated).
# - Use **favour_sources** (already imported) to impose **trust ranking** rather than voting/union.
# - Add **conflict rules**: if disagreement is high (e.g., country is region-like vs actual country), prefer the curated source or drop the region-like token.
#
# ## 4) Concrete, actionable improvements for next iteration (fusion-focused)
#
# ### A. Make fusion source-aware (stop naive voting/union on noisy fields)
# 1) **release-country: replace `voting` with source preference + canonicalization**
#    - Prefer MusicBrainz if present; else Discogs; else LastFM.
#    - Additionally, strip/ignore region or multi-country strings (e.g., contains `&`, `/`, `,`, “europe”, “worldwide”, “uk & europe”).
#
#    **Implementation direction:**
#    - Pre-normalize `release-country` in each dataset (see normalization section).
#    - Then fuse with:
#      - `favour_sources(["musicbrainz", "discogs", "lastfm"])` (exact call signature depends on PyDI, but you already import it)
#      - fallback to `voting` only if all sources have canonical single-country values.
#
# 2) **tracks_*: stop using raw `union`**
#    - For track lists, “union” guarantees inflated lists when clusters are dirty.
#    - Prefer a **single best source** (MusicBrainz) for `tracks_track_name`, `tracks_track_position`, `tracks_track_duration`.
#    This will dramatically improve accuracy under evaluation because gold tracklists are typically consistent with one curated representation.
#
#    **Action:**
#    - Add explicit fusers for these columns:
#      - `strategy.add_attribute_fuser("tracks_track_name", favour_sources(...))`
#      - same for duration/position
#    - Only use `union` for genuinely multi-valued categorical fields where union is desirable (maybe genre styles), and even then with normalization/dedup.
#
# 3) **release-date: prefer MusicBrainz, then Discogs; avoid median**
#    - Median across sources is not semantically meaningful for release dates (original vs reissue vs “year-only default Jan 1”).
#    - Use `favour_sources` or “most_complete from trusted source”.
#
# ### B. Add lightweight canonicalization/dedup for list/text values before fusion
# 1) **Unicode fix + punctuation canonicalization**
#    - Convert curly quotes / mojibake (`â€™`) to normal apostrophes.
#    - Normalize whitespace, remove duplicate bracket/parenthesis variants if desired.
#
# 2) **Track list dedup**
#    - Lowercase + strip already exists in matching preprocess, but not in fused output.
#    - Apply a canonicalizer to each list element then deduplicate while preserving order.
#
# ### C. Reduce nulls from `most_complete` by making “completeness” source-aware
# For `label`, `genre`, possibly `duration`:
# - Use `favour_sources` first, then fallback to `most_complete`.
# This reduces cases where the “most_complete” row is from a source that lacks that attribute (or where cluster mixing causes a wrong non-null to win).
#
# ### D. Cluster-robust fusion (guardrails against over-cluster contamination)
# Given the unhealthy one-to-many in two correspondence sets, add a simple protection:
# - If a fused cluster contains **too many source rows** (e.g., >3) or contains **multiple rows from the same dataset**, then:
#   - For sensitive attributes (country/date/tracks), **only take from MusicBrainz** (or drop to null if not present).
#   - For name/artist, keep most_complete (they’re already high accuracy).
#
# This is a fusion-only way to mitigate upstream over-matching without changing thresholds.
#
# ## Normalization Recommendations
#
# ### 1) `release-country` (high priority)
# Apply country normalization **in the integration pipeline before fusion** (not just in evaluation):
#
# - Target columns: **`release-country`** in discogs/lastfm/musicbrainz.
# - Use PyDI: `normalize_country(value, output_format="name")` (or infer desired output format globally; validation appears to use names like “United Kingdom”, “France”, etc.).
# - Add a preprocessing step to handle region/multi-country tokens:
#   - Map/blank out: `"europe"`, `"uk & europe"`, `"worldwide"`, etc.
#   - If multiple countries in one string, pick first *only if* it’s a valid country after normalization; otherwise set null.
#
# ### 2) Track list columns (high priority)
# You already run `detect_list_like_columns / normalize_list_like_columns`, keep that. Add element-level normalization specifically for:
# - `tracks_track_name`
# - `tracks_track_position`
# - `tracks_track_duration`
#
# Actions:
# - Unicode normalize (NFKC), fix mojibake apostrophes, strip, lowercase for dedup keys.
# - Remove obvious non-track tokens (e.g., “bonus tracks”, “encore”) if they are section headers rather than tracks (optional but often helps).
#
# ### 3) Text fields with encoding issues (medium priority)
# - `name`, `artist`, `label` should get the same unicode/quote normalization (to avoid “m. chemical romance” style truncations/abbreviations propagating).
#   - The “m. chemical romance” vs “My Chemical Romance” suggests either a bad source value or cluster contamination; canonicalization won’t fully solve it, but it helps.
#
# ---
#
# ## Next iteration checklist (minimal, high-impact)
# 1) **Replace fusion for `release-country`, `release-date`, `tracks_*` with `favour_sources` (MusicBrainz first).**
# 2) **Normalize `release-country` in pipeline using `normalize_country(..., output_format="name")` + filter region-like tokens.**
# 3) **Stop `union` for track lists; either favour_sources or union-after-canonicalized-dedup.**
# 4) **Add cluster-size / multi-row-per-dataset guardrail: if cluster looks contaminated, trust MusicBrainz-only for sensitive attributes.**
#
# These changes directly target the worst attributes (country/date/tracks) that currently drive overall accuracy down to ~0.53.
# TOKEN USAGE (investigator_normalization_assessment):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 6,347
#    Completion tokens: 429
#    Total tokens: 6,776
#    Estimated cost: $0.012224
# [*] Investigator decision: rerun normalization before next pipeline iteration
# [INVESTIGATION REPORT]
#   - overall_accuracy=53.200%, evaluation_attempt=1/3
#   - probes: reason_distribution: mismatch=0.72, missing_fused_value=0.28 | worst_attributes: release-date_accuracy=0.12, release-country_accuracy=0.16, tracks_track_duration_accuracy=0.24, tracks_track_position_accuracy=0.40, tracks_track_name_accuracy=0.44
#   - objective: composite=0.0 worst_pressure=0.88 missing_penalty=0.282051
#   - normalization acceptance: None (delta=None, required=None)
#   - routing score=1.448675 threshold=0.72 blocked_action_plan=False blocked_regret=False
# [*] Running normalization node
# [+] Normalization completed; using normalized datasets
# [*] Blocking config already present in state; skipping BlockingTester
# [*] Matching config already present in state; skipping MatchingTester
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 27,557
#    Completion tokens: 255
#    Total tokens: 27,812
#    Estimated cost: $0.036996
# [SEARCH TOOL CALL 1]: Asking 'PyDI.fusion.favour_sources: how to use it in DataFusionStrategy.add_attribute_fuser? What parameters does favour_sources accept and what does it return?'
# [SEARCH TOOL CALL 2]: Asking 'PyDI.fusion prefer_higher_trust usage example with trust_map in DataFusionStrategy.add_attribute_fuser'
# [SEARCH TOOL CALL 3]: Asking 'Does PyDI have built-in fusers for dates: most_recent / earliest? What are their names and how to register?'
# [SEARCH TOOL CALL 4]: Asking 'RuleBasedMatcher output correspondences format: expected columns for fusion (id1,id2,score,notes?) and compatibility with DataFusionEngine'
# [SEARCH TOOL CALL 5]: Asking 'DataFusionEngine run: include_singletons parameter behavior and how IDs are assigned in fused output'
# [SEARCH TOOL CALL 6]: Asking 'Is there a built-in fuser for lists that selects from trusted source (like favour_sources) and how does it handle lists?'
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 37,316
#    Completion tokens: 4,085
#    Total tokens: 41,401
#    Estimated cost: $0.087495
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Normalized list-like columns: tracks_track_duration, tracks_track_name, tracks_track_position
# Performing Blocking
# Matching Entities
# Fusing Data
#
# [FUSION SIZE COMPARISON]
#   blocking: expected_rows=27233 actual_rows=30316 rows_pct_error=0.11320824000293761
#   matching: expected_rows=27771 actual_rows=30316 rows_pct_error=0.09164236073601958
# [*] Running consolidated evaluation node
# [EVALUATION EXECUTION] Attempt 1/3
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 14,557
#    Completion tokens: 48
#    Total tokens: 14,605
#    Estimated cost: $0.018676
# [SEARCH TOOL CALL 1]: Asking 'DataFusionEvaluator usage: evaluate(fused_df, fused_id_column, gold_df, gold_id_column) and how to add evaluation functions in DataFusionStrategy'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 15,899
#    Completion tokens: 2,816
#    Total tokens: 18,715
#    Estimated cost: $0.048034
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [LIST NORMALIZATION] columns=['tracks_track_duration', 'tracks_track_name', 'tracks_track_position']
# [COUNTRY NORMALIZATION] output_format=name, columns=['release-country']
# [ID ALIGNMENT] direct _id coverage: 4/25
# [ID ALIGNMENT] mapped eval_id coverage: 25/25
# [EVAL FUNCS] artist:tokenized_match(threshold=0.75) | duration:numeric_tolerance_match | genre:tokenized_match(threshold=0.7) | label:tokenized_match(threshold=0.85) | name:tokenized_match(threshold=0.85) | release-country:tokenized_match(threshold=0.65) | release-date:year_only_match | tracks_track_duration:tokenized_match(threshold=0.85) | tracks_track_name:tokenized_match(threshold=0.65) | tracks_track_position:tokenized_match(threshold=0.9)
# [EVALUATION METRICS]
# {
#   "artist_accuracy": 0.92,
#   "artist_count": 25,
#   "duration_accuracy": 0.24,
#   "duration_count": 25,
#   "genre_accuracy": 0.68,
#   "genre_count": 25,
#   "label_accuracy": 0.68,
#   "label_count": 25,
#   "macro_accuracy": 0.5560000000000002,
#   "name_accuracy": 0.92,
#   "name_count": 25,
#   "num_evaluated_attributes": 10,
#   "num_evaluated_records": 25,
#   "overall_accuracy": 0.556,
#   "release-country_accuracy": 0.4,
#   "release-country_count": 25,
#   "release-date_accuracy": 0.96,
#   "release-date_count": 25,
#   "total_correct": 139,
#   "total_evaluations": 250,
#   "tracks_track_duration_accuracy": 0.04,
#   "tracks_track_duration_count": 25,
#   "tracks_track_name_accuracy": 0.36,
#   "tracks_track_name_count": 25,
#   "tracks_track_position_accuracy": 0.36,
#   "tracks_track_position_count": 25
# }
#
# [EVALUATION EXECUTION] Status: success
# [*] Running consolidated investigator node
# [*] Running free integration diagnostics
# TOKEN USAGE (integration_diagnostics_generation):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 10,509
#    Completion tokens: 11,276
#    Total tokens: 21,785
#    Estimated cost: $0.125896
# [INTEGRATION DIAGNOSTICS STDOUT]
# Wrote: output/pipeline_evaluation/integration_diagnostics.json
# Wrote: output/pipeline_evaluation/integration_diagnostics.md
#
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.532, "macro_accuracy": 0.5319999999999999, "num_evaluated_records": 25, "num_evaluated_attributes": 10, "total_evaluations": 250, "total_correct": 133, "duration_accuracy": 0.6, "duration_count": 25, "label_accuracy": 0.76, "label_count": 25, "artist_accuracy": 0.92, "artist_count": 25, "release-country_accuracy": 0.16, "release-country_count": 25, "name_accuracy": 0.92, "name_count": 25, "tracks_track_name_accuracy": 0.44, "tracks_track_name_count": 25, "tracks_track_duration_accuracy": 0.24, "tracks_track_duration_count": 25, "tracks_track_position_accuracy": 0.4, "tracks_track_position_count": 25, "release-date_accuracy": 0.12, "release-date_count": 25, "genre_accuracy": 0.76, "genre_count": 25}
# [EVALUATION REPORT]
#   Stage: validation
#   Attempt: 2/3
#   Overall Accuracy: 53.200%
#   Problems Detected:
#     - overall_accuracy below target: 53.200% < 85.000%
#     - low attribute accuracy: release-country=16.000%, release-date=12.000%, tracks_track_duration=24.000%, tracks_track_name=44.000%, tracks_track_position=40.000%
#     - low direct ID coverage: 16.000%
#   Planned Adaptation:
#     - investigator runs diagnostics report + cluster evidence analysis
# ...
#    - Apply `_unicode_clean` to scalar text columns like `label`, `genre`, `name`, `artist` as well (non-destructive).
#
# ---
#
# ## Normalization Recommendations
#
# ### 1) `release-country`
# Stop blanking multi-country/region values; instead normalize.
# - Apply **PyDI country normalization** on `release-country` during preprocessing:
#
# ```python
# from PyDI.normalization import normalize_country
# df["release-country"] = df["release-country"].apply(lambda x: normalize_country(x, output_format="name") or x)
# ```
#
# If values contain multiple countries, split and take the first recognized country (or keep list).
#
# **Target column:** `release-country`
#
# ### 2) List-like formatting normalization
# The diagnostics explicitly flag list-format inconsistencies and noisy list fusion.
# - Run `detect_list_like_columns / normalize_list_like_columns` (you already do), but add **post-normalization element canonicalization + dedup** for:
#   - `genre`
#   - `label` (often delimiter-separated)
#   - `tracks_track_name`, `tracks_track_duration`, `tracks_track_position`
#
# **Target columns:** `genre`, `label`, `tracks_track_name`, `tracks_track_duration`, `tracks_track_position`
#
# ### 3) Unicode/text canonicalization for scalar fields
# Apply `_unicode_clean` to scalar text attributes to fix cases like `â€™`:
# - **Target columns:** `name`, `artist`, `label`, `genre`
#
# ---
#
# ## Summary of what to change next (minimal high-impact set)
# 1. Fix the duplicate `release-date` fuser registration.
# 2. Replace `most_complete` for `genre` (and likely `label`) with a conservative policy (prefer musicbrainz, else discogs).
# 3. Normalize `release-country` using `normalize_country(..., output_format="name")` instead of dropping multi-token values.
# 4. Implement tracklist fusion that validates coherence (length/consensus) rather than raw `favour_sources`.
# 5. Apply `_unicode_clean` broadly (scalar + list elements) and deduplicate list elements post-normalization.
#
# These changes directly target your worst attributes (release-country, release-date, tracks_*) and the observed mismatch patterns, while respecting the constraint to focus on fusion improvements.
# TOKEN USAGE (investigator_normalization_assessment):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 12,175
#    Completion tokens: 407
#    Total tokens: 12,582
#    Estimated cost: $0.019289
# [*] Investigator decision: rerun normalization before next pipeline iteration
# [INVESTIGATION REPORT]
#   - overall_accuracy=53.200%, evaluation_attempt=2/3
#   - probes: reason_distribution: mismatch=0.86, missing_fused_value=0.14 | worst_attributes: release-date_accuracy=0.12, release-country_accuracy=0.16, tracks_track_duration_accuracy=0.24, tracks_track_position_accuracy=0.40, tracks_track_name_accuracy=0.44 | recent_mismatches: reasons[mismatch:96, missing_fused_value:15] attrs[tracks_track_duration:24, duration:19, tracks_track_name:16] | directive_coverage: lastfm: genre, label, release-country; musicbrainz: genre, label
#   - objective: composite=0.0 worst_pressure=0.88 missing_penalty=0.135135
#   - normalization acceptance: None (delta=None, required=None)
#   - routing score=1.334826 threshold=0.8 blocked_action_plan=False blocked_regret=False
# [*] Running normalization node
# [+] Normalization completed; using normalized datasets
# [*] Blocking config already present in state; skipping BlockingTester
# [*] Matching config already present in state; skipping MatchingTester
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 34,649
#    Completion tokens: 4,141
#    Total tokens: 38,790
#    Estimated cost: $0.084721
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Normalized list-like columns: tracks_track_duration, tracks_track_name, tracks_track_position
# Performing Blocking
# Matching Entities
# Fusing Data
#
# [FUSION SIZE COMPARISON]
#   blocking: expected_rows=27233 actual_rows=30298 rows_pct_error=0.11254727720045533
#   matching: expected_rows=27771 actual_rows=30298 rows_pct_error=0.09099420258543084
# [*] Running consolidated evaluation node
# [EVALUATION EXECUTION] Attempt 1/3
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 14,236
#    Completion tokens: 107
#    Total tokens: 14,343
#    Estimated cost: $0.018865
# [SEARCH TOOL CALL 1]: Asking 'How do I use PyDI.fusion.DataFusionEvaluator.evaluate? What does evaluation_results contain and how to print structured metrics?'
# [SEARCH TOOL CALL 2]: Asking 'What evaluation/match functions are available in PyDI.fusion (tokenized_match, year_only_match, numeric_tolerance_match, set_equality_match) and their parameters?'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 17,617
#    Completion tokens: 2,889
#    Total tokens: 20,506
#    Estimated cost: $0.050911
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [COUNTRY NORMALIZATION] output_format=name, columns=['release-country']
# [ID ALIGNMENT] direct _id coverage: 3/25
# [ID ALIGNMENT] mapped eval_id coverage: 25/25
# [EVAL FUNCTIONS] artist:tokenized_match(threshold=0.75) | duration:numeric_tolerance_match(tolerance=5.0) | genre:tokenized_match(threshold=0.7) | label:tokenized_match(threshold=0.85) | name:tokenized_match(threshold=0.85) | release-country:tokenized_match(threshold=0.65) | release-date:year_only_match | tracks_track_duration:tokenized_match(threshold=0.85) | tracks_track_name:tokenized_match(threshold=0.65) | tracks_track_position:tokenized_match(threshold=0.9)
# [EVALUATION METRICS]
# {
#   "artist_accuracy": 0.92,
#   "artist_count": 25,
#   "duration_accuracy": 0.6,
#   "duration_count": 25,
#   "genre_accuracy": 0.48,
#   "genre_count": 25,
#   "label_accuracy": 0.68,
#   "label_count": 25,
#   "macro_accuracy": 0.552,
#   "name_accuracy": 0.92,
#   "name_count": 25,
#   "num_evaluated_attributes": 10,
#   "num_evaluated_records": 25,
#   "overall_accuracy": 0.552,
#   "release-country_accuracy": 0.16,
#   "release-country_count": 25,
#   "release-date_accuracy": 0.96,
#   "release-date_count": 25,
#   "total_correct": 138,
#   "total_evaluations": 250,
#   "tracks_track_duration_accuracy": 0.04,
#   "tracks_track_duration_count": 25,
#   "tracks_track_name_accuracy": 0.4,
#   "tracks_track_name_count": 25,
#   "tracks_track_position_accuracy": 0.36,
#   "tracks_track_position_count": 25
# }
#
# [EVALUATION EXECUTION] Status: success
# [*] Running consolidated investigator node
# [*] Running free integration diagnostics
# TOKEN USAGE (integration_diagnostics_generation):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 10,773
#    Completion tokens: 12,470
#    Total tokens: 23,243
#    Estimated cost: $0.138166
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.532, "macro_accuracy": 0.5319999999999999, "num_evaluated_records": 25, "num_evaluated_attributes": 10, "total_evaluations": 250, "total_correct": 133, "duration_accuracy": 0.6, "duration_count": 25, "label_accuracy": 0.76, "label_count": 25, "artist_accuracy": 0.92, "artist_count": 25, "release-country_accuracy": 0.16, "release-country_count": 25, "name_accuracy": 0.92, "name_count": 25, "tracks_track_name_accuracy": 0.44, "tracks_track_name_count": 25, "tracks_track_duration_accuracy": 0.24, "tracks_track_duration_count": 25, "tracks_track_position_accuracy": 0.4, "tracks_track_position_count": 25, "release-date_accuracy": 0.12, "release-date_count": 25, "genre_accuracy": 0.76, "genre_count": 25}
# [EVALUATION REPORT]
#   Stage: validation
#   Attempt: 3/3
#   Overall Accuracy: 53.200%
#   Problems Detected:
#     - overall_accuracy below target: 53.200% < 85.000%
#     - low attribute accuracy: release-country=16.000%, release-date=12.000%, tracks_track_duration=24.000%, tracks_track_name=44.000%, tracks_track_position=40.000%
#     - low direct ID coverage: 12.000%
#   Planned Adaptation:
#     - max automatic iterations reached; stop adaptation loop
# [*] Auto diagnostics:
# {
#   "debug_reason_counts": {
#     "mismatch": 101,
#     "missing_fused_value": 11
#   },
#   "debug_reason_ratios": {
#     "mismatch": 0.9017857142857143,
#     "missing_fused_value": 0.09821428571428571
#   },
#   "evaluation_stage": "validation",
#   "evaluation_testset_path": "input/datasets/music/testsets/validation_set.xml",
#   "id_alignment": {
#     "gold_count": 25,
#     "direct_coverage": 3,
#     "direct_coverage_ratio": 0.12,
#     "mapped_coverage": 25,
#     "mapped_coverage_ratio": 1.0,
#     "missing_gold_ids": []
#   },
#   "fusion_size_comparison": {
#     "estimate_path": "output/pipeline_evaluation/fusion_size_estimate.json",
#     "actual": {
#       "rows": 30298,
#       "unique_ids": 30298
#     },
#     "comparisons": {
#       "blocking": {
#         "expected_rows": 27233,
#         "actual_rows": 30298,
#         "rows_abs_error": 3065,
#         "rows_pct_error": 0.11254727720045533,
#         "expected_rows_matched_only": 10022,
#         "expected_rows_singleton_aware": 27233,
#         "rows_pct_error_matched_only": 2.023149072041509,
#         "rows_pct_error_singleton_aware": 0.11254727720045533,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 27233,
#         "actual_unique_ids": 30298,
#         "unique_ids_abs_error": 3065,
#         "unique_ids_pct_error": 0.11254727720045533,
#         "reasoning": "Estimate is moderately off; candidate generation and matching quality likely explain the gap. Blocking estimate was conservative; downstream matching/fusion retained more entities than expected.",
#         "compared_at": "2026-03-04T12:20:22.909383+00:00"
#       },
#       "matching": {
#         "expected_rows": 27771,
#         "actual_rows": 30298,
#         "rows_abs_error": 2527,
#         "rows_pct_error": 0.09099420258543084,
#         "expected_rows_matched_only": 9484,
#         "expected_rows_singleton_aware": 27771,
#         "rows_pct_error_matched_only": 2.1946436102910165,
#         "rows_pct_error_singleton_aware": 0.09099420258543084,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 27771,
#         "actual_unique_ids": 30298,
#         "unique_ids_abs_error": 2527,
#         "unique_ids_pct_error": 0.09099420258543084,
#         "reasoning": "Estimate is close to actual fused size. Matching estimate seems conservative; matcher/fusion retained more clusters than projected.",
#         "compared_at": "2026-03-04T12:20:22.909426+00:00"
#       }
#     }
#   },
#   "overall_accuracy": 0.532
# }
# TOTAL TOKEN USAGE:
#    Prompt tokens: 2,530,742
#    Completion tokens: 603,448
#    Total tokens: 3,134,190
#    Estimated cost: $9.197907
# [*] Investigator decision: proceed to human review
# [INVESTIGATION REPORT]
#   - overall_accuracy=53.200%, evaluation_attempt=3/3
#   - probes: reason_distribution: mismatch=0.90, missing_fused_value=0.10 | worst_attributes: release-date_accuracy=0.12, release-country_accuracy=0.16, tracks_track_duration_accuracy=0.24, tracks_track_position_accuracy=0.40, tracks_track_name_accuracy=0.44 | recent_mismatches: reasons[mismatch:101, missing_fused_value:11] attrs[tracks_track_duration:24, release-country:21, tracks_track_position:16] | directive_coverage: lastfm: genre, label, release-country; musicbrainz: genre, label
#   - objective: composite=0.003804 worst_pressure=0.88 missing_penalty=0.098214
#   - normalization acceptance: None (delta=None, required=None)
# [*] Building final human-review package
# TOKEN USAGE (human_review_export_generation):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 28,405
#    Completion tokens: 5,451
#    Total tokens: 33,856
#    Estimated cost: $0.090016
# [*] Human-review export completed
# [*] Running sealed final test evaluation on held-out test set
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 14,131
#    Completion tokens: 165
#    Total tokens: 14,296
#    Estimated cost: $0.019314
# [SEARCH TOOL CALL 1]: Asking 'DataFusionEvaluator.evaluate usage example: required columns, return format, how to register evaluation functions in DataFusionStrategy'
# [SEARCH TOOL CALL 2]: Asking 'PyDI fusion evaluation functions: tokenized_match, year_only_match, numeric_tolerance_match, set_equality_match; how thresholds are interpreted'
# [SEARCH TOOL CALL 3]: Asking 'PyDI.io.load_xml parameters for nested_handling='aggregate' and expected dataframe columns for test set'
# [SEARCH TOOL CALL 4]: Asking 'Does DataFusionEvaluator support debug output or per-attribute metrics; what keys in evaluation_results JSON?'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 20,798
#    Completion tokens: 2,785
#    Total tokens: 23,583
#    Estimated cost: $0.053847
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [LIST NORMALIZATION] columns=['tracks_track_duration', 'tracks_track_name', 'tracks_track_position']
# [COUNTRY NORMALIZATION] output_format=name, columns=['release-country']
# [ID ALIGNMENT] direct _id coverage: 0/23
# [ID ALIGNMENT] mapped eval_id coverage: 23/23
# [EVAL FUNCTIONS] artist:tokenized_match(threshold=0.75) | duration:numeric_tolerance_match(tolerance=5.0) | genre:tokenized_match(threshold=0.7) | label:tokenized_match(threshold=0.85) | name:tokenized_match(threshold=0.85) | release-country:tokenized_match(threshold=0.65) | release-date:year_only_match | tracks_track_duration:tokenized_match(threshold=0.85) | tracks_track_name:tokenized_match(threshold=0.65) | tracks_track_position:tokenized_match(threshold=0.9)
# [EVAL METRICS]
# {
#   "overall_accuracy": 0.7614213197969543,
#   "macro_accuracy": 0.7650362318840579,
#   "num_evaluated_records": 23,
#   "num_evaluated_attributes": 9,
#   "total_evaluations": 197,
#   "total_correct": 150,
#   "tracks_track_position_accuracy": 0.8260869565217391,
#   "tracks_track_position_count": 23,
#   "duration_accuracy": 0.391304347826087,
#   "duration_count": 23,
#   "release-country_accuracy": 0.7391304347826086,
#   "release-country_count": 23,
#   "tracks_track_name_accuracy": 0.8260869565217391,
#   "tracks_track_name_count": 23,
#   "artist_accuracy": 0.8260869565217391,
#   "artist_count": 23,
#   "tracks_track_duration_accuracy": 0.6,
#   "tracks_track_duration_count": 20,
#   "label_accuracy": 0.9375,
#   "label_count": 16,
#   "name_accuracy": 0.782608695652174,
#   "name_count": 23,
#   "release-date_accuracy": 0.9565217391304348,
#   "release-date_count": 23
# }
#
# [EVALUATION STDERR]
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/evaluation.py:131: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   return bool(pd.isna(value))
#
# [*] Sealed final test overall accuracy: 76.142%
# [+] Results saved to: output/results/run_20260304_132547.json
# [+] Run audit saved to: output/results/run_audit_20260304_132547.json
# [+] Run report saved to: output/results/run_report_20260304_132547.md
# [*] Music run complete
# {
#   "investigator_decision": "human_review_export",
#   "validation_overall_accuracy": 0.532,
#   "sealed_test_overall_accuracy": 0.7614213197969543,
#   "normalization_attempts": 3,
#   "evaluation_attempts": 3,
#   "run_id": "20260303_125833_844806",
#   "run_output_root": "output/runs/20260303_125833_844806",
#   "run_audit_path": "output/results/run_audit_20260304_132547.json",
#   "run_report_path": "output/results/run_report_20260304_132547.md"
# }
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
go eat shit
# Out:
#   Cell In[43], line 1
#     go eat shit
#        ^
# SyntaxError: invalid syntax
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Music use case (commented out)
# entity_matching_testsets = {
#     ("discogs", "lastfm"): INPUT_DIR + "gen_TrainSets/discogs_lastfm_goldstandard_blocking.csv",
#     ("discogs", "musicbrainz"): INPUT_DIR + "gen_TrainSets/discogs_musicbrainz_goldstandard_blocking.csv",
#     ("musicbrainz", "lastfm"): INPUT_DIR + "gen_TrainSets/musicbrainz_lastfm_goldstandard_blocking.csv",
# }
# datasets = [
#     INPUT_DIR + "datasets/music/discogs.xml",
#     INPUT_DIR + "datasets/music/lastfm.xml",
#     INPUT_DIR + "datasets/music/musicbrainz.xml"
# ]
# fusion_testset = INPUT_DIR + "datasets/music/testsets/test_set.xml"
# validation_fusion_testset = INPUT_DIR + "datasets/music/input/fusion/validation_set.xml"

# Games use case
# Using canonical games testsets (not generated train sets)
entity_matching_testsets = {
    ("dbpedia", "sales"): INPUT_DIR + "datasets/games/testsets/dpedia_games_sales_goldstandard_blocking.csv",
    ("dbpedia", "metacritic"): INPUT_DIR + "datasets/games/testsets/dpedia_games_metacritic_goldstandard_blocking.csv",
    ("sales", "metacritic"): INPUT_DIR + "datasets/games/testsets/sales_metacritic_goldstandard_blocking.csv",
}
datasets = [
    INPUT_DIR + "datasets/games/dbpedia.xml",
    INPUT_DIR + "datasets/games/metacritic.xml",
    INPUT_DIR + "datasets/games/sales.xml"
]
fusion_testset = INPUT_DIR + "datasets/games/testsets/test_set.xml"
# Optional sealed-eval input: set validation_fusion_testset when available
# validation_fusion_testset = INPUT_DIR + "datasets/games/testsets/validation_set.xml"
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# # Restaurants use case
# entity_matching_testsets = {
#     ("kaggle_small", "uber_eats_small"): INPUT_DIR + "datasets/restaurant/testsets/kaggle_uber_eats_goldstandard_blocking_small.csv",
#     ("kaggle_small", "yelp_small"): INPUT_DIR + "datasets/restaurant/testsets/kaggle_yelp_goldstandard_blocking_small.csv",
#     ("uber_eats_small", "yelp_small"): INPUT_DIR + "datasets/restaurant/testsets/uber_eats_yelp_goldstandard_blocking_small.csv",
# }

# datasets = [
#     INPUT_DIR + "datasets/restaurant/kaggle_small.parquet",
#     INPUT_DIR + "datasets/restaurant/uber_eats_small.parquet",
#     INPUT_DIR + "datasets/restaurant/yelp_small.parquet"
# ]
# fusion_testset = INPUT_DIR + "datasets/restaurant/testsets/Restaurant_Fusion_Test_Set.csv"
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# # Games use case
# entity_matching_testsets= {
#     ("dbpedia","sales"): INPUT_DIR + "datasets/games/testsets/dpedia_games_sales_goldstandard_blocking.csv",
#     ("dbpedia","metacritic"): INPUT_DIR + "datasets/games/testsets/dpedia_games_metacritic_goldstandard_blocking.csv",
#     ("sales","metacritic"): INPUT_DIR + "datasets/games/testsets/sales_metacritic_goldstandard_blocking.csv",
# }

# datasets= [
#     INPUT_DIR + "datasets/games/dbpedia.xml",
#     INPUT_DIR + "datasets/games/metacritic.xml",
#     INPUT_DIR + "datasets/games/sales.xml"
# ]
# fusion_testset= INPUT_DIR + "datasets/games/testsets/test_set.xml"
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# # Books use case
# entity_matching_testsets= {
#     ("goodreads_small","amazon_small"): INPUT_DIR + "datasets/books/testsets/goodreads_2_amazon.csv",
#     ("metabooks_small","amazon_small"): INPUT_DIR + "datasets/books/testsets/metabooks_2_amazon.csv",
#     ("metabooks_small","goodreads_small"): INPUT_DIR + "datasets/books/testsets/metabooks_2_goodreads.csv",
# }

# datasets= [
#     INPUT_DIR + "datasets/books/amazon_small.parquet",
#     INPUT_DIR + "datasets/books/goodreads_small.parquet",
#     INPUT_DIR + "datasets/books/metabooks_small.parquet"
# ]
# fusion_testset= INPUT_DIR + "datasets/books/testsets/golden_fused_books.csv"
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Music use case (commented out)
entity_matching_testsets = {
     ("discogs", "lastfm"): INPUT_DIR + "gen_TrainSets/discogs_lastfm_goldstandard_blocking.csv",
     ("discogs", "musicbrainz"): INPUT_DIR + "gen_TrainSets/discogs_musicbrainz_goldstandard_blocking.csv",
     ("musicbrainz", "lastfm"): INPUT_DIR + "gen_TrainSets/musicbrainz_lastfm_goldstandard_blocking.csv",
 }
datasets = [
     INPUT_DIR + "datasets/music/discogs.xml",
     INPUT_DIR + "datasets/music/lastfm.xml",
     INPUT_DIR + "datasets/music/musicbrainz.xml"
 ]
fusion_testset = INPUT_DIR + "datasets/music/testsets/test_set.xml"
validation_fusion_testset = INPUT_DIR + "datasets/music/testsets/validation_set.xml"
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Skip Blocking and Matching node and use existing strategies saved in 
# "output/blocking-evaluation/blocking_config.json" and "output/matching-evaluation/matching_config.json"
SKIP_BLOCKING_TESTER=False
SKIP_MATCHING_TESTER=False
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Music Dataset
# prepare agent
# agent = SimpleModelAgent(llm, ProfileDatasetTool())
profile_tool = ProfileDatasetTool()
search_tool = SearchDocumentationTool()
all_tools = {profile_tool.name: profile_tool, search_tool.name: search_tool}

agent = SimpleModelAgent(llm, tools=all_tools)

# invoke agent
invoke_payload = {
    "datasets": datasets,
    "original_datasets": list(datasets),
    "normalized_datasets": [],
    "entity_matching_testsets": entity_matching_testsets,
    "fusion_testset": fusion_testset,
    "matcher_mode": "rulebased",
    "evaluation_attempts": 0,
    "normalization_attempts": 0,
    "normalization_execution_result": "",
    "normalization_rework_required": False,
    "normalization_rework_reasons": [],
    "normalization_directives": {},
    "investigator_decision": "",
}

# Optional: enable sealed evaluation mode if validation set is provided.
# In sealed mode, adaptation/evaluation loops use validation_fusion_testset,
# and a final one-time held-out test evaluation runs on fusion_testset.
if "validation_fusion_testset" in globals() and validation_fusion_testset:
    invoke_payload["validation_fusion_testset"] = validation_fusion_testset

result = agent.graph.invoke(
    invoke_payload,
    config={"recursion_limit": 200},
)
# Out:
# [*] Running schema matching
# [*] Schema alignment columns:
#     discogs: ['id', 'name', 'artist', 'release-date', 'release-country', 'duration', 'label', 'genre', 'tracks_track_name', 'tracks_track_position', 'tracks_track_duration']
#     lastfm: ['id', 'name', 'artist', 'duration', 'tracks_track_name', 'tracks_track_duration', 'tracks_track_position']
#     musicbrainz: ['id', 'name', 'artist', 'release-date', 'release-country', 'duration', 'tracks_track_name', 'tracks_track_duration', 'tracks_track_position']
# [*] Profiling datasets
# TOKEN USAGE (profile_data):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 287
#    Completion tokens: 82
#    Total tokens: 369
#    Estimated cost: $0.001179
# [*] Running normalization node
# [+] Normalization completed; using normalized datasets
# [*] Running BlockingTester
# [*] Loading dataset: discogs
# [*] Loading dataset: lastfm
# [*] Loading dataset: musicbrainz
# [*] Loading gold standard for discogs <-> lastfm
#     Loaded 417 ground truth pairs (positives: 67, negatives/other: 350)
# [*] Loading gold standard for discogs <-> musicbrainz
#     Loaded 500 ground truth pairs (positives: 150, negatives/other: 350)
# [*] Loading gold standard for musicbrainz <-> lastfm
#     Loaded 500 ground truth pairs (positives: 150, negatives/other: 350)
# [*] Adaptive max_candidates set to 542,856 (r=0.35%, median_pairs=107,772,401)
#
# ============================================================
# 🤖 BLOCKING: discogs <-> lastfm
# ============================================================
# Gold pairs: 417, PC threshold: 0.9
# Candidate limit: 542,856 (hard: 624,284 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 22,627 × 9,865 = 223,215,355 potential pairs
# Common columns: ['tracks_track_position', 'tracks_track_name', 'duration', 'artist', 'tracks_track_duration', 'name']
#
# --- Attempt 1/5 ---
# LLM chose: token_blocking on ['name']
#   Params: {'min_token_len': 5}
#   Reasoning: N×M is very large (223M) with a strict candidate cap (~543k), so we need aggressive blocking. Exact ...
#     Token (name, len>=5): 2,176,540 candidates
#     ⛔ SKIPPING EVALUATION: 2,176,540 > 624,284 (hard limit)
#     💡 Try increasing min_token_len or ngram_size, or use a more selective column
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['artist', 'name', 'duration']
#   Params: {'top_k': 20}
#   Reasoning: Token blocking on name produced far too many candidates and still missed matches (PC=0), indicating ...
#     Embedding (artist+name+duration, k=20): 451,223 candidates
#     ✅ PC=1.0000, RR=0.9980
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: discogs <-> musicbrainz
# ============================================================
# Gold pairs: 500, PC threshold: 0.9
# Candidate limit: 542,856 (hard: 624,284 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 22,627 × 4,763 = 107,772,401 potential pairs
# Common columns: ['tracks_track_position', 'tracks_track_name', 'duration', 'release-country', 'artist', 'tracks_track_duration', 'name', 'release-date']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['artist', 'name']
#   Params: {}
#   Reasoning: With 107.8M possible pairs and a strict 542,856 max-candidates cap, we need very selective blocking....
#     Standard (artist+name): 2,183 candidates
#     ✅ PC=0.9533, RR=1.0000
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: musicbrainz <-> lastfm
# ============================================================
# Gold pairs: 500, PC threshold: 0.9
# Candidate limit: 542,856 (hard: 624,284 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 4,763 × 9,865 = 46,986,995 potential pairs
# Common columns: ['tracks_track_position', 'tracks_track_name', 'duration', 'artist', 'tracks_track_duration', 'name']
#
# --- Attempt 1/5 ---
# LLM chose: semantic_similarity on ['name', 'artist', 'tracks_track_name']
#   Params: {'top_k': 20}
#   Reasoning: With ~47M possible pairs and a 542,856 max-candidate cap, semantic_similarity provides predictable c...
#     Embedding (name+artist+tracks_track_name, k=20): 95,232 candidates
#     ✅ PC=0.9867, RR=0.9980
# ✅ Found acceptable strategy!
#
# ============================================================
# 📊 RESULTS SUMMARY: 3 pairs evaluated
# ============================================================
#   ✅ discogs_lastfm: PC=1.0000, candidates=451,223, strategy=semantic_similarity
#   ✅ discogs_musicbrainz: PC=0.9533, candidates=2,183, strategy=exact_match_multi
#   ✅ musicbrainz_lastfm: PC=0.9867, candidates=95,232, strategy=semantic_similarity
# [*] Blocking fused-size estimate: rows=27110, unique_ids=27110
# [*] Blocking estimate breakdown: matched_only_rows=10145, singleton_aware_rows=27110
# [*] Fused-size report updated: /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/pipeline_evaluation/fusion_size_estimate.json
#
# 💾 Config saved to: output/blocking-evaluation/blocking_config.json
# [*] Blocking config computed:
# {
#   "blocking_strategies": {
#     "discogs_lastfm": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "artist",
#         "name",
#         "duration"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 1.0,
#       "num_candidates": 451223,
#       "is_acceptable": true
#     },
#     "discogs_musicbrainz": {
#       "strategy": "exact_match_multi",
#       "columns": [
#         "artist",
#         "name"
#       ],
#       "params": {},
#       "pair_completeness": 0.9533333333333334,
#       "num_candidates": 2183,
#       "is_acceptable": true
#     },
#     "musicbrainz_lastfm": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "artist",
#         "tracks_track_name"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.9866666666666667,
#       "num_candidates": 95232,
#       "is_acceptable": true
#     }
#   },
#   "id_columns": {
#     "discogs": "id",
#     "lastfm": "id",
#     "musicbrainz": "id"
#   },
#   "fusion_size_estimate": {
#     "stage": "blocking",
#     "method": "3-way inclusion-exclusion over pair estimates: E=E12+E13+E23-2*E123, with E123 estimated from per-dataset overlap probabilities; singleton-aware projection applied for final fused output (include_singletons=True assumption)",
#     "expected_rows": 27110,
#     "expected_unique_ids": 27110,
#     "expected_rows_range": [
#       18628,
#       27232
#     ],
#     "expected_unique_ids_range": [
#       18628,
#       27232
#     ],
#     "three_way_intersection": {
#       "enabled": true,
#       "datasets": [
#         "discogs",
#         "lastfm",
#         "musicbrainz"
#       ],
#       "pair_cluster_estimates": {
#         "discogs_lastfm": 9865,
#         "discogs_musicbrainz": 4541,
#         "lastfm_musicbrainz": 4699
#       },
#       "triple_intersection_estimates": {
#         "via_discogs": 1979.801343527644,
#         "via_lastfm": 4699.0,
#         "via_musicbrainz": 4479.982993911401,
#         "median_used": 4479.982993911401,
#         "final_triple_intersection": 4480,
#         "triple_intersection_range": [
#           0,
#           4541
#         ]
#       },
#       "expected_union_clusters": 10145,
#       "expected_union_range": [
#         10023,
#         18627
#       ],
#       "formula": "E_union = E12 + E13 + E23 - 2*E123"
#     },
#     "pair_estimates": [
#       {
#         "pair_key": "discogs_lastfm",
#         "left_dataset": "discogs",
#         "right_dataset": "lastfm",
#         "min_pair_size": 9865,
#         "pair_completeness": 1.0,
#         "expected_cluster_count": 9865
#       },
#       {
#         "pair_key": "discogs_musicbrainz",
#         "left_dataset": "discogs",
#         "right_dataset": "musicbrainz",
#         "min_pair_size": 4763,
#         "pair_completeness": 0.9533333333333334,
#         "expected_cluster_count": 4541
#       },
#       {
#         "pair_key": "musicbrainz_lastfm",
#         "left_dataset": "lastfm",
#         "right_dataset": "musicbrainz",
#         "min_pair_size": 4763,
#         "pair_completeness": 0.9866666666666667,
#         "expected_cluster_count": 4699
#       }
#     ],
#     "created_at": "2026-02-25T08:15:19.376338+00:00",
#     "expected_rows_matched_only": 10145,
#     "expected_unique_ids_matched_only": 10145,
#     "expected_rows_matched_only_range": [
#       10023,
#       18627
#     ],
#     "expected_unique_ids_matched_only_range": [
#       10023,
#       18627
#     ],
#     "expected_rows_singleton_aware": 27110,
#     "expected_unique_ids_singleton_aware": 27110,
#     "expected_rows_singleton_aware_range": [
#       18628,
#       27232
#     ],
#     "expected_unique_ids_singleton_aware_range": [
#       18628,
#       27232
#     ],
#     "singleton_assumption": {
#       "assumed_include_singletons": true,
#       "total_input_rows": 37255,
#       "formula": "E_final_rows = total_input_rows - E_matched_clusters",
#       "notes": "Conservative singleton-aware estimate: each expected matched cluster reduces the final row count by at least one."
#     }
#   }
# }
# [*] Using MatchingTester module: /Users/nickblazek/Desktop/Agent_Pipeline/agents/matching_tester.py
# [*] Running MatchingTester
# [*] Loading dataset: discogs
# [*] Loading dataset: lastfm
# [*] Loading dataset: musicbrainz
# [*] Normalized list-like columns for matching: tracks_track_duration, tracks_track_name, tracks_track_position
# [*] Loading matching gold standard for discogs <-> lastfm
#     Loaded 417 ground truth pairs
# [*] Loading matching gold standard for discogs <-> musicbrainz
#     Loaded 500 ground truth pairs
# [*] Loading matching gold standard for musicbrainz <-> lastfm
#     Loaded 500 ground truth pairs
#
# ==================================================
# MATCHING EVALUATION
# ==================================================
#
# ==================================================
# MATCHING: discogs <-> lastfm
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['artist', 'name', 'duration']
#
# --- Attempt 1/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine', 'duration:5.0']
# Weights: [0.35, 0.45, 0.2]
# Threshold: 0.75
#     Reasoning: Use blocking columns artist and duration plus title/name for robust matching; avoid list-like track fields. Artist is a strong identifier (typo-tolerant JW), name can include extra tokens so cosine on normalized text works well, and duration is numeric but has high nulls on one side so it gets lower weight with a small tolerance.
#     Reasoning (100c): Use blocking columns artist and duration plus title/name for robust matching; avoid list-like track
# SUCCESS: F1=0.7852
#
# ==================================================
# MATCHING: discogs <-> musicbrainz
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['artist', 'name']
#
# --- Attempt 1/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine', 'release-date:365', 'duration:10.0', 'release-country:jaro_winkler']
# Weights: [0.35, 0.35, 0.15, 0.1, 0.05]
# Threshold: 0.78
#     Reasoning: Use blocking columns artist+name as primary signals (artist for minor typos, name for token-level similarity); support with release-date (allowing year-level discrepancies), duration as a weak numeric check, and release-country as a low-weight auxiliary due to higher nulls and variability. Avoid list-like track fields per constraints.
#     Reasoning (100c): Use blocking columns artist+name as primary signals (artist for minor typos, name for token-level si
# SUCCESS: F1=0.8707
#
# ==================================================
# MATCHING: musicbrainz <-> lastfm
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'artist', 'tracks_track_name']
#
# --- Attempt 1/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine']
# Weights: [0.45, 0.55]
# Threshold: 0.78
#     Reasoning: Avoided list-like track and duration fields per guidance. Used blocking columns that are scalar and informative: artist (stable identifier; handle minor variations via jaro_winkler) and name (longer text; token-based cosine robust to added prefixes like 'john b -'). Slightly higher weight on name since it encodes release/title context; moderately high threshold to reduce false positives.
#     Reasoning (100c): Avoided list-like track and duration fields per guidance. Used blocking columns that are scalar and
# F1=0.6995 < 0.75
#
# --- Attempt 2/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine']
# Weights: [0.4, 0.6]
# Threshold: 0.68
#     Reasoning: Avoided all list-like fields as instructed. Used artist as a strong short identifier with typo-robust jaro_winkler, and name as the most informative remaining scalar field with cosine to handle longer tokenized text (e.g., prefixes like 'john b -'). Lowered threshold slightly from the prior 0.75 since the best previous score was ~0.70 using these two fields; increased weight on name to better discriminate releases/tracks.
#     Reasoning (100c): Avoided all list-like fields as instructed. Used artist as a strong short identifier with typo-robus
# F1=0.6912 < 0.75
#
# --- Attempt 3/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine']
# Weights: [0.45, 0.55]
# Threshold: 0.68
#     Reasoning: Avoided all list-like columns as instructed. Kept blocking columns artist/name (tracks_track_name is list-like) and adjusted similarity functions to better handle naming variation (LastFM often prefixes artist in name). Increased weight on name with token-based cosine and used jaro_winkler on artist for robustness to minor spelling/format differences. Lowered threshold slightly from prior ~0.70 attempts to improve recall given noisy name formatting while still requiring agreement on both fields.
#     Reasoning (100c): Avoided all list-like columns as instructed. Kept blocking columns artist/name (tracks_track_name is
# F1=0.6851 < 0.75
#
# --- Attempt 4/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine']
# Weights: [0.4, 0.6]
# Threshold: 0.65
#     Reasoning: Avoided all list-like columns per instruction; used strong scalar identifiers artist and release name. Switched artist to jaro_winkler to better handle minor variations, kept name with cosine to be robust to added artist prefixes ('john b - ...') and token reordering. Lowered threshold slightly since prior runs with only these two fields scored ~0.69-0.70 under 0.75.
#     Reasoning (100c): Avoided all list-like columns per instruction; used strong scalar identifiers artist and release nam
# F1=0.6834 < 0.75
# Max attempts reached. Best F1=0.6995
#
# 📊 Results: 3 pairs evaluated
#   OK discogs_lastfm: F1=0.7852
#   OK discogs_musicbrainz: F1=0.8707
#   WARN musicbrainz_lastfm: F1=0.6995
# [*] Matching fused-size estimate: rows=27431, unique_ids=27431
# [*] Matching estimate breakdown: matched_only_rows=9824, singleton_aware_rows=27431
# [*] Fused-size report updated: /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/pipeline_evaluation/fusion_size_estimate.json
# Config saved to matching_config.json
# [*] Matching config computed:
# {
#   "id_columns": {
#     "discogs": "id",
#     "lastfm": "id",
#     "musicbrainz": "id"
#   },
#   "matching_strategies": {
#     "discogs_lastfm": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "artist",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "numeric",
#           "column": "duration",
#           "max_difference": 5.0
#         }
#       ],
#       "weights": [
#         0.35,
#         0.45,
#         0.2
#       ],
#       "threshold": 0.75,
#       "f1": 0.7851851851851852
#     },
#     "discogs_musicbrainz": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "artist",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "date",
#           "column": "release-date",
#           "max_days_difference": 365
#         },
#         {
#           "type": "numeric",
#           "column": "duration",
#           "max_difference": 10.0
#         },
#         {
#           "type": "string",
#           "column": "release-country",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         }
#       ],
#       "weights": [
#         0.35,
#         0.35,
#         0.15,
#         0.1,
#         0.05
#       ],
#       "threshold": 0.78,
#       "f1": 0.8706624605678233
#     },
#     "musicbrainz_lastfm": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "artist",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip"
#         }
#       ],
#       "weights": [
#         0.45,
#         0.55
#       ],
#       "threshold": 0.78,
#       "f1": 0.6995073891625616
#     }
#   },
#   "fusion_size_estimate": {
#     "stage": "matching",
#     "method": "3-way inclusion-exclusion over pair estimates: E=E12+E13+E23-2*E123, with E123 estimated from per-dataset overlap probabilities; singleton-aware projection applied for final fused output (include_singletons=True assumption)",
#     "expected_rows": 27431,
#     "expected_unique_ids": 27431,
#     "expected_rows_range": [
#       22269,
#       28843
#     ],
#     "expected_unique_ids_range": [
#       22269,
#       28843
#     ],
#     "three_way_intersection": {
#       "enabled": true,
#       "datasets": [
#         "discogs",
#         "lastfm",
#         "musicbrainz"
#       ],
#       "pair_cluster_estimates": {
#         "discogs_lastfm": 7746,
#         "discogs_musicbrainz": 3953,
#         "lastfm_musicbrainz": 3287
#       },
#       "triple_intersection_estimates": {
#         "via_discogs": 1353.2478012993327,
#         "via_lastfm": 2580.9530663963506,
#         "via_musicbrainz": 2728.0098677304222,
#         "median_used": 2580.9530663963506,
#         "final_triple_intersection": 2581,
#         "triple_intersection_range": [
#           0,
#           3287
#         ]
#       },
#       "expected_union_clusters": 9824,
#       "expected_union_range": [
#         8412,
#         14986
#       ],
#       "formula": "E_union = E12 + E13 + E23 - 2*E123"
#     },
#     "pair_estimates": [
#       {
#         "pair_key": "discogs_lastfm",
#         "left_dataset": "discogs",
#         "right_dataset": "lastfm",
#         "min_pair_size": 9865,
#         "pair_completeness": 1.0,
#         "f1": 0.7851851851851852,
#         "expected_cluster_count": 7746
#       },
#       {
#         "pair_key": "discogs_musicbrainz",
#         "left_dataset": "discogs",
#         "right_dataset": "musicbrainz",
#         "min_pair_size": 4763,
#         "pair_completeness": 0.9533333333333334,
#         "f1": 0.8706624605678233,
#         "expected_cluster_count": 3953
#       },
#       {
#         "pair_key": "musicbrainz_lastfm",
#         "left_dataset": "lastfm",
#         "right_dataset": "musicbrainz",
#         "min_pair_size": 4763,
#         "pair_completeness": 0.9866666666666667,
#         "f1": 0.6995073891625616,
#         "expected_cluster_count": 3287
#       }
#     ],
#     "created_at": "2026-02-25T08:17:54.151497+00:00",
#     "expected_rows_matched_only": 9824,
#     "expected_unique_ids_matched_only": 9824,
#     "expected_rows_matched_only_range": [
#       8412,
#       14986
#     ],
#     "expected_unique_ids_matched_only_range": [
#       8412,
#       14986
#     ],
#     "expected_rows_singleton_aware": 27431,
#     "expected_unique_ids_singleton_aware": 27431,
#     "expected_rows_singleton_aware_range": [
#       22269,
#       28843
#     ],
#     "expected_unique_ids_singleton_aware_range": [
#       22269,
#       28843
#     ],
#     "singleton_assumption": {
#       "assumed_include_singletons": true,
#       "total_input_rows": 37255,
#       "formula": "E_final_rows = total_input_rows - E_matched_clusters",
#       "notes": "Conservative singleton-aware estimate: each expected matched cluster reduces the final row count by at least one."
#     }
#   }
# }
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 14,418
#    Completion tokens: 4,295
#    Total tokens: 18,713
#    Estimated cost: $0.060972
# [DEBUG] Updated variable assignment for discogs_lastfm to 0.75
# [DEBUG] Updated variable assignment for discogs_musicbrainz to 0.78
# [DEBUG] Updated variable assignment for musicbrainz_lastfm to 0.78
# [+] Applied programmatic threshold updates to generated pipeline code.
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Normalized list-like columns: tracks_track_duration, tracks_track_name, tracks_track_position
# Performing Blocking
# Matching Entities
# Post-clustering (MaximumBipartiteMatching)
# Fusing Data
#
# [PIPELINE STDERR]
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/pipeline.py:69: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   return bool(pd.isna(x))
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/pipeline.py:69: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   return bool(pd.isna(x))
#
# [FUSION SIZE COMPARISON]
#   blocking: expected_rows=27110 actual_rows=31684 rows_pct_error=0.16872002950940612
#   matching: expected_rows=27431 actual_rows=31684 rows_pct_error=0.15504356385111734
# [*] Running consolidated evaluation node
# [EVALUATION EXECUTION] Attempt 1/3
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 10,222
#    Completion tokens: 2,617
#    Total tokens: 12,839
#    Estimated cost: $0.038948
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# {
#   "paths": {
#     "fused": "output/data_fusion/fusion_data.csv",
#     "gold": "input/datasets/music/testsets/validation_set.xml"
#   },
#   "id_alignment": {
#     "gold_size": 25,
#     "direct__id_coverage": 12,
#     "mapped_eval_id_coverage": 25
#   },
#   "normalization": {
#     "list_eval_columns": [
#       "genre",
#       "tracks_track_duration",
#       "tracks_track_name",
#       "tracks_track_position"
#     ],
#     "country_eval_columns": [
#       "release-country"
#     ],
#     "country_output_format": "name"
#   }
# }
# [EVAL_FUNCTIONS] artist:tokenized_match(threshold=0.75) | duration:numeric_tolerance_match | genre:tokenized_match(threshold=0.75) | label:tokenized_match(threshold=0.85) | name:tokenized_match(threshold=0.85) | release-country:tokenized_match(threshold=0.65) | release-date:year_only_match | tracks_track_duration:tokenized_match(threshold=0.85) | tracks_track_name:tokenized_match(threshold=0.65) | tracks_track_position:tokenized_match(threshold=0.9)
# [EVALUATION_RESULTS]
# {
#   "overall_accuracy": 0.552,
#   "macro_accuracy": 0.552,
#   "num_evaluated_records": 25,
#   "num_evaluated_attributes": 10,
#   "total_evaluations": 250,
#   "total_correct": 138,
#   "name_accuracy": 0.92,
#   "name_count": 25,
#   "artist_accuracy": 0.92,
#   "artist_count": 25,
#   "tracks_track_duration_accuracy": 0.2,
#   "tracks_track_duration_count": 25,
#   "release-country_accuracy": 0.84,
#   "release-country_count": 25,
#   "label_accuracy": 0.28,
#   "label_count": 25,
#   "release-date_accuracy": 1.0,
#   "release-date_count": 25,
#   "tracks_track_name_accuracy": 0.36,
#   "tracks_track_name_count": 25,
#   "tracks_track_position_accuracy": 0.44,
#   "tracks_track_position_count": 25,
#   "duration_accuracy": 0.32,
#   "duration_count": 25,
#   "genre_accuracy": 0.24,
#   "genre_count": 25
# }
#
# [EVALUATION EXECUTION] Status: success
# [*] Running consolidated investigator node
# [*] Running free integration diagnostics
# [INTEGRATION DIAGNOSTICS STDOUT]
# Wrote: output/pipeline_evaluation/integration_diagnostics.json
# Wrote: output/pipeline_evaluation/integration_diagnostics.md
# Top finding: [HIGH] Missing expected pairwise correspondence files for at least one source pair.
#
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.6345177664974619, "macro_accuracy": 0.6293478260869566, "num_evaluated_records": 23, "num_evaluated_attributes": 9, "total_evaluations": 197, "total_correct": 125, "name_accuracy": 0.6521739130434783, "name_count": 23, "duration_accuracy": 0.4782608695652174, "duration_count": 23, "tracks_track_name_accuracy": 0.6521739130434783, "tracks_track_name_count": 23, "tracks_track_position_accuracy": 0.8695652173913043, "tracks_track_position_count": 23, "artist_accuracy": 0.30434782608695654, "artist_count": 23, "release-country_accuracy": 0.9130434782608695, "release-country_count": 23, "label_accuracy": 0.625, "label_count": 16, "release-date_accuracy": 0.8695652173913043, "release-date_count": 23, "tracks_track_duration_accuracy": 0.3, "tracks_track_duration_count": 20}
# [EVALUATION REPORT]
#   Stage: validation
#   Attempt: 1/3
#   Overall Accuracy: 63.452%
#   Problems Detected:
#     - overall_accuracy below target: 63.452% < 85.000%
#     - low attribute accuracy: artist=30.435%, duration=47.826%, tracks_track_duration=30.000%
#     - low direct ID coverage: 48.000%
#     - high missing_fused_value mismatch ratio: 33.036%
#   Planned Adaptation:
#     - investigator runs diagnostics report + cluster evidence analysis
#     - reasoning node proposes targeted pipeline/code changes
#     - prioritize ID alignment and singleton handling
#     - prioritize fusion strategy changes for sparse attributes
# [*] Auto diagnostics:
# {
#   "debug_reason_counts": {
#     "mismatch": 75,
#     "missing_fused_value": 37
#   },
#   "debug_reason_ratios": {
#     "mismatch": 0.6696428571428571,
#     "missing_fused_value": 0.33035714285714285
#   },
#   "evaluation_stage": "validation",
#   "evaluation_testset_path": "input/datasets/music/testsets/validation_set.xml",
#   "id_alignment": {
#     "gold_count": 25,
#     "direct_coverage": 12,
#     "direct_coverage_ratio": 0.48,
#     "mapped_coverage": 25,
#     "mapped_coverage_ratio": 1.0,
#     "missing_gold_ids": []
#   },
#   "fusion_size_comparison": {
#     "estimate_path": "output/pipeline_evaluation/fusion_size_estimate.json",
#     "actual": {
#       "rows": 31684,
#       "unique_ids": 31684
#     },
#     "comparisons": {
#       "blocking": {
#         "expected_rows": 27110,
#         "actual_rows": 31684,
#         "rows_abs_error": 4574,
#         "rows_pct_error": 0.16872002950940612,
#         "expected_rows_matched_only": 10145,
#         "expected_rows_singleton_aware": 27110,
#         "rows_pct_error_matched_only": 2.1231148348940363,
#         "rows_pct_error_singleton_aware": 0.16872002950940612,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 27110,
#         "actual_unique_ids": 31684,
#         "unique_ids_abs_error": 4574,
#         "unique_ids_pct_error": 0.16872002950940612,
#         "reasoning": "Estimate is moderately off; candidate generation and matching quality likely explain the gap. Blocking estimate was conservative; downstream matching/fusion retained more entities than expected.",
#         "compared_at": "2026-02-25T08:20:37.804542+00:00"
#       },
#       "matching": {
#         "expected_rows": 27431,
#         "actual_rows": 31684,
#         "rows_abs_error": 4253,
#         "rows_pct_error": 0.15504356385111734,
#         "expected_rows_matched_only": 9824,
#         "expected_rows_singleton_aware": 27431,
#         "rows_pct_error_matched_only": 2.2251628664495113,
#         "rows_pct_error_singleton_aware": 0.15504356385111734,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 27431,
#         "actual_unique_ids": 31684,
#         "unique_ids_abs_error": 4253,
#         "unique_ids_pct_error": 0.15504356385111734,
#         "reasoning": "Estimate is moderately off; candidate generation and matching quality likely explain the gap. Matching estimate seems conservative; matcher/fusion retained more clusters than projected.",
#         "compared_at": "2026-02-25T08:20:37.804604+00:00"
#       }
#     }
#   },
#   "overall_accuracy": 0.6345177664974619
# }
# [*] Running cluster analysis helper...
# [*] Found 3 pairwise correspondence files to analyze.
#
#
# ===================
#  CLUSTER ANALYSIS
# ===================
# [*] Analyzing clusters from correspondences_discogs_lastfm.csv
#     Metrics: clusters=1641, max_size=18, small=86.41%, large=1.95%, one_to_many=14.18%
#     Recommended Strategy: AdjustMatchingConfig
# [*] Analyzing clusters from correspondences_discogs_musicbrainz.csv
#     Metrics: clusters=1662, max_size=6, small=89.17%, large=0.24%, one_to_many=10.83%
#     Recommended Strategy: None
# [*] Analyzing clusters from correspondences_musicbrainz_lastfm.csv
#     Metrics: clusters=2548, max_size=26, small=91.41%, large=2.04%, one_to_many=11.14%
#     Recommended Strategy: AdjustMatchingConfig
#     Overall: recommended_strategy=AdjustMatchingConfig, unhealthy_files=2
#
#     Aggregated cluster analysis report saved to output/cluster-evaluation/cluster_analysis_report.json
# [+] Applied cluster-driven matching threshold adjustments for: ['discogs_lastfm', 'musicbrainz_lastfm']
# [*] Evaluation reasoning:
# ## 1) Dominant error types (from metrics + debug events)
#
# ### A. Fusion policy errors (dominant)
# These are not blocking/matching misses; they are *wrong conflict resolution choices* during fusion.
#
# - **Label: 0.625 accuracy (and 37 “missing_fused_value” overall)**
#   - Debug shows many cases where **`label` becomes `null`** while gold expects a value.
#   - That strongly suggests the fused cluster *had a label in at least one source*, but the fusion strategy did not select it (or the attribute got dropped/emptied during preprocessing).
#
# - **Artist: 0.304 accuracy (worst attribute)**
#   - Examples: `"m. chemical romance"` vs `"My Chemical Romance"`, `"fuellsand feat."` vs `"Fuellsand"`.
#   - This is classic **string canonicalization + “feat.” handling** and **abbreviation expansion** problems; `longest_string` often picks the *wrong* variant (longest ≠ best/canonical).
#
# - **Tracks (list attributes) are noisy under `union`**
#   - `tracks_track_duration` accuracy **0.3** and lots of mismatches show **extra/missing items** and sometimes obviously bad values (e.g., `"0"`).
#   - `union` maximizes recall but produces *supersets* compared to gold, which is penalized by `tokenized_match` (it’s not “contains”, it’s “similar enough” as a whole).
#   - Similarly, `tracks_track_name` mismatches show duplicates/variants and corrupted tokens (`aintmt`, mojibake apostrophes), again exacerbated by `union`.
#
# ### B. Schema/preprocessing issues (secondary but important)
# - **Mojibake/encoding issues still leak into fused output**
#   - `"Sheâ€™s Got Issues"` mismatch indicates that either:
#     - `_repair_mojibake` didn’t fix the exact byte-pattern, or
#     - different sources are repaired differently, or
#     - later steps reintroduce bad encodings (less likely).
# - **Release-country mismatches include region-like values**
#   - `"europe"` vs `"Luxembourg"`, `"Germany"` vs `"XW"`, `null` vs `"Luxembourg"`.
#   - This is **semantic granularity conflict** (region vs country, or unknown code vs country name), not blocking.
#
# ### C. Matching/cluster errors exist, but are not the main driver of *attribute* accuracy
# Cluster analysis flags over-clustering for discogs↔lastfm and musicbrainz↔lastfm; that can inject wrong values into clusters and degrade fusion. However, the debug mismatches you shared are overwhelmingly **within correctly aligned fused_id==expected_id**, i.e., *the entity is right but the fused attribute value is wrong* → fusion policy/normalization dominates.
#
# ---
#
# ## 2) Likely root causes (blocking vs matching vs schema vs code)
#
# ### Blocking
# - Given “optimal blocking” pair-completeness ~0.95–1.0 and full mapped gold coverage (25/25 via `_fusion_sources`), **blocking is not the main issue for this evaluation**.
#
# ### Matching
# - Your pipeline thresholds differ from the “optimal matching configuration”:
#   - discogs_lastfm: **0.75 used vs 0.80 optimal**
#   - musicbrainz_lastfm: **0.78 used vs 0.83 optimal**
# - Cluster analysis also indicates **over-clustering** for those two pairs.
# - But per your instruction, blocking/matching are “already determined”; still, note this because **over-matching directly harms fusion** (polluted clusters → wrong union/longest_string).
#
# ### Schema/preprocessing
# - **Yes, contributes materially**:
#   - artist normalization (“feat.”, abbreviations like “m.”, punctuation)
#   - track list cleaning (remove 0 durations, de-duplicate, normalize apostrophes/diacritics consistently)
#   - country normalization/granularity harmonization (region tokens like “Europe”)
#
# ### Pipeline fusion logic (primary)
# Current fusion choices are mismatched to the data:
# - `longest_string` for `artist`, `label`, `release-country`, `name` is often a poor proxy for “best”.
# - `union` for track lists produces noisy supersets; gold seems closer to “canonical tracklist” not “all observed variants”.
#
# ---
#
# ## 3) Cluster analysis report: what it implies for fusion
#
# - **discogs_lastfm and musicbrainz_lastfm are unhealthy (non-long-tail, large max cluster sizes 18 and 26)**
#   - Even with MaximumBipartiteMatching, you can still end up with multi-record clusters across the *3-way union* when combining three correspondence sets.
#   - Fusion functions like `union` and `longest_string` are *very sensitive* to polluted clusters:
#     - `union` adds spurious track entries/durations
#     - `longest_string` may pick an outlier (e.g., “feat.” strings, marketing suffixes)
# - discogs_musicbrainz is healthy; treat it as the “anchor” source pair for canonical attributes when available.
#
# ---
#
# ## 4) Concrete, actionable improvements (next iteration, focusing on fusion)
#
# ### 4.1 Replace naive `longest_string` with “best-supported / most-consensual” fusers
# Goal: pick values that multiple sources agree on, not the longest.
#
# **Recommended approach**
# - For scalar strings (`artist`, `label`, `release-country`, `name`):
#   1. Normalize candidates (casefold, strip, mojibake repair, remove “feat.” suffix for artist, normalize punctuation)
#   2. Choose the **mode** (most frequent normalized value) when there is agreement
#   3. Tie-break by:
#      - prefer MusicBrainz for artist/name canonicalization (often cleaner)
#      - else prefer Discogs for label/country (often populated)
#      - else fallback to longest_string
#
# In PyDI terms, if you don’t have a built-in “most_common” fuser, implement a small custom fuser that receives the inputs and returns the best-supported value.
#
# ### 4.2 Track lists: stop using raw `union` for `tracks_*`
# `union` is causing the largest accuracy collapses (`tracks_track_duration` 0.3).
#
# **Better fusion policy for tracks**
# - De-duplicate after normalization (token-normalize track names; int-normalize durations)
# - Filter implausible durations (`0`, negative, very small like `< 30s` unless you know intros exist)
# - Prefer **MusicBrainz tracklists as canonical**, and only enrich from other sources when:
#   - track position matches and
#   - duration within tolerance (±2–5s) and/or name similarity above a threshold
#
# If you must keep a single fuser:
# - For `tracks_track_duration`: consider a *position-aligned median* (requires custom logic), not a set union.
# - For `tracks_track_name`: consider *position-aligned “best name”* rather than union.
#
# ### 4.3 Labels missing in fused output: fix “null selection”
# Given repeated `missing_fused_value` for `label`, do two checks:
# - **Check whether label exists in inputs but gets lost**
#   - If yes: your fuser is not seeing it (schema mismatch) or is receiving empty strings that evaluate as missing.
# - **Make label list-aware**
#   - Gold label examples include multi-label strings with `|`. You currently treat label as scalar and use `longest_string`.
#   - Consider normalizing label to list (split on `|`) and fusing with `union`, then serialize back to `|`-joined canonical order (or keep JSON list, but align with evaluation expectations).
#
# ### 4.4 Add post-fusion cleaning steps (low effort, high impact)
# After fusion (before saving):
# - Artist cleanup:
#   - strip “feat.”, “featuring”, trailing “feat.” fragments
#   - expand common abbreviations if present (at least handle `"m."` when next token suggests a known band pattern; or simpler: drop single-letter abbreviation + dot at start)
# - Tracks:
#   - remove duplicates
#   - remove duration `0`
#   - ensure positions are unique integers; if duplicates, keep smallest/most-supported
#
# ### 4.5 Keep discogs_musicbrainz as a “trusted backbone”
# When discogs↔musicbrainz match exists, prefer:
# - `release-date`, `release-country` from MusicBrainz (already high accuracy)
# - `label` from Discogs (seems very populated per agreement stats)
# - `artist` from MusicBrainz (usually canonical)
#
# This is essentially **source-priority fusion conditioned on correspondence presence**.
#
# ---
#
# ## Normalization Recommendations
#
# 1) **Country normalization (explicit)**
# - Target column: `release-country`
# - Use PyDI: `normalize_country(value, output_format="name")` during *pipeline preprocessing* (not only evaluation).
# - Add mapping for region-like tokens before calling normalize_country:
#   - `"europe"` → keep as `None` (or special code) rather than a “country”, so it doesn’t override a real country in fusion.
#
# 2) **List normalization**
# - Targets: `label` (if you convert to multi-value), `tracks_track_name`, `tracks_track_duration`, `genre`
# - You already use `detect_list_like_columns / normalize_list_like_columns`; extend it by:
#   - applying it to `label` as well (split on `|` when present)
#   - applying consistent lowercasing + mojibake repair to each list item
#
# 3) **Artist canonicalization**
# - Target: `artist`
# - Add normalization steps:
#   - remove/normalize `feat.` / `featuring` patterns (`r"\s+(feat\.|featuring)\b.*$"`)
#   - collapse punctuation/diacritics consistently (you already do NFKC; ensure it’s applied before any matching/fusion too)
#
# 4) **Track duration normalization**
# - Target: `tracks_track_duration`
# - Filter values:
#   - drop `0`
#   - drop non-numeric
#   - optionally cap absurd durations (e.g., > 3600s) unless domain allows
#
# ---
#
# ## Summary: what to change next
# - The biggest quality gains will come from **fusion policy upgrades**:
#   - replace `longest_string` (artist/label/country/name) with **consensus/source-priority** fusers
#   - replace `union` for track attributes with **position-aligned canonical tracklist fusion** (or at least strong de-dup + filtering)
# - Secondarily, ensure **country + artist + track token normalization** happens *pre-fusion* (not just in evaluation).
# - Cluster analysis suggests over-matching in two pairs; even if you keep the “determined” matching config, the fusion layer must be robust to occasional polluted clusters (consensus-based fusers are exactly that).
# TOKEN USAGE (investigator_normalization_assessment):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 10,862
#    Completion tokens: 527
#    Total tokens: 11,389
#    Estimated cost: $0.018847
# [*] Investigator decision: rerun normalization before next pipeline iteration
# [INVESTIGATION REPORT]
#   Investigation Performed:
#     - Ran integration diagnostics script and loaded findings
#     - Re-read evaluation metrics and auto diagnostics
#     - Ran cluster analysis on latest pairwise correspondence files
#     - Cluster files inspected: 3
#   Problem Determination:
#     - overall_accuracy=63.452%, evaluation_attempt=1/3
#     - diagnostics finding: HIGH: Missing expected pairwise correspondence files for at least one source pair.
#     - diagnostics finding: MEDIUM: List-format inconsistencies detected directly in fused output (JSON-list vs scalar vs malformed).
#     - diagnostics finding: MEDIUM: Fusion size-estimate drift detected (expected vs actual fused rows).
#     - cluster recommendation: AdjustMatchingConfig
#     - reasoning summary: ## 1) Dominant error types (from metrics + debug events)  ### A. Fusion policy errors (dominant) These are not blocking/matching misses; they are *wrong conflict resolution choices* during fusion.  - **Label: 0.625 accur...
#     - suggested country normalization columns: release-country
#     - suggested country output format: name
#     - suggested list normalization columns: tracks_track_name, tracks_track_position, tracks_track_duration
#     - suggested lowercase columns (validation-style): id, release-date_provenance, release-country_provenance, duration_provenance, label_provenance, genre_provenance
#   Recommendation:
#     - rerun normalization before adapting pipeline
#     - normalization trigger: Integration diagnostics detected list-format inconsistencies in the fused output for `name` (989 scalar vs 11 delimited in a 1000-value sample), which can break exact comparisons against validation-style scalars.
#     - normalization trigger: Multiple evaluated attributes are list-mode in source agreement (`tracks_track_name`, `tracks_track_position`, `tracks_track_duration`, `genre`), so consistent list encoding/cleaning is likely required; current track accuracies are very low (e.g., `tracks_track_duration`=0.3), consistent with noisy/unrepaired list representations and malformed items (e.g., '0' durations) described in the reasoning.
#     - normalization trigger: Evaluation reasoning notes mojibake/encoding artifacts (e.g., "Sheâ€™s Got Issues"), indicating text canonicalization gaps that can produce mismatches even when the underlying value is the same.
#     - normalization trigger: Validation hints indicate country values should be normalized to country names (`inferred_country_output_format`='name'); `release-country` is explicitly country-mode in agreement stats, so rerunning/ensuring country normalization to names is appropriate even though country mismatches are not dominant in debug signals.
# [*] Running normalization node
# [+] Normalization completed; using normalized datasets
# [*] Blocking config already present in state; skipping BlockingTester
# [*] Existing matching config found in state, but forcing recomputation to refresh failed settings.
# [*] Using MatchingTester module: /Users/nickblazek/Desktop/Agent_Pipeline/agents/matching_tester.py
# [*] Running MatchingTester
# [*] Loading dataset: discogs
# [*] Loading dataset: lastfm
# [*] Loading dataset: musicbrainz
# [*] Normalized list-like columns for matching: tracks_track_duration, tracks_track_name, tracks_track_position
# [*] Loading matching gold standard for discogs <-> lastfm
#     Loaded 417 ground truth pairs
# [*] Loading matching gold standard for discogs <-> musicbrainz
#     Loaded 500 ground truth pairs
# [*] Loading matching gold standard for musicbrainz <-> lastfm
#     Loaded 500 ground truth pairs
#
# ==================================================
# MATCHING EVALUATION
# ==================================================
#
# ==================================================
# MATCHING: discogs <-> lastfm
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['artist', 'name', 'duration']
#
# --- Attempt 1/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine', 'duration:5.0']
# Weights: [0.4, 0.45, 0.15]
# Threshold: 0.75
#     Reasoning: Use blocking columns artist and duration plus title/name for robust matching. Avoid list-like track fields as instructed. Artist is a strong identifier (typo-tolerant JW), name can include extra tokens so cosine on normalized text is appropriate, and duration (often missing on one side) is a light supporting signal with small tolerance.
#     Reasoning (100c): Use blocking columns artist and duration plus title/name for robust matching. Avoid list-like track
# SUCCESS: F1=0.7922
#
# ==================================================
# MATCHING: discogs <-> musicbrainz
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['artist', 'name']
#
# --- Attempt 1/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine', 'release-date:365', 'duration:30.0']
# Weights: [0.4, 0.4, 0.1, 0.1]
# Threshold: 0.78
#     Reasoning: Use blocking columns artist and name as primary identifiers; artist benefits from typo-tolerant Jaro-Winkler, while release name works well with token-based cosine after normalization. Add release-date (within 1 year) and total duration (within 30s) as supporting evidence. Avoid track list fields per instruction.
#     Reasoning (100c): Use blocking columns artist and name as primary identifiers; artist benefits from typo-tolerant Jaro
# SUCCESS: F1=0.8589
#
# ==================================================
# MATCHING: musicbrainz <-> lastfm
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'artist', 'tracks_track_name']
#
# --- Attempt 1/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine']
# Weights: [0.45, 0.55]
# Threshold: 0.78
#     Reasoning: Avoided list-like columns (tracks/duration fields) per guidance. Used scalar blocking columns artist and name: artist is a strong identifier suited to jaro_winkler for minor variations, while name can include extra tokens (e.g., artist prefix) so cosine on normalized text is robust. Slightly higher weight on name and a moderately high threshold to reduce false positives.
#     Reasoning (100c): Avoided list-like columns (tracks/duration fields) per guidance. Used scalar blocking columns artist
# F1=0.6995 < 0.75
#
# --- Attempt 2/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine']
# Weights: [0.55, 0.45]
# Threshold: 0.68
#     Reasoning: Avoided all list-like columns as instructed. Strengthened string matching by using Jaro-Winkler on short 'artist' (robust to minor variations) and cosine on longer 'name' (handles extra tokens like 'john b -'). Lowered threshold slightly from prior 0.75 since matches were close (0.70) and data is somewhat noisy in 'name'.
#     Reasoning (100c): Avoided all list-like columns as instructed. Strengthened string matching by using Jaro-Winkler on s
# F1=0.6697 < 0.75
#
# --- Attempt 3/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine']
# Weights: [0.45, 0.55]
# Threshold: 0.68
#     Reasoning: Avoided all list-like columns per guidance; used blocking scalar columns artist and name. Jaro-Winkler on artist is robust to minor spelling/punctuation differences, while cosine on name helps match longer titles where one side may prepend the artist (e.g., 'john b - ...'). Lowered threshold slightly since previous runs with only these two fields were just below 0.75 and name strings contain extra tokens.
#     Reasoning (100c): Avoided all list-like columns per guidance; used blocking scalar columns artist and name. Jaro-Winkl
# F1=0.6851 < 0.75
#
# --- Attempt 4/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine']
# Weights: [0.55, 0.45]
# Threshold: 0.66
#     Reasoning: Avoided list-like track/duration fields per guidance. Switched artist to jaro_winkler to be strict on short identifier-like strings, and used cosine on name to handle longer tokenized titles where one side may include the artist prefix. Lowered threshold slightly from prior 0.75 since only two scalar text fields are usable and prior scores clustered around 0.67–0.70.
#     Reasoning (100c): Avoided list-like track/duration fields per guidance. Switched artist to jaro_winkler to be strict o
# F1=0.6727 < 0.75
# Max attempts reached. Best F1=0.6995
#
# 📊 Results: 3 pairs evaluated
#   OK discogs_lastfm: F1=0.7922
#   OK discogs_musicbrainz: F1=0.8589
#   WARN musicbrainz_lastfm: F1=0.6995
# [*] Matching fused-size estimate: rows=27461, unique_ids=27461
# [*] Matching estimate breakdown: matched_only_rows=9794, singleton_aware_rows=27461
# ...
#     "stage": "matching",
#     "method": "3-way inclusion-exclusion over pair estimates: E=E12+E13+E23-2*E123, with E123 estimated from per-dataset overlap probabilities; singleton-aware projection applied for final fused output (include_singletons=True assumption)",
#     "expected_rows": 27452,
#     "expected_unique_ids": 27452,
#     "expected_rows_range": [
#       22096,
#       28790
#     ],
#     "expected_unique_ids_range": [
#       22096,
#       28790
#     ],
#     "three_way_intersection": {
#       "enabled": true,
#       "datasets": [
#         "discogs",
#         "lastfm",
#         "musicbrainz"
#       ],
#       "pair_cluster_estimates": {
#         "discogs_lastfm": 7892,
#         "discogs_musicbrainz": 3920,
#         "lastfm_musicbrainz": 3347
#       },
#       "triple_intersection_estimates": {
#         "via_discogs": 1367.2444424802227,
#         "via_lastfm": 2677.6,
#         "via_musicbrainz": 2754.616838127231,
#         "median_used": 2677.6,
#         "final_triple_intersection": 2678,
#         "triple_intersection_range": [
#           0,
#           3347
#         ]
#       },
#       "expected_union_clusters": 9803,
#       "expected_union_range": [
#         8465,
#         15159
#       ],
#       "formula": "E_union = E12 + E13 + E23 - 2*E123"
#     },
#     "pair_estimates": [
#       {
#         "pair_key": "discogs_lastfm",
#         "left_dataset": "discogs",
#         "right_dataset": "lastfm",
#         "min_pair_size": 9865,
#         "pair_completeness": 1.0,
#         "f1": 0.8,
#         "expected_cluster_count": 7892
#       },
#       {
#         "pair_key": "discogs_musicbrainz",
#         "left_dataset": "discogs",
#         "right_dataset": "musicbrainz",
#         "min_pair_size": 4763,
#         "pair_completeness": 0.9533333333333334,
#         "f1": 0.8633540372670808,
#         "expected_cluster_count": 3920
#       },
#       {
#         "pair_key": "musicbrainz_lastfm",
#         "left_dataset": "lastfm",
#         "right_dataset": "musicbrainz",
#         "min_pair_size": 4763,
#         "pair_completeness": 0.9866666666666667,
#         "f1": 0.7121951219512195,
#         "expected_cluster_count": 3347
#       }
#     ],
#     "created_at": "2026-02-25T08:44:57.481229+00:00",
#     "expected_rows_matched_only": 9803,
#     "expected_unique_ids_matched_only": 9803,
#     "expected_rows_matched_only_range": [
#       8465,
#       15159
#     ],
#     "expected_unique_ids_matched_only_range": [
#       8465,
#       15159
#     ],
#     "expected_rows_singleton_aware": 27452,
#     "expected_unique_ids_singleton_aware": 27452,
#     "expected_rows_singleton_aware_range": [
#       22096,
#       28790
#     ],
#     "expected_unique_ids_singleton_aware_range": [
#       22096,
#       28790
#     ],
#     "singleton_assumption": {
#       "assumed_include_singletons": true,
#       "total_input_rows": 37255,
#       "formula": "E_final_rows = total_input_rows - E_matched_clusters",
#       "notes": "Conservative singleton-aware estimate: each expected matched cluster reduces the final row count by at least one."
#     }
#   }
# }
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 45,314
#    Completion tokens: 4,821
#    Total tokens: 50,135
#    Estimated cost: $0.104853
# [DEBUG] Updated variable assignment for discogs_lastfm to 0.78
# [DEBUG] Updated variable assignment for discogs_musicbrainz to 0.78
# [DEBUG] Updated variable assignment for musicbrainz_lastfm to 0.78
# [+] Applied programmatic threshold updates to generated pipeline code.
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Normalized list-like columns: tracks_track_duration, tracks_track_name, tracks_track_position
# Performing Blocking
# Matching Entities
# Post-clustering (MaximumBipartiteMatching)
# Fusing Data
#
# [PIPELINE STDERR]
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/pipeline.py:69: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   return bool(pd.isna(x))
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/pipeline.py:69: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   return bool(pd.isna(x))
#
# [FUSION SIZE COMPARISON]
#   blocking: expected_rows=27110 actual_rows=31384 rows_pct_error=0.15765400221320547
#   matching: expected_rows=27452 actual_rows=31384 rows_pct_error=0.1432318228180096
# [*] Running consolidated evaluation node
# [EVALUATION EXECUTION] Attempt 1/3
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 13,671
#    Completion tokens: 151
#    Total tokens: 13,822
#    Estimated cost: $0.018599
# [SEARCH TOOL CALL 1]: Asking 'PyDI DataFusionEvaluator usage: evaluate parameters, expected input columns, output metrics structure'
# [SEARCH TOOL CALL 2]: Asking 'PyDI fusion evaluation functions: tokenized_match, year_only_match, numeric_tolerance_match, set_equality_match; how to configure thresholds/kwargs'
# [SEARCH TOOL CALL 3]: Asking 'DataFusionStrategy.add_evaluation_function signature and examples'
# [SEARCH TOOL CALL 4]: Asking 'PyDI.io.load_xml parameters for testset loading; nested_handling options and id column naming'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 19,963
#    Completion tokens: 2,822
#    Total tokens: 22,785
#    Estimated cost: $0.053174
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# {
#   "id_alignment": {
#     "gold_size": 25,
#     "direct__id_coverage": 11,
#     "mapped_eval_id_coverage": 25,
#     "used_gold_path": "input/datasets/music/testsets/validation_set.xml",
#     "used_fused_path": "output/data_fusion/fusion_data.csv"
#   },
#   "country_normalization": {
#     "columns": [
#       "release-country"
#     ],
#     "output_format": "name"
#   },
#   "list_normalization": {
#     "columns": [
#       "genre",
#       "tracks_track_duration",
#       "tracks_track_name",
#       "tracks_track_position"
#     ]
#   }
# }
#
# EVAL_FUNCTIONS_SUMMARY: artist:tokenized_match(threshold=0.75) | duration:numeric_tolerance_match(tolerance=30.0) | genre:tokenized_match(threshold=0.75) | label:tokenized_match(threshold=0.85) | name:tokenized_match(threshold=0.85) | release-country:tokenized_match(threshold=0.65) | release-date:year_only_match | tracks_track_duration:tokenized_match(threshold=0.85) | tracks_track_name:tokenized_match(threshold=0.65) | tracks_track_position:tokenized_match(threshold=0.9)
#
# EVALUATION_METRICS_JSON:
# {
#   "artist_accuracy": 0.92,
#   "artist_count": 25,
#   "duration_accuracy": 0.8,
#   "duration_count": 25,
#   "genre_accuracy": 0.28,
#   "genre_count": 25,
#   "label_accuracy": 0.36,
#   "label_count": 25,
#   "macro_accuracy": 0.5920000000000001,
#   "name_accuracy": 0.92,
#   "name_count": 25,
#   "num_evaluated_attributes": 10,
#   "num_evaluated_records": 25,
#   "overall_accuracy": 0.592,
#   "release-country_accuracy": 0.84,
#   "release-country_count": 25,
#   "release-date_accuracy": 1.0,
#   "release-date_count": 25,
#   "total_correct": 148,
#   "total_evaluations": 250,
#   "tracks_track_duration_accuracy": 0.04,
#   "tracks_track_duration_count": 25,
#   "tracks_track_name_accuracy": 0.4,
#   "tracks_track_name_count": 25,
#   "tracks_track_position_accuracy": 0.36,
#   "tracks_track_position_count": 25
# }
#
# [EVALUATION EXECUTION] Status: success
# [*] Running consolidated investigator node
# [*] Running free integration diagnostics
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.592, "macro_accuracy": 0.5920000000000001, "num_evaluated_records": 25, "num_evaluated_attributes": 10, "total_evaluations": 250, "total_correct": 148, "genre_accuracy": 0.28, "genre_count": 25, "artist_accuracy": 0.92, "artist_count": 25, "duration_accuracy": 0.8, "duration_count": 25, "tracks_track_duration_accuracy": 0.04, "tracks_track_duration_count": 25, "tracks_track_position_accuracy": 0.36, "tracks_track_position_count": 25, "release-country_accuracy": 0.84, "release-country_count": 25, "name_accuracy": 0.92, "name_count": 25, "release-date_accuracy": 1.0, "release-date_count": 25, "label_accuracy": 0.36, "label_count": 25, "tracks_track_name_accuracy": 0.4, "tracks_track_name_count": 25}
# [EVALUATION REPORT]
#   Stage: validation
#   Attempt: 3/3
#   Overall Accuracy: 59.200%
#   Problems Detected:
#     - overall_accuracy below target: 59.200% < 85.000%
#     - low attribute accuracy: genre=28.000%, label=36.000%, tracks_track_duration=4.000%, tracks_track_name=40.000%, tracks_track_position=36.000%
#     - low direct ID coverage: 44.000%
#     - high missing_fused_value mismatch ratio: 29.412%
#   Planned Adaptation:
#     - max automatic iterations reached; stop adaptation loop
# [*] Auto diagnostics:
# {
#   "debug_reason_counts": {
#     "missing_fused_value": 30,
#     "mismatch": 72
#   },
#   "debug_reason_ratios": {
#     "missing_fused_value": 0.29411764705882354,
#     "mismatch": 0.7058823529411765
#   },
#   "evaluation_stage": "validation",
#   "evaluation_testset_path": "input/datasets/music/testsets/validation_set.xml",
#   "id_alignment": {
#     "gold_count": 25,
#     "direct_coverage": 11,
#     "direct_coverage_ratio": 0.44,
#     "mapped_coverage": 25,
#     "mapped_coverage_ratio": 1.0,
#     "missing_gold_ids": []
#   },
#   "fusion_size_comparison": {
#     "estimate_path": "output/pipeline_evaluation/fusion_size_estimate.json",
#     "actual": {
#       "rows": 31384,
#       "unique_ids": 31384
#     },
#     "comparisons": {
#       "blocking": {
#         "expected_rows": 27110,
#         "actual_rows": 31384,
#         "rows_abs_error": 4274,
#         "rows_pct_error": 0.15765400221320547,
#         "expected_rows_matched_only": 10145,
#         "expected_rows_singleton_aware": 27110,
#         "rows_pct_error_matched_only": 2.093543617545589,
#         "rows_pct_error_singleton_aware": 0.15765400221320547,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 27110,
#         "actual_unique_ids": 31384,
#         "unique_ids_abs_error": 4274,
#         "unique_ids_pct_error": 0.15765400221320547,
#         "reasoning": "Estimate is moderately off; candidate generation and matching quality likely explain the gap. Blocking estimate was conservative; downstream matching/fusion retained more entities than expected.",
#         "compared_at": "2026-02-25T08:47:45.140793+00:00"
#       },
#       "matching": {
#         "expected_rows": 27452,
#         "actual_rows": 31384,
#         "rows_abs_error": 3932,
#         "rows_pct_error": 0.1432318228180096,
#         "expected_rows_matched_only": 9803,
#         "expected_rows_singleton_aware": 27452,
#         "rows_pct_error_matched_only": 2.2014689380801795,
#         "rows_pct_error_singleton_aware": 0.1432318228180096,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 27452,
#         "actual_unique_ids": 31384,
#         "unique_ids_abs_error": 3932,
#         "unique_ids_pct_error": 0.1432318228180096,
#         "reasoning": "Estimate is moderately off; candidate generation and matching quality likely explain the gap. Matching estimate seems conservative; matcher/fusion retained more clusters than projected.",
#         "compared_at": "2026-02-25T08:47:45.140856+00:00"
#       }
#     }
#   },
#   "overall_accuracy": 0.592
# }
# TOTAL TOKEN USAGE:
#    Prompt tokens: 202,893
#    Completion tokens: 24,934
#    Total tokens: 227,827
#    Estimated cost: $0.502956
# [*] Investigator decision: proceed to human review
# [INVESTIGATION REPORT]
#   Investigation Performed:
#     - Ran integration diagnostics script and loaded findings
#     - Re-read evaluation metrics and auto diagnostics
#     - Skipped cluster analysis (target reached or retry budget exhausted)
#   Problem Determination:
#     - overall_accuracy=59.200%, evaluation_attempt=3/3
#     - diagnostics finding: HIGH: List-format inconsistencies detected in fused output
#     - diagnostics finding: MEDIUM: Country canonicalization mismatches detected
#     - diagnostics finding: MEDIUM: Coverage gaps: high missingness in fused attributes
#     - reasoning summary: ## 1) Dominant error types (from metrics + debug events)  ### A. **Fusion errors on track-level list attributes (dominant)** These drive the very low accuracies: - `tracks_track_duration_accuracy = 0.04` - `tracks_track_...
#     - suggested country normalization columns: release-country
#     - suggested country output format: name
#     - suggested list normalization columns: tracks_track_duration, tracks_track_name, tracks_track_position
#     - suggested lowercase columns (validation-style): duration_provenance, genre_provenance, id, label_provenance, release-country_provenance, release-date_provenance
#   Recommendation:
#     - proceed to human_review_export
# [*] Building final human-review package
# [*] Human-review export completed
# [*] Running sealed final test evaluation on held-out test set
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 13,566
#    Completion tokens: 50
#    Total tokens: 13,616
#    Estimated cost: $0.017458
# [SEARCH TOOL CALL 1]: Asking 'DataFusionEvaluator evaluate usage example: required columns, how to add evaluation functions (tokenized_match, year_only_match, numeric_tolerance_match), and output metrics structure'
# TOKEN USAGE (evaluation_adaption):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 14,985
#    Completion tokens: 2,712
#    Total tokens: 17,697
#    Estimated cost: $0.045851
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# {
#   "id_alignment": {
#     "gold_size": 23,
#     "direct__id_coverage": 4,
#     "mapped_eval_id_coverage": 23
#   },
#   "normalization": {
#     "list_eval_columns": [
#       "genre",
#       "tracks_track_duration",
#       "tracks_track_name",
#       "tracks_track_position"
#     ],
#     "country_eval_columns": [
#       "release-country"
#     ],
#     "country_output_format": "name"
#   }
# }
# EVAL_FUNCTIONS: artist:tokenized_match(threshold=0.75) | duration:numeric_tolerance_match(tolerance=30.0) | genre:tokenized_match(threshold=0.75) | label:tokenized_match(threshold=0.85) | name:tokenized_match(threshold=0.85) | release-country:tokenized_match(threshold=0.65) | release-date:year_only_match | tracks_track_duration:tokenized_match(threshold=0.85) | tracks_track_name:tokenized_match(threshold=0.65) | tracks_track_position:tokenized_match(threshold=0.9)
# {
#   "overall_accuracy": 0.7411167512690355,
#   "macro_accuracy": 0.735084541062802,
#   "num_evaluated_records": 23,
#   "num_evaluated_attributes": 9,
#   "total_evaluations": 197,
#   "total_correct": 146,
#   "release-country_accuracy": 0.9130434782608695,
#   "release-country_count": 23,
#   "label_accuracy": 0.6875,
#   "label_count": 16,
#   "tracks_track_position_accuracy": 0.7391304347826086,
#   "tracks_track_position_count": 23,
#   "duration_accuracy": 0.4782608695652174,
#   "duration_count": 23,
#   "artist_accuracy": 0.8695652173913043,
#   "artist_count": 23,
#   "tracks_track_name_accuracy": 0.7391304347826086,
#   "tracks_track_name_count": 23,
#   "release-date_accuracy": 0.9565217391304348,
#   "release-date_count": 23,
#   "name_accuracy": 0.782608695652174,
#   "name_count": 23,
#   "tracks_track_duration_accuracy": 0.45,
#   "tracks_track_duration_count": 20
# }
#
# [*] Sealed final test overall accuracy: 59.200%
# [+] Results saved to: output/results/run_20260225_095422.json
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# from IPython.display import Image, display

# display(Image(agent.graph.get_graph().draw_mermaid_png()))
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
entity_matching_testsets = {
    ("dbpedia", "sales"): INPUT_DIR + "datasets/games/testsets/dbpedia_2_sales_test.csv",
    ("metacritic", "dbpedia"): INPUT_DIR + "datasets/games/testsets/metacritic_2_dbpedia_test.csv",
    ("metacritic", "sales"): INPUT_DIR + "datasets/games/testsets/metacritic_2_sales_test.csv",
}
datasets = [
    INPUT_DIR + "datasets/games/dbpedia.xml",
    INPUT_DIR + "datasets/games/metacritic.xml",
    INPUT_DIR + "datasets/games/sales.xml"
]
fusion_testset = INPUT_DIR + "datasets/games/testsets/test_set_fusion.xml"
validation_fusion_testset = INPUT_DIR + "datasets/games/testsets/validation_set_fusion.xml"
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Skip Blocking and Matching node and use existing strategies saved in 
# "output/blocking-evaluation/blocking_config.json" and "output/matching-evaluation/matching_config.json"
SKIP_BLOCKING_TESTER=False
SKIP_MATCHING_TESTER=False
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Games Dataset
# prepare agent
# agent = SimpleModelAgent(llm, ProfileDatasetTool())
profile_tool = ProfileDatasetTool()
search_tool = SearchDocumentationTool()
all_tools = {profile_tool.name: profile_tool, search_tool.name: search_tool}

agent = SimpleModelAgent(llm, tools=all_tools)

# invoke agent
invoke_payload = {
    "datasets": datasets,
    "original_datasets": list(datasets),
    "normalized_datasets": [],
    "entity_matching_testsets": entity_matching_testsets,
    "fusion_testset": fusion_testset,
    "matcher_mode": "rulebased",
    "evaluation_attempts": 0,
    "normalization_attempts": 0,
    "normalization_execution_result": "",
    "normalization_rework_required": False,
    "normalization_rework_reasons": [],
    "normalization_directives": {},
    "investigator_decision": "",
}

# Optional: enable sealed evaluation mode if validation set is provided.
# In sealed mode, adaptation/evaluation loops use validation_fusion_testset,
# and a final one-time held-out test evaluation runs on fusion_testset.
if "validation_fusion_testset" in globals() and validation_fusion_testset:
    invoke_payload["validation_fusion_testset"] = validation_fusion_testset

result = agent.graph.invoke(
    invoke_payload,
    config={"recursion_limit": 200},
)
# Out:
# [*] Running schema matching
# [*] Schema alignment columns:
#     dbpedia: ['id', 'name', 'releaseYear', 'developer', 'platform', 'series']
#     metacritic: ['id', 'name', 'releaseYear', 'developer', 'platform', 'criticScore', 'userScore', 'ESRB']
#     sales: ['id', 'name', 'releaseYear', 'developer', 'publisher', 'platform', 'criticScore', 'userScore', 'ESRB', 'globalSales']
# [*] Profiling datasets
# TOKEN USAGE (profile_data):
#    Model: gpt-5.2-2025-12-11
#    Prompt tokens: 285
#    Completion tokens: 80
#    Total tokens: 365
#    Estimated cost: $0.001156
# [*] Running normalization node
# [+] Normalization completed; using normalized datasets
# [*] Running BlockingTester
# [*] Loading dataset: dbpedia
# [*] Loading dataset: metacritic
# [*] Loading dataset: sales
# [*] Loading gold standard for dbpedia <-> sales
#     Loaded 596 ground truth pairs (positives: 206, negatives/other: 390)
# [*] Loading gold standard for metacritic <-> dbpedia
#     Loaded 579 ground truth pairs (positives: 187, negatives/other: 392)
# [*] Loading gold standard for metacritic <-> sales
#     Loaded 582 ground truth pairs (positives: 135, negatives/other: 447)
# [*] Adaptive max_candidates set to 2,071,389 (r=0.35%, median_pairs=366,910,660)
#
# ============================================================
# 🤖 BLOCKING: dbpedia <-> sales
# ============================================================
# Gold pairs: 596, PC threshold: 0.9
# Candidate limit: 2,071,389 (hard: 2,382,097 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 46,580 × 7,877 = 366,910,660 potential pairs
# Common columns: ['developer', 'releaseYear', 'platform', 'name']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['name', 'releaseYear', 'platform']
#   Params: {}
#   Reasoning: With 366.9M possible pairs, we need very restrictive blocking to stay under the 2.07M candidate cap....
#     Standard (name+releaseYear+platform): 3,122 candidates
#     ⚠️ PC=0.8641, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['name', 'platform', 'releaseYear']
#   Params: {'top_k': 20}
#   Reasoning: Previous exact_match_multi on (name, releaseYear, platform) was too restrictive (PC=0.864). Use sema...
#     Embedding (name+platform+releaseYear, k=20): 929,573 candidates
#     ✅ PC=0.9126, RR=0.9975
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: metacritic <-> dbpedia
# ============================================================
# Gold pairs: 579, PC threshold: 0.9
# Candidate limit: 2,071,389 (hard: 2,382,097 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 20,494 × 46,580 = 954,610,520 potential pairs
# Common columns: ['developer', 'releaseYear', 'platform', 'name']
#
# --- Attempt 1/5 ---
# LLM chose: semantic_similarity on ['name', 'developer', 'releaseYear']
#   Params: {'top_k': 20}
#   Reasoning: N×M is ~955M so blocking must tightly control candidates. Exact matching is likely to miss many true...
#     Embedding (name+developer+releaseYear, k=20): 409,855 candidates
#     ✅ PC=0.9679, RR=0.9996
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: metacritic <-> sales
# ============================================================
# Gold pairs: 582, PC threshold: 0.9
# Candidate limit: 2,071,389 (hard: 2,382,097 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 20,494 × 7,877 = 161,431,238 potential pairs
# Common columns: ['developer', 'criticScore', 'releaseYear', 'platform', 'userScore', 'name', 'ESRB']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['name', 'platform', 'releaseYear']
#   Params: {}
#   Reasoning: With 161M possible pairs, we need a very restrictive block. Game entities are typically uniquely ide...
#     Standard (name+platform+releaseYear): 5,681 candidates
#     ⚠️ PC=0.7259, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: token_blocking on ['name']
#   Params: {'min_token_len': 5}
#   Reasoning: Exact match on (name, platform, releaseYear) was too restrictive (PC=0.726). To raise PC while keepi...
#     Token (name, len>=5): 635,946 candidates
#     ✅ PC=0.9407, RR=0.9961
# ✅ Found acceptable strategy!
#
# ============================================================
# 📊 RESULTS SUMMARY: 3 pairs evaluated
# ============================================================
#   ✅ dbpedia_sales: PC=0.9126, candidates=929,573, strategy=semantic_similarity
#   ✅ metacritic_dbpedia: PC=0.9679, candidates=409,855, strategy=semantic_similarity
#   ✅ metacritic_sales: PC=0.9407, candidates=635,946, strategy=token_blocking
# [*] Blocking fused-size estimate: rows=54042, unique_ids=54042
# [*] Blocking estimate breakdown: matched_only_rows=20909, singleton_aware_rows=54042
# [*] Fused-size report updated: /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/pipeline_evaluation/fusion_size_estimate.json
#
# 💾 Config saved to: output/blocking-evaluation/blocking_config.json
# [*] Blocking config computed:
# {
#   "blocking_strategies": {
#     "dbpedia_sales": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "platform",
#         "releaseYear"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.912621359223301,
#       "num_candidates": 929573,
#       "is_acceptable": true
#     },
#     "metacritic_dbpedia": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "developer",
#         "releaseYear"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.9679144385026738,
#       "num_candidates": 409855,
#       "is_acceptable": true
#     },
#     "metacritic_sales": {
#       "strategy": "token_blocking",
#       "columns": [
#         "name"
#       ],
#       "params": {
#         "min_token_len": 5
#       },
#       "pair_completeness": 0.9407407407407408,
#       "num_candidates": 635946,
#       "is_acceptable": true
#     }
#   },
#   "id_columns": {
#     "dbpedia": "id",
#     "metacritic": "id",
#     "sales": "id"
#   },
#   "fusion_size_estimate": {
#     "stage": "blocking",
#     "method": "3-way inclusion-exclusion over pair estimates: E=E12+E13+E23-2*E123, with E123 estimated from per-dataset overlap probabilities; singleton-aware projection applied for final fused output (include_singletons=True assumption)",
#     "expected_rows": 54042,
#     "expected_unique_ids": 54042,
#     "expected_rows_range": [
#       40516,
#       54894
#     ],
#     "expected_unique_ids_range": [
#       40516,
#       54894
#     ],
#     "three_way_intersection": {
#       "enabled": true,
#       "datasets": [
#         "dbpedia",
#         "metacritic",
#         "sales"
#       ],
#       "pair_cluster_estimates": {
#         "dbpedia_metacritic": 19836,
#         "dbpedia_sales": 7189,
#         "metacritic_sales": 7410
#       },
#       "triple_intersection_estimates": {
#         "via_dbpedia": 3061.42129669386,
#         "via_metacritic": 7172.087440226408,
#         "via_sales": 6762.789132918624,
#         "median_used": 6762.789132918624,
#         "final_triple_intersection": 6763,
#         "triple_intersection_range": [
#           0,
#           7189
#         ]
#       },
#       "expected_union_clusters": 20909,
#       "expected_union_range": [
#         20057,
#         34435
#       ],
#       "formula": "E_union = E12 + E13 + E23 - 2*E123"
#     },
#     "pair_estimates": [
#       {
#         "pair_key": "dbpedia_sales",
#         "left_dataset": "dbpedia",
#         "right_dataset": "sales",
#         "min_pair_size": 7877,
#         "pair_completeness": 0.912621359223301,
#         "expected_cluster_count": 7189
#       },
#       {
#         "pair_key": "metacritic_dbpedia",
#         "left_dataset": "dbpedia",
#         "right_dataset": "metacritic",
#         "min_pair_size": 20494,
#         "pair_completeness": 0.9679144385026738,
#         "expected_cluster_count": 19836
#       },
#       {
#         "pair_key": "metacritic_sales",
#         "left_dataset": "metacritic",
#         "right_dataset": "sales",
#         "min_pair_size": 7877,
#         "pair_completeness": 0.9407407407407408,
#         "expected_cluster_count": 7410
#       }
#     ],
#     "created_at": "2026-02-25T08:59:26.028995+00:00",
#     "expected_rows_matched_only": 20909,
#     "expected_unique_ids_matched_only": 20909,
#     "expected_rows_matched_only_range": [
#       20057,
#       34435
#     ],
#     "expected_unique_ids_matched_only_range": [
#       20057,
#       34435
#     ],
#     "expected_rows_singleton_aware": 54042,
#     "expected_unique_ids_singleton_aware": 54042,
#     "expected_rows_singleton_aware_range": [
#       40516,
#       54894
#     ],
#     "expected_unique_ids_singleton_aware_range": [
#       40516,
#       54894
#     ],
#     "singleton_assumption": {
#       "assumed_include_singletons": true,
#       "total_input_rows": 74951,
#       "formula": "E_final_rows = total_input_rows - E_matched_clusters",
#       "notes": "Conservative singleton-aware estimate: each expected matched cluster reduces the final row count by at least one."
#     }
#   }
# }
# [*] Using MatchingTester module: /Users/nickblazek/Desktop/Agent_Pipeline/agents/matching_tester.py
# [*] Running MatchingTester
# [*] Loading dataset: dbpedia
# [*] Loading dataset: metacritic
# [*] Loading dataset: sales
# [*] Loading matching gold standard for dbpedia <-> sales
#     Loaded 596 ground truth pairs
# [*] Loading matching gold standard for metacritic <-> dbpedia
#     Loaded 579 ground truth pairs
# [*] Loading matching gold standard for metacritic <-> sales
#     Loaded 582 ground truth pairs
#
# ==================================================
# MATCHING EVALUATION
# ==================================================
#
# ==================================================
# MATCHING: dbpedia <-> sales
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'platform', 'releaseYear']
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'platform:jaro_winkler', 'releaseYear:366', 'developer:jaro_winkler']
# Weights: [0.55, 0.2, 0.15, 0.1]
# Threshold: 0.8
#     Reasoning: Use blocking columns (name, platform, releaseYear) as primary strong signals; apply Jaro-Winkler for short game/platform/developer strings with minor variations and a 1-year date tolerance for releaseYear formatting differences. Developer is informative but slightly noisier, so lower weight; higher threshold favors precision given strong identifiers.
#     Reasoning (100c): Use blocking columns (name, platform, releaseYear) as primary strong signals; apply Jaro-Winkler for
# SUCCESS: F1=0.8488
#
# ==================================================
# MATCHING: metacritic <-> dbpedia
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'developer', 'releaseYear']
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'developer:jaro_winkler', 'releaseYear:366', 'platform:jaro_winkler']
# Weights: [0.55, 0.2, 0.2, 0.05]
# Threshold: 0.78
#     Reasoning: Use all blocking columns: name is the strongest identifier (handle minor title typos), developer adds disambiguation, releaseYear should match within a year due to date normalization (YYYY-01-01), and platform is a weak tie-breaker.
#     Reasoning (100c): Use all blocking columns: name is the strongest identifier (handle minor title typos), developer add
# SUCCESS: F1=0.8917
#
# ==================================================
# MATCHING: metacritic <-> sales
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name']
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'platform:jaro_winkler', 'releaseYear:366', 'developer:jaro_winkler', 'ESRB:jaro_winkler', 'criticScore:5.0', 'userScore:1.0']
# Weights: [0.5, 0.15, 0.1, 0.1, 0.05, 0.05, 0.05]
# Threshold: 0.78
#     Reasoning: Use strong identifier 'name' (also blocking) with typo-tolerant similarity; reinforce with platform and release date to disambiguate editions/ports; add developer and ESRB as secondary checks; include critic/user scores with loose tolerances due to potential scale/rounding and some missing userScore.
#     Reasoning (100c): Use strong identifier 'name' (also blocking) with typo-tolerant similarity; reinforce with platform
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 33
#      30 if "validation_fusion_testset" in globals() and validation_fusion_testset:
#      31     invoke_payload["validation_fusion_testset"] = validation_fusion_testset
# ---> 33 result = agent.graph.invoke(
#      34     invoke_payload,
#      35     config={"recursion_limit": 200},
#      36 )
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/langgraph/pregel/main.py:3085, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3082 chunks: list[dict[str, Any] | Any] = []
#    3083 interrupts: list[Interrupt] = []
# -> 3085 for chunk in self.stream(
#    3086     input,
#    3087     config,
#    3088     context=context,
#    3089     stream_mode=["updates", "values"]
#    3090     if stream_mode == "values"
#    3091     else stream_mode,
#    3092     print_mode=print_mode,
#    3093     output_keys=output_keys,
#    3094     interrupt_before=interrupt_before,
#    3095     interrupt_after=interrupt_after,
#    3096     durability=durability,
#    3097     **kwargs,
#    3098 ):
#    3099     if stream_mode == "values":
#    3100         if len(chunk) == 2:
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/langgraph/pregel/main.py:2674, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2672 for task in loop.match_cached_writes():
#    2673     loop.output_writes(task.id, task.writes, cached=True)
# -> 2674 for _ in runner.tick(
#    2675     [t for t in loop.tasks.values() if not t.writes],
#    2676     timeout=self.step_timeout,
#    2677     get_waiter=get_waiter,
#    2678     schedule_task=loop.accept_push,
#    2679 ):
#    2680     # emit output
#    2681     yield from _output(
#    2682         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2683     )
#    2684 loop.after_tick()
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/langgraph/pregel/_runner.py:162, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     160 t = tasks[0]
#     161 try:
# --> 162     run_with_retry(
#     163         t,
#     164         retry_policy,
#     165         configurable={
#     166             CONFIG_KEY_CALL: partial(
#     167                 _call,
#     168                 weakref.ref(t),
#     169                 retry_policy=retry_policy,
#     170                 futures=weakref.ref(futures),
#     171                 schedule_task=schedule_task,
#     172                 submit=self.submit,
#     173             ),
#     174         },
#     175     )
#     176     self.commit(t, None)
#     177 except Exception as exc:
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/langgraph/pregel/_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:657, in RunnableSeq.invoke(self, input, config, **kwargs)
#     655     # run in context
#     656     with set_config_context(config, run) as context:
# --> 657         input = context.run(step.invoke, input, config, **kwargs)
#     658 else:
#     659     input = step.invoke(input, config)
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:401, in RunnableCallable.invoke(self, input, config, **kwargs)
#     399         run_manager.on_chain_end(ret)
#     400 else:
# --> 401     ret = self.func(*args, **kwargs)
#     402 if self.recurse and isinstance(ret, Runnable):
#     403     return ret.invoke(input, config)
#
# Cell In[10], line 943, in SimpleModelAgent.run_matching_tester(self, state)
#     929 print("[*] Running MatchingTester")
#     930 tester = RuntimeMatchingTester(
#     931     llm=self.base_model,
#     932     datasets=state["datasets"],
#    (...)    941     disallow_list_comparators=True,
#     942 )
# --> 943 _, matching_config = tester.run_all()
#     944 print("[*] Matching config computed:\n" + json.dumps(matching_config, indent=2))
#     945 self.logger.info("Leaving run_matching_tester")
#
# File ~/Desktop/Agent_Pipeline/agents/matching_tester.py:1427, in MatchingTester.run_all(self, id_column)
#    1425 for pair in self.gold_standards.keys():
#    1426     name_left, name_right = pair
# -> 1427     result = self.run_pair_with_llm(name_left, name_right, id_column)
#    1428     if result:
#    1429         all_results.append(result)
#
# File ~/Desktop/Agent_Pipeline/agents/matching_tester.py:1349, in MatchingTester.run_pair_with_llm(self, name_left, name_right, id_column)
#    1347         continue
#    1348 else:
# -> 1349     metrics, error = self._try_execute_matcher(
#    1350         name_left, name_right, blocker, id_column, active_choice, gold
#    1351     )
#    1352 if error:
#    1353     first_line = error.splitlines()[0] if isinstance(error, str) else str(error)
#
# File ~/Desktop/Agent_Pipeline/agents/matching_tester.py:1027, in MatchingTester._try_execute_matcher(self, name_left, name_right, blocker, id_column, choice, gold)
#    1025 comparators = self._build_comparators(stable_choice["comparators"])
#    1026 matcher = RuleBasedMatcher()
# -> 1027 correspondences = matcher.match(
#    1028     df_left=self.datasets_loaded[name_left],
#    1029     df_right=self.datasets_loaded[name_right],
#    1030     candidates=blocker,
#    1031     comparators=comparators,
#    1032     weights=stable_choice["weights"],
#    1033     threshold=stable_choice["threshold"],
#    1034     id_column=id_column,
#    1035 )
#    1036 metrics = self.evaluator.evaluate_matching(
#    1037     correspondences=correspondences,
#    1038     test_pairs=gold,
#    1039 )
#    1040 metrics = self._normalize_metrics(metrics)
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/PyDI/entitymatching/rule_based.py:149, in RuleBasedMatcher.match(self, df_left, df_right, candidates, id_column, comparators, weights, threshold, debug, **kwargs)
#     147         debug_results.extend(batch_debug)
#     148     else:
# --> 149         batch_results = self._process_batch(
#     150             batch, left_lookup, right_lookup, parsed_comparators, threshold, debug=False
#     151         )
#     153     results.extend(batch_results)
#     155 # Calculate total elapsed time
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/PyDI/entitymatching/rule_based.py:297, in RuleBasedMatcher._process_batch(self, batch, left_lookup, right_lookup, comparators, threshold, debug)
#     295     debug_results.extend(pair_debug_results)
#     296 else:
# --> 297     similarity = self._compute_similarity(record1, record2, comparators)
#     299 # Add to results if above threshold
#     300 if similarity >= threshold:
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/PyDI/entitymatching/rule_based.py:343, in RuleBasedMatcher._compute_similarity(self, record1, record2, comparators)
#     341 # Compute similarity using comparator
#     342 if isinstance(comparator, BaseComparator):
# --> 343     similarity = comparator.compare(record1, record2)
#     344 else:
#     345     # Assume it's a callable
#     346     similarity = comparator(record1, record2)
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/PyDI/entitymatching/comparators.py:499, in DateComparator.compare(self, record1, record2)
#     496 if self.list_strategy is None:
#     497     # Both are single values - compare directly
#     498     try:
# --> 499         date1 = pd.to_datetime(val1)
#     500         date2 = pd.to_datetime(val2)
#     501         diff_days = abs((date1 - date2).days)
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1106, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1104         result = convert_listlike(argc, format)
#    1105 else:
# -> 1106     result = convert_listlike(np.array([arg]), format)[0]
#    1107     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1108         result = bool(result)  # TODO: avoid this kludge.
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:431, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     428 arg = ensure_object(arg)
#     430 if format is None:
# --> 431     format = _guess_datetime_format_for_array(arg, dayfirst=dayfirst)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
#
# File ~/Desktop/Agent_Pipeline/agents/venv/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:133, in _guess_datetime_format_for_array(arr, dayfirst)
#     130 if (first_non_null := tslib.first_non_null(arr)) != -1:
#     131     if type(first_non_nan_element := arr[first_non_null]) is str:  # noqa: E721
#     132         # GH#32264 np.str_ object
# --> 133         guessed_format = guess_datetime_format(
#     134             first_non_nan_element, dayfirst=dayfirst
#     135         )
#     136         if guessed_format is not None:
#     137             return guessed_format
#
# File pandas/_libs/tslibs/parsing.pyx:1013, in pandas._libs.tslibs.parsing.guess_datetime_format()
#
# File pandas/_libs/tslibs/parsing.pyx:1072, in pandas._libs.tslibs.parsing._fill_token()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/re/__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# KeyboardInterrupt:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Company Datasets
entity_matching_testsets = {
    ("forbes", "dbpedia"): INPUT_DIR + "datasets/companies/testsets/forbes_dbpedia_art.csv",
    ("forbes", "fullcontact"): INPUT_DIR + "datasets/companies/testsets/forbes_fullcontact_art.csv",
    ("fullcontact", "dbpedia"): INPUT_DIR + "datasets/companies/testsets/fullcontact_dbpedia_art.csv",
}
datasets = [
    INPUT_DIR + "datasets/companies/forbes.csv",
    INPUT_DIR + "datasets/companies/dbpedia.xml",
    INPUT_DIR + "datasets/companies/fullcontact.xml"
]
fusion_testset = INPUT_DIR + "datasets/companies/testsets/test_set.xml"
validation_fusion_testset = INPUT_DIR + "datasets/companies/testsets/validation_set.xml"
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Skip Blocking and Matching node and use existing strategies saved in 
# "output/blocking-evaluation/blocking_config.json" and "output/matching-evaluation/matching_config.json"
SKIP_BLOCKING_TESTER=False
SKIP_MATCHING_TESTER=False
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Company Dataset
# prepare agent
# agent = SimpleModelAgent(llm, ProfileDatasetTool())
profile_tool = ProfileDatasetTool()
search_tool = SearchDocumentationTool()
all_tools = {profile_tool.name: profile_tool, search_tool.name: search_tool}

agent = SimpleModelAgent(llm, tools=all_tools)

# invoke agent
invoke_payload = {
    "datasets": datasets,
    "original_datasets": list(datasets),
    "normalized_datasets": [],
    "entity_matching_testsets": entity_matching_testsets,
    "fusion_testset": fusion_testset,
    "matcher_mode": "rulebased",
    "evaluation_attempts": 0,
    "normalization_attempts": 0,
    "normalization_execution_result": "",
    "normalization_rework_required": False,
    "normalization_rework_reasons": [],
    "normalization_directives": {},
    "investigator_decision": "",
}

# Optional: enable sealed evaluation mode if validation set is provided.
# In sealed mode, adaptation/evaluation loops use validation_fusion_testset,
# and a final one-time held-out test evaluation runs on fusion_testset.
if "validation_fusion_testset" in globals() and validation_fusion_testset:
    invoke_payload["validation_fusion_testset"] = validation_fusion_testset

result = agent.graph.invoke(
    invoke_payload,
    config={"recursion_limit": 200},
)
# Out:
# [*] Running schema matching
# [*] Schema alignment columns:
#     forbes: ['name', 'Sector', 'industry', 'Continent', 'country', 'Market Value', 'Sales', 'Profits', 'assets', 'Rank', 'id']
#     dbpedia: ['id', 'name', 'founded', 'country', 'city', 'industry', 'keypeople_name', 'assets', 'Sales']
#     fullcontact: ['id', 'name', 'country', 'city', 'keypeople_name', 'founded']
# [*] Profiling datasets
# TOKEN USAGE (profile_data):
#    Prompt tokens: 285
#    Completion tokens: 80
#    Total tokens: 365
#    Estimated cost: $0.000000
# [*] Running BlockingTester
# [*] Loading dataset: forbes
# [*] Loading dataset: dbpedia
# [*] Loading dataset: fullcontact
# [*] Loading gold standard for forbes <-> dbpedia
#     Loaded 460 ground truth pairs (positives: 110, negatives/other: 350)
# [*] Loading gold standard for forbes <-> fullcontact
#     Loaded 500 ground truth pairs (positives: 150, negatives/other: 350)
# [*] Loading gold standard for fullcontact <-> dbpedia
#     Loaded 500 ground truth pairs (positives: 150, negatives/other: 350)
# [*] Adaptive max_candidates set to 69,375 (r=0.35%, median_pairs=19,476,066)
#
# ============================================================
# 🤖 BLOCKING: forbes <-> dbpedia
# ============================================================
# Gold pairs: 460, PC threshold: 0.9
# Candidate limit: 69,375 (hard: 79,781 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 2,000 × 10,086 = 20,172,000 potential pairs
# Common columns: ['industry', 'assets', 'name', 'country', 'Sales']
#
# --- Attempt 1/5 ---
# LLM chose: semantic_similarity on ['name', 'industry', 'country']
#   Params: {'top_k': 20}
#   Reasoning: Exact matching is unlikely to work well due to naming variations (abbreviations, punctuation, langua...
#     Embedding (name+industry+country, k=20): 39,997 candidates
#     ✅ PC=1.0000, RR=0.9980
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: forbes <-> fullcontact
# ============================================================
# Gold pairs: 500, PC threshold: 0.9
# Candidate limit: 69,375 (hard: 79,781 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 2,000 × 1,931 = 3,862,000 potential pairs
# Common columns: ['name', 'country']
#
# --- Attempt 1/5 ---
# LLM chose: token_blocking on ['name']
#   Params: {'min_token_len': 5}
#   Reasoning: Exact match on name is likely too strict due to formatting/legal suffix differences (e.g., Inc/DEL, ...
#     Token (name, len>=5): 21,475 candidates
#     ✅ PC=0.9267, RR=0.9944
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: fullcontact <-> dbpedia
# ============================================================
# Gold pairs: 500, PC threshold: 0.9
# Candidate limit: 69,375 (hard: 79,781 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 1,931 × 10,086 = 19,476,066 potential pairs
# Common columns: ['city', 'keypeople_name', 'name', 'country', 'founded']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['name', 'country']
#   Params: {}
#   Reasoning: With ~19.5M possible pairs and a tight max-candidates limit (69,375), we need very selective blockin...
#     Standard (name+country): 271 candidates
#     ⚠️ PC=0.7400, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['name', 'city', 'country']
#   Params: {'top_k': 20}
#   Reasoning: Exact match on (name,country) was too restrictive (PC=0.74). Organization names between FullContact ...
#     Embedding (name+city+country, k=20): 38,130 candidates
#     ✅ PC=0.9867, RR=0.9980
# ✅ Found acceptable strategy!
#
# ============================================================
# 📊 RESULTS SUMMARY: 3 pairs evaluated
# ============================================================
#   ✅ forbes_dbpedia: PC=1.0000, candidates=39,997, strategy=semantic_similarity
#   ✅ forbes_fullcontact: PC=0.9267, candidates=21,475, strategy=token_blocking
#   ✅ fullcontact_dbpedia: PC=0.9867, candidates=38,130, strategy=semantic_similarity
# [*] Blocking fused-size estimate: rows=11853, unique_ids=11853
# [*] Blocking estimate breakdown: matched_only_rows=2164, singleton_aware_rows=11853
# [*] Fused-size report updated: /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/pipeline_evaluation/fusion_size_estimate.json
#
# 💾 Config saved to: output/blocking-evaluation/blocking_config.json
# [*] Blocking config computed:
# {
#   "blocking_strategies": {
#     "forbes_dbpedia": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "industry",
#         "country"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 1.0,
#       "num_candidates": 39997,
#       "is_acceptable": true
#     },
#     "forbes_fullcontact": {
#       "strategy": "token_blocking",
#       "columns": [
#         "name"
#       ],
#       "params": {
#         "min_token_len": 5
#       },
#       "pair_completeness": 0.9266666666666666,
#       "num_candidates": 21475,
#       "is_acceptable": true
#     },
#     "fullcontact_dbpedia": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "city",
#         "country"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.9866666666666667,
#       "num_candidates": 38130,
#       "is_acceptable": true
#     }
#   },
#   "id_columns": {
#     "forbes": "id",
#     "dbpedia": "id",
#     "fullcontact": "id"
#   },
#   "fusion_size_estimate": {
#     "stage": "blocking",
#     "method": "3-way inclusion-exclusion over pair estimates: E=E12+E13+E23-2*E123, with E123 estimated from per-dataset overlap probabilities; singleton-aware projection applied for final fused output (include_singletons=True assumption)",
#     "expected_rows": 11853,
#     "expected_unique_ids": 11853,
#     "expected_rows_range": [
#       8323,
#       11901
#     ],
#     "expected_unique_ids_range": [
#       8323,
#       11901
#     ],
#     "three_way_intersection": {
#       "enabled": true,
#       "datasets": [
#         "forbes",
#         "dbpedia",
#         "fullcontact"
#       ],
#       "pair_cluster_estimates": {
#         "forbes_dbpedia": 2000,
#         "forbes_fullcontact": 1789,
#         "dbpedia_fullcontact": 1905
#       },
#       "triple_intersection_estimates": {
#         "via_forbes": 1789.0,
#         "via_dbpedia": 377.75133848899463,
#         "via_fullcontact": 1764.91196271362,
#         "median_used": 1764.91196271362,
#         "final_triple_intersection": 1765,
#         "triple_intersection_range": [
#           0,
#           1789
#         ]
#       },
#       "expected_union_clusters": 2164,
#       "expected_union_range": [
#         2116,
#         5694
#       ],
#       "formula": "E_union = E12 + E13 + E23 - 2*E123"
#     },
#     "pair_estimates": [
#       {
#         "pair_key": "forbes_dbpedia",
#         "left_dataset": "forbes",
#         "right_dataset": "dbpedia",
#         "min_pair_size": 2000,
#         "pair_completeness": 1.0,
#         "expected_cluster_count": 2000
#       },
#       {
#         "pair_key": "forbes_fullcontact",
#         "left_dataset": "forbes",
#         "right_dataset": "fullcontact",
#         "min_pair_size": 1931,
#         "pair_completeness": 0.9266666666666666,
#         "expected_cluster_count": 1789
#       },
#       {
#         "pair_key": "fullcontact_dbpedia",
#         "left_dataset": "dbpedia",
#         "right_dataset": "fullcontact",
#         "min_pair_size": 1931,
#         "pair_completeness": 0.9866666666666667,
#         "expected_cluster_count": 1905
#       }
#     ],
#     "created_at": "2026-02-18T20:02:15.083359+00:00",
#     "expected_rows_matched_only": 2164,
#     "expected_unique_ids_matched_only": 2164,
#     "expected_rows_matched_only_range": [
#       2116,
#       5694
#     ],
#     "expected_unique_ids_matched_only_range": [
#       2116,
#       5694
#     ],
#     "expected_rows_singleton_aware": 11853,
#     "expected_unique_ids_singleton_aware": 11853,
#     "expected_rows_singleton_aware_range": [
#       8323,
#       11901
#     ],
#     "expected_unique_ids_singleton_aware_range": [
#       8323,
#       11901
#     ],
#     "singleton_assumption": {
#       "assumed_include_singletons": true,
#       "total_input_rows": 14017,
#       "formula": "E_final_rows = total_input_rows - E_matched_clusters",
#       "notes": "Conservative singleton-aware estimate: each expected matched cluster reduces the final row count by at least one."
#     }
#   }
# }
# [*] Running MatchingTester
# [*] Loading dataset: forbes
# [*] Loading dataset: dbpedia
# [*] Loading dataset: fullcontact
# [*] Loading matching gold standard for forbes <-> dbpedia
#     Loaded 460 ground truth pairs
# [*] Loading matching gold standard for forbes <-> fullcontact
#     Loaded 500 ground truth pairs
# [*] Loading matching gold standard for fullcontact <-> dbpedia
#     Loaded 500 ground truth pairs
#
# ==================================================
# MATCHING EVALUATION
# ==================================================
#
# ==================================================
# MATCHING: forbes <-> dbpedia
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'industry', 'country']
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'country:jaro_winkler', 'industry:cosine']
# Weights: [0.7, 0.15, 0.15]
# Threshold: 0.78
#     Reasoning: Use blocking columns with strongest signal: name (non-null, primary identifier) plus country and industry. Avoid numeric fields (assets, Sales) due to extreme nulls on dbpedia side and likely scale/coverage mismatch; focus on robust string similarity with Jaro-Winkler for short names/countries and cosine for industry labels.
#     Reasoning (100c): Use blocking columns with strongest signal: name (non-null, primary identifier) plus country and ind
# F1=0.7087 < 0.75
#
# --- Attempt 2/4 ---
# Comparators: ['name:jaro_winkler', 'country:jaro_winkler', 'industry:cosine']
# Weights: [0.7, 0.2, 0.1]
# Threshold: 0.72
#     Reasoning: Prior config underperformed; strengthen the most reliable identifier (name) using a typo-tolerant metric (jaro_winkler) and downweight noisier fields. Keep blocking columns covered; avoid numeric fields due to very high null rates in dbpedia (assets/sales) and likely scale/definition mismatch. Slightly lower threshold to improve recall while relying on heavier name weight for precision.
#     Reasoning (100c): Prior config underperformed; strengthen the most reliable identifier (name) using a typo-tolerant me
# SUCCESS: F1=0.8029
#
# ==================================================
# MATCHING: forbes <-> fullcontact
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name']
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'country:cosine']
# Weights: [0.85, 0.15]
# Threshold: 0.78
#     Reasoning: Use strong emphasis on the blocking/primary identifier 'name' with typo-tolerant jaro_winkler; include 'country' as a light consistency check despite higher nulls and potential code/name variation.
#     Reasoning (100c): Use strong emphasis on the blocking/primary identifier 'name' with typo-tolerant jaro_winkler; inclu
# F1=0.6873 < 0.75
#
# --- Attempt 2/4 ---
# Comparators: ['name:jaro_winkler', 'country:cosine']
# Weights: [0.85, 0.15]
# Threshold: 0.68
#     Reasoning: Prior config with name+country underperformed; emphasize blocking key 'name' using typo-robust jaro_winkler and downweight country due to high nulls/inconsistent formats (e.g., CHN vs United States). Lower threshold slightly to improve recall while keeping most signal in name.
#     Reasoning (100c): Prior config with name+country underperformed; emphasize blocking key 'name' using typo-robust jaro_
# F1=0.4550 < 0.75
#
# --- Attempt 3/4 ---
# Comparators: ['name:jaro_winkler', 'country:jaro_winkler']
# Weights: [0.85, 0.15]
# Threshold: 0.65
#     Reasoning: Name is the blocking key and most informative; use Jaro-Winkler to handle short org-name variations/typos (e.g., abbreviations). Country is noisier (high nulls, differing formats like CHN vs United States), so keep low weight and also use Jaro-Winkler. Lower threshold to recover recall after prior configs missed 0.75.
#     Reasoning (100c): Name is the blocking key and most informative; use Jaro-Winkler to handle short org-name variations/
# F1=0.4413 < 0.75
#
# --- Attempt 4/4 ---
# Comparators: ['name:jaro_winkler', 'country:jaro_winkler']
# Weights: [0.85, 0.15]
# Threshold: 0.68
#     Reasoning: Prior cosine-like setups underperformed; company names are short and benefit from typo/abbreviation-tolerant jaro_winkler. Country is often missing/inconsistent (codes vs full names), so downweight it and slightly lower threshold while keeping name as the dominant signal. Includes blocking column 'name'.
#     Reasoning (100c): Prior cosine-like setups underperformed; company names are short and benefit from typo/abbreviation-
# F1=0.4420 < 0.75
# Max attempts reached. Best F1=0.6873
#
# ==================================================
# MATCHING: fullcontact <-> dbpedia
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'city', 'country']
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'city:jaro_winkler', 'country:jaro_winkler', 'founded:3650']
# Weights: [0.6, 0.15, 0.1, 0.15]
# Threshold: 0.78
#     Reasoning: Use strong company name match as primary signal (non-null, high discriminative power), include blocking fields city/country for disambiguation, and treat founded as a date with generous tolerance due to missingness/format variability; exclude keypeople_name because it is extremely sparse and noisy.
#     Reasoning (100c): Use strong company name match as primary signal (non-null, high discriminative power), include block
# F1=0.7459 < 0.75
#
# --- Attempt 2/4 ---
# Comparators: ['name:jaro_winkler', 'city:jaro_winkler', 'country:jaro_winkler', 'founded:730']
# Weights: [0.62, 0.13, 0.1, 0.15]
# Threshold: 0.72
#     Reasoning: Prior config likely too strict on threshold and less typo-tolerant. Use Jaro-Winkler for short org/location strings, keep all blocking columns, and treat founded as a date with a 2-year tolerance to handle defaulted/approximate founding dates; reweight heavily toward name and slightly lower threshold for better recall while maintaining precision.
#     Reasoning (100c): Prior config likely too strict on threshold and less typo-tolerant. Use Jaro-Winkler for short org/l
# SUCCESS: F1=0.7775
#
# 📊 Results: 3 pairs evaluated
#   OK forbes_dbpedia: F1=0.8029
#   WARN forbes_fullcontact: F1=0.6873
#   OK fullcontact_dbpedia: F1=0.7775
# [*] Matching fused-size estimate: rows=11586, unique_ids=11586
# [*] Matching estimate breakdown: matched_only_rows=2431, singleton_aware_rows=11586
# [*] Fused-size report updated: /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/pipeline_evaluation/fusion_size_estimate.json
# Config saved to matching_config.json
# [*] Matching config computed:
# {
#   "id_columns": {
#     "forbes": "id",
#     "dbpedia": "id",
#     "fullcontact": "id"
#   },
#   "matching_strategies": {
#     "forbes_dbpedia": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "country",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "industry",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         }
#       ],
#       "weights": [
#         0.7,
#         0.2,
#         0.1
#       ],
#       "threshold": 0.72,
#       "f1": 0.8029197080291971
#     },
#     "forbes_fullcontact": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "country",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         }
#       ],
#       "weights": [
#         0.85,
#         0.15
#       ],
#       "threshold": 0.78,
#       "f1": 0.6873065015479876
#     },
#     "fullcontact_dbpedia": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "city",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "country",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "date",
#           "column": "founded",
#           "max_days_difference": 730
#         }
#       ],
#       "weights": [
#         0.62,
#         0.13,
#         0.1,
#         0.15
#       ],
#       "threshold": 0.72,
#       "f1": 0.7774798927613941
#     }
#   },
#   "fusion_size_estimate": {
#     "stage": "matching",
#     "method": "3-way inclusion-exclusion over pair estimates: E=E12+E13+E23-2*E123, with E123 estimated from per-dataset overlap probabilities; singleton-aware projection applied for final fused output (include_singletons=True assumption)",
#     "expected_rows": 11586,
#     "expected_unique_ids": 11586,
#     "expected_rows_range": [
#       9700,
#       12160
#     ],
#     "expected_unique_ids_range": [
#       9700,
#       12160
#     ],
#     "three_way_intersection": {
#       "enabled": true,
#       "datasets": [
#         "forbes",
#         "dbpedia",
#         "fullcontact"
#       ],
#       "pair_cluster_estimates": {
#         "forbes_dbpedia": 1606,
#         "forbes_fullcontact": 1230,
#         "dbpedia_fullcontact": 1481
#       },
#       "triple_intersection_estimates": {
#         "via_forbes": 987.69,
#         "via_dbpedia": 235.82054332738448,
#         "via_fullcontact": 943.3609528741584,
#         "median_used": 943.3609528741584,
#         "final_triple_intersection": 943,
#         "triple_intersection_range": [
#           0,
#           1230
#         ]
#       },
#       "expected_union_clusters": 2431,
#       "expected_union_range": [
#         1857,
#         4317
#       ],
#       "formula": "E_union = E12 + E13 + E23 - 2*E123"
#     },
#     "pair_estimates": [
#       {
#         "pair_key": "forbes_dbpedia",
#         "left_dataset": "forbes",
#         "right_dataset": "dbpedia",
#         "min_pair_size": 2000,
#         "pair_completeness": 1.0,
#         "f1": 0.8029197080291971,
#         "expected_cluster_count": 1606
#       },
#       {
#         "pair_key": "forbes_fullcontact",
#         "left_dataset": "forbes",
#         "right_dataset": "fullcontact",
#         "min_pair_size": 1931,
#         "pair_completeness": 0.9266666666666666,
#         "f1": 0.6873065015479876,
#         "expected_cluster_count": 1230
#       },
#       {
#         "pair_key": "fullcontact_dbpedia",
#         "left_dataset": "dbpedia",
#         "right_dataset": "fullcontact",
#         "min_pair_size": 1931,
#         "pair_completeness": 0.9866666666666667,
#         "f1": 0.7774798927613941,
#         "expected_cluster_count": 1481
#       }
#     ],
#     "created_at": "2026-02-18T20:03:34.609128+00:00",
#     "expected_rows_matched_only": 2431,
#     "expected_unique_ids_matched_only": 2431,
#     "expected_rows_matched_only_range": [
#       1857,
#       4317
#     ],
#     "expected_unique_ids_matched_only_range": [
#       1857,
#       4317
#     ],
#     "expected_rows_singleton_aware": 11586,
#     "expected_unique_ids_singleton_aware": 11586,
#     "expected_rows_singleton_aware_range": [
#       9700,
#       12160
#     ],
#     "expected_unique_ids_singleton_aware_range": [
#       9700,
#       12160
#     ],
#     "singleton_assumption": {
#       "assumed_include_singletons": true,
#       "total_input_rows": 14017,
#       "formula": "E_final_rows = total_input_rows - E_matched_clusters",
#       "notes": "Conservative singleton-aware estimate: each expected matched cluster reduces the final row count by at least one."
#     }
#   }
# }
# [*] Creating initial pipeline
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 6,963
#    Completion tokens: 48
#    Total tokens: 7,011
#    Estimated cost: $0.000000
# [SEARCH TOOL CALL 1]: Asking 'PyDI EmbeddingBlocker parameters: text_cols, model, index_backend, top_k, batch_size, output_dir, id_column usage and expected inputs'
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 8,248
#    Completion tokens: 1,891
#    Total tokens: 10,139
#    Estimated cost: $0.000000
# [DEBUG] Updated variable assignment for forbes_dbpedia to 0.72
# [DEBUG] Updated variable assignment for forbes_fullcontact to 0.78
# [DEBUG] Updated variable assignment for fullcontact_dbpedia to 0.72
# [+] Applied programmatic threshold updates to generated pipeline code.
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Performing Blocking
# Matching Entities
# Fusing Data
#
# [WARN] Could not compare expected vs actual fusion size: field larger than field limit (131072)
# [*] Running Cluster Analysis to get recommendations...
# [-] No relevant correspondence files found, skipping cluster analysis.
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 4,614
#    Completion tokens: 50
#    Total tokens: 4,664
#    Estimated cost: $0.000000
# [SEARCH TOOL CALL 1]: Asking 'PyDI DataFusionEvaluator evaluate() usage and available match/evaluation functions (tokenized_match, year_only_match, numeric_tolerance_match, set_equality_match)'
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 5,879
#    Completion tokens: 2,016
#    Total tokens: 7,895
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [ID ALIGNMENT] direct _id coverage: 15/25
# [ID ALIGNMENT] mapped eval_id coverage: 25/25
# [EVAL FUNCS] assets:numeric_tolerance_match(tol=0.01) | city:tokenized_match | country:tokenized_match | founded:year_only_match | keypeople_name:tokenized_match | name:tokenized_match | revenue:numeric_tolerance_match(tol=0.01)
# {
#   "overall_accuracy": 0.25757575757575757,
#   "macro_accuracy": 0.260952380952381,
#   "num_evaluated_records": 25,
#   "num_evaluated_attributes": 6,
#   "total_evaluations": 132,
#   "total_correct": 34,
#   "name_accuracy": 0.56,
#   "name_count": 25,
#   "city_accuracy": 0.12,
#   "city_count": 25,
#   "founded_accuracy": 0.28,
#   "founded_count": 25,
#   "country_accuracy": 0.32,
#   "country_count": 25,
#   "keypeople_name_accuracy": 0.2857142857142857,
#   "keypeople_name_count": 7,
#   "assets_accuracy": 0.0,
#   "assets_count": 25
# }
#
# [EVALUATION STDERR]
# year_only_match: could not convert values to date (fused='1472-01-01', expected='1849-01-01T00:00:00')
#
# [*] Running free integration diagnostics
# [INTEGRATION DIAGNOSTICS STDERR]
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/integration_diagnostics.py:18: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.datetime.utcnow().replace(microsecond=0).isoformat() + "Z"
#
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.25757575757575757, "macro_accuracy": 0.260952380952381, "num_evaluated_records": 25, "num_evaluated_attributes": 6, "total_evaluations": 132, "total_correct": 34, "name_accuracy": 0.56, "name_count": 25, "city_accuracy": 0.12, "city_count": 25, "founded_accuracy": 0.28, "founded_count": 25, "country_accuracy": 0.32, "country_count": 25, "keypeople_name_accuracy": 0.2857142857142857, "keypeople_name_count": 7, "assets_accuracy": 0.0, "assets_count": 25}
# [*] Evaluation stage: validation
# [*] Overall Accuracy: 25.758%
# [*] Auto diagnostics:
# {
#   "debug_reason_counts": {
#     "mismatch": 71,
#     "missing_fused_value": 27
#   },
#   "debug_reason_ratios": {
#     "mismatch": 0.7244897959183674,
#     "missing_fused_value": 0.2755102040816326
#   },
#   "evaluation_stage": "validation",
#   "evaluation_testset_path": "input/datasets/companies/testsets/validation_set.xml",
#   "id_alignment": {
#     "gold_count": 25,
#     "direct_coverage": 15,
#     "direct_coverage_ratio": 0.6,
#     "mapped_coverage": 25,
#     "mapped_coverage_ratio": 1.0,
#     "missing_gold_ids": []
#   },
#   "overall_accuracy": 0.25757575757575757
# }
# [*] Evaluation reasoning:
# ## 1) Dominant error types (from metrics + debug)
#
# ### Attribute-level failure pattern (fusion errors)
# - **City accuracy 0.12 (very poor)** with many:
#   - **missing_fused_value** (null fused city when gold has one)
#   - **wrong fused value** (often a *different* city or a “region+city concatenation” like `CaliforniaSan Diego`)
# - **Founded accuracy 0.28 (poor)** with many:
#   - **missing_fused_value**
#   - **wrong year** (even under `year_only_match`, so not just formatting)
# - **Assets accuracy 0.0 (catastrophic)**: fusion strategy guarantees bad numeric behavior (see below).
# - **Name accuracy 0.56 (ok-ish)** but mismatches are systematic: “AG / Inc. / Plc / Limited / Incorporated” or selecting the *wrong entity name entirely* (e.g., China Communications Services fused as a different company).
#
# ### Error type classification
# Given we are told blocking/matching are already optimized, the observed errors mostly indicate **fusion-stage issues**:
# - **False positives / over-clustering symptoms**: fused values come from *other entities* (e.g., Yamaha Motor → Yamaha Corporation; BYD → BYD Electronic; wrong cities/countries). This is typical when a cluster contains multiple real-world entities and fusion picks a value from the wrong member.
# - **False negatives / under-clustering symptoms** show up indirectly as **missing_fused_value**: a gold attribute exists, but the chosen cluster does not include the source that has it (or fusion drops it). This can happen if the correct record didn’t end up in the cluster, or if fusion policy picks null / bad field.
# - Net: **Over-clustering (bad merges) + bad attribute selection** dominates. The debug reason ratios support this: **72% “mismatch”** (wrong value chosen), **28% “missing_fused_value”** (coverage/selection gaps).
#
# ## 2) Likely root cause category
#
# ### Not primarily blocking/matching
# - Blocking completeness is very high (≈0.93–1.0) and matching F1 is decent (0.69–0.80). That’s inconsistent with such disastrous attribute accuracies *unless fusion is wrong or clusters are wrong*.
# - ID alignment coverage is 100% after mapping; evaluation isn’t failing due to missing IDs.
#
# ### Dominant causes: Fusion logic + preprocessing/schema handling
# 1. **Fusion strategy uses `longest_string` for almost everything**
#    - This *systematically* biases toward verbose/garbage values:
#      - **Name**: picks “QUALCOMM Incorporated” over “Qualcomm” (expected shorter canonical).
#      - **City**: picks long address-like strings (`New York (Third Avenue)`, `Castlereagh Street, SydneySydney`) over canonical city.
#      - **Founded**: picks any long date string, not “best” year; also may pick wrong founded from wrong entity if cluster is noisy.
#      - **Assets**: using `longest_string` on numeric fields virtually guarantees failure against `numeric_tolerance_match` → explains **assets_accuracy = 0.0**.
# 2. **Schema/value normalization issues (especially city)**
#    - Many fused city values look concatenated (`GuangdongShenzhen`, `HamamatsuShizuoka Prefecture`, `MilwaukeeWisconsin`). That suggests:
#      - upstream data had delimiter/spacing issues, or list normalization concatenated tokens without separators, or source extraction produced “region+city” strings.
#    - Fusion then selects these because they are “longest”.
# 3. **Cluster quality issues (over-aggregation) likely amplified by fusion**
#    - Wrong-company values (name/city/founded) imply **clusters contain incorrect members**.
#    - Even if matching is “optimal” globally, you still need **fusion-time conflict handling** to prevent a single bad correspondence from dominating attribute choice.
#
# ## 3) Cluster analysis report usage
# - The provided Cluster Analysis Report is empty (`{}`), and the diagnostics explicitly say:
#   - “Could not infer cluster id field from debug JSONL; cluster diagnostics limited.”
# So we can’t leverage cluster-by-cluster recommendations from that report. However, the integration diagnostics *do* flag:
# - **“Potential noisy list fusion (high fan-in list fields)”** with `_fusion_metadata` having extremely high items/cell → indirect evidence of **over-aggregation / too many sources per cluster** or poor metadata serialization.
#
# ## 4) Concrete, actionable improvements (focus: fusion)
#
# ### A. Replace `longest_string` with attribute-appropriate fusers
# **Goal:** choose canonical/clean values and avoid numeric corruption.
#
# - **name**: prefer *shorter canonical legal name* (strip suffixes, pick “best” by voting)
#   - Implement a fuser that:
#     1) normalizes (lower, remove punctuation, remove legal suffixes: `inc`, `ltd`, `plc`, `ag`, `corp`, `incorporated`, etc.)
#     2) uses **majority vote on normalized form**
#     3) returns the *most common* raw value among winners (or shortest raw among tied)
# - **city / country**: do *normalized vote*, not longest
#   - Normalize city strings by:
#     - splitting camelcase/merged tokens if possible, inserting spaces between letter-case transitions
#     - replacing common separators, trimming parentheticals
#     - optionally dropping state/province if appended (`"CaliforniaSan Diego"` → `"San Diego"` heuristic: keep last token(s))
#   - Then **vote**; if tie, choose value from the **highest-confidence source record**.
# - **founded**: choose most plausible year via voting/median
#   - Parse to date/year; take **mode year** (or median year) across sources in the cluster.
#   - Avoid taking outliers (e.g., 1472) unless multiple sources agree.
# - **assets / Sales / Market Value / Profits**: numeric parsing + robust selection
#   - Parse numeric (strip currency, commas, units).
#   - Choose **median** (robust to outliers) or **value from preferred source** (e.g., Forbes) if present.
#   - This change alone should move **assets_accuracy from 0.0 to non-zero**.
#
# ### B. Add source-priority + confidence-weighted fusion
# Right now, fusion ignores match scores except for `_fusion_confidence` metadata.
# - Use a fuser that prioritizes sources known to be authoritative per attribute:
#   - Example policy:
#     - financials: **Forbes > DBpedia > FullContact**
#     - founded/city: **DBpedia/FullContact > Forbes** (since Forbes dataset doesn’t even have city/founded in your schema-matched columns)
# - When multiple sources exist, **weight votes by correspondence score** (or cluster confidence) so a weakly-matched record can’t override.
#
# ### C. Prevent bad merges from poisoning attributes (fusion-time guards)
# Even with “optimal” matching, some false positives remain; fusion must be defensive:
# - **Consistency checks inside cluster before accepting a value**:
#   - If candidate city values disagree strongly (low string similarity) and no majority, return null rather than a random long address.
#   - If founded years differ by > X (e.g., 50 years) and no consensus, pick null or the year from the highest-priority dataset.
# - **Attribute completeness rule**: if the selected value is null but another cluster member has non-null, pick non-null (i.e., don’t let null “win”).
#
# ### D. Fix city concatenation/preprocessing
# Those merged strings (`GuangdongShenzhen`) indicate preprocessing bugs upstream of fusion.
# Add a cleaning step before fusion:
# - regex insert spaces between lowercase→uppercase transitions and between letter blocks (`GuangdongShenzhen` → `Guangdong Shenzhen`)
# - replace duplicated tokens (`SydneySydney` → `Sydney`)
# - strip street/address parts (keep last locality token set)
#
# ### E. Improve fusion debugging to enable real cluster analysis next run
# Your evaluation debug JSONL lacks cluster identifiers, limiting diagnostics.
# - Ensure fusion debug includes:
#   - cluster id (`_id`)
#   - list of contributing record ids per dataset
#   - per-attribute candidate list with source + score
# This will let you quantify over-clustering vs under-clustering and identify which correspondences are poisoning clusters.
#
# ---
#
# ### Minimal code-direction summary (what to change next iteration)
# 1. Replace `strategy.add_attribute_fuser(..., longest_string)` for:
#    - `assets`, `Sales`, `Market Value`, `Profits`, `Rank` → numeric median / preferred-source numeric
#    - `city`, `country`, `name` → normalized voting (optionally confidence-weighted)
#    - `founded` → year mode/median after parsing
# 2. Add preprocessing cleaners for `city` and `name` prior to fusion.
# 3. Add fusion-time conflict guards + source-priority rules.
#
# If you share a few sample fused cluster rows (including `_fusion_sources`, `name/city/founded/assets`), I can propose concrete fuser functions (drop-in Python) tailored to PyDI’s `DataFusionStrategy` calling conventions.
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 19,529
#    Completion tokens: 47
#    Total tokens: 19,576
#    Estimated cost: $0.000000
# [SEARCH TOOL CALL 1]: Asking 'PyDI.fusion DataFusionStrategy add_attribute_fuser callable signature: what arguments are passed to custom fuser functions? Example custom fuser implementation.'
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 20,679
#    Completion tokens: 4,928
#    Total tokens: 25,607
#    Estimated cost: $0.000000
# [DEBUG] Updated variable assignment for forbes_dbpedia to 0.72
# [DEBUG] Updated variable assignment for forbes_fullcontact to 0.78
# [DEBUG] Updated variable assignment for fullcontact_dbpedia to 0.72
# [+] Applied programmatic threshold updates to generated pipeline code.
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [PIPELINE STDOUT]
# Performing Blocking
# Matching Entities
# Fusing Data
#
# [PIPELINE STDERR]
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/pipeline.py:181: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   if 1500 <= y <= datetime.utcnow().year:
# /Users/nickblazek/Desktop/Agent_Pipeline/agents/output/code/pipeline.py:181: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   if 1500 <= y <= datetime.utcnow().year:
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# ...
# WARNING:PyDI.fusion.base:Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_sales failed: fuser_sales() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_name failed: fuser_name() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_country failed: fuser_country() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_assets failed: fuser_assets() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_founded failed: fuser_founded() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_city failed: fuser_city() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_profits failed: fuser_profits() got an unexpected keyword argument 'sources'
# WARNING:PyDI.fusion.base:Function resolver fuser_market_value failed: fuser_market_value() got an unexpected keyword argument 'sources'
#
# [FUSION SIZE COMPARISON]
#   blocking: expected_rows=11853 actual_rows=12833 rows_pct_error=0.08267949042436513
#   matching: expected_rows=11586 actual_rows=12833 rows_pct_error=0.1076298981529432
# [*] Running Cluster Analysis to get recommendations...
# [*] Found 6 relevant correspondence files to analyze.
#
#
# ===================
#  CLUSTER ANALYSIS
# ===================
# [*] Analyzing clusters from correspondences_forbes_fullcontact.csv
#     Metrics: clusters=214, max_size=6, small=97.20%, large=0.47%, one_to_many=2.74%
#     Recommended Strategy: None
# [*] Analyzing clusters from correspondences_fullcontact_dbpedia.csv
#     Metrics: clusters=581, max_size=7, small=88.64%, large=0.17%, one_to_many=10.41%
#     Recommended Strategy: None
# [*] Analyzing clusters from correspondences_forbes_dbpedia.csv
#     Metrics: clusters=356, max_size=43, small=82.02%, large=3.37%, one_to_many=18.98%
#     Recommended Strategy: AdjustMatchingConfig
# [*] Analyzing clusters from correspondences_forbes_fullcontact_mbm.csv
#     Metrics: clusters=216, max_size=2, small=100.00%, large=0.00%, one_to_many=0.00%
#     Recommended Strategy: None
# [*] Analyzing clusters from correspondences_fullcontact_dbpedia_mbm.csv
#     Metrics: clusters=592, max_size=2, small=100.00%, large=0.00%, one_to_many=0.00%
#     Recommended Strategy: None
# [*] Analyzing clusters from correspondences_forbes_dbpedia_mbm.csv
#     Metrics: clusters=400, max_size=2, small=100.00%, large=0.00%, one_to_many=0.00%
#     Recommended Strategy: None
#     Overall: recommended_strategy=AdjustMatchingConfig, unhealthy_files=1
#
#     Aggregated cluster analysis report saved to output/cluster-evaluation/cluster_analysis_report.json
# [+] Applied cluster-driven matching threshold adjustments for: ['forbes_dbpedia']
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 9,414
#    Completion tokens: 49
#    Total tokens: 9,463
#    Estimated cost: $0.000000
# [SEARCH TOOL CALL 1]: Asking 'How do I use DataFusionEvaluator in PyDI to evaluate a fused DataFrame against a gold standard? What does evaluation_results contain and how to print metrics?'
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 10,767
#    Completion tokens: 1,939
#    Total tokens: 12,706
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [ID ALIGNMENT] direct _id coverage: 19/25
# [ID ALIGNMENT] mapped eval_id coverage: 25/25
# [EVAL FUNCTIONS] assets:numeric_tolerance_match | city:tokenized_match | country:tokenized_match | founded:year_only_match | keypeople_name:tokenized_match | name:tokenized_match | revenue:numeric_tolerance_match
# [EVALUATION METRICS]
# {
#   "assets_accuracy": 0.0,
#   "assets_count": 25,
#   "city_accuracy": 0.12,
#   "city_count": 25,
#   "country_accuracy": 0.2,
#   "country_count": 25,
#   "founded_accuracy": 0.24,
#   "founded_count": 25,
#   "keypeople_name_accuracy": 0.2857142857142857,
#   "keypeople_name_count": 7,
#   "macro_accuracy": 0.2742857142857143,
#   "name_accuracy": 0.8,
#   "name_count": 25,
#   "num_evaluated_attributes": 6,
#   "num_evaluated_records": 25,
#   "overall_accuracy": 0.2727272727272727,
#   "total_correct": 36,
#   "total_evaluations": 132
# }
#
# [*] Running free integration diagnostics
# [INTEGRATION DIAGNOSTICS STDOUT]
# Wrote diagnostics JSON: output/pipeline_evaluation/integration_diagnostics.json
# Wrote diagnostics MD:   output/pipeline_evaluation/integration_diagnostics.md
#
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.2727272727272727, "macro_accuracy": 0.2742857142857143, "num_evaluated_records": 25, "num_evaluated_attributes": 6, "total_evaluations": 132, "total_correct": 36, "assets_accuracy": 0.0, "assets_count": 25, "name_accuracy": 0.8, "name_count": 25, "city_accuracy": 0.12, "city_count": 25, "country_accuracy": 0.2, "country_count": 25, "founded_accuracy": 0.24, "founded_count": 25, "keypeople_name_accuracy": 0.2857142857142857, "keypeople_name_count": 7}
# [*] Evaluation stage: validation
# [*] Overall Accuracy: 27.273%
# [*] Auto diagnostics:
# {
#   "debug_reason_counts": {
#     "mismatch": 63,
#     "missing_fused_value": 33
#   },
#   "debug_reason_ratios": {
#     "mismatch": 0.65625,
#     "missing_fused_value": 0.34375
#   },
#   "evaluation_stage": "validation",
#   "evaluation_testset_path": "input/datasets/companies/testsets/validation_set.xml",
#   "id_alignment": {
#     "gold_count": 25,
#     "direct_coverage": 19,
#     "direct_coverage_ratio": 0.76,
#     "mapped_coverage": 25,
#     "mapped_coverage_ratio": 1.0,
#     "missing_gold_ids": []
#   },
#   "fusion_size_comparison": {
#     "estimate_path": "output/pipeline_evaluation/fusion_size_estimate.json",
#     "actual": {
#       "rows": 12833,
#       "unique_ids": 12833
#     },
#     "comparisons": {
#       "blocking": {
#         "expected_rows": 11853,
#         "actual_rows": 12833,
#         "rows_abs_error": 980,
#         "rows_pct_error": 0.08267949042436513,
#         "expected_rows_matched_only": 2164,
#         "expected_rows_singleton_aware": 11853,
#         "rows_pct_error_matched_only": 4.9302218114602585,
#         "rows_pct_error_singleton_aware": 0.08267949042436513,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 11853,
#         "actual_unique_ids": 12833,
#         "unique_ids_abs_error": 980,
#         "unique_ids_pct_error": 0.08267949042436513,
#         "reasoning": "Estimate is close to actual fused size. Blocking estimate was conservative; downstream matching/fusion retained more entities than expected.",
#         "compared_at": "2026-02-18T20:16:07.830757+00:00"
#       },
#       "matching": {
#         "expected_rows": 11586,
#         "actual_rows": 12833,
#         "rows_abs_error": 1247,
#         "rows_pct_error": 0.1076298981529432,
#         "expected_rows_matched_only": 2431,
#         "expected_rows_singleton_aware": 11586,
#         "rows_pct_error_matched_only": 4.27889757301522,
#         "rows_pct_error_singleton_aware": 0.1076298981529432,
#         "better_variant": "singleton_aware",
#         "expected_unique_ids": 11586,
#         "actual_unique_ids": 12833,
#         "unique_ids_abs_error": 1247,
#         "unique_ids_pct_error": 0.1076298981529432,
#         "reasoning": "Estimate is moderately off; candidate generation and matching quality likely explain the gap. Matching estimate seems conservative; matcher/fusion retained more clusters than projected.",
#         "compared_at": "2026-02-18T20:16:07.830829+00:00"
#       }
#     }
#   },
#   "overall_accuracy": 0.2727272727272727
# }
# TOTAL TOKEN USAGE:
#    Prompt tokens: 307,995
#    Completion tokens: 18,161
#    Total tokens: 326,156
#    Estimated cost: $0.000000
# [*] Building final human-review package
# [*] Human-review export completed
# [*] Running sealed final test evaluation on held-out test set
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 9,374
#    Completion tokens: 58
#    Total tokens: 9,432
#    Estimated cost: $0.000000
# [SEARCH TOOL CALL 1]: Asking 'How do I use DataFusionEvaluator in PyDI to evaluate a fused dataframe against a gold XML testset? What are the available built-in evaluation match functions and how to register them with DataFusionStrategy?'
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 10,668
#    Completion tokens: 1,886
#    Total tokens: 12,554
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [EVALUATION STDOUT]
# [ID ALIGNMENT] direct _id coverage: 8/18
# [ID ALIGNMENT] mapped eval_id coverage: 18/18
# [EVAL FUNCTIONS] assets:numeric_tolerance_match | city:tokenized_match | country:tokenized_match | founded:year_only_match | name:tokenized_match | revenue:numeric_tolerance_match
# {
#   "assets_accuracy": 0.16666666666666666,
#   "assets_count": 18,
#   "city_accuracy": 0.7222222222222222,
#   "city_count": 18,
#   "country_accuracy": 0.5555555555555556,
#   "country_count": 18,
#   "founded_accuracy": 0.9444444444444444,
#   "founded_count": 18,
#   "keypeople_name_accuracy": 0.3333333333333333,
#   "keypeople_name_count": 9,
#   "macro_accuracy": 0.6111111111111112,
#   "name_accuracy": 0.9444444444444444,
#   "name_count": 18,
#   "num_evaluated_attributes": 6,
#   "num_evaluated_records": 18,
#   "overall_accuracy": 0.6363636363636364,
#   "total_correct": 63,
#   "total_evaluations": 99
# }
#
# [*] Sealed final test overall accuracy: 63.636%
# [+] Results saved to: output/results/run_20260218_212041.json
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
