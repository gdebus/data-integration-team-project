# %%
import os
import json 
import getpass
import logging
from pathlib import Path
from time import sleep
import subprocess
import sys

from langchain_core.tools import Tool
from langgraph.graph import StateGraph, END
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
from langchain.callbacks import get_openai_callback
from langchain.tools import BaseTool

from typing import TypedDict, Dict, List

from PyDI.io import load_xml, load_parquet, load_csv
from PyDI.profiling import DataProfiler
from blocking_tester import BlockingTester
from matching_tester import MatchingTester
from PyDI.entitymatching import RuleBasedMatcher
from schema_matching_node import run_schema_matching

# %% [markdown]
# ## Initialize

# %%
OUTPUT_DIR = "output/"
INPUT_DIR = "input/"

INCLUDE_DOCS = False # IMPORTANT: Use carefully since token usage is increased drastically with documentation
USE_LLM = "gpt"
#USE_LLM = "gemini"
#USE_LLM = "groq"

# %%
if USE_LLM == "gemini": # or USE_LLM == "gemini_broken":
    if "GOOGLE_API_KEY" not in os.environ:
        os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")
elif USE_LLM == "groq":
    if "GROQ_API_KEY" not in os.environ:
        os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")
elif USE_LLM == "gpt":
    if "OPENAI_API_KEY" not in os.environ:
        os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

# %%
logging.basicConfig(filename= OUTPUT_DIR + 'agent.log',
                    filemode='a',
                    format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.DEBUG,
                    encoding='utf-8')

# %% [markdown]
# ## Utilities

# %%
def load_dataset(path):
    # check file exists
    if not os.path.exists(path):
        raise FileNotFoundError(f"Dataset not found at: {path}")
    ext = os.path.splitext(path)[1].lower()

    # load dataset according to extension
    if ext == ".parquet":
        df = load_parquet(path)
    elif ext == ".csv":
        df = load_csv(path)
    elif ext == ".xml":
        df = load_xml(path, nested_handling="aggregate")
    else:
        raise ValueError(f"Unsupported format: {ext}. Supported: .csv, .parquet, .xml")
    return df

# %% [markdown]
# ## Tools

# %%
class ProfileDatasetTool(BaseTool):
    name: str = "profile_dataset"
    description: str = """
        A tool that takes the path as a argument called `path` of type str of the dataset file as string and performs data analysis. 
        A JSON string is returned with the profile data.
    """
    
    def _run(self, path) -> str:   
        return self.create_profile(path)

    def create_profile(self, path):

        if not path or not isinstance(path, str):
                raise ValueError("ProfileDatasetTool requires a single path string argument.")

        df = load_dataset(path)    
        
        if df is None or getattr(df, "empty", False):
            # return a structured JSON error string (LLM will see this as content)
            return json.dumps({"error": f"Dataset at {path} loaded as empty or failed to load."})

        profiler = DataProfiler()
        profile = profiler.summary(df, print_summary=False)

        # ensure to return a JSON string (your docstring promised JSON string)
        try:
            profile_json = json.dumps(profile, default=str)
        except Exception:
            # fallback: convert to str if not json-serializable
            profile_json = json.dumps({"profile_str": str(profile)})

        return profile_json

# %% [markdown]
# ## Agents

# %%
class SimpleModelAgentState(TypedDict):
    datasets: list
    entity_matching_testsets: list
    fusion_testset: str
    blocking_config: Dict  # NEW: Blocking config from BlockingTester
    matching_config: Dict  # NEW: Matching config from MatchingTester
    matcher_mode: str  # NEW: Matcher mode (rule_based/ml/auto)
    schema_correspondences: Dict  # NEW: Schema matching results
    
    data_profiles: Dict
    
    integration_pipeline_code: str
    pipeline_execution_result: str
    pipeline_execution_attempts: int

    evaluation_code: str
    evaluation_execution_result: str
    evaluation_execution_attempts: int

    evaluation_attempts: int
    evaluation_metrics: Dict
    evaluation_analysis: str

class SimpleModelAgent:
    
    def __init__(self, model, profileTool):
        # initialize logger
        self.logger = logging.getLogger()
        self.base_model = model
        self.token_usage = {"prompt_tokens": 0, "completion_tokens": 0, "total_tokens": 0, "total_cost": 0.0}
        
        # prepare the StateGraph
        graph = StateGraph(SimpleModelAgentState)

        # create nodes
        graph.add_node("match_schemas", self.match_schemas)
        graph.add_node("profile_data", self.profile_data)
        graph.add_node("run_blocking_tester", self.run_blocking_tester)
        graph.add_node("run_matching_tester", self.run_matching_tester)
        graph.add_node("pipeline_adaption", self.pipeline_adaption)
        graph.add_node("execute_pipeline", self.execute_pipeline)
        graph.add_node("evaluation_adaption", self.evaluation_adaption)
        graph.add_node("execute_evaluation", self.execute_evaluation)
        graph.add_node("evaluation_decision", self.evaluation_decision)
        #graph.add_node("evaluation_reasoning", self.evaluation_reasoning)

        # create edges
        graph.add_edge("match_schemas", "profile_data")
        graph.add_edge("profile_data", "run_blocking_tester")
        graph.add_edge("run_blocking_tester", "run_matching_tester")
        graph.add_edge("run_matching_tester", "pipeline_adaption")
        graph.add_edge("pipeline_adaption", "execute_pipeline")
        
        graph.add_conditional_edges(
            "execute_pipeline",
            lambda state: (
                "evaluation_adaption"
                if isinstance(state.get("pipeline_execution_result", ""), str)
                   and state["pipeline_execution_result"].lower().startswith("success")
                else "pipeline_adaption"
                if state.get("pipeline_execution_attempts", 0) < 5
                else END
            ),
            {
                "pipeline_adaption": "pipeline_adaption",
                "evaluation_adaption": "evaluation_adaption",
                END: END
            }
        )

        graph.add_edge("evaluation_adaption", "execute_evaluation")

        graph.add_conditional_edges(
            "execute_evaluation",
            lambda state: (
                "evaluation_decision" 
                if isinstance(state.get("evaluation_execution_result", ""), str)
                   and state["evaluation_execution_result"].lower().startswith("success")
                else "evaluation_adaption"
                if state.get("evaluation_execution_attempts", 0) < 5
                else END
            ),
            {
                "evaluation_adaption": "evaluation_adaption",
                "evaluation_decision": "evaluation_decision",
                END: END
            }
        )


        #graph.add_conditional_edges(
        #    "evaluation_decision",
        #    lambda state: (
        #        "evaluation_reasoning"
        #        if state.get("evaluation_metrics", {}).get("overall_accuracy", 0) < 0.85
        #           and state.get("evaluation_attempts", 0) < 3
        #        else END
        #    ),
        #    {
        #        "evaluation_reasoning": "evaluation_reasoning",
        #        END: END
        #    }
        #)

        #graph.add_edge("evaluation_reasoning", "pipeline_adaption")
        graph.add_conditional_edges(
            "evaluation_decision",
            lambda state: (
                END
                if state.get("evaluation_metrics", {}).get("overall_accuracy", 0) >= 0.85
                   or state.get("evaluation_attempts", 0) >= 5
                else "pipeline_adaption"
            ),
            {
                "pipeline_adaption": "pipeline_adaption",
                END: END
            }
        )

        graph.set_entry_point("match_schemas")
        self.graph = graph.compile()

        # make tools available to the model based on model type
        self.tools = {profileTool.name: profileTool}
#        if USE_LLM == "groq" or USE_LLM == "gpt" or USE_LLM == "gemini":
        self.model = model.bind_tools([profileTool])
#        elif USE_LLM == "gemini_broken":
#            self.model = model.bind_tools(profileTool)
        

    def _invoke_with_usage(self, message, tag):
        with get_openai_callback() as cb:
            result = self.model.invoke(message)
        self.token_usage["prompt_tokens"] += cb.prompt_tokens
        self.token_usage["completion_tokens"] += cb.completion_tokens
        self.token_usage["total_tokens"] += cb.total_tokens
        self.token_usage["total_cost"] += cb.total_cost
        print(f"TOKEN USAGE ({tag}):")
        print(f"   Prompt tokens: {cb.prompt_tokens:,}")
        print(f"   Completion tokens: {cb.completion_tokens:,}")
        print(f"   Total tokens: {cb.total_tokens:,}")
        print(f"   Estimated cost: ${cb.total_cost:.6f}")
        return result

    def _print_total_usage(self):
        t = self.token_usage
        print("TOTAL TOKEN USAGE:")
        print(f"   Prompt tokens: {t['prompt_tokens']:,}")
        print(f"   Completion tokens: {t['completion_tokens']:,}")
        print(f"   Total tokens: {t['total_tokens']:,}")
        print(f"   Estimated cost: ${t['total_cost']:.6f}")

    # Creates tool calls to profile the data and saves it into agent state 
    def match_schemas(self, state: SimpleModelAgentState):
        self.logger.info("----------------------- Entering match_schemas -----------------------")
        if state.get("schema_correspondences"):
            print("[*] Schema correspondences already present; skipping match_schemas")
            return {}

        print("[*] Running schema matching")
        result = run_schema_matching(
            dataset_paths=state["datasets"],
            model=self.base_model,
            output_dir="output/schema-matching",
        )
        self.logger.info("Leaving match_schemas")
        return result

    def profile_data(self, state:SimpleModelAgentState):
        self.logger.info('----------------------- Entering profile_data -----------------------')

        print("[*] Profiling datasets")

        system_prompt = """
            You are a data scientist tasked with the integration of several datasets.
            For each dataset path provided, call the tool `profile_dataset` with the path
            (one tool call per dataset).
        """
        
        datasets_list_str = "\n".join(state['datasets'])
        human_content = f"Please profile these datasets (one call per dataset):\n{datasets_list_str}"
        message = [SystemMessage(content=system_prompt), HumanMessage(content=human_content)]
        self.logger.info("Input Message:" + str(message))
        
        result = self._invoke_with_usage(message, "profile_data")
        self.logger.info("RESULT:" + str(result))

        # call tools
        tool_calls = result.tool_calls

        self.logger.info("Tool Calls:" + str(tool_calls))
        results = {}
        for t in tool_calls:
            if not t['name'] in self.tools:      # check for bad tool name from LLM
                self.logger.info("adapt_pipeline: ....bad tool name....")
                result = "bad tool name, retry"  # instruct LLM to retry if bad
            else:
                result = self.tools[t['name']].invoke(t['args'])
            
#            if USE_LLM == "groq" or USE_LLM == "gpt" or USE_LLM == "gemini":
            results[t['args']['path']] = result
#            elif USE_LLM == "gemini_broken":
#                results[t['args']['__arg1']] = result

        with open(OUTPUT_DIR + "profile/profiles.json", "w") as file:
            file.write(json.dumps(results, indent=2))
          
        self.logger.info('Leaving profile_data')
        return {'data_profiles': results}

    def run_blocking_tester(self, state: SimpleModelAgentState):
        self.logger.info("----------------------- Entering run_blocking_tester -----------------------")

        if SKIP_BLOCKING_TESTER:
            path = Path(OUTPUT_DIR + "blocking-evaluation/blocking_config.json")
            if path.exists():
                with path.open("r", encoding="utf-8") as f:
                    blocking_config = json.load(f)
                    print("[+] Using saved blocking strategy: " + json.dumps(blocking_config, indent=2))
                    return {"blocking_config": blocking_config}
            else:
                print("[-] Cannot skip blocking tester. No saved blocking strategy found")
        
        if state.get("blocking_config"):
            print("[*] Blocking config already present in state; skipping BlockingTester")
            return {}

        print("[*] Running BlockingTester")
        tester = BlockingTester(
            llm=self.base_model,
            datasets=state["datasets"],
            max_candidates=350000,
            blocking_testsets=state['entity_matching_testsets'],
            output_dir="output/blocking-evaluation",
            pc_threshold=0.9,
            max_attempts=5,
            max_error_retries=2,
            verbose=True
        )
        _, blocking_config = tester.run_all_pairs()
        print("[*] Blocking config computed:\n" + json.dumps(blocking_config, indent=2))
        self.logger.info("Leaving run_blocking_tester")
        return {"blocking_config": blocking_config}

    def run_matching_tester(self, state: SimpleModelAgentState):
        self.logger.info("----------------------- Entering run_matching_tester -----------------------")

        if SKIP_MATCHING_TESTER:
            path = Path(OUTPUT_DIR + "matching-evaluation/matching_config.json")
            if path.exists():
                with path.open("r", encoding="utf-8") as f:
                    matching_config = json.load(f)
                    print("[+] Using saved matching strategy: " + json.dumps(matching_config, indent=2))
                    return {"matching_config": matching_config}
            else:
                print("[-] Cannot skip matching tester. No saved matching strategy found")
        
        if state.get("matching_config"):
            print("[*] Matching config already present in state; skipping MatchingTester")
            return {}

        print("[*] Running MatchingTester")
        tester = MatchingTester(
            llm=self.base_model,
            datasets=state["datasets"],
            matching_testsets=state['entity_matching_testsets'],
            blocking_config=state.get("blocking_config", {}),
            output_dir="output/matching-evaluation",
            f1_threshold=0.75,
            max_attempts=4,
            max_error_retries=2,
            verbose=True,
            matcher_mode=state.get("matcher_mode", "ml"),
        )
        _, matching_config = tester.run_all()
        print("[*] Matching config computed:\n" + json.dumps(matching_config, indent=2))
        self.logger.info("Leaving run_matching_tester")
        return {"matching_config": matching_config}


    def pipeline_adaption(self, state: SimpleModelAgentState):
        self.logger.info('----------------------- Entering pipeline_adaption -----------------------')

        ####### PREPARE SYSTEM PROMT #######
    
        # Load example pipeline code
        matcher_mode = state.get("matcher_mode", "ml")
        example_name = "example_pipeline_ml.py" if matcher_mode == "ml" else "example_pipeline.py"
        example_pipeline_path = os.path.join(INPUT_DIR, f"example_pipelines/{example_name}")
        if not os.path.exists(example_pipeline_path):
            raise FileNotFoundError(f"Example pipeline not found at: {example_pipeline_path}")
    
        with open(example_pipeline_path, "r", encoding="utf-8") as f:
            example_pipeline_code = f.read()

        # Prepare first-row previews for each dataset
        dataset_previews = {}
        for path in state['datasets']:
            df = load_dataset(path)
            if df is not None and not df.empty:
                # Take only first row and convert to dictionary
                dataset_previews[path] = df.iloc[0].to_dict()
            else:
                dataset_previews[path] = "Failed to load or empty dataset"
                
        # Prepare prompt for the model
        entity_matching_section = ""

        if state["matcher_mode"] == "ml":
            entity_matching_section = f"""
            2b. Entity matching testsets paths:
            {state["entity_matching_testsets"]}
            """
        
        system_prompt = f"""
        You are a data scientist tasked with the integration of several datasets.
        You are provided with the following inputs:

        1. An example integration pipeline (Python code using PyDI library). Pay
        attention to the comments within the pipeline, as they also contain important instructions:
        {example_pipeline_code}
    
        2. A list of dataset file paths:
        {json.dumps(state['datasets'], indent=2)}

        {entity_matching_section}
    
        3. The first row of each dataset to help understand the structure:
        {json.dumps(dataset_previews, indent=2)}
    
        4. A dictionary containing the profile data of the datasets
        (including number of rows, nulls_per_column and dtypes of 
        the columns):
        {json.dumps(state['data_profiles'], indent=2)}
        """
        
        # Include blocking config if available (from BlockingTester)
        blocking_config = state.get('blocking_config')
        if blocking_config:
            system_prompt += f"""

        5. **BLOCKING CONFIGURATION** (pre-computed optimal blocking strategies):
        This configuration was determined by a blocking evaluation agent. Use these settings
        for your blocking step in the pipeline:
        {json.dumps(blocking_config, indent=2)}
        
        IMPORTANT: Use the id_columns and blocking_strategies from this config:
        - Use the correct id_column for each dataset as specified
        - Use the recommended strategy (exact_match_single/multi or semantic_similarity)
        - Use the recommended columns for blocking
        - Strategy to blocker mapping:
          * exact_match_single / exact_match_multi -> StandardBlocker (exact match on columns)
          * token_blocking / ngram_blocking -> TokenBlocker (token or n-gram blocking)
          * sorted_neighbourhood -> SortedNeighbourhoodBlocker (window)
          * semantic_similarity -> EmbeddingBlocker (top_k)
        """

        # Include matching config if available (from MatchingTester)
        matching_config = state.get('matching_config')
        if matching_config:
            if matcher_mode == "ml":
                system_prompt += f"""

        6. **MATCHING CONFIGURATION** (pre-computed comparator settings):
        This configuration was determined by a matching evaluation agent. Use these settings
        for your MLBasedMatcher feature extraction and training:
        {json.dumps(matching_config, indent=2)}

        IMPORTANT: Use the matching_strategies from this config:
        - Build comparators (StringComparator/NumericComparator/DateComparator) for each dataset pair
        - Use the comparators as features in FeatureExtractor
        - Train a classifier on the labeled pairs (labels in the testset) and use MLBasedMatcher
        - Do NOT set weights; ML model learns weights internally
        - Do NOT add RuleBasedMatcher fallback branches
        - Follow the example ML pipeline structure and naming closely; do not invent new variable roles
        - preprocess mapping: "lower" -> str.lower, "strip" -> str.strip, "lower_strip" -> lambda x: str(x).lower().strip()
        """
            else:
                system_prompt += f"""

        6. **MATCHING CONFIGURATION** (pre-computed comparator settings):
        This configuration was determined by a matching evaluation agent. Use these settings
        for your RuleBasedMatcher step in the pipeline:
        {json.dumps(matching_config, indent=2)}

        IMPORTANT: Use the matching_strategies from this config:
        - Build comparators (StringComparator/NumericComparator/DateComparator) for each dataset pair
        - Use the specified weights and threshold
        - preprocess mapping: "lower" -> str.lower, "strip" -> str.strip, "lower_strip" -> lambda x: str(x).lower().strip()
        """

        system_prompt += """

        Your task is to **create a similar integration pipeline** so that it works with
        the datasets provided. Output should only consist of the relevant Python code
        for the integration pipeline.
        """

        evaluation_analysis = state.get("evaluation_analysis", None)
        if evaluation_analysis:
            system_prompt += f"""
            8. Evaluation reasoning from prior pipeline run:
            {evaluation_analysis}
            """
        # Include documentation if global variable is set
        if INCLUDE_DOCS:
            doc_path = os.path.join(INPUT_DIR, "documentation")
            if os.path.exists(doc_path):
                doc_files = [f for f in os.listdir(doc_path) if f.endswith(".md")]
                all_docs = ""
                for f_name in doc_files:
                    with open(os.path.join(doc_path, f_name), "r", encoding="utf-8", errors="replace") as f:
                        all_docs += f.read() + "\n\n"
                system_prompt += "\n\n### Documentation\n" + all_docs

        ####### PREPARE TASK PROMT #######

        # Determine if this is initial generation, fix due to execution error, or fix due to poor evaluation
        if "pipeline_execution_result" not in state and "evaluation_metrics" not in state:
            print("[*] Creating initial pipeline")
            human_content = "Create the integration pipeline for the provided datasets."
    
        else:
            # Either a pipeline execution error or evaluation-based adaption
            broken_pipeline_path = OUTPUT_DIR + "code/pipeline.py"
            with open(broken_pipeline_path, "r", encoding="utf-8", errors="ignore") as f:
                broken_code = f.read()
    
            human_content = "You previously generated Python integration pipeline code.\n"
            
            # Add execution error if exists
            if "pipeline_execution_result" in state and state["pipeline_execution_result"].lower().startswith("error"):
                print("[*] Trying to fix pipeline")
                human_content += f"Executing this pipeline caused the following error:\n{state['pipeline_execution_result']}\n"
    
            # Add evaluation feedback if available
            if "evaluation_metrics" in state:
                print("[*] Trying to improve pipeline based on evaluation")
                human_content += f"Evaluation of the last run shows the following metrics:\n{json.dumps(state['evaluation_metrics'], indent=2)}\n"
                human_content += "Improve the pipeline to increase overall accuracy and correct errors highlighted by the evaluation.\n"
    
            human_content += "Here is the current pipeline code:\n" + broken_code
            human_content += "\nOutput ONLY the corrected Python code."
            
        ####### EXECUTE PROMT #######
        
        message = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content)
        ]
    
        self.logger.info("Input Message:" + str(message))
    
        # Call the model
        adapted_pipeline = self._invoke_with_usage(message, "pipeline_adaption")
        adapted_pipeline = adapted_pipeline.content if hasattr(adapted_pipeline, "content") else str(adapted_pipeline)

        self.logger.info("RESULT:" + str(adapted_pipeline))
        
        # Strip leading/trailing ``` if present
        if adapted_pipeline.startswith("```python") and adapted_pipeline.endswith("```"):
            adapted_pipeline = adapted_pipeline[9:-3].strip()
        
        with open(OUTPUT_DIR + "code/pipeline.py", 'w', errors="ignore") as file:
            file.write(str(adapted_pipeline))
    
        self.logger.info('Leaving pipeline_adaption')
        return {'integration_pipeline_code': adapted_pipeline}

    def execute_pipeline(self, state: SimpleModelAgentState):
        self.logger.info('----------------------- Entering execute_pipeline -----------------------')

        print("[*] Running generated pipeline")

        attempts = state.get("pipeline_execution_attempts", 0) + 1
        state["pipeline_execution_attempts"] = attempts
    
        pipeline_path = OUTPUT_DIR + "code/pipeline.py"
    
        try:
            result = subprocess.run(
                [sys.executable, pipeline_path],
                capture_output=True,
                text=True,
                timeout=3600
            )
    
            if result.returncode == 0:
                print("[+] Pipeline successfully completed")
                execution_result = "success"
            else:
                execution_result = f"error: {result.stderr}"[:10000]
                print("Error: " + str(execution_result))
    
        except Exception as e:
            execution_result = f"error: {str(e)}"
    
        self.logger.info("Pipeline execution result: " + execution_result)
        self.logger.info('Leaving execute_pipeline')
    
        return {
            "pipeline_execution_result": execution_result,
            "pipeline_execution_attempts": attempts
        }
        
    def evaluation_adaption(self, state: SimpleModelAgentState):
        self.logger.info('----------------------- Entering evaluation_adaption -----------------------')
        
        example_eval_path = INPUT_DIR + "example_pipelines/example_evaluation.py"
        example_eval_code = open(example_eval_path).read()
    
        fused_output_path = "output/data_fusion/fusion_data.csv"

        # Prepare first-row preview for testset
        dataset = load_dataset(state['fusion_testset'])
        if dataset is not None and not dataset.empty:
            # Take only first row and convert to dictionary
            testset_preview = dataset.iloc[0].to_dict()
        else:
            testset_preview = "Failed to load or empty dataset"
    
        system_prompt = f"""
        You are a data scientist evaluating a data fusion pipeline.
    
        Example evaluation code:
        {example_eval_code}
    
        Generated integration pipeline:
        {state['integration_pipeline_code']}
    
        Dataset profiles:
        {json.dumps(state['data_profiles'], indent=2)}
    
        The fused output is located at:
        {fused_output_path}

        The testset is located at:
        {state['fusion_testset']}

        The first row of the testset looks like the following:
        {testset_preview}
    
        Create evaluation code that:
        - Uses the correct fusion strategy
        - Loads the fused output
        - Loads the gold standard test set
        - Prints structured evaluation metrics
        - Prints chosen evaluation functions in a compact one-line summary
        """

        ####### HUMAN PROMPT #######
        if not state.get("evaluation_execution_result"):
            print("[*] Adapting evaluation code")
            # First generation
            human_content = """
            Create the evaluation code.
            """
        else:
            # Fix broken evaluation
            print("[*] Fixing evaluation code")
            attempts = state.get("evaluation_execution_attempts", 0)
    
            if attempts >= 5:
                self.logger.info("Maximum evaluation fix attempts reached")
                return {"evaluation_execution_result": "error: max attempts reached"}
    
            eval_path = OUTPUT_DIR + "code/evaluation.py"
            with open(eval_path, "r", encoding="utf-8") as f:
                broken_code = f.read()
    
            error = state["evaluation_execution_result"]
    
            human_content = f"""
            You previously generated Python evaluation code.
            Executing this code caused the following error:
    
            {error}
    
            Here is the current evaluation code:
            {broken_code}
    
            Fix the code so that it executes successfully.
            Output ONLY the corrected Python code.
            """
    
        ####### MODEL CALL #######
    
        message = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content)
        ]
    
        self.logger.info("Input Message:" + str(message))
    
        result = self._invoke_with_usage(message, "evaluation_adaption")
        code = result.content.strip("```python").strip("```")
    
        self.logger.info("RESULT:" + str(code))
    
        with open(OUTPUT_DIR + "code/evaluation.py", "w") as f:
            f.write(code)

        self.logger.info('Leaving evaluation_adaption')
    
        return {"evaluation_code": code}

    def execute_evaluation(self, state: SimpleModelAgentState):
        self.logger.info('----------------------- Entering execute_evaluation -----------------------')
    
        print("[*] Running generated evaluation")
    
        attempts = state.get("evaluation_execution_attempts", 0) + 1
        state["evaluation_execution_attempts"] = attempts
    
        evaluation_path = OUTPUT_DIR + "code/evaluation.py"
    
        try:
            result = subprocess.run(
                [sys.executable, evaluation_path],
                capture_output=True,
                text=True,
                timeout=3600
            )
    
            if result.returncode == 0:
                print("[+] Evaluation successfully completed")
                execution_result = "success"
            else:
                print("[-] Evaluation could not be executed")
                execution_result = f"error: {result.stderr}"[:10000]
                print("Error: " + str(execution_result))
    
        except Exception as e:
            execution_result = f"error: {str(e)}"
    
        self.logger.info("Evaluation execution result: " + execution_result)
        self.logger.info('Leaving execute_evaluation')
    
        return {
            "evaluation_execution_result": execution_result,
            "evaluation_execution_attempts": attempts
        }

    def evaluation_decision(self, state: SimpleModelAgentState):
        self.logger.info('----------------------- Entering evaluation_decision -----------------------')
        print("[*] Reading evaluation metrics")

        attempts = state.get("evaluation_attempts", 0) + 1
    
        eval_path = "output/pipeline_evaluation/pipeline_evaluation.json"
    
        if not os.path.exists(eval_path):
            self.logger.warning("Evaluation file missing")
            metrics = {"error": "evaluation file missing"}
        else:
            with open(eval_path, "r", encoding="utf-8") as f:
                metrics = json.load(f)
    
        self.logger.info(f"Evaluation metrics: {metrics}")
        print(f"Evaluation metrics: {json.dumps(metrics)}")
    
        # Store metrics in the state
        state["evaluation_metrics"] = metrics

        overall_acc = metrics.get("overall_accuracy", 0.0)
        print(f"[*] Overall Accuracy: {overall_acc:.3%}")

        if overall_acc >= 0.85 or attempts >= 5:
            self._print_total_usage()
    
        self.logger.info('Leaving evaluation_decision')

        return {
            "evaluation_metrics": metrics,
            "evaluation_attempts": attempts,
            "pipeline_execution_result": "",
            "pipeline_execution_attempts": 0,
            "evaluation_execution_result": "",
            "evaluation_execution_attempts": 0
        }
    def evaluation_reasoning(self, state: SimpleModelAgentState):
        self.logger.info('----------------------- Entering evaluation_reasoning -----------------------')
    
        debug_path = "output/pipeline_evaluation/debug_fusion_eval.jsonl"
        debug_events = []
    
        if os.path.exists(debug_path):
            with open(debug_path, "r", encoding="utf-8") as f:
                for line in f:
                    try:
                        debug_events.append(json.loads(line))
                    except Exception:
                        continue
    
        # Prepare system prompt
        system_prompt = """
        You are a data integration expert analyzing the evaluation results of a data integration pipeline.
    
        You are given:
        - Aggregate evaluation metrics
        - Detailed per-record debugging events from a fusion evaluation
        - The current integration pipeline code
        - The optimal blocking and matching configurations
    
        Your task:
        1. Identify the dominant error types (false positives, false negatives, missed blocks, bad matches)
        2. Determine whether errors are more likely caused by:
           - Blocking being too restrictive or too loose
           - Matching thresholds or comparator choices
           - Schema or preprocessing issues
           - Logic in the current pipeline code
        3. Suggest concrete, actionable improvements for the next pipeline iteration
    
        Respond with concise, structured reasoning.
        """
    
        # Prepare human content
        human_content = f"""
        Evaluation metrics:
        {json.dumps(state.get("evaluation_metrics", {}), indent=2)}
    
        Debug fusion events (JSONL):
        {json.dumps(debug_events[:50], indent=2)}
    
        Current integration pipeline code:
        {state.get("integration_pipeline_code", "Pipeline code not available")}

        Current pipeline evaluation code:
        {state.get("evaluation_code", "Pipeline evaluation code not available")}
    
        Optimal blocking configuration:
        {json.dumps(state.get("blocking_config", {}), indent=2)}
    
        Optimal matching configuration:
        {json.dumps(state.get("matching_config", {}), indent=2)}
        """
    
        # Model call
        message = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content)
        ]
    
        result = self.model.invoke(message)
        analysis = result.content if hasattr(result, "content") else str(result)
    
        self.logger.info("Evaluation reasoning produced")
        print("[*] Evaluation reasoning:\n" + analysis)
    
        return {"evaluation_analysis": analysis}

# %% [markdown]
# ## Invoke Pipeline

# %%
if USE_LLM == "gemini":
    llm = ChatGoogleGenerativeAI(
        model="gemini-2.0-flash",
        temperature=0,
        max_tokens=None,
        timeout=None,
        max_retries=2,
    )
elif USE_LLM == "groq":
    llm = ChatGroq(
        model="llama-3.3-70b-versatile",
        temperature=0.2
    )
elif USE_LLM == "gpt":
    llm = ChatOpenAI(
        model="gpt-5.2",
        temperature=0,
        max_tokens=None,
    )

# %%
# Skip Blocking and Matching node and use existing strategies saved in 
# "output/blocking-evaluation/blocking_config.json" and "output/matching-evaluation/matching_config.json"
SKIP_BLOCKING_TESTER=False
SKIP_MATCHING_TESTER=False

# %%
# Music use case
entity_matching_testsets = {
    ("discogs", "lastfm"): INPUT_DIR + "datasets/music/testsets/discogs_lastfm_goldstandard_blocking.csv",
    ("discogs", "musicbrainz"): INPUT_DIR + "datasets/music/testsets/discogs_musicbrainz_goldstandard_blocking.csv",
    ("musicbrainz", "lastfm"): INPUT_DIR + "datasets/music/testsets/musicbrainz_lastfm_goldstandard_blocking.csv",
}
datasets = [
    INPUT_DIR + "datasets/music/discogs.xml",
    INPUT_DIR + "datasets/music/lastfm.xml",
    INPUT_DIR + "datasets/music/musicbrainz.xml"
]
fusion_testset = INPUT_DIR + "datasets/music/testsets/test_set.xml"

# %%
# prepare agent
from workflow_logging import attach_logging
agent = SimpleModelAgent(llm, ProfileDatasetTool())
attach_logging(agent, output_dir=OUTPUT_DIR, summary_model_name="gpt-4.1-mini", notebook_name="AdaptationPipeline_Final_Blocker_Matcher_Music")

# invoke agent
result = agent.graph.invoke({
    "datasets": datasets,
    "entity_matching_testsets": entity_matching_testsets,
    "fusion_testset": fusion_testset,
    "matcher_mode": "rulebased"
},
config={"recursion_limit": 5000})
# Out:
# [*] Running schema matching
# [*] Schema alignment columns:
#     discogs: ['id', 'name', 'artist', 'release-date', 'release-country', 'duration', 'label', 'genre', 'tracks_track_name', 'tracks_track_position', 'tracks_track_duration']
#     lastfm: ['id', 'name', 'artist', 'duration', 'tracks_track_name', 'tracks_track_duration', 'tracks_track_position']
#     musicbrainz: ['id', 'name', 'artist', 'release-date', 'release-country', 'duration', 'tracks_track_name', 'tracks_track_duration', 'tracks_track_position']
# [*] Profiling datasets
# TOKEN USAGE (profile_data):
#    Prompt tokens: 235
#    Completion tokens: 82
#    Total tokens: 317
#    Estimated cost: $0.000000
# [*] Running BlockingTester
# [*] Loading dataset: discogs
# [*] Loading dataset: lastfm
# [*] Loading dataset: musicbrainz
# [*] Loading gold standard for discogs <-> lastfm
#     Loaded 100 ground truth pairs (positives: 56, negatives/other: 44)
# [*] Loading gold standard for discogs <-> musicbrainz
#     Loaded 100 ground truth pairs (positives: 80, negatives/other: 20)
# [*] Loading gold standard for musicbrainz <-> lastfm
#     Loaded 100 ground truth pairs (positives: 79, negatives/other: 21)
# [*] Adaptive max_candidates set to 542,856 (r=0.35%, median_pairs=107,772,401)
#
# ============================================================
# 🤖 BLOCKING: discogs <-> lastfm
# ============================================================
# Gold pairs: 100, PC threshold: 0.9
# Candidate limit: 542,856 (hard: 624,284 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 22,627 × 9,865 = 223,215,355 potential pairs
# Common columns: ['tracks_track_position', 'name', 'artist', 'tracks_track_name', 'tracks_track_duration', 'duration']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['artist', 'name']
#   Params: {}
#   Reasoning: With 223M possible pairs and a strict 542k candidate cap, we need very restrictive blocking. 'artist...
#     Standard (artist+name): 1,240 candidates
#     ⚠️ PC=0.3571, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: token_blocking on ['name']
#   Params: {'min_token_len': 5}
#   Reasoning: Exact match on (artist,name) was too restrictive (low PC). Use token_blocking on the release/title f...
#     Token (name, len>=5): 2,176,544 candidates
#     ⛔ SKIPPING EVALUATION: 2,176,544 > 624,284 (hard limit)
#     💡 Try increasing min_token_len or ngram_size, or use a more selective column
#
# --- Attempt 3/5 ---
# LLM chose: semantic_similarity on ['name', 'artist']
#   Params: {'top_k': 20}
#   Reasoning: Exact match on (artist,name) had very low PC, indicating substantial formatting/text variation (e.g....
#     Embedding (name+artist, k=20): 449,753 candidates
#     ✅ PC=0.9643, RR=0.9980
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: discogs <-> musicbrainz
# ============================================================
# Gold pairs: 100, PC threshold: 0.9
# Candidate limit: 542,856 (hard: 624,284 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 22,627 × 4,763 = 107,772,401 potential pairs
# Common columns: ['release-date', 'tracks_track_position', 'name', 'artist', 'release-country', 'tracks_track_name', 'tracks_track_duration', 'duration']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['name', 'artist', 'release-date']
#   Params: {}
#   Reasoning: N×M is ~108M so we need very restrictive blocking to stay under 542,856 candidates. Using exact matc...
#     Standard (name+artist+release-date): 575 candidates
#     ⚠️ PC=0.1625, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: token_blocking on ['tracks_track_name']
#   Params: {'min_token_len': 6}
#   Reasoning: Exact match on (name, artist, release-date) was too restrictive (very low PC). Use token_blocking on...
#     Token (tracks_track_name, len>=6): 3,287,536 candidates
#     ⛔ SKIPPING EVALUATION: 3,287,536 > 624,284 (hard limit)
#     💡 Try increasing min_token_len or ngram_size, or use a more selective column
#
# --- Attempt 3/5 ---
# LLM chose: semantic_similarity on ['name', 'artist', 'release-date']
#   Params: {'top_k': 20}
#   Reasoning: Exact match on (name, artist, release-date) was too restrictive (very low PC), and token blocking on...
#     Embedding (name+artist+release-date, k=20): 450,205 candidates
#     ✅ PC=0.9500, RR=0.9958
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: musicbrainz <-> lastfm
# ============================================================
# Gold pairs: 100, PC threshold: 0.9
# Candidate limit: 542,856 (hard: 624,284 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 4,763 × 9,865 = 46,986,995 potential pairs
# Common columns: ['tracks_track_position', 'name', 'artist', 'tracks_track_name', 'tracks_track_duration', 'duration']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['artist', 'name']
#   Params: {}
#   Reasoning: With ~47M possible pairs and a 542k candidate cap, we need a very restrictive block. Both 'artist' a...
#     Standard (artist+name): 748 candidates
#     ⚠️ PC=0.4177, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['name', 'artist', 'duration']
#   Params: {'top_k': 20}
#   Reasoning: Exact match on (artist,name) was too restrictive (PC=0.418), likely due to formatting differences (e...
#     Embedding (name+artist+duration, k=20): 95,134 candidates
#     ✅ PC=0.9367, RR=0.9980
# ✅ Found acceptable strategy!
#
# ============================================================
# 📊 RESULTS SUMMARY: 3 pairs evaluated
# ============================================================
#   ✅ discogs_lastfm: PC=0.9643, candidates=449,753, strategy=semantic_similarity
#   ✅ discogs_musicbrainz: PC=0.9500, candidates=450,205, strategy=semantic_similarity
#   ✅ musicbrainz_lastfm: PC=0.9367, candidates=95,134, strategy=semantic_similarity
#
# 💾 Config saved to: output/blocking-evaluation/blocking_config.json
# [*] Blocking config computed:
# {
#   "blocking_strategies": {
#     "discogs_lastfm": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "artist"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.9642857142857143,
#       "num_candidates": 449753,
#       "is_acceptable": true
#     },
#     "discogs_musicbrainz": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "artist",
#         "release-date"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.95,
#       "num_candidates": 450205,
#       "is_acceptable": true
#     },
#     "musicbrainz_lastfm": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "artist",
#         "duration"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.9367088607594937,
#       "num_candidates": 95134,
#       "is_acceptable": true
#     }
#   },
#   "id_columns": {
#     "discogs": "id",
#     "lastfm": "id",
#     "musicbrainz": "id"
#   }
# }
# [*] Running MatchingTester
# [*] Loading dataset: discogs
# [*] Loading dataset: lastfm
# [*] Loading dataset: musicbrainz
# [*] Loading matching gold standard for discogs <-> lastfm
#     Loaded 100 ground truth pairs
# [*] Loading matching gold standard for discogs <-> musicbrainz
#     Loaded 100 ground truth pairs
# [*] Loading matching gold standard for musicbrainz <-> lastfm
#     Loaded 100 ground truth pairs
#
# ==================================================
# MATCHING EVALUATION
# ==================================================
#
# ==================================================
# MATCHING: discogs <-> lastfm
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'artist']
#
# --- Attempt 1/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine', 'tracks_track_name:jaccard', 'duration:30.0']
# Weights: [0.35, 0.35, 0.2, 0.1]
# Threshold: 0.78
#     Reasoning: Use blocking columns artist and name as primary signals (artist is short -> jaro_winkler; release/track title text -> cosine). Track list names are informative but often missing, so use set-based jaccard with lower weight. Duration is numeric and partially missing; allow moderate tolerance for metadata differences and give low weight. Slightly higher threshold to favor precision given strong title/artist fields.
#     Reasoning (100c): Use blocking columns artist and name as primary signals (artist is short -> jaro_winkler; release/tr
# F1=0.1639 < 0.75
#
# --- Attempt 2/4 ---
# Comparators: ['artist:jaro_winkler', 'name:jaro_winkler', 'tracks_track_name:jaccard', 'duration:120.0']
# Weights: [0.35, 0.35, 0.2, 0.1]
# Threshold: 0.55
#     Reasoning: Prior config underperformed likely due to album name formatting differences (e.g., artist prefixed in name) and missing track/duration fields on one side. Use jaro_winkler for short artist/title strings with punctuation/spacing variation, treat track names as a set with jaccard to be robust to ordering/missing entries, allow looser duration tolerance, and lower threshold to improve recall given high nulls in track-related fields.
#     Reasoning (100c): Prior config underperformed likely due to album name formatting differences (e.g., artist prefixed i
# SUCCESS: F1=0.8926
#
# ==================================================
# MATCHING: discogs <-> musicbrainz
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'artist', 'release-date']
#
# --- Attempt 1/4 ---
# Comparators: ['name:jaro_winkler', 'artist:jaro_winkler', 'release-date:365', 'tracks_track_name:cosine', 'duration:120.0']
# Weights: [0.32, 0.28, 0.15, 0.15, 0.1]
# Threshold: 0.78
#     Reasoning: Use blocking fields (name, artist, release-date) as primary high-signal matchers; add track list title similarity for releases with same artist/title variants; include total duration with a tolerant window to handle differing time sources while keeping precision with a moderately high threshold.
#     Reasoning (100c): Use blocking fields (name, artist, release-date) as primary high-signal matchers; add track list tit
# SUCCESS: F1=0.8571
#
# ==================================================
# MATCHING: musicbrainz <-> lastfm
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name', 'artist', 'duration']
#
# --- Attempt 1/4 ---
# Comparators: ['artist:jaro_winkler', 'name:cosine', 'duration:15.0']
# Weights: [0.35, 0.45, 0.2]
# Threshold: 0.75
#     Reasoning: Use blocking fields with high coverage: artist is a strong identifier (JW for short names), name can contain extra tokens so cosine works well, and duration provides a numeric consistency check (allowing small cross-source differences). Higher threshold to favor precision given noisy title formatting and partial missing track-level fields.
#     Reasoning (100c): Use blocking fields with high coverage: artist is a strong identifier (JW for short names), name can
# SUCCESS: F1=0.8030
#
# 📊 Results: 3 pairs evaluated
#   OK discogs_lastfm: F1=0.8926
#   OK discogs_musicbrainz: F1=0.8571
#   OK musicbrainz_lastfm: F1=0.8030
# Config saved to matching_config.json
# [*] Matching config computed:
# {
#   "id_columns": {
#     "discogs": "id",
#     "lastfm": "id",
#     "musicbrainz": "id"
#   },
#   "matching_strategies": {
#     "discogs_lastfm": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "artist",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "tracks_track_name",
#           "similarity_function": "jaccard",
#           "preprocess": "lower_strip",
#           "list_strategy": "set_jaccard"
#         },
#         {
#           "type": "numeric",
#           "column": "duration",
#           "max_difference": 120.0
#         }
#       ],
#       "weights": [
#         0.35,
#         0.35,
#         0.2,
#         0.1
#       ],
#       "threshold": 0.55,
#       "f1": 0.8925619834710744
#     },
#     "discogs_musicbrainz": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "artist",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "date",
#           "column": "release-date",
#           "max_days_difference": 365
#         },
#         {
#           "type": "string",
#           "column": "tracks_track_name",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "numeric",
#           "column": "duration",
#           "max_difference": 120.0
#         }
#       ],
#       "weights": [
#         0.32,
#         0.28,
#         0.15,
#         0.15,
#         0.1
#       ],
#       "threshold": 0.78,
#       "f1": 0.8571428571428571
#     },
#     "musicbrainz_lastfm": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "artist",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "numeric",
#           "column": "duration",
#           "max_difference": 15.0
#         }
#       ],
#       "weights": [
#         0.35,
#         0.45,
#         0.2
#       ],
#       "threshold": 0.75,
#       "f1": 0.8030303030303031
#     }
#   }
# }
# [*] Creating initial pipeline
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 4,891
#    Completion tokens: 1,971
#    Total tokens: 6,862
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 4,605
#    Completion tokens: 1,838
#    Total tokens: 6,443
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.6495619524405507, "macro_accuracy": 0.6666040100250625, "num_evaluated_records": 40, "num_evaluated_attributes": 21, "total_evaluations": 799, "total_correct": 519, "address_line1_accuracy": 0.95, "address_line1_count": 40, "map_url_accuracy": 0.575, "map_url_count": 40, "latitude_accuracy": 0.975, "latitude_count": 40, "phone_raw_accuracy": 0.0, "phone_raw_count": 40, "country_accuracy": 0.975, "country_count": 40, "name_accuracy": 0.975, "name_count": 40, "street_accuracy": 0.85, "street_count": 40, "_id_accuracy": 0.5, "_id_count": 40, "rating_accuracy": 0.475, "rating_count": 40, "longitude_accuracy": 0.975, "longitude_count": 40, "address_line2_accuracy": 1.0, "address_line2_count": 7, "source_accuracy": 0.0, "source_count": 40, "state_accuracy": 0.975, "state_count": 40, "categories_accuracy": 0.95, "categories_count": 40, "city_accuracy": 0.975, "city_count": 40, "phone_e164_accuracy": 0.0, "phone_e164_count": 40, "postal_code_accuracy": 0.0, "postal_code_count": 40, "rating_count_accuracy": 1.0, "rating_count_count": 34, "house_number_accuracy": 0.0, "house_number_count": 40, "website_accuracy": 0.9736842105263158, "website_count": 38, "name_norm_accuracy": 0.875, "name_norm_count": 40}
# [*] Overall Accuracy: 64.956%
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 7,563
#    Completion tokens: 2,645
#    Total tokens: 10,208
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Error: error: Traceback (most recent call last):
#   File "/Users/onurcanmemis/Desktop/data-integration-team-project/agents/output/code/pipeline.py", line 163, in <module>
#     df["tracks_track_name"] = df["tracks_track_name"].apply(parse_listish)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/onurcanmemis/Desktop/Lectures/2025-2026_Winter/Team_Project/.venv/lib/python3.12/site-packages/pandas/core/series.py", line 4943, in apply
#     ).apply()
#       ^^^^^^^
#   File "/Users/onurcanmemis/Desktop/Lectures/2025-2026_Winter/Team_Project/.venv/lib/python3.12/site-packages/pandas/core/apply.py", line 1422, in apply
#     return self.apply_standard()
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/onurcanmemis/Desktop/Lectures/2025-2026_Winter/Team_Project/.venv/lib/python3.12/site-packages/pandas/core/apply.py", line 1502, in apply_standard
#     mapped = obj._map_values(
#              ^^^^^^^^^^^^^^^^
#   File "/Users/onurcanmemis/Desktop/Lectures/2025-2026_Winter/Team_Project/.venv/lib/python3.12/site-packages/pandas/core/base.py", line 925, in _map_values
#     return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/onurcanmemis/Desktop/Lectures/2025-2026_Winter/Team_Project/.venv/lib/python3.12/site-packages/pandas/core/algorithms.py", line 1743, in map_array
#     return lib.map_infer(values, mapper, convert=convert)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "pandas/_libs/lib.pyx", line 2999, in pandas._libs.lib.map_infer
#   File "/Users/onurcanmemis/Desktop/data-integration-team-project/agents/output/code/pipeline.py", line 68, in parse_listish
#     if x is None or pd.isna(x):
#                     ^^^^^^^^^^
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# [*] Trying to fix pipeline
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 8,758
#    Completion tokens: 3,094
#    Total tokens: 11,852
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 5,728
#    Completion tokens: 1,742
#    Total tokens: 7,470
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.4263959390862944, "macro_accuracy": 0.42699275362318834, "num_evaluated_records": 23, "num_evaluated_attributes": 9, "total_evaluations": 197, "total_correct": 84, "tracks_track_name_accuracy": 0.0, "tracks_track_name_count": 23, "tracks_track_position_accuracy": 0.5652173913043478, "tracks_track_position_count": 23, "label_accuracy": 0.5625, "label_count": 16, "artist_accuracy": 0.5652173913043478, "artist_count": 23, "release-date_accuracy": 0.5217391304347826, "release-date_count": 23, "duration_accuracy": 0.4782608695652174, "duration_count": 23, "release-country_accuracy": 0.6086956521739131, "release-country_count": 23, "name_accuracy": 0.391304347826087, "name_count": 23, "tracks_track_duration_accuracy": 0.15, "tracks_track_duration_count": 20}
# [*] Overall Accuracy: 42.640%
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 8,487
#    Completion tokens: 4,855
#    Total tokens: 13,342
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 7,489
#    Completion tokens: 1,704
#    Total tokens: 9,193
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.34517766497461927, "macro_accuracy": 0.34414251207729474, "num_evaluated_records": 23, "num_evaluated_attributes": 9, "total_evaluations": 197, "total_correct": 68, "label_accuracy": 0.3125, "label_count": 16, "tracks_track_position_accuracy": 0.4782608695652174, "tracks_track_position_count": 23, "name_accuracy": 0.30434782608695654, "name_count": 23, "release-date_accuracy": 0.391304347826087, "release-date_count": 23, "artist_accuracy": 0.4782608695652174, "artist_count": 23, "tracks_track_name_accuracy": 0.0, "tracks_track_name_count": 23, "duration_accuracy": 0.391304347826087, "duration_count": 23, "release-country_accuracy": 0.391304347826087, "release-country_count": 23, "tracks_track_duration_accuracy": 0.35, "tracks_track_duration_count": 20}
# [*] Overall Accuracy: 34.518%
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 10,246
#    Completion tokens: 4,843
#    Total tokens: 15,089
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 7,477
#    Completion tokens: 1,679
#    Total tokens: 9,156
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.3350253807106599, "macro_accuracy": 0.3351449275362319, "num_evaluated_records": 23, "num_evaluated_attributes": 9, "total_evaluations": 197, "total_correct": 66, "tracks_track_name_accuracy": 0.0, "tracks_track_name_count": 23, "name_accuracy": 0.4782608695652174, "name_count": 23, "label_accuracy": 0.375, "label_count": 16, "release-country_accuracy": 0.30434782608695654, "release-country_count": 23, "artist_accuracy": 0.391304347826087, "artist_count": 23, "tracks_track_duration_accuracy": 0.25, "tracks_track_duration_count": 20, "tracks_track_position_accuracy": 0.391304347826087, "tracks_track_position_count": 23, "duration_accuracy": 0.391304347826087, "duration_count": 23, "release-date_accuracy": 0.43478260869565216, "release-date_count": 23}
# [*] Overall Accuracy: 33.503%
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 10,233
#    Completion tokens: 5,903
#    Total tokens: 16,136
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 8,537
#    Completion tokens: 1,637
#    Total tokens: 10,174
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.3350253807106599, "macro_accuracy": 0.3351449275362319, "num_evaluated_records": 23, "num_evaluated_attributes": 9, "total_evaluations": 197, "total_correct": 66, "tracks_track_name_accuracy": 0.0, "tracks_track_name_count": 23, "name_accuracy": 0.4782608695652174, "name_count": 23, "label_accuracy": 0.375, "label_count": 16, "release-country_accuracy": 0.30434782608695654, "release-country_count": 23, "artist_accuracy": 0.391304347826087, "artist_count": 23, "tracks_track_duration_accuracy": 0.25, "tracks_track_duration_count": 20, "tracks_track_position_accuracy": 0.391304347826087, "tracks_track_position_count": 23, "duration_accuracy": 0.391304347826087, "duration_count": 23, "release-date_accuracy": 0.43478260869565216, "release-date_count": 23}
# [*] Overall Accuracy: 33.503%
# TOTAL TOKEN USAGE:
#    Prompt tokens: 84,249
#    Completion tokens: 31,993
#    Total tokens: 116,242
#    Estimated cost: $0.000000

# %%
# Restaurants use case
entity_matching_testsets = {
    ("kaggle_small", "uber_eats_small"): INPUT_DIR + "datasets/restaurant/testsets/kaggle_uber_eats_goldstandard_blocking_small.csv",
    ("kaggle_small", "yelp_small"): INPUT_DIR + "datasets/restaurant/testsets/kaggle_yelp_goldstandard_blocking_small.csv",
    ("uber_eats_small", "yelp_small"): INPUT_DIR + "datasets/restaurant/testsets/uber_eats_yelp_goldstandard_blocking_small.csv",
}

datasets = [
    INPUT_DIR + "datasets/restaurant/kaggle_small.parquet",
    INPUT_DIR + "datasets/restaurant/uber_eats_small.parquet",
    INPUT_DIR + "datasets/restaurant/yelp_small.parquet"
]
fusion_testset = INPUT_DIR + "datasets/restaurant/testsets/Restaurant_Fusion_Test_Set.csv"

# %%
# prepare agent
from workflow_logging import attach_logging
agent = SimpleModelAgent(llm, ProfileDatasetTool())
attach_logging(agent, output_dir=OUTPUT_DIR, summary_model_name="gpt-4.1-mini", notebook_name="AdaptationPipeline_Final_Blocker_Matcher_Restaurant")

# invoke agent
result = agent.graph.invoke({
    "datasets": datasets,
    "entity_matching_testsets": entity_matching_testsets,
    "fusion_testset": fusion_testset,
    "matcher_mode": "rulebased"
},
config={"recursion_limit": 5000})
# Out:
# [*] Running schema matching
# [*] Schema alignment columns:
#     kaggle_small: ['id', 'source', 'name', 'name_norm', 'website', 'map_url', 'phone_raw', 'phone_e164', 'address_line1', 'address_line2', 'street', 'house_number', 'city', 'state', 'postal_code', 'country', 'latitude', 'longitude', 'categories', 'rating']
#     uber_eats_small: ['id', 'source', 'name', 'name_norm', 'address_line1', 'address_line2', 'street', 'house_number', 'city', 'state', 'postal_code', 'country', 'latitude', 'longitude', 'categories', 'rating', 'rating_count']
#     yelp_small: ['id', 'source', 'name', 'name_norm', 'map_url', 'phone_raw', 'phone_e164', 'address_line1', 'address_line2', 'street', 'house_number', 'city', 'state', 'postal_code', 'country', 'latitude', 'longitude', 'categories', 'rating', 'rating_count']
# [*] Profiling datasets
# TOKEN USAGE (profile_data):
#    Prompt tokens: 241
#    Completion tokens: 88
#    Total tokens: 329
#    Estimated cost: $0.000000
# [*] Running BlockingTester
# [*] Loading dataset: kaggle_small
# [*] Loading dataset: uber_eats_small
# [*] Loading dataset: yelp_small
# [*] Loading gold standard for kaggle_small <-> uber_eats_small
#     Loaded 100 ground truth pairs (positives: 20, negatives/other: 80)
# [*] Loading gold standard for kaggle_small <-> yelp_small
#     Loaded 100 ground truth pairs (positives: 30, negatives/other: 70)
# [*] Loading gold standard for uber_eats_small <-> yelp_small
#     Loaded 100 ground truth pairs (positives: 20, negatives/other: 80)
# [*] Adaptive max_candidates set to 350,000 (r=0.35%, median_pairs=100,000,000)
#
# ============================================================
# 🤖 BLOCKING: kaggle_small <-> uber_eats_small
# ============================================================
# Gold pairs: 100, PC threshold: 0.9
# Candidate limit: 350,000 (hard: 402,499 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 10,000 × 10,000 = 100,000,000 potential pairs
# Common columns: ['house_number', 'source', 'city', 'longitude', 'name_norm', 'name', 'postal_code', 'address_line2', 'country', 'rating', 'state', 'street', 'categories', 'address_line1', 'latitude']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['postal_code', 'house_number']
#   Params: {}
#   Reasoning: With 10k×10k (100M) possible pairs and a 350k candidate cap, we need very restrictive blocking. Exac...
#     Standard (postal_code+house_number): 27,850 candidates
#     ✅ PC=1.0000, RR=0.9997
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: kaggle_small <-> yelp_small
# ============================================================
# Gold pairs: 100, PC threshold: 0.9
# Candidate limit: 350,000 (hard: 402,499 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 10,000 × 10,000 = 100,000,000 potential pairs
# Common columns: ['map_url', 'categories', 'house_number', 'phone_raw', 'name_norm', 'name', 'rating', 'phone_e164', 'latitude', 'state', 'address_line1', 'source', 'city', 'longitude', 'postal_code', 'address_line2', 'country', 'street']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_single on ['phone_e164']
#   Params: {}
#   Reasoning: With 10k×10k (100M) potential pairs and a strict 350k max-candidate budget, blocking on a highly uni...
#     Standard (phone_e164): 565,654 candidates
#     ⛔ SKIPPING EVALUATION: 565,654 > 402,499 (hard limit)
#     💡 Try increasing min_token_len or ngram_size, or use a more selective column
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['name_norm', 'address_line1', 'city']
#   Params: {'top_k': 15}
#   Reasoning: Exact phone matching produced too many candidates and zero PC, indicating phone formats/coverage dif...
#     Embedding (name_norm+address_line1+city, k=15): 149,812 candidates
#     ✅ PC=1.0000, RR=0.9985
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: uber_eats_small <-> yelp_small
# ============================================================
# Gold pairs: 100, PC threshold: 0.9
# Candidate limit: 350,000 (hard: 402,499 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 10,000 × 10,000 = 100,000,000 potential pairs
# Common columns: ['house_number', 'source', 'city', 'longitude', 'name_norm', 'name', 'postal_code', 'address_line2', 'country', 'rating', 'state', 'street', 'categories', 'rating_count', 'address_line1', 'latitude']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['postal_code', 'house_number']
#   Params: {}
#   Reasoning: With 10k×10k (100M) potential pairs and a 350k candidate cap, use a very restrictive fast block. 'po...
#     Standard (postal_code+house_number): 82 candidates
#     ✅ PC=1.0000, RR=1.0000
# ✅ Found acceptable strategy!
#
# ============================================================
# 📊 RESULTS SUMMARY: 3 pairs evaluated
# ============================================================
#   ✅ kaggle_small_uber_eats_small: PC=1.0000, candidates=27,850, strategy=exact_match_multi
#   ✅ kaggle_small_yelp_small: PC=1.0000, candidates=149,812, strategy=semantic_similarity
#   ✅ uber_eats_small_yelp_small: PC=1.0000, candidates=82, strategy=exact_match_multi
#
# 💾 Config saved to: output/blocking-evaluation/blocking_config.json
# [*] Blocking config computed:
# {
#   "blocking_strategies": {
#     "kaggle_small_uber_eats_small": {
#       "strategy": "exact_match_multi",
#       "columns": [
#         "postal_code",
#         "house_number"
#       ],
#       "params": {},
#       "pair_completeness": 1.0,
#       "num_candidates": 27850,
#       "is_acceptable": true
#     },
#     "kaggle_small_yelp_small": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name_norm",
#         "address_line1",
#         "city"
#       ],
#       "params": {
#         "top_k": 15
#       },
#       "pair_completeness": 1.0,
#       "num_candidates": 149812,
#       "is_acceptable": true
#     },
#     "uber_eats_small_yelp_small": {
#       "strategy": "exact_match_multi",
#       "columns": [
#         "postal_code",
#         "house_number"
#       ],
#       "params": {},
#       "pair_completeness": 1.0,
#       "num_candidates": 82,
#       "is_acceptable": true
#     }
#   },
#   "id_columns": {
#     "kaggle_small": "id",
#     "uber_eats_small": "id",
#     "yelp_small": "id"
#   }
# }
# [*] Running MatchingTester
# [*] Loading dataset: kaggle_small
# [*] Loading dataset: uber_eats_small
# [*] Loading dataset: yelp_small
# [*] Loading matching gold standard for kaggle_small <-> uber_eats_small
#     Loaded 100 ground truth pairs
# [*] Loading matching gold standard for kaggle_small <-> yelp_small
#     Loaded 100 ground truth pairs
# [*] Loading matching gold standard for uber_eats_small <-> yelp_small
#     Loaded 100 ground truth pairs
#
# ==================================================
# MATCHING EVALUATION
# ==================================================
#
# ==================================================
# MATCHING: kaggle_small <-> uber_eats_small
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['postal_code', 'house_number']
#
# --- Attempt 1/4 ---
# Comparators: ['postal_code:levenshtein', 'house_number:levenshtein', 'name_norm:jaro_winkler', 'street:jaro_winkler', 'latitude:0.002', 'longitude:0.002']
# Weights: [0.18, 0.18, 0.3, 0.16, 0.09, 0.09]
# Threshold: 0.78
#     Reasoning: Use blocking columns (postal_code, house_number) as strong exact/near-exact identifiers; reinforce with name_norm and street for typos/format differences; add tight lat/long tolerances to disambiguate same-name venues nearby. Avoid high-null address_line2 and sparse rating.
#     Reasoning (100c): Use blocking columns (postal_code, house_number) as strong exact/near-exact identifiers; reinforce w
# SUCCESS: F1=0.9756
#
# ==================================================
# MATCHING: kaggle_small <-> yelp_small
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['name_norm', 'address_line1', 'city']
#
# --- Attempt 1/4 ---
# Comparators: ['name_norm:jaro_winkler', 'address_line1:cosine', 'city:jaro_winkler', 'phone_e164:levenshtein', 'latitude:0.002', 'longitude:0.002']
# Weights: [0.3, 0.25, 0.1, 0.2, 0.075, 0.075]
# Threshold: 0.78
#     Reasoning: Use blocking columns (name_norm, address_line1, city) as primary signals; add phone_e164 as strong identifier when present; latitude/longitude provide robust disambiguation with tight tolerance. Address uses token-based cosine for varied formatting; names/city use jaro_winkler for typos/variants. Moderate-high threshold to prioritize precision across similar businesses.
#     Reasoning (100c): Use blocking columns (name_norm, address_line1, city) as primary signals; add phone_e164 as strong i
# SUCCESS: F1=1.0000
#
# ==================================================
# MATCHING: uber_eats_small <-> yelp_small
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['postal_code', 'house_number']
#
# --- Attempt 1/4 ---
# Comparators: ['postal_code:jaro_winkler', 'house_number:jaro_winkler', 'street:cosine', 'name:cosine', 'latitude:0.001', 'longitude:0.001', 'categories:jaccard']
# Weights: [0.18, 0.18, 0.14, 0.2, 0.12, 0.12, 0.06]
# Threshold: 0.75
#     Reasoning: Use blocking keys (postal_code, house_number) with high weight; reinforce with street and business name text similarity, plus tight lat/long proximity for same-location matches; categories adds a small tie-breaker signal. Avoid high-null address_line2 and unreliable rating/rating_count due to missingness mismatch.
#     Reasoning (100c): Use blocking keys (postal_code, house_number) with high weight; reinforce with street and business n
# SUCCESS: F1=0.9500
#
# 📊 Results: 3 pairs evaluated
#   OK kaggle_small_uber_eats_small: F1=0.9756
#   OK kaggle_small_yelp_small: F1=1.0000
#   OK uber_eats_small_yelp_small: F1=0.9500
# Config saved to matching_config.json
# [*] Matching config computed:
# {
#   "id_columns": {
#     "kaggle_small": "id",
#     "uber_eats_small": "id",
#     "yelp_small": "id"
#   },
#   "matching_strategies": {
#     "kaggle_small_uber_eats_small": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "postal_code",
#           "similarity_function": "levenshtein",
#           "preprocess": "strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "house_number",
#           "similarity_function": "levenshtein",
#           "preprocess": "strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "name_norm",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "street",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "numeric",
#           "column": "latitude",
#           "max_difference": 0.002
#         },
#         {
#           "type": "numeric",
#           "column": "longitude",
#           "max_difference": 0.002
#         }
#       ],
#       "weights": [
#         0.18,
#         0.18,
#         0.3,
#         0.16,
#         0.09,
#         0.09
#       ],
#       "threshold": 0.78,
#       "f1": 0.975609756097561
#     },
#     "kaggle_small_yelp_small": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name_norm",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "address_line1",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "city",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "phone_e164",
#           "similarity_function": "levenshtein",
#           "preprocess": "strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "numeric",
#           "column": "latitude",
#           "max_difference": 0.002
#         },
#         {
#           "type": "numeric",
#           "column": "longitude",
#           "max_difference": 0.002
#         }
#       ],
#       "weights": [
#         0.3,
#         0.25,
#         0.1,
#         0.2,
#         0.075,
#         0.075
#       ],
#       "threshold": 0.78,
#       "f1": 1.0
#     },
#     "uber_eats_small_yelp_small": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "postal_code",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "house_number",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "street",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "numeric",
#           "column": "latitude",
#           "max_difference": 0.001
#         },
#         {
#           "type": "numeric",
#           "column": "longitude",
#           "max_difference": 0.001
#         },
#         {
#           "type": "string",
#           "column": "categories",
#           "similarity_function": "jaccard",
#           "preprocess": "lower_strip",
#           "list_strategy": "set_jaccard"
#         }
#       ],
#       "weights": [
#         0.18,
#         0.18,
#         0.14,
#         0.2,
#         0.12,
#         0.12,
#         0.06
#       ],
#       "threshold": 0.75,
#       "f1": 0.9500000000000001
#     }
#   }
# }
# [*] Creating initial pipeline
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 6,106
#    Completion tokens: 2,353
#    Total tokens: 8,459
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 7,823
#    Completion tokens: 1,969
#    Total tokens: 9,792
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.6795994993742178, "macro_accuracy": 0.6952380952380952, "num_evaluated_records": 40, "num_evaluated_attributes": 21, "total_evaluations": 799, "total_correct": 543, "longitude_accuracy": 0.975, "longitude_count": 40, "house_number_accuracy": 0.0, "house_number_count": 40, "phone_raw_accuracy": 0.0, "phone_raw_count": 40, "_id_accuracy": 0.5, "_id_count": 40, "name_norm_accuracy": 0.875, "name_norm_count": 40, "categories_accuracy": 0.975, "categories_count": 40, "phone_e164_accuracy": 0.0, "phone_e164_count": 40, "latitude_accuracy": 0.975, "latitude_count": 40, "state_accuracy": 0.975, "state_count": 40, "source_accuracy": 0.5, "source_count": 40, "rating_count_accuracy": 1.0, "rating_count_count": 34, "street_accuracy": 0.85, "street_count": 40, "postal_code_accuracy": 0.0, "postal_code_count": 40, "map_url_accuracy": 0.4, "map_url_count": 40, "rating_accuracy": 0.7, "rating_count": 40, "name_accuracy": 0.975, "name_count": 40, "city_accuracy": 0.975, "city_count": 40, "address_line1_accuracy": 0.95, "address_line1_count": 40, "website_accuracy": 1.0, "website_count": 38, "country_accuracy": 0.975, "country_count": 40, "address_line2_accuracy": 1.0, "address_line2_count": 7}
# [*] Overall Accuracy: 67.960%
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 8,964
#    Completion tokens: 3,065
#    Total tokens: 12,029
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 8,535
#    Completion tokens: 1,823
#    Total tokens: 10,358
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.6608260325406758, "macro_accuracy": 0.6773809523809524, "num_evaluated_records": 40, "num_evaluated_attributes": 21, "total_evaluations": 799, "total_correct": 528, "name_norm_accuracy": 0.825, "name_norm_count": 40, "_id_accuracy": 0.45, "_id_count": 40, "latitude_accuracy": 0.975, "latitude_count": 40, "categories_accuracy": 0.975, "categories_count": 40, "country_accuracy": 0.975, "country_count": 40, "map_url_accuracy": 0.4, "map_url_count": 40, "state_accuracy": 0.975, "state_count": 40, "house_number_accuracy": 0.0, "house_number_count": 40, "city_accuracy": 0.975, "city_count": 40, "longitude_accuracy": 0.975, "longitude_count": 40, "name_accuracy": 0.975, "name_count": 40, "phone_raw_accuracy": 0.0, "phone_raw_count": 40, "website_accuracy": 1.0, "website_count": 38, "postal_code_accuracy": 0.0, "postal_code_count": 40, "address_line1_accuracy": 0.95, "address_line1_count": 40, "rating_accuracy": 0.475, "rating_count": 40, "rating_count_accuracy": 1.0, "rating_count_count": 34, "source_accuracy": 0.45, "source_count": 40, "street_accuracy": 0.85, "street_count": 40, "phone_e164_accuracy": 0.0, "phone_e164_count": 40, "address_line2_accuracy": 1.0, "address_line2_count": 7}
# [*] Overall Accuracy: 66.083%
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 9,676
#    Completion tokens: 3,662
#    Total tokens: 13,338
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 9,132
#    Completion tokens: 1,966
#    Total tokens: 11,098
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [-] Evaluation could not be executed
# Error: error: Traceback (most recent call last):
#   File "/Users/onurcanmemis/Desktop/data-integration-team-project/agents/output/code/evaluation.py", line 224, in <module>
#     main()
#   File "/Users/onurcanmemis/Desktop/data-integration-team-project/agents/output/code/evaluation.py", line 131, in main
#     gold = load_csv(gold_path, name="fusion_test_set", nested_handling="aggregate")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/onurcanmemis/Desktop/Lectures/2025-2026_Winter/Team_Project/.venv/lib/python3.12/site-packages/PyDI/io/loaders.py", line 351, in load_csv
#     return load_with_provenance(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/onurcanmemis/Desktop/Lectures/2025-2026_Winter/Team_Project/.venv/lib/python3.12/site-packages/PyDI/io/loaders.py", line 284, in load_with_provenance
#     result = reader_fn(path_or_buf, **reader_kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: read_csv() got an unexpected keyword argument 'nested_handling'
#
# [*] Fixing evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 11,397
#    Completion tokens: 2,118
#    Total tokens: 13,515
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.6795994993742178, "macro_accuracy": 0.6951754385964912, "num_evaluated_records": 40, "num_evaluated_attributes": 21, "total_evaluations": 799, "total_correct": 543, "phone_raw_accuracy": 0.0, "phone_raw_count": 40, "rating_count_accuracy": 1.0, "rating_count_count": 34, "map_url_accuracy": 0.6, "map_url_count": 40, "latitude_accuracy": 0.975, "latitude_count": 40, "source_accuracy": 0.525, "source_count": 40, "rating_accuracy": 0.475, "rating_count": 40, "address_line2_accuracy": 1.0, "address_line2_count": 7, "name_accuracy": 0.975, "name_count": 40, "categories_accuracy": 0.975, "categories_count": 40, "postal_code_accuracy": 0.0, "postal_code_count": 40, "street_accuracy": 0.85, "street_count": 40, "_id_accuracy": 0.525, "_id_count": 40, "phone_e164_accuracy": 0.0, "phone_e164_count": 40, "house_number_accuracy": 0.0, "house_number_count": 40, "longitude_accuracy": 0.975, "longitude_count": 40, "website_accuracy": 0.9736842105263158, "website_count": 38, "name_norm_accuracy": 0.875, "name_norm_count": 40, "state_accuracy": 0.975, "state_count": 40, "country_accuracy": 0.975, "country_count": 40, "address_line1_accuracy": 0.95, "address_line1_count": 40, "city_accuracy": 0.975, "city_count": 40}
# [*] Overall Accuracy: 67.960%
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 10,278
#    Completion tokens: 3,553
#    Total tokens: 13,831
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 9,023
#    Completion tokens: 1,894
#    Total tokens: 10,917
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [-] Evaluation could not be executed
# Error: error: Traceback (most recent call last):
#   File "/Users/onurcanmemis/Desktop/data-integration-team-project/agents/output/code/evaluation.py", line 124, in <module>
#     gold = load_csv(GOLD_PATH, name="fusion_test_set", nested_handling="aggregate")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/onurcanmemis/Desktop/Lectures/2025-2026_Winter/Team_Project/.venv/lib/python3.12/site-packages/PyDI/io/loaders.py", line 351, in load_csv
#     return load_with_provenance(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/onurcanmemis/Desktop/Lectures/2025-2026_Winter/Team_Project/.venv/lib/python3.12/site-packages/PyDI/io/loaders.py", line 284, in load_with_provenance
#     result = reader_fn(path_or_buf, **reader_kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: read_csv() got an unexpected keyword argument 'nested_handling'
#
# [*] Fixing evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 11,183
#    Completion tokens: 1,915
#    Total tokens: 13,098
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.6708385481852316, "macro_accuracy": 0.6869047619047618, "num_evaluated_records": 40, "num_evaluated_attributes": 21, "total_evaluations": 799, "total_correct": 536, "name_norm_accuracy": 0.875, "name_norm_count": 40, "website_accuracy": 1.0, "website_count": 38, "house_number_accuracy": 0.0, "house_number_count": 40, "rating_count_accuracy": 1.0, "rating_count_count": 34, "phone_raw_accuracy": 0.0, "phone_raw_count": 40, "phone_e164_accuracy": 0.0, "phone_e164_count": 40, "map_url_accuracy": 0.5, "map_url_count": 40, "longitude_accuracy": 0.975, "longitude_count": 40, "categories_accuracy": 0.975, "categories_count": 40, "source_accuracy": 0.475, "source_count": 40, "city_accuracy": 0.975, "city_count": 40, "latitude_accuracy": 0.975, "latitude_count": 40, "address_line2_accuracy": 1.0, "address_line2_count": 7, "country_accuracy": 0.975, "country_count": 40, "postal_code_accuracy": 0.0, "postal_code_count": 40, "_id_accuracy": 0.475, "_id_count": 40, "rating_accuracy": 0.475, "rating_count": 40, "state_accuracy": 0.975, "state_count": 40, "name_accuracy": 0.975, "name_count": 40, "street_accuracy": 0.85, "street_count": 40, "address_line1_accuracy": 0.95, "address_line1_count": 40}
# [*] Overall Accuracy: 67.084%
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 10,164
#    Completion tokens: 3,901
#    Total tokens: 14,065
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 9,371
#    Completion tokens: 1,623
#    Total tokens: 10,994
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.6495619524405507, "macro_accuracy": 0.6666040100250625, "num_evaluated_records": 40, "num_evaluated_attributes": 21, "total_evaluations": 799, "total_correct": 519, "address_line1_accuracy": 0.95, "address_line1_count": 40, "map_url_accuracy": 0.575, "map_url_count": 40, "latitude_accuracy": 0.975, "latitude_count": 40, "phone_raw_accuracy": 0.0, "phone_raw_count": 40, "country_accuracy": 0.975, "country_count": 40, "name_accuracy": 0.975, "name_count": 40, "street_accuracy": 0.85, "street_count": 40, "_id_accuracy": 0.5, "_id_count": 40, "rating_accuracy": 0.475, "rating_count": 40, "longitude_accuracy": 0.975, "longitude_count": 40, "address_line2_accuracy": 1.0, "address_line2_count": 7, "source_accuracy": 0.0, "source_count": 40, "state_accuracy": 0.975, "state_count": 40, "categories_accuracy": 0.95, "categories_count": 40, "city_accuracy": 0.975, "city_count": 40, "phone_e164_accuracy": 0.0, "phone_e164_count": 40, "postal_code_accuracy": 0.0, "postal_code_count": 40, "rating_count_accuracy": 1.0, "rating_count_count": 34, "house_number_accuracy": 0.0, "house_number_count": 40, "website_accuracy": 0.9736842105263158, "website_count": 38, "name_norm_accuracy": 0.875, "name_norm_count": 40}
# [*] Overall Accuracy: 64.956%
# TOTAL TOKEN USAGE:
#    Prompt tokens: 111,893
#    Completion tokens: 29,930
#    Total tokens: 141,823
#    Estimated cost: $0.000000

# %%
# Games use case
#entity_matching_testsets= {
#    ("dbpedia","sales"): INPUT_DIR + "datasets/games/testsets/dpedia_games_sales_goldstandard_blocking.csv",
#    ("dbpedia","metacritic"): INPUT_DIR + "datasets/games/testsets/dpedia_games_metacritic_goldstandard_blocking.csv",
#    ("sales","metacritic"): INPUT_DIR + "datasets/games/testsets/sales_metacritic_goldstandard_blocking.csv",
#}

entity_matching_testsets= {
    ("dbpedia","sales"): INPUT_DIR + "datasets/games/testsets/dbpedia_2_sales_test.csv",
    ("metacritic","dbpedia"): INPUT_DIR + "datasets/games/testsets/metacritic_2_dbpedia_test.csv",
    ("metacritic","sales"): INPUT_DIR + "datasets/games/testsets/metacritic_2_sales_test.csv",
}

datasets= [
    INPUT_DIR + "datasets/games/dbpedia.xml",
    INPUT_DIR + "datasets/games/metacritic.xml",
    INPUT_DIR + "datasets/games/sales.xml"
]
fusion_testset= INPUT_DIR + "datasets/games/testsets/test_set.xml"

# %%
# prepare agent
from workflow_logging import attach_logging
agent = SimpleModelAgent(llm, ProfileDatasetTool())
attach_logging(agent, output_dir=OUTPUT_DIR, summary_model_name="gpt-4.1-mini", notebook_name="AdaptationPipeline_Final_Blocker_Matcher_Games")

# invoke agent
result = agent.graph.invoke({
    "datasets": datasets,
    "entity_matching_testsets": entity_matching_testsets,
    "fusion_testset": fusion_testset,
    "matcher_mode": "rulebased"
},
config={"recursion_limit": 5000})

# %%
# Books use case
entity_matching_testsets= {
    ("goodreads_small","amazon_small"): INPUT_DIR + "datasets/books/testsets/goodreads_2_amazon.csv",
    ("metabooks_small","amazon_small"): INPUT_DIR + "datasets/books/testsets/metabooks_2_amazon.csv",
    ("metabooks_small","goodreads_small"): INPUT_DIR + "datasets/books/testsets/metabooks_2_goodreads.csv",
}

datasets= [
    INPUT_DIR + "datasets/books/amazon_small.parquet",
    INPUT_DIR + "datasets/books/goodreads_small.parquet",
    INPUT_DIR + "datasets/books/metabooks_small.parquet"
]
fusion_testset= INPUT_DIR + "datasets/books/testsets/golden_fused_books.csv"

# %%
# prepare agent
from workflow_logging import attach_logging
agent = SimpleModelAgent(llm, ProfileDatasetTool())
attach_logging(agent, output_dir=OUTPUT_DIR, summary_model_name="gpt-4.1-mini", notebook_name="AdaptationPipeline_Final_Blocker_Matcher_Books")

# invoke agent
result = agent.graph.invoke({
    "datasets": datasets,
    "entity_matching_testsets": entity_matching_testsets,
    "fusion_testset": fusion_testset,
    "matcher_mode": "rulebased"
},
config={"recursion_limit": 5000})
# Out:
# [*] Running schema matching
# [*] Schema alignment columns:
#     amazon_small: ['id', 'title', 'author', 'publish_year', 'publisher']
#     goodreads_small: ['id', 'title', 'author', 'rating', 'numratings', 'language', 'genres', 'bookformat', 'edition', 'page_count', 'publisher', 'publish_year', 'price']
#     metabooks_small: ['id', 'title', 'author', 'rating', 'numratings', 'language', 'genres', 'publisher', 'page_count', 'price', 'publish_year']
# [*] Profiling datasets
# TOKEN USAGE (profile_data):
#    Prompt tokens: 240
#    Completion tokens: 87
#    Total tokens: 327
#    Estimated cost: $0.000000
# [*] Running BlockingTester
# [*] Loading dataset: amazon_small
# [*] Loading dataset: goodreads_small
# [*] Loading dataset: metabooks_small
# [*] Loading gold standard for goodreads_small <-> amazon_small
#     Loaded 926 ground truth pairs (positives: 446, negatives/other: 480)
# [*] Loading gold standard for metabooks_small <-> amazon_small
#     Loaded 971 ground truth pairs (positives: 662, negatives/other: 309)
# [*] Loading gold standard for metabooks_small <-> goodreads_small
#     Loaded 956 ground truth pairs (positives: 575, negatives/other: 381)
# [*] Adaptive max_candidates set to 350,000 (r=0.35%, median_pairs=100,000,000)
#
# ============================================================
# 🤖 BLOCKING: goodreads_small <-> amazon_small
# ============================================================
# Gold pairs: 926, PC threshold: 0.9
# Candidate limit: 350,000 (hard: 402,499 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 10,000 × 10,000 = 100,000,000 potential pairs
# Common columns: ['publisher', 'publish_year', 'title', 'author']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['title', 'publish_year']
#   Params: {}
#   Reasoning: Need very strong reduction (100M potential pairs, max 350k). Exact matching on title alone is alread...
#     Standard (title+publish_year): 264 candidates
#     ⚠️ PC=0.3901, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['title', 'author', 'publish_year']
#   Params: {'top_k': 20}
#   Reasoning: Exact match on (title,publish_year) was too restrictive (PC=0.39), likely due to title/author format...
#     Embedding (title+author+publish_year, k=20): 199,823 candidates
#     ✅ PC=0.9978, RR=0.9980
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: metabooks_small <-> amazon_small
# ============================================================
# Gold pairs: 971, PC threshold: 0.9
# Candidate limit: 350,000 (hard: 402,499 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 10,000 × 10,000 = 100,000,000 potential pairs
# Common columns: ['publisher', 'publish_year', 'title', 'author']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['title', 'author']
#   Params: {}
#   Reasoning: With 10k×10k=100M possible pairs and a strict 350k candidate cap, we need very restrictive blocking....
#     Standard (title+author): 1,376 candidates
#     ⚠️ PC=0.4940, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['title', 'author', 'publisher']
#   Params: {'top_k': 20}
#   Reasoning: Exact match on title+author was too restrictive (PC=0.494), indicating frequent formatting/casing/HT...
#     Embedding (title+author+publisher, k=20): 199,641 candidates
#     ✅ PC=0.9955, RR=0.9980
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: metabooks_small <-> goodreads_small
# ============================================================
# Gold pairs: 956, PC threshold: 0.9
# Candidate limit: 350,000 (hard: 402,499 with tolerance)
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Dataset sizes: 10,000 × 10,000 = 100,000,000 potential pairs
# Common columns: ['page_count', 'publisher', 'publish_year', 'title', 'rating', 'language', 'numratings', 'author', 'price', 'genres']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['title', 'author', 'language']
#   Params: {}
#   Reasoning: With 10k×10k (100M) potential pairs and a strict 350k candidate cap, use a very restrictive fast blo...
#     Standard (title+author+language): 302 candidates
#     ⚠️ PC=0.2087, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['title', 'author', 'publisher']
#   Params: {'top_k': 20}
#   Reasoning: Exact matching on title+author+language was far too restrictive (PC=0.209). For books, matches often...
#     Embedding (title+author+publisher, k=20): 199,106 candidates
#     ✅ PC=0.9948, RR=0.9980
# ✅ Found acceptable strategy!
#
# ============================================================
# 📊 RESULTS SUMMARY: 3 pairs evaluated
# ============================================================
#   ✅ goodreads_small_amazon_small: PC=0.9978, candidates=199,823, strategy=semantic_similarity
#   ✅ metabooks_small_amazon_small: PC=0.9955, candidates=199,641, strategy=semantic_similarity
#   ✅ metabooks_small_goodreads_small: PC=0.9948, candidates=199,106, strategy=semantic_similarity
#
# 💾 Config saved to: output/blocking-evaluation/blocking_config.json
# [*] Blocking config computed:
# {
#   "blocking_strategies": {
#     "goodreads_small_amazon_small": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "title",
#         "author",
#         "publish_year"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.9977578475336323,
#       "num_candidates": 199823,
#       "is_acceptable": true
#     },
#     "metabooks_small_amazon_small": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "title",
#         "author",
#         "publisher"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.9954682779456193,
#       "num_candidates": 199641,
#       "is_acceptable": true
#     },
#     "metabooks_small_goodreads_small": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "title",
#         "author",
#         "publisher"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.9947826086956522,
#       "num_candidates": 199106,
#       "is_acceptable": true
#     }
#   },
#   "id_columns": {
#     "amazon_small": "id",
#     "goodreads_small": "id",
#     "metabooks_small": "id"
#   }
# }
# [*] Running MatchingTester
# [*] Loading dataset: amazon_small
# [*] Loading dataset: goodreads_small
# [*] Loading dataset: metabooks_small
# [*] Loading matching gold standard for goodreads_small <-> amazon_small
#     Loaded 926 ground truth pairs
# [*] Loading matching gold standard for metabooks_small <-> amazon_small
#     Loaded 971 ground truth pairs
# [*] Loading matching gold standard for metabooks_small <-> goodreads_small
#     Loaded 956 ground truth pairs
#
# ==================================================
# MATCHING EVALUATION
# ==================================================
#
# ==================================================
# MATCHING: goodreads_small <-> amazon_small
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['title', 'author', 'publish_year']
#
# --- Attempt 1/4 ---
# Comparators: ['title:cosine', 'author:jaro_winkler', 'publish_year:365', 'publisher:jaro_winkler']
# Weights: [0.45, 0.3, 0.2, 0.05]
# Threshold: 0.78
#     Reasoning: Use blocking columns title/author/publish_year with strong weight: title benefits from token-based cosine; author has casing/parenthetical noise so jaro_winkler with normalization; publish_year treated as date with 1-year tolerance for edition differences; publisher is informative but more variable, so low weight. Slightly higher threshold to reduce false positives.
#     Reasoning (100c): Use blocking columns title/author/publish_year with strong weight: title benefits from token-based c
# F1=0.7167 < 0.75
#
# --- Attempt 2/4 ---
# Comparators: ['title:cosine', 'author:jaro_winkler', 'publish_year:1.0', 'publisher:jaro_winkler']
# Weights: [0.45, 0.35, 0.15, 0.05]
# Threshold: 0.73
#     Reasoning: Strengthen author matching with jaro_winkler for casing/typos and normalize text; keep title cosine for token-level similarity; tighten publish_year to ±1 to reduce false matches while allowing minor discrepancies; downweight publisher as secondary signal; slightly lower threshold from 0.75 since prior best was 0.72 with noisier author/title formatting.
#     Reasoning (100c): Strengthen author matching with jaro_winkler for casing/typos and normalize text; keep title cosine
# SUCCESS: F1=0.7789
#
# ==================================================
# MATCHING: metabooks_small <-> amazon_small
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['title', 'author', 'publisher']
#
# --- Attempt 1/4 ---
# Comparators: ['title:cosine', 'author:jaro_winkler', 'publisher:jaro_winkler', 'publish_year:1.0']
# Weights: [0.45, 0.3, 0.15, 0.1]
# Threshold: 0.78
#     Reasoning: Use blocking columns title/author/publisher for strong identity signals; title may contain HTML/entities and truncation so token-based cosine helps, while author/publisher benefit from typo-tolerant jaro_winkler. publish_year is often missing on one side (high null) so give it low weight but allow small year discrepancies with max_difference=1. Higher threshold favors precision given strong text identifiers.
#     Reasoning (100c): Use blocking columns title/author/publisher for strong identity signals; title may contain HTML/enti
# SUCCESS: F1=0.8192
#
# ==================================================
# MATCHING: metabooks_small <-> goodreads_small
# ==================================================
#     Using ID column: 'id'
#     Using ID column: 'id'
#     Gold id1 -> left(id), id2 -> right(id)
# Blocking columns: ['title', 'author', 'publisher']
#
# --- Attempt 1/4 ---
# Comparators: ['title:cosine', 'author:jaro_winkler', 'publisher:jaro_winkler', 'page_count:25.0']
# Weights: [0.5, 0.25, 0.15, 0.1]
# Threshold: 0.78
#     Reasoning: Use blocking fields (title/author/publisher) as primary signals: title can be long/truncated so token-based cosine helps; author/publisher are shorter with minor formatting differences so jaro_winkler is robust. Add page_count as a weak numeric check. Avoid publish_year due to high nulls on one side; other numeric fields (numratings/price/rating) are not stable identifiers across sources.
#     Reasoning (100c): Use blocking fields (title/author/publisher) as primary signals: title can be long/truncated so toke
# F1=0.7449 < 0.75
#
# --- Attempt 2/4 ---
# Comparators: ['title:cosine', 'author:jaro_winkler', 'publisher:cosine', 'publish_year:730']
# Weights: [0.55, 0.25, 0.12, 0.08]
# Threshold: 0.72
#     Reasoning: Prior config was just below target; increase emphasis on title (most discriminative), use typo-tolerant Jaro-Winkler for author (handles suffixes like '(Goodreads Author)'), keep publisher as supporting signal, and add publish_year with a 2-year tolerance due to high nulls on one side; slightly lower threshold to recover true matches while maintaining precision using strong text fields and blocking columns.
#     Reasoning (100c): Prior config was just below target; increase emphasis on title (most discriminative), use typo-toler
# SUCCESS: F1=0.7590
#
# 📊 Results: 3 pairs evaluated
#   OK goodreads_small_amazon_small: F1=0.7789
#   OK metabooks_small_amazon_small: F1=0.8192
#   OK metabooks_small_goodreads_small: F1=0.7590
# Config saved to matching_config.json
# [*] Matching config computed:
# {
#   "id_columns": {
#     "amazon_small": "id",
#     "goodreads_small": "id",
#     "metabooks_small": "id"
#   },
#   "matching_strategies": {
#     "goodreads_small_amazon_small": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "title",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "author",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "numeric",
#           "column": "publish_year",
#           "max_difference": 1.0
#         },
#         {
#           "type": "string",
#           "column": "publisher",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         }
#       ],
#       "weights": [
#         0.45,
#         0.35,
#         0.15,
#         0.05
#       ],
#       "threshold": 0.73,
#       "f1": 0.7789473684210525
#     },
#     "metabooks_small_amazon_small": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "title",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "author",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "publisher",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "numeric",
#           "column": "publish_year",
#           "max_difference": 1.0
#         }
#       ],
#       "weights": [
#         0.45,
#         0.3,
#         0.15,
#         0.1
#       ],
#       "threshold": 0.78,
#       "f1": 0.8191757779646762
#     },
#     "metabooks_small_goodreads_small": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "title",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "author",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "publisher",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "date",
#           "column": "publish_year",
#           "max_days_difference": 730
#         }
#       ],
#       "weights": [
#         0.55,
#         0.25,
#         0.12,
#         0.08
#       ],
#       "threshold": 0.72,
#       "f1": 0.7590027700831025
#     }
#   }
# }
# [*] Creating initial pipeline
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 5,128
#    Completion tokens: 2,106
#    Total tokens: 7,234
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 4,588
#    Completion tokens: 1,879
#    Total tokens: 6,467
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.5428571428571428, "macro_accuracy": 0.5428571428571428, "num_evaluated_records": 20, "num_evaluated_attributes": 7, "total_evaluations": 140, "total_correct": 76, "publish_year_accuracy": 0.8, "publish_year_count": 20, "publisher_accuracy": 0.5, "publisher_count": 20, "language_accuracy": 0.8, "language_count": 20, "title_accuracy": 0.6, "title_count": 20, "genres_accuracy": 0.05, "genres_count": 20, "author_accuracy": 0.4, "author_count": 20, "page_count_accuracy": 0.65, "page_count_count": 20}
# [*] Overall Accuracy: 54.286%
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 7,467
#    Completion tokens: 3,514
#    Total tokens: 10,981
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 5,996
#    Completion tokens: 1,814
#    Total tokens: 7,810
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.6071428571428571, "macro_accuracy": 0.6071428571428571, "num_evaluated_records": 20, "num_evaluated_attributes": 7, "total_evaluations": 140, "total_correct": 85, "author_accuracy": 0.7, "author_count": 20, "publisher_accuracy": 0.5, "publisher_count": 20, "genres_accuracy": 0.0, "genres_count": 20, "publish_year_accuracy": 0.8, "publish_year_count": 20, "language_accuracy": 0.8, "language_count": 20, "title_accuracy": 0.8, "title_count": 20, "page_count_accuracy": 0.65, "page_count_count": 20}
# [*] Overall Accuracy: 60.714%
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 8,875
#    Completion tokens: 4,469
#    Total tokens: 13,344
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 6,951
#    Completion tokens: 1,532
#    Total tokens: 8,483
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.5857142857142857, "macro_accuracy": 0.5857142857142856, "num_evaluated_records": 20, "num_evaluated_attributes": 7, "total_evaluations": 140, "total_correct": 82, "author_accuracy": 0.7, "author_count": 20, "page_count_accuracy": 0.6, "page_count_count": 20, "publish_year_accuracy": 0.8, "publish_year_count": 20, "genres_accuracy": 0.0, "genres_count": 20, "publisher_accuracy": 0.5, "publisher_count": 20, "language_accuracy": 0.8, "language_count": 20, "title_accuracy": 0.7, "title_count": 20}
# [*] Overall Accuracy: 58.571%
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 9,830
#    Completion tokens: 4,900
#    Total tokens: 14,730
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 7,382
#    Completion tokens: 1,628
#    Total tokens: 9,010
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.65, "macro_accuracy": 0.65, "num_evaluated_records": 20, "num_evaluated_attributes": 7, "total_evaluations": 140, "total_correct": 91, "language_accuracy": 0.8, "language_count": 20, "title_accuracy": 0.65, "title_count": 20, "genres_accuracy": 0.75, "genres_count": 20, "page_count_accuracy": 0.55, "page_count_count": 20, "author_accuracy": 0.7, "author_count": 20, "publish_year_accuracy": 0.8, "publish_year_count": 20, "publisher_accuracy": 0.3, "publisher_count": 20}
# [*] Overall Accuracy: 65.000%
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 10,251
#    Completion tokens: 4,374
#    Total tokens: 14,625
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 6,856
#    Completion tokens: 1,803
#    Total tokens: 8,659
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.65, "macro_accuracy": 0.65, "num_evaluated_records": 20, "num_evaluated_attributes": 7, "total_evaluations": 140, "total_correct": 91, "language_accuracy": 0.8, "language_count": 20, "title_accuracy": 0.65, "title_count": 20, "genres_accuracy": 0.75, "genres_count": 20, "page_count_accuracy": 0.55, "page_count_count": 20, "author_accuracy": 0.7, "author_count": 20, "publish_year_accuracy": 0.8, "publish_year_count": 20, "publisher_accuracy": 0.3, "publisher_count": 20}
# [*] Overall Accuracy: 65.000%
# TOTAL TOKEN USAGE:
#    Prompt tokens: 73,564
#    Completion tokens: 28,106
#    Total tokens: 101,670
#    Estimated cost: $0.000000
