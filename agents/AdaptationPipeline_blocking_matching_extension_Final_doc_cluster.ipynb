# %%
import os
import json 
import getpass
import logging
from pathlib import Path
from time import sleep
import subprocess
import sys
import traceback

from langchain_core.tools import Tool
from langgraph.graph import StateGraph, END
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
from langchain.tools import BaseTool

from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings

from typing import TypedDict, Dict, List

from PyDI.io import load_xml, load_parquet, load_csv
from PyDI.profiling import DataProfiler
from blocking_tester import BlockingTester
from matching_tester import MatchingTester
from cluster_tester import ClusterTester

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialize

# %%
OUTPUT_DIR = "output/"
INPUT_DIR = "input/"

INCLUDE_DOCS = False # IMPORTANT: Use carefully since token usage is increased drastically with documentation
USE_LLM = "gpt"
#USE_LLM = "gemini"
#USE_LLM = "groq"

# %%
if USE_LLM == "gemini": # or USE_LLM == "gemini_broken":
    if "GOOGLE_API_KEY" not in os.environ:
        os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")
elif USE_LLM == "groq":
    if "GROQ_API_KEY" not in os.environ:
        os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")
elif USE_LLM == "gpt":
    if "OPENAI_API_KEY" not in os.environ:
        os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

# %%
logging.basicConfig(filename= OUTPUT_DIR + 'agent.log',
                    filemode='a',
                    format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.DEBUG,
                    encoding='utf-8')

# %% [markdown]
# ## Utilities

# %%
def load_dataset(path):
    # check file exists
    if not os.path.exists(path):
        raise FileNotFoundError(f"Dataset not found at: {path}")
    ext = os.path.splitext(path)[1].lower()

    # load dataset according to extension
    if ext == ".parquet":
        df = load_parquet(path)
    elif ext == ".csv":
        df = load_csv(path)
    elif ext == ".xml":
        df = load_xml(path, nested_handling="aggregate")
    else:
        raise ValueError(f"Unsupported format: {ext}. Supported: .csv, .parquet, .xml")
    return df

# %% [markdown]
# ## Tools

# %%
class ProfileDatasetTool(BaseTool):
    name: str = "profile_dataset"
    description: str = """
        A tool that takes the path as a argument called `path` of type str of the dataset file as string and performs data analysis. 
        A JSON string is returned with the profile data.
    """
    
    def _run(self, path) -> str:   
        return self.create_profile(path)

    def create_profile(self, path):

        if not path or not isinstance(path, str):
                raise ValueError("ProfileDatasetTool requires a single path string argument.")

        df = load_dataset(path)
        
        if df is None or getattr(df, "empty", False):
            # return a structured JSON error string (LLM will see this as content)
            return json.dumps({"error": f"Dataset at {path} loaded as empty or failed to load."})

        profiler = DataProfiler()
        profile = profiler.summary(df, print_summary=False)

        # ensure to return a JSON string (your docstring promised JSON string)
        try:
            profile_json = json.dumps(profile, default=str)
        except Exception:
            # fallback: convert to str if not json-serializable
            profile_json = json.dumps({"profile_str": str(profile)})

        return profile_json

# %%
class SearchDocumentationTool(BaseTool):
    name: str = "search_documentation"
    description: str = """
        A tool that searches the PyDI documentation for a given query.
        Use this to find information about functions, classes, or how-to instructions in the PyDI library.
        The input is a string query.
        The output is a string with the most relevant documentation snippets.
    """
    def _run(self, query: str) -> str:
        embeddings = OpenAIEmbeddings(
            model="text-embedding-3-large"
        )

        vector_db_path = os.path.join(INPUT_DIR, "api_documentation/pydi_apidocs_vector_db/")
        if not os.path.exists(vector_db_path):
            return f"Error: Vector DB not found at {vector_db_path}"
        try:
            db = Chroma(persist_directory=vector_db_path, embedding_function=embeddings)
            docs = db.similarity_search(query, k=5)
            
            if not docs:
                return "No relevant documentation found for your query."

            output = "\n\n-----\n\n".join([r.page_content for r in docs])
            return output
        except Exception as e:
            return f"An error occurred while searching documentation: {str(e)}\\n{traceback.format_exc()}"

# %%
if USE_LLM == "gemini":
    llm = ChatGoogleGenerativeAI(
        model="gemini-2.0-flash",
        temperature=0,
        max_tokens=None,
        timeout=None,
        max_retries=2,
    )
elif USE_LLM == "groq":
    llm = ChatGroq(
        model="llama-3.3-70b-versatile",
        temperature=0.2
    )
elif USE_LLM == "gpt":
    llm = ChatOpenAI(
        model="gpt-5.2",
        temperature=0,
        max_tokens=None,
    )
# Define blocking gold standard testsets
blocking_testsets = {
    ("discogs", "lastfm"): INPUT_DIR + "testsets/music/discogs_lastfm_goldstandard_blocking.csv",
    ("discogs", "musicbrainz"): INPUT_DIR + "testsets/music/discogs_musicbrainz_goldstandard_blocking.csv",
    ("musicbrainz", "lastfm"): INPUT_DIR + "testsets/music/musicbrainz_lastfm_goldstandard_blocking.csv",
}
datasets = [
    INPUT_DIR + "datasets/discogs.xml",
    INPUT_DIR + "datasets/lastfm.xml",
    INPUT_DIR + "datasets/musicbrainz.xml"
]
# Matching testsets (default to blocking testsets)
matching_testsets = blocking_testsets

# %% [markdown]
# ## Agents

# %%
class SimpleModelAgentState(TypedDict):
    datasets: list
    fusion_testset: str
    blocking_config: Dict  # NEW: Blocking config from BlockingTester
    matching_config: Dict  # NEW: Matching config from MatchingTester

    data_profiles: Dict
    documentation: str

    integration_pipeline_code: str
    pipeline_execution_result: str
    pipeline_execution_attempts: int

    cluster_analysis_result: Dict

    evaluation_code: str
    evaluation_execution_result: str
    evaluation_execution_attempts: int

    evaluation_attempts: int
    evaluation_metrics: Dict

    evaluation_analysis: str


class SimpleModelAgent:

    def __init__(self, model, profileTool, search_tool):
        # initialize logger
        self.logger = logging.getLogger()
        self.base_model = model

        # prepare the StateGraph
        graph = StateGraph(SimpleModelAgentState)

        # create nodes
        graph.add_node("profile_data", self.profile_data)
        graph.add_node("pydi_doc", self.pydi_doc)
        graph.add_node("run_blocking_tester", self.run_blocking_tester)
        graph.add_node("run_matching_tester", self.run_matching_tester)
        graph.add_node("pipeline_adaption", self.pipeline_adaption)
        graph.add_node("execute_pipeline", self.execute_pipeline)
        graph.add_node("cluster_analysis", self.cluster_analysis)
        graph.add_node("evaluation_adaption", self.evaluation_adaption)
        graph.add_node("execute_evaluation", self.execute_evaluation)
        graph.add_node("evaluation_decision", self.evaluation_decision)
        graph.add_node("evaluation_reasoning", self.evaluation_reasoning)

        # create edges
        graph.add_edge("profile_data", "pydi_doc")
        graph.add_edge("pydi_doc", "run_blocking_tester")
        graph.add_edge("run_blocking_tester", "run_matching_tester")
        graph.add_edge("run_matching_tester", "pipeline_adaption")
        graph.add_edge("pipeline_adaption", "execute_pipeline")

        # graph.add_conditional_edges(
        #     "execute_pipeline",
        #     lambda state: (
        #         "evaluation_adaption"
        #         if isinstance(state.get("pipeline_execution_result", ""), str)
        #            and state["pipeline_execution_result"].lower().startswith("success")
        #         else "pipeline_adaption"
        #         if state.get("pipeline_execution_attempts", 0) < 3
        #         else END
        #     ),
        #     {
        #         "pipeline_adaption": "pipeline_adaption",
        #         "evaluation_adaption": "evaluation_adaption",
        #         END: END
        #     }
        # )

        # graph.add_edge("evaluation_adaption", "execute_evaluation")

        graph.add_conditional_edges(
            "execute_pipeline",
            lambda state: (
                "cluster_analysis"
                if state.get("pipeline_execution_result", "")
                .lower()
                .startswith("success")
                else (
                    "pipeline_adaption"
                    if state.get("pipeline_execution_attempts", 0) < 3
                    else END
                )
            ),
            {
                "cluster_analysis": "cluster_analysis",
                "pipeline_adaption": "pipeline_adaption",
                END: END,
            },
        )

        graph.add_edge("cluster_analysis", "evaluation_adaption")

        graph.add_edge("evaluation_adaption", "execute_evaluation")

        graph.add_conditional_edges(
            "execute_evaluation",
            lambda state: (
                "evaluation_decision"
                if isinstance(state.get("evaluation_execution_result", ""), str)
                and state["evaluation_execution_result"].lower().startswith("success")
                else (
                    "evaluation_adaption"
                    if state.get("evaluation_attempts", 0) < 3
                    else END
                )
            ),
            {
                "evaluation_adaption": "evaluation_adaption",
                "evaluation_decision": "evaluation_decision",
                END: END,
            },
        )

        graph.add_conditional_edges(
            "evaluation_decision",
            lambda state: (
                "evaluation_reasoning"
                if state.get("evaluation_metrics", {}).get("overall_accuracy", 0) < 0.85
                and state.get("evaluation_attempts", 0) < 3
                else END
            ),
            {"evaluation_reasoning": "evaluation_reasoning", END: END},
        )

        graph.add_edge("evaluation_reasoning", "pipeline_adaption")

        graph.set_entry_point("profile_data")
        self.graph = graph.compile()

        # make tools available to the model based on model type
        # self.tools = {profileTool.name: profileTool}
        #        if USE_LLM == "groq" or USE_LLM == "gpt" or USE_LLM == "gemini":
        # self.model = model.bind_tools([profileTool])
        self.tools = {profileTool.name: profileTool, search_tool.name: search_tool}
        self.model = model.bind_tools(list(self.tools.values()))

    #        elif USE_LLM == "gemini_broken":
    #            self.model = model.bind_tools(profileTool)

    # Creates tool calls to profile the data and saves it into agent state
    def profile_data(self, state: SimpleModelAgentState):
        self.logger.info(
            "----------------------- Entering profile_data -----------------------"
        )

        print("[*] Profiling datasets")

        system_prompt = f"""
            You are a data scientist tasked with the integration of several datasets.
            For each dataset path provided, call the tool `profile_dataset` with the path
            (one tool call per dataset).
        """

        datasets_list_str = "\n".join(state["datasets"])
        human_content = f"Please profile these datasets (one call per dataset):\n{datasets_list_str}"
        message = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content),
        ]
        self.logger.info("Input Message:" + str(message))

        result = self.model.invoke(message)
        self.logger.info("RESULT:" + str(result))

        # call tools
        tool_calls = result.tool_calls

        self.logger.info("Tool Calls:" + str(tool_calls))
        results = {}
        for t in tool_calls:
            if not t["name"] in self.tools:  # check for bad tool name from LLM
                self.logger.info("adapt_pipeline: ....bad tool name....")
                result = "bad tool name, retry"  # instruct LLM to retry if bad
            else:
                result = self.tools[t["name"]].invoke(t["args"])

            #            if USE_LLM == "groq" or USE_LLM == "gpt" or USE_LLM == "gemini":
            results[t["args"]["path"]] = result
        #            elif USE_LLM == "gemini_broken":
        #                results[t['args']['__arg1']] = result

        with open(OUTPUT_DIR + "profile/profiles.json", "w") as file:
            file.write(json.dumps(results, indent=2))

        self.logger.info("Leaving profile_data")
        return {"data_profiles": results}

    def pydi_doc(self, state: SimpleModelAgentState):
        print("[*] Getting Documentation")
        system_prompt = """Your task is to **create a similar integration pipeline** so that it works with
        the datasets provided.
        To do this, you can use the `search_documentation` tool to find information about the PyDI library.
        You can use it multiple times to explore functions, classes, and usage examples.
        When you have enough information and are ready to write the code, output ONLY the relevant Python code
        for the integration pipeline. Do not use tools in your final response."""

        human_message = """Please retrieve relavent documentation before writing any code. Ask for specific
        questions about how to use a function or class and what parameters is has, for example, 'How to apply
        StandardBlocker?', 'How to use RuleBasedMatcher?', 'What are the parameters of SortedNeighbourhoodBlocker?', etc.
        You can ask multiple questions like this."""

        messages = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_message),
        ]

        result = self.model.invoke(messages)

        # call tools
        tool_calls = result.tool_calls

        # results = {}
        for t in tool_calls:
            if not t["name"] in self.tools:
                result = "bad tool name, retry"
            else:
                result = self.tools[t["name"]].invoke(t["args"])
            # results[t['args']['path']] = result
        with open(OUTPUT_DIR + "profile/documentation.json", "w") as file:
            file.write(json.dumps(result, indent=2))

        return {"documentation": result}

    def run_blocking_tester(self, state: SimpleModelAgentState):
        self.logger.info(
            "----------------------- Entering run_blocking_tester -----------------------"
        )
        if state.get("blocking_config"):
            print(
                "[*] Blocking config already present in state; skipping BlockingTester"
            )
            return {}

        print("[*] Running BlockingTester")
        tester = BlockingTester(
            llm=self.base_model,
            datasets=state["datasets"],
            max_candidates=350000,
            blocking_testsets=blocking_testsets,
            output_dir="output/blocking-evaluation",
            pc_threshold=0.95,
            max_attempts=5,
            max_error_retries=2,
            verbose=True,
        )
        _, blocking_config = tester.run_all_pairs()
        print("[*] Blocking config computed:\n" + json.dumps(blocking_config, indent=2))
        self.logger.info("Leaving run_blocking_tester")
        return {"blocking_config": blocking_config}

    def run_matching_tester(self, state: SimpleModelAgentState):
        self.logger.info(
            "----------------------- Entering run_matching_tester -----------------------"
        )
        if state.get("matching_config"):
            print(
                "[*] Matching config already present in state; skipping MatchingTester"
            )
            return {}

        print("[*] Running MatchingTester")
        tester = MatchingTester(
            llm=self.base_model,
            datasets=state["datasets"],
            matching_testsets=matching_testsets,
            blocking_config=state.get("blocking_config", {}),
            output_dir="output/matching-evaluation",
            f1_threshold=0.75,
            max_attempts=3,
            max_error_retries=2,
            verbose=True,
        )
        _, matching_config = tester.run_all()
        print("[*] Matching config computed:\n" + json.dumps(matching_config, indent=2))
        self.logger.info("Leaving run_matching_tester")
        return {"matching_config": matching_config}

    def pipeline_adaption(self, state: SimpleModelAgentState):
        self.logger.info(
            "----------------------- Entering pipeline_adaption -----------------------"
        )

        ####### PREPARE SYSTEM PROMT #######

        # Load example pipeline code
        example_pipeline_path = os.path.join(
            INPUT_DIR, "example_pipelines/example_pipeline.py"
        )
        if not os.path.exists(example_pipeline_path):
            raise FileNotFoundError(
                f"Example pipeline not found at: {example_pipeline_path}"
            )

        with open(example_pipeline_path, "r", encoding="utf-8") as f:
            example_pipeline_code = f.read()

        # Prepare first-row previews for each dataset
        dataset_previews = {}
        for path in state["datasets"]:
            df = load_dataset(path)
            if df is not None and not df.empty:
                # Take only first row and convert to dictionary
                dataset_previews[path] = df.iloc[0].to_dict()
            else:
                dataset_previews[path] = "Failed to load or empty dataset"

        # Prepare prompt for the model
        system_prompt = f"""
        You are a data scientist tasked with the integration of several datasets.
        You are provided with the following inputs:
    
        1. An example integration pipeline (Python code using PyDI library). Pay
        attention to the comments within the pipeline, as they also contain important instructions:
        {example_pipeline_code}
    
        2. A list of dataset file locations:
        {json.dumps(state['datasets'], indent=2)}
    
        3. The first row of each dataset to help understand the structure:
        {json.dumps(dataset_previews, indent=2)}
    
        4. A dictionary containing the profile data of the datasets
        (including number of rows, nulls_per_column and dtypes of 
        the columns):
        {json.dumps(state['data_profiles'], indent=2)}
        """

        # Include blocking config if available (from BlockingTester)
        blocking_config = state.get("blocking_config")
        if blocking_config:
            system_prompt += f"""

            5. **BLOCKING CONFIGURATION** (pre-computed optimal blocking strategies):
            This configuration was determined by a blocking evaluation agent. Use these settings
            for your blocking step in the pipeline:
            {json.dumps(blocking_config, indent=2)}
            
            IMPORTANT: Use the id_columns and blocking_strategies from this config:
            - Use the correct id_column for each dataset as specified
            - Use the recommended strategy (exact_match_single/multi or semantic_similarity)
            - Use the recommended columns for blocking
            """

        # Include matching config if available (from MatchingTester)
        matching_config = state.get("matching_config")
        if matching_config:
            system_prompt += f"""

            6. **MATCHING CONFIGURATION** (pre-computed comparator settings):
            This configuration was determined by a matching evaluation agent. Use these settings
            for your RuleBasedMatcher step in the pipeline:
            {json.dumps(matching_config, indent=2)}
    
            IMPORTANT: Use the matching_strategies from this config:
            - Build comparators (StringComparator/NumericComparator/DateComparator) for each dataset pair
            - Use the specified weights and threshold
            - preprocess mapping: "lower" -> str.lower, "strip" -> str.strip, "lower_strip" -> lambda x: str(x).lower().strip()
            """

        cluster_analysis_result = state.get("cluster_analysis_result")
        if cluster_analysis_result:
            system_prompt += f"""

            7. **CLUSTER ANALYSIS REPORT**:
            This report was generated from the correspondences of the previous run. Use the
            analysis and suggestions to improve the matching logic (e.g., comparators, thresholds)
            to create better clusters in the next run.
            {json.dumps(cluster_analysis_result, indent=2)}
            """

        prior_pipeline_code = state.get("integration_pipeline_code", None)
        if prior_pipeline_code:
            system_prompt += f"""

            7. Previously generated pipeline code:
            {prior_pipeline_code}
            """

        # Include evaluation reasoning from the evaluation node
        evaluation_analysis = state.get("evaluation_analysis", None)
        if evaluation_analysis:
            system_prompt += f"""

            8. Evaluation reasoning from prior pipeline run:
            {evaluation_analysis}
            """

        # Include evaluation metrics if available
        evaluation_metrics = state.get("evaluation_metrics", None)
        if evaluation_metrics:
            system_prompt += f"""

            9. Evaluation metrics from prior pipeline run:
            {json.dumps(evaluation_metrics, indent=2)}
            """

        system_prompt += f"""

        Your task is to **create a similar integration pipeline** so that it works with
        the datasets provided. Output should only consist of the relevant Python code
        for the integration pipeline.
        Make sure to save correspondences for each pair afer applying Rule-Based or ML-Based Matcher.
        Example: 
        ```
        if not os.path.exists("output/correspondences"):
            os.makedirs("output/correspondences", exist_ok=True)
        correspondences_dataset1_dataset2.to_csv("output/correspondences/correspondences_dataset1_dataset2")
        correspondences_dataset1_dataset3.to_csv("output/correspondences/correspondences_dataset1_dataset3")
        correspondences_dataset3_dataset2.to_csv("output/correspondences/correspondences_dataset3_dataset2")
        ```
        **Use proper filename to save the correspondences**
        """

        # Include documentation if global variable is set
        # if INCLUDE_DOCS:
        #     doc_path = os.path.join(INPUT_DIR, "documentation")
        #     if os.path.exists(doc_path):
        #         doc_files = [f for f in os.listdir(doc_path) if f.endswith(".md")]
        #         all_docs = ""
        #         for f_name in doc_files:
        #             with open(os.path.join(doc_path, f_name), "r", encoding="utf-8", errors="replace") as f:
        #                 all_docs += f.read() + "\n\n"
        #         system_prompt += "\n\n### Documentation\n" + all_docs
        # API Documentation
        system_prompt += f"""PyDI Documentation containing how to use PyDI functions, classes and code
        examples:
        {json.dumps(state['documentation'], indent=2)}
        """

        ####### PREPARE TASK PROMT #######

        # Determine if this is initial generation, fix due to execution error, or fix due to poor evaluation
        if (
            "pipeline_execution_result" not in state
            and "evaluation_metrics" not in state
        ):
            print("[*] Creating initial pipeline")
            human_content = "Create the integration pipeline for the provided datasets."

        else:
            # Either a pipeline execution error or evaluation-based adaption
            human_content = "You previously generated integration pipeline code.\n"

            # Add execution error if exists
            if "pipeline_execution_result" in state and state[
                "pipeline_execution_result"
            ].lower().startswith("error"):
                print("[*] Fixing pipeline")
                human_content += f"""
                
                Executing this pipeline caused the following error:\n{state['pipeline_execution_result']}\n
                Fix the code.\n
                """

            # Add evaluation feedback if available
            if "evaluation_metrics" in state:
                print("[*] Improving pipeline based on evaluation")
                human_content += f"""
                
                You have been provided with the evaluation results and reasoning for that pipeline. 
                Use the evaluation results to improve the pipeline.\n
                """

            human_content += f"""
            
            Output ONLY the corrected Python code. You may add comments you generated code to explain the reasoning behind 
            the changes.
            """

        ####### EXECUTE PROMT #######

        message = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content),
        ]

        self.logger.info("Input Message:" + str(message))

        # Call the model
        adapted_pipeline = self.model.invoke(message)
        adapted_pipeline = (
            adapted_pipeline.content
            if hasattr(adapted_pipeline, "content")
            else str(adapted_pipeline)
        )

        self.logger.info("RESULT:" + str(adapted_pipeline))

        # Strip leading/trailing ``` if present
        if adapted_pipeline.startswith("```python") and adapted_pipeline.endswith(
            "```"
        ):
            adapted_pipeline = adapted_pipeline[9:-3].strip()

        with open(OUTPUT_DIR + "code/pipeline.py", "w", errors="ignore") as file:
            file.write(str(adapted_pipeline))

        self.logger.info("Leaving pipeline_adaption")
        return {"integration_pipeline_code": adapted_pipeline}

    def execute_pipeline(self, state: SimpleModelAgentState):
        self.logger.info(
            "----------------------- Entering execute_pipeline -----------------------"
        )

        print("[*] Running generated pipeline")

        attempts = state.get("pipeline_execution_attempts", 0) + 1
        state["pipeline_execution_attempts"] = attempts

        pipeline_path = OUTPUT_DIR + "code/pipeline.py"

        try:
            result = subprocess.run(
                [sys.executable, pipeline_path],
                capture_output=True,
                text=True,
                timeout=3600,
            )

            if result.returncode == 0:
                print("[+] Pipeline successfully completed")
                execution_result = "success"
            else:
                print("[-] Pipeline could not be executed")
                execution_result = f"error: {result.stderr}"[:3000]
                print("Error: " + str(execution_result))

        except Exception as e:
            execution_result = f"error: {str(e)}"

        self.logger.info("Pipeline execution result: " + execution_result)
        self.logger.info("Leaving execute_pipeline")

        return {
            "pipeline_execution_result": execution_result,
            "pipeline_execution_attempts": attempts,
        }

    def cluster_analysis(self, state: SimpleModelAgentState):
        self.logger.info(
            "----------------------- Entering cluster_analysis -----------------------"
        )
        print("[*] Running cluster analysis")

        correspondences_path = state.get(
            "correspondences_path", "output/correspondences/"
        )

        correspondence_files = []
        if os.path.isdir(correspondences_path):
            try:
                # Filter for files starting with 'correspondences_'
                correspondence_files = [
                    os.path.join(correspondences_path, f)
                    for f in os.listdir(correspondences_path)
                    if f.endswith(".csv")
                ]
            except FileNotFoundError:
                pass
        elif os.path.isfile(correspondences_path):
            if correspondences_path.endswith(".csv"):
                correspondence_files.append(correspondences_path)

        if not correspondence_files:
            print(
                f"[-] No correspondence files found in {correspondences_path}, skipping cluster analysis."
            )
            return {"cluster_analysis_result": {}}

        try:
            cluster_tester = ClusterTester(llm=self.base_model)
            report = cluster_tester.run(correspondence_files)

            return {"cluster_analysis_result": report}
        except Exception as e:
            print(f"[-] Error during cluster analysis: {e}")
            return {"cluster_analysis_result": {"error": str(e)}}

    def evaluation_adaption(self, state: SimpleModelAgentState):
        self.logger.info(
            "----------------------- Entering evaluation_adaption -----------------------"
        )

        example_eval_path = INPUT_DIR + "example_pipelines/example_evaluation.py"
        example_eval_code = open(example_eval_path).read()

        fused_output_path = "output/data_fusion/fusion_rb_standard_blocker.csv"

        system_prompt = f"""
        You are a data scientist evaluating a data fusion pipeline.
    
        Example evaluation code:
        {example_eval_code}
    
        Generated integration pipeline:
        {state['integration_pipeline_code']}
    
        Dataset profiles:
        {json.dumps(state['data_profiles'], indent=2)}
    
        The fused output is located at:
        {fused_output_path}

        The testset is located at:
        {state['fusion_testset']}
    
        Create evaluation code that:
        - Uses the correct fusion strategy
        - Loads the fused output
        - Loads the gold standard test set
        - Prints structured evaluation metrics
        """

        ####### HUMAN PROMPT #######
        if not state.get("evaluation_execution_result"):
            print("[*] Adapting evaluation code")
            # First generation
            human_content = """
            Create the evaluation code.
            """
        else:
            # Fix broken evaluation
            print("[*] Fixing evaluation code")
            attempts = state.get("evaluation_execution_attempts", 0)

            if attempts >= 3:
                self.logger.info("Maximum evaluation fix attempts reached")
                return {"evaluation_execution_result": "error: max attempts reached"}

            eval_path = OUTPUT_DIR + "code/evaluation.py"
            with open(eval_path, "r", encoding="utf-8") as f:
                broken_code = f.read()

            error = state["evaluation_execution_result"]

            human_content = f"""
            You previously generated Python evaluation code.
            Executing this code caused the following error:
    
            {error}
    
            Here is the current evaluation code:
            {broken_code}
    
            Fix the code so that it executes successfully.
            Output ONLY the corrected Python code.
            """

        ####### MODEL CALL #######

        message = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content),
        ]

        self.logger.info("Input Message:" + str(message))

        result = self.model.invoke(message)
        code = result.content.strip("```python").strip("```")

        self.logger.info("RESULT:" + str(code))

        with open(OUTPUT_DIR + "code/evaluation.py", "w") as f:
            f.write(code)

        self.logger.info("Leaving evaluation_adaption")

        return {"evaluation_code": code}

    def execute_evaluation(self, state: SimpleModelAgentState):
        self.logger.info(
            "----------------------- Entering execute_evaluation -----------------------"
        )

        print("[*] Running generated evaluation")

        attempts = state.get("evaluation_execution_attempts", 0) + 1
        state["evaluation_execution_attempts"] = attempts

        evaluation_path = OUTPUT_DIR + "code/evaluation.py"

        try:
            result = subprocess.run(
                [sys.executable, evaluation_path],
                capture_output=True,
                text=True,
                timeout=3600,
            )

            if result.returncode == 0:
                print("[+] Evaluation successfully completed")
                execution_result = "success"
            else:
                print("[-] Evaluation could not be executed")
                execution_result = f"error: {result.stderr}"[:3000]
                print("Error: " + str(execution_result))

        except Exception as e:
            execution_result = f"error: {str(e)}"

        self.logger.info("Evaluation execution result: " + execution_result)
        self.logger.info("Leaving execute_evaluation")

        return {
            "evaluation_execution_result": execution_result,
            "evaluation_execution_attempts": attempts,
        }

    def evaluation_decision(self, state: SimpleModelAgentState):
        self.logger.info(
            "----------------------- Entering evaluation_decision -----------------------"
        )
        print("[*] Reading evaluation metrics")

        attempts = state.get("evaluation_attempts", 0) + 1

        eval_path = "output/pipeline_evaluation/pipeline_evaluation.json"

        if not os.path.exists(eval_path):
            self.logger.warning("Evaluation file missing")
            metrics = {"error": "evaluation file missing"}
        else:
            with open(eval_path, "r", encoding="utf-8") as f:
                metrics = json.load(f)

        self.logger.info(f"Evaluation metrics: {metrics}")
        print(f"Evaluation metrics: {json.dumps(metrics)}")

        # Store metrics in the state
        state["evaluation_metrics"] = metrics

        overall_acc = metrics.get("overall_accuracy", 0.0)
        print(f"[*] Overall Accuracy: {overall_acc:.3%}")

        self.logger.info("Leaving evaluation_decision")

        return {
            "evaluation_metrics": metrics,
            "evaluation_attempts": attempts,
            "pipeline_execution_result": "",
            "pipeline_execution_attempts": 0,
            "evaluation_execution_result": "",
            "evaluation_execution_attempts": 0,
        }

    def evaluation_reasoning(self, state: SimpleModelAgentState):
        self.logger.info(
            "----------------------- Entering evaluation_reasoning -----------------------"
        )

        debug_path = "output/pipeline_evaluation/debug_fusion_eval.jsonl"
        debug_events = []

        if os.path.exists(debug_path):
            with open(debug_path, "r", encoding="utf-8") as f:
                for line in f:
                    try:
                        debug_events.append(json.loads(line))
                    except Exception:
                        continue

        # Prepare system prompt
        system_prompt = """
        You are a data integration expert analyzing the evaluation results of a data integration pipeline.
    
        You are given:
        - Aggregate evaluation metrics
        - Detailed per-record debugging events from a fusion evaluation
        - The current integration pipeline code
        - The optimal blocking and matching configurations
        - Cluster analysis report from the matching phase
    
        Your task:
        1. Identify the dominant error types (false positives, false negatives, missed blocks, bad matches)
        2. Determine whether errors are more likely caused by:
           - Blocking being too restrictive or too loose
           - Matching thresholds or comparator choices
           - Schema or preprocessing issues
           - Logic in the current pipeline code
        3. Suggest concrete, actionable improvements for the next pipeline iteration
    
        Respond with concise, structured reasoning.
        """

        # Prepare human content
        human_content = f"""
        Evaluation metrics:
        {json.dumps(state.get("evaluation_metrics", {}), indent=2)}
    
        Debug fusion events (JSONL):
        {json.dumps(debug_events[:50], indent=2)}
    
        Current integration pipeline code:
        {state.get("integration_pipeline_code", "Pipeline code not available")}
    
        Optimal blocking configuration:
        {json.dumps(state.get("blocking_config", {}), indent=2)}
    
        Optimal matching configuration:
        {json.dumps(state.get("matching_config", {}), indent=2)}

        Cluster analysis report:
        {json.dumps(state.get("cluster_analysis_result", {}), indent=2)}
        """

        # Model call
        message = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content),
        ]

        result = self.model.invoke(message)
        analysis = result.content if hasattr(result, "content") else str(result)

        self.logger.info("Evaluation reasoning produced")
        print("[*] Evaluation reasoning:\n" + analysis)

        return {"evaluation_analysis": analysis}

# %% [markdown]
# ## Invoke Pipeline

# %%
# prepare agent
agent = SimpleModelAgent(llm, ProfileDatasetTool(), SearchDocumentationTool())
fusion_testset = INPUT_DIR + "testsets/music/test_set.xml"
# invoke agent
result = agent.graph.invoke({
    "datasets": datasets, 
    "fusion_testset": fusion_testset
})
# Out:
# [*] Profiling datasets
# [*] Getting Documentation
# [*] Running BlockingTester
# [*] Loading dataset: discogs
# [*] Loading dataset: lastfm
# [*] Loading dataset: musicbrainz
# [*] Loading gold standard for discogs <-> lastfm
#     Loaded 55 ground truth pairs
# [*] Loading gold standard for discogs <-> musicbrainz
#     Loaded 78 ground truth pairs
# [*] Loading gold standard for musicbrainz <-> lastfm
#     Loaded 79 ground truth pairs
#
# ============================================================
# 🤖 BLOCKING: discogs <-> lastfm
# ============================================================
# Gold pairs: 55, PC threshold: 0.95
# Candidate limit: 350,000 (hard: 402,499 with tolerance)
#     Using ID column: 'id'
# Dataset sizes: 22,627 × 9,865 = 223,215,355 potential pairs
# Common columns: ['artist', 'tracks_track_name', 'tracks_track_duration', 'name', 'tracks_track_position', 'duration']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['artist', 'name']
#   Params: min_token_len=4, ngram_size=4, window=15, top_k=20
#   Reasoning: With 223M potential pairs and a strict 350k candidate cap, we need a very restrictive block. Both 'a...
#     Standard (artist+name): 1,240 candidates
#     ⚠️ PC=0.3636, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['name']
#   Params: min_token_len=4, ngram_size=4, window=15, top_k=10
#   Reasoning: Exact blocking on (artist,name) was far too restrictive (PC=0.364). With very large N×M (223M) and a...
#     Embedding (name, k=10): 226,076 candidates
#     ⚠️ PC=0.8727, RR=0.9990
#
# --- Attempt 3/5 ---
# LLM chose: semantic_similarity on ['artist', 'name']
#   Params: min_token_len=4, ngram_size=4, window=15, top_k=10
#   Reasoning: Exact blocking on artist+name was far too restrictive (PC=0.364). Semantic blocking previously on na...
#     Embedding (artist+name, k=10): 225,643 candidates
#     ✅ PC=0.9636, RR=0.9990
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: discogs <-> musicbrainz
# ============================================================
# Gold pairs: 78, PC threshold: 0.95
# Candidate limit: 350,000 (hard: 402,499 with tolerance)
#     Using ID column: 'id'
# Dataset sizes: 22,627 × 4,763 = 107,772,401 potential pairs
# Common columns: ['artist', 'tracks_track_name', 'release-date', 'tracks_track_duration', 'release-country', 'name', 'tracks_track_position', 'duration']
#
# --- Attempt 1/5 ---
# LLM chose: exact_match_multi on ['artist', 'name', 'release-date']
#   Params: min_token_len=4, ngram_size=4, window=15, top_k=10
#   Reasoning: N×M is ~108M with a strict 350k candidate cap, so we need a very selective blocker. Exact match on a...
#     Standard (artist+name+release-date): 575 candidates
#     ⚠️ PC=0.1538, RR=1.0000
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['artist', 'name', 'release-date']
#   Params: min_token_len=4, ngram_size=4, window=15, top_k=10
#   Reasoning: Exact multi-column blocking was far too restrictive (PC=0.154). Use embedding-based semantic similar...
#     Embedding (artist+name+release-date, k=10): 225,778 candidates
#     ⚠️ PC=0.9487, RR=0.9979
#
# --- Attempt 3/5 ---
# LLM chose: semantic_similarity on ['artist', 'name']
#   Params: min_token_len=4, ngram_size=4, window=15, top_k=10
#   Reasoning: Previous semantic_similarity on (artist,name,release-date) nearly met PC (0.949) with 225,778 candid...
#     Embedding (artist+name, k=10): 224,256 candidates
#     ✅ PC=0.9615, RR=0.9979
# ✅ Found acceptable strategy!
#
# ============================================================
# 🤖 BLOCKING: musicbrainz <-> lastfm
# ============================================================
# Gold pairs: 79, PC threshold: 0.95
# Candidate limit: 350,000 (hard: 402,499 with tolerance)
#     Using ID column: 'id'
# Dataset sizes: 4,763 × 9,865 = 46,986,995 potential pairs
# Common columns: ['artist', 'tracks_track_name', 'tracks_track_duration', 'name', 'tracks_track_position', 'duration']
#
# --- Attempt 1/5 ---
# LLM chose: semantic_similarity on ['name', 'artist']
#   Params: min_token_len=4, ngram_size=4, window=15, top_k=10
#   Reasoning: With ~47M potential pairs and a 350k candidate cap, exact match is likely too brittle due to formatt...
#     Embedding (name+artist, k=10): 47,508 candidates
#     ⚠️ PC=0.9367, RR=0.9990
#
# --- Attempt 2/5 ---
# LLM chose: semantic_similarity on ['name', 'artist']
#   Params: min_token_len=4, ngram_size=4, window=15, top_k=10
#   Reasoning: Prior semantic_similarity on ['name','artist'] missed the PC target (0.937). Other blocking options ...
#     Embedding (name+artist, k=10): 47,508 candidates
#     ⚠️ PC=0.9367, RR=0.9990
#
# --- Attempt 3/5 ---
# LLM chose: semantic_similarity on ['name', 'artist']
#   Params: min_token_len=4, ngram_size=4, window=15, top_k=10
#   Reasoning: Exact/token blocks risk missing true matches due to formatting differences (e.g., 'John B - Fermats ...
#     Embedding (name+artist, k=10): 47,508 candidates
#     ⚠️ PC=0.9367, RR=0.9990
#
# --- Attempt 4/5 ---
# LLM chose: token_blocking on ['name']
#   Params: min_token_len=3, ngram_size=4, window=15, top_k=20
#   Reasoning: Semantic similarity on (name, artist) plateaued at PC=0.937; switch to a less restrictive lexical bl...
#     Token (name, len>=3): 3,735,945 candidates
#     ⛔ SKIPPING EVALUATION: 3,735,945 > 402,499 (hard limit)
#     💡 Try increasing min_token_len or ngram_size, or use a more selective column
#
# --- Attempt 5/5 ---
# LLM chose: semantic_similarity on ['name', 'artist']
#   Params: min_token_len=4, ngram_size=4, window=15, top_k=10
#   Reasoning: Given the 46.9M possible pairs and 350k max candidates, semantic_similarity is the only reliable way...
#     Embedding (name+artist, k=10): 47,508 candidates
#     ⚠️ PC=0.9367, RR=0.9990
#
# ============================================================
# 📊 RESULTS SUMMARY: 3 pairs evaluated
# ============================================================
#   ✅ discogs_lastfm: PC=0.9636, candidates=225,643, strategy=semantic_similarity
#   ✅ discogs_musicbrainz: PC=0.9615, candidates=224,256, strategy=semantic_similarity
#   ⚠️ musicbrainz_lastfm: PC=0.9367, candidates=47,508, strategy=semantic_similarity
#
# 💾 Config saved to: output/blocking-evaluation/blocking_config.json
# [*] Blocking config computed:
# {
#   "blocking_strategies": {
#     "discogs_lastfm": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "artist",
#         "name"
#       ],
#       "params": {
#         "min_token_len": 4,
#         "ngram_size": 4,
#         "window": 15,
#         "top_k": 10
#       },
#       "pair_completeness": 0.9636363636363636,
#       "num_candidates": 225643
#     },
#     "discogs_musicbrainz": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "artist",
#         "name"
#       ],
#       "params": {
#         "min_token_len": 4,
#         "ngram_size": 4,
#         "window": 15,
#         "top_k": 10
#       },
#       "pair_completeness": 0.9615384615384616,
#       "num_candidates": 224256
#     }
#   },
#   "id_columns": {
#     "discogs": "id",
#     "lastfm": "id",
#     "musicbrainz": "id"
#   }
# }
# [*] Running MatchingTester
# [*] Loading dataset: discogs
# [*] Loading dataset: lastfm
# [*] Loading dataset: musicbrainz
# [*] Loading matching gold standard for discogs <-> lastfm
#     Loaded 100 ground truth pairs
# [*] Loading matching gold standard for discogs <-> musicbrainz
#     Loaded 100 ground truth pairs
# [*] Loading matching gold standard for musicbrainz <-> lastfm
#     Loaded 100 ground truth pairs
#
# ==================================================
# MATCHING EVALUATION
# ==================================================
#
# ==================================================
# MATCHING: discogs <-> lastfm
# ==================================================
#     Using ID column: 'id'
# Blocking columns: ['artist', 'name']
#
# --- Attempt 1/3 ---
# Comparators: ['artist', 'name', 'tracks_track_name', 'duration']
#     Reasoning: Use blocking fields artist and name as primary signals (artist robust to minor typos via jaro_winkler; name compared with token cosine due to extra prefixes like 'John B -'). Track list compared as a set with jaccard to capture overlap/ordering differences. Duration is noisy but helpful when present; allow small tolerance.
# F1=0.4058 < 0.75
#
# --- Attempt 2/3 ---
# Comparators: ['artist', 'name', 'tracks_track_name', 'duration']
#     Reasoning: Use blocking columns with stronger fuzzy matching (artist via jaro_winkler for short names; name via token/cosine for longer titles), add tracklist overlap via list-aware set_jaccard to compensate for title formatting differences, and keep duration as a weak numeric check due to frequent missingness and possible unit/format inconsistencies; lower threshold to recover recall given prior low scores.
# SUCCESS: F1=0.8247
#
# ==================================================
# MATCHING: discogs <-> musicbrainz
# ==================================================
#     Using ID column: 'id'
# Blocking columns: ['artist', 'name']
#
# --- Attempt 1/3 ---
# Comparators: ['artist', 'name', 'tracks_track_name', 'release-date', 'duration']
#     Reasoning: Use blocking keys artist+name as primary identifiers (artist robust to small typos; name token-based for multiword titles). Track list overlap is highly informative for releases, handled as set similarity. Release date provides secondary confirmation with tolerance for missing/approximate dates. Total duration adds a lightweight numeric check with small tolerance for rounding/editions; avoid noisy/high-null track_duration.
# SUCCESS: F1=0.8000
#
# ==================================================
# MATCHING: musicbrainz <-> lastfm
# ==================================================
#     Using ID column: 'id'
# Blocking columns: []
#     No blocking config found. Falling back to StandardBlocker on artist
#
# --- Attempt 1/3 ---
# Comparators: ['artist', 'name', 'tracks_track_name', 'duration']
#     Reasoning: Use artist and release name as strong text signals; compare track-name lists with set-based Jaccard to handle ordering/format differences and missing values; include total duration as a weak numeric check with a generous tolerance due to inconsistencies and higher nulls on track-level duration fields in lastfm.
# F1=0.6723 < 0.75
#
# --- Attempt 2/3 ---
# Comparators: ['artist', 'tracks_track_name', 'duration', 'name']
#     Reasoning: Prior combo underperformed; emphasize track-list overlap via set Jaccard for track names (more discriminative across sources), keep artist with typo-tolerant Jaro-Winkler, add numeric duration tolerance to handle differing totals/track-level sums, and downweight noisy freeform title 'name'. Lower threshold slightly to improve recall given missing/unequal list fields on lastfm.
# F1=0.5636 < 0.75
#
# --- Attempt 3/3 ---
# Comparators: ['artist', 'tracks_track_name', 'name', 'duration']
#     Reasoning: Use set-based Jaccard on track-name lists (most discriminative across releases), keep artist with typo-robust Jaro-Winkler, and cosine on full name for additional signal despite formatting differences; use a tolerant numeric duration comparator to account for tracklist/total-duration mismatches and noisy values. Lower threshold to improve recall given high nulls on list fields in lastfm and prior under-threshold scores.
# F1=0.6610 < 0.75
# Max attempts reached. Best F1=0.6723
#
# 📊 Results: 3 pairs evaluated
#   OK discogs_lastfm: F1=0.8247
#   OK discogs_musicbrainz: F1=0.8000
#   WARN musicbrainz_lastfm: F1=0.6723
# Config saved to matching_config.json
# [*] Matching config computed:
# {
#   "id_columns": {
#     "discogs": "id",
#     "lastfm": "id",
#     "musicbrainz": "id"
#   },
#   "matching_strategies": {
#     "discogs_lastfm": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "artist",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "tracks_track_name",
#           "similarity_function": "jaccard",
#           "preprocess": "lower_strip",
#           "list_strategy": "set_jaccard"
#         },
#         {
#           "type": "numeric",
#           "column": "duration",
#           "max_difference": 30.0
#         }
#       ],
#       "weights": [
#         0.3,
#         0.35,
#         0.25,
#         0.1
#       ],
#       "threshold": 0.6,
#       "f1": 0.8247422680412371
#     },
#     "discogs_musicbrainz": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "artist",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "tracks_track_name",
#           "similarity_function": "jaccard",
#           "preprocess": "lower_strip",
#           "list_strategy": "set_jaccard"
#         },
#         {
#           "type": "date",
#           "column": "release-date",
#           "max_days_difference": 365
#         },
#         {
#           "type": "numeric",
#           "column": "duration",
#           "max_difference": 60.0
#         }
#       ],
#       "weights": [
#         0.25,
#         0.3,
#         0.25,
#         0.1,
#         0.1
#       ],
#       "threshold": 0.78,
#       "f1": 0.8
#     },
#     "musicbrainz_lastfm": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "artist",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "name",
#           "similarity_function": "cosine",
#           "preprocess": "lower_strip"
#         },
#         {
#           "type": "string",
#           "column": "tracks_track_name",
#           "similarity_function": "jaccard",
#           "preprocess": "lower_strip",
#           "list_strategy": "set_jaccard"
#         },
#         {
#           "type": "numeric",
#           "column": "duration",
#           "max_difference": 300.0
#         }
#       ],
#       "weights": [
#         0.25,
#         0.35,
#         0.3,
#         0.1
#       ],
#       "threshold": 0.72,
#       "f1": 0.6722689075630253
#     }
#   }
# }
# [*] Creating initial pipeline
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Running cluster analysis
# [*] Analyzing clusters from output/correspondences/correspondences_musicbrainz_lastfm.csv
#     Total clusters: 2270
#     Max cluster size: 4
#     Cluster Distribution:
#    cluster_size  frequency  percentage
# 0             2       2263   99.691630
# 1             3          6    0.264317
# 2             4          1    0.044053
#     Analysis for correspondences_musicbrainz_lastfm.csv: The distribution is extremely concentrated at cluster size 2 (~99.7%), with only 7 clusters larger than 2 and a maximum size of 4. There are no singletons reported, and there is no long tail into larger cluster sizes. This pattern suggests the matcher is effectively producing almost exclusively one-to-one pairings (deduping into pairs) and may be systematically preventing legitimate multi-record entities from forming (under-clustering), or the pipeline may be generating only pairwise outputs rather than true connected components. The absence of size-1 clusters is also unusual and may indicate the input was pre-filtered to only records that had at least one match, or that unmatched records are being dropped from clustering stats.
# [*] Analyzing clusters from output/correspondences/correspondences_discogs_lastfm.csv
#     Total clusters: 979
#     Max cluster size: 11
#     Cluster Distribution:
#    cluster_size  frequency  percentage
# 0             2        868   88.661900
# 1             3         73    7.456588
# 2             4         17    1.736466
# 3             5          9    0.919305
# 4             6          4    0.408580
# 5             7          7    0.715015
# 6            11          1    0.102145
#     Analysis for correspondences_discogs_lastfm.csv: The distribution is heavily concentrated in very small clusters: ~88.7% of clusters are size 2 and ~96.1% are size 2–3. There are no singletons reported (size 1), which suggests either they were excluded from the stats or the pipeline only outputs matched entities. Large clusters are extremely rare (only one cluster of size 11; nothing above that), so there is no sign of giant-cluster over-matching or runaway transitive closure. Overall this looks precise and conservative; however, compared to a typical “healthy long tail” expectation (with more spread into sizes 3–10), the extreme dominance of size-2 clusters can also indicate slight under-matching (splitting true multi-record entities into multiple pairs) or an overly pair-oriented rule set.
# [*] Analyzing clusters from output/correspondences/correspondences_discogs_musicbrainz.csv
#     Total clusters: 1603
#     Max cluster size: 7
#     Cluster Distribution:
#    cluster_size  frequency  percentage
# 0             2       1430   89.207735
# 1             3        132    8.234560
# 2             4         27    1.684342
# 3             5          9    0.561447
# 4             6          3    0.187149
# 5             7          2    0.124766
#     Analysis for correspondences_discogs_musicbrainz.csv: The distribution is extremely concentrated in very small clusters: ~89% of clusters are size 2 and another ~8% are size 3, with no singletons reported and a maximum cluster size of only 7. The absence of large clusters suggests there is no obvious over-matching or transitive-closure runaway. However, the shape is not a healthy long tail (it drops off too sharply) and the overwhelming dominance of size-2 clusters often indicates the matcher is effectively pairing records but not linking additional related records into the same entity. This pattern can reflect under-matching for multi-record entities (threshold too strict beyond the strongest pair), or blocking/candidate generation that prevents discovering additional matches.
#     Aggregated cluster analysis report saved to output/cluster-evaluation/cluster_analysis_report.json
# [*] Adapting evaluation code
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.16751269035532995, "macro_accuracy": 0.1636473429951691, "num_evaluated_records": 23, "num_evaluated_attributes": 9, "total_evaluations": 197, "total_correct": 33, "tracks_track_position_accuracy": 0.0, "tracks_track_position_count": 23, "tracks_track_duration_accuracy": 0.0, "tracks_track_duration_count": 20, "release-date_accuracy": 0.34782608695652173, "release-date_count": 23, "release-country_accuracy": 0.34782608695652173, "release-country_count": 23, "artist_accuracy": 0.34782608695652173, "artist_count": 23, "name_accuracy": 0.17391304347826086, "name_count": 23, "label_accuracy": 0.125, "label_count": 16, "tracks_track_name_accuracy": 0.0, "tracks_track_name_count": 23, "duration_accuracy": 0.13043478260869565, "duration_count": 23}
# [*] Overall Accuracy: 16.751%
# [*] Evaluation reasoning:
# ## 1) Dominant error types
#
# ### A. Fusion/content errors (most visible in debug)
# - **Systematic “missing_fused_value”** for many records across:
#   - `tracks_track_position`, `tracks_track_duration`, and also `release-date`.
#   - This is effectively **false negatives at the entity level** (the record that should exist in fused output isn’t there / wasn’t clustered), not just a wrong attribute choice.
# - **List/collection fusion mismatches** even when `fused_id == expected_id`:
#   - `tracks_track_position` and `tracks_track_duration` show fused values like `"['1','10','2',...]"` and extra/missing elements compared to expected.
#   - Causes: **wrong data type/serialization** (stringified list), **ordering**, and **deduplication** (set-like union loses duplicates; expected contains duplicates like `"2","2"`).
#
# ### B. Under-clustering / linkage coverage issues (from cluster report + missing_fused_value)
# - Cluster distributions are ~89–99% size-2, almost no larger clusters, **no singletons reported**.
# - Combined with `include_singletons=False`, you are explicitly dropping any entity that doesn’t match anything, which will inflate “missing” during evaluation if the gold expects those entities present.
# - Pattern indicates **conservative linkage and/or pairwise-only linking** (no robust connected-components/transitive closure), leading to many expected entities not appearing in fused output.
#
# ### C. “Exact match” evaluation vs representation mismatch (causing 0% on track fields)
# - Track attributes are evaluated with `exact_match`. Your fused track fields appear as **string representations** of Python lists (e.g., `"['1','2']"`), while expected is a JSON list `["1","2"]`.
# - Even when logically equal, this will always be scored as mismatch → explains **0.0 accuracy** for `tracks_track_position`, `tracks_track_duration`, `tracks_track_name`.
#
# ## 2) Likely root causes (what’s driving the errors)
#
# ### Blocking: likely too restrictive for discogs pairs
# - Optimal blocking says **semantic_similarity on (artist,name), top_k=10** with pair completeness ~0.96.
# - Current pipeline uses **StandardBlocker on exact keys** for discogs–lastfm and discogs–musicbrainz. If StandardBlocker is equality-based (typical), that will miss most fuzzy variations (“Beyoncé” vs “Beyonce”, punctuation, feat., etc.).
# - This strongly contributes to **missed blocks → false negatives → missing_fused_value**.
#
# ### Matching thresholds/comparators: probably not the main problem (but a secondary factor)
# - You are already using the provided “optimal” weights/thresholds and comparators largely match the config.
# - However, you deviated from the optimal config in one important detail:
#   - Optimal config for discogs–musicbrainz specifies `list_strategy: concatenate` for `artist` and `name` (suggesting those fields can be lists in one dataset).
#   - Your code does not set `list_strategy` for `artist`/`name` in discogs–musicbrainz, so list-valued cells may be stringified and compared poorly → **missed matches**.
#
# ### Schema/preprocessing issues: major contributor (track fields + dates)
# - Track fields are being fused as **strings**, not as structured lists.
# - `union` is set-like; expected contains duplicates and ordering, so even with correct typing it may not match gold.
# - `release-date` is fused with `longest_string`, which is a poor choice for dates (can pick verbose/dirty strings). But most date errors shown are *missing_fused_value*, again pointing upstream to linkage/coverage rather than wrong choice among inputs.
#
# ### Pipeline logic: includes an explicit drop mechanism
# - `include_singletons=False` guarantees missing entities in fused output for any record without a match.
# - Cluster analysis notes “no singletons”; your fusion setting reinforces that, causing many evaluation misses.
#
# ## 3) Concrete, actionable improvements for next iteration
#
# ### Highest impact fixes (do these first)
# 1. **Stop dropping singletons during evaluation**
#    - Set `include_singletons=True` in `engine.run(...)`.
#    - This alone will reduce `missing_fused_value` massively for attributes like `release-date` where the record exists but had no linked partner.
#
# 2. **Use the optimal semantic blocker for discogs pairs (despite >20k)**
#    - The rule “use StandardBlocker when >20k” is hurting recall here; it’s producing missed blocks.
#    - Action options:
#      - Use `EmbeddingBlocker` / semantic blocker anyway but tune for scale: lower `top_k`, increase batch_size, use a faster index backend (faiss if available), or do two-stage blocking (cheap broad then semantic rerank).
#      - Or add **multiple blocking keys** with StandardBlocker (see #3) to approximate semantic recall.
#
# 3. **If you must keep StandardBlocker, make it recall-oriented**
#    - Block on normalized keys, not raw `artist,name`:
#      - Add preprocessing columns: `artist_norm`, `name_norm` (lowercase, remove punctuation, remove “feat.” parts, strip diacritics).
#      - Block on weaker keys: e.g., `(artist_norm_prefix3, name_norm_prefix5)` or token-based keys.
#    - Add **secondary blocking passes** (OR-union of candidate sets): artist-only, name-only, and artist+year (if available). Missed blocks are your dominant FN driver.
#
# ### Fix the track-field fusion/evaluation mismatch (explains the 0% accuracies)
# 4. **Ensure track columns are real lists, not stringified lists**
#    - Before fusion, parse/normalize:
#      - If values look like `"['1','2']"` parse them to Python lists.
#      - Ensure consistent element typing (strings vs ints).
#    - Then `union` will operate on actual lists.
#
# 5. **Replace `union` with a track-aware fuser**
#    - Gold expects duplicates and ordering (e.g., repeated positions), while `union` removes duplicates and often reorders.
#    - Implement fusers that:
#      - Preserve order by `tracks_track_position`
#      - Align `track_name` and `track_duration` by position
#      - Keep duplicates when they represent multi-disc or repeated indices
#
# ### Matching/config correctness
# 6. **Match the “optimal” list handling for discogs–musicbrainz**
#    - Add `list_strategy="concatenate"` for `artist` and `name` comparators where the config requires it.
#    - This should improve similarity scoring when one side is list-valued.
#
# 7. **Validate clustering/transitive closure**
#    - The size-2 dominance suggests you may be treating correspondences as isolated pairs.
#    - Ensure the fusion engine (or a prior step) builds entities via connected components across all pairwise correspondences (A–B and B–C implies A–C in same entity).
#
# ### Smaller improvements
# 8. **Use date/duration-specific fusers**
#    - For `release-date`: parse to date and use “most frequent” or “earliest non-null” instead of `longest_string`.
#    - For `duration`: numeric median/majority, not longest string.
#
# ---
#
# ### Summary diagnosis
# - The dominant failures are **false negatives from missed blocks/under-linkage plus pipeline dropping singletons**, and **systematic type/representation errors on track list fields** that force 0% accuracy.
# - Fixing `include_singletons`, improving discogs blocking recall (semantic or multi-pass), and normalizing/fusing track lists structurally should produce the biggest step-change in the next run.
# [*] Improving pipeline based on evaluation
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Running cluster analysis
# [*] Analyzing clusters from output/correspondences/correspondences_musicbrainz_lastfm.csv
#     Total clusters: 2270
#     Max cluster size: 4
#     Cluster Distribution:
#    cluster_size  frequency  percentage
# 0             2       2263   99.691630
# 1             3          6    0.264317
# 2             4          1    0.044053
#     Analysis for correspondences_musicbrainz_lastfm.csv: The distribution is extremely concentrated at size 2 (99.69%), with virtually no singletons reported and no clusters larger than 4. The absence of size-1 clusters is unusual in most real entity-resolution problems and suggests the output may be constrained to only emit matched pairs (or that singletons were filtered out), rather than representing full entity clusters. If this is truly the full clustering result, it indicates strong under-clustering/fragmentation: records that should form larger groups (same entity appearing in 3+ sources/rows) are mostly split into separate pairs, implying missed transitive links or overly conservative matching that prevents multi-record clusters from forming.
# [*] Analyzing clusters from output/correspondences/correspondences_discogs_lastfm.csv
#     Total clusters: 2414
#     Max cluster size: 16
#     Cluster Distribution:
#     cluster_size  frequency  percentage
# 0              2       2060   85.335543
# 1              3        194    8.036454
# 2              4         88    3.645402
# 3              5         23    0.952775
# 4              6         11    0.455675
# 5              7         15    0.621375
# 6              8          8    0.331400
# 7              9          5    0.207125
# 8             10          3    0.124275
# 9             11          2    0.082850
# 10            13          2    0.082850
# 11            14          1    0.041425
# 12            15          1    0.041425
# 13            16          1    0.041425
#     Analysis for correspondences_discogs_lastfm.csv: The distribution is heavily concentrated at cluster size 2 (85.3%), with a steep drop-off for sizes 3+ and very few clusters above size 10 (0.41% total). There are no giant clusters (max size 16), so there is no strong sign of runaway transitive closure or severe over-matching. However, the extremely high proportion of size-2 clusters compared to a typical long-tail profile suggests the matcher may be too conservative and mostly only links near-duplicates, potentially under-matching true multi-record entities that should form size 3+ clusters. Overall: low risk of over-matching, moderate risk of under-matching/over-fragmentation into pairs.
# [*] Analyzing clusters from output/correspondences/correspondences_discogs_musicbrainz.csv
#     Total clusters: 2437
#     Max cluster size: 7
#     Cluster Distribution:
#    cluster_size  frequency  percentage
# 0             2       2192   89.946656
# 1             3        192    7.878539
# 2             4         36    1.477226
# 3             5         12    0.492409
# 4             6          3    0.123102
# 5             7          2    0.082068
#     Analysis for correspondences_discogs_musicbrainz.csv: The distribution is extremely concentrated at cluster size 2 (≈89.95%), with a small remainder in sizes 3–7 and no singletons reported. There are no giant clusters (max size 7), so there is little evidence of runaway over-matching or transitive-closure blowups. However, the near-all-pairs pattern is atypical for a healthy long tail (where size-2 clusters are closer to ~42%). This suggests the matcher is effectively forming mostly 1:1 pairings and rarely linking more than two records together—often a sign of under-matching (missing legitimate links) or a pipeline/output issue where only pairwise links are being emitted as separate size-2 clusters rather than being merged into larger connected components. The absence of size-1 clusters also suggests you may be filtering to only matched records, which can mask true coverage/recall issues.
#     Aggregated cluster analysis report saved to output/cluster-evaluation/cluster_analysis_report.json
# [*] Adapting evaluation code
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.2639593908629442, "macro_accuracy": 0.2617753623188406, "num_evaluated_records": 23, "num_evaluated_attributes": 9, "total_evaluations": 197, "total_correct": 52, "label_accuracy": 0.3125, "label_count": 16, "artist_accuracy": 0.4782608695652174, "artist_count": 23, "duration_accuracy": 0.30434782608695654, "duration_count": 23, "tracks_track_duration_accuracy": 0.0, "tracks_track_duration_count": 20, "tracks_track_name_accuracy": 0.0, "tracks_track_name_count": 23, "release-country_accuracy": 0.43478260869565216, "release-country_count": 23, "name_accuracy": 0.391304347826087, "name_count": 23, "tracks_track_position_accuracy": 0.0, "tracks_track_position_count": 23, "release-date_accuracy": 0.43478260869565216, "release-date_count": 23}
# [*] Overall Accuracy: 26.396%
# [*] Evaluation reasoning:
# ## 1) Dominant error types
#
# ### A. **False negatives / coverage failures (dominant)**
# Evidence:
# - Fusion debug events are overwhelmingly `reason: "missing_fused_value"` for core scalar attributes (`label`, `artist`, `duration`) across many `expected_id`s.
# - Some events even show `fused_id: NaN`, which strongly suggests those expected entities never appeared in the fused output (not just “attribute missing”).
#
# Interpretation: many gold entities are **not being produced as fused entities**, or are produced without pulling any contributing record values.
#
# ### B. **Fusion/representation mismatches for track-level lists (dominant for track fields)**
# Evidence:
# - `tracks_track_*_accuracy` is **0.0** for name/position/duration.
# - Debug shows fused values like `"['197', '200', ...]"` (a *stringified list*) vs expected being a JSON list, and also order/content mismatches.
# - Some are missing entirely (`missing_fused_value`) for track durations.
#
# Interpretation: even when the entity exists, track attributes are being fused in a format/order that will **never satisfy `exact_match`**.
#
# ### C. **Bad value selection / unit issues on duration (secondary)**
# Evidence:
# - Several `duration` mismatches are non-trivial (e.g., fused `1880.0` vs expected `3100`; fused `2546.0` vs expected `2733`), not just small tolerance misses.
# Interpretation: either (i) wrong record got fused into that entity (match/clustering error), or (ii) duration normalization/unit inconsistency (seconds vs ms) or “longest_string” is a poor fuser for numeric.
#
# ### D. **False positives**
# Not strongly indicated in provided fusion debug (which is mismatch-focused and mostly missing values). Cluster report also shows **no giant clusters**, so runaway overmatching is unlikely. False positives may exist, but they’re not the dominant failure mode here.
#
# ---
#
# ## 2) Most likely root causes (by component)
#
# ### 2.1 Blocking: **not the main culprit**, but verify implementation vs “optimal”
# - Your “optimal blocking” describes a **token/ngram semantic_similarity** approach with params (`min_token_len`, `ngram_size`, `window`, `top_k`).
# - Your pipeline uses `EmbeddingBlocker` with a transformer model. That may be fine conceptually, but it is **not the same method/params** as the tuned “semantic_similarity” config that achieved high pair completeness.
# - However: pair completeness in the optimal config is already very high (~0.96), and your dominant failures look more like **IDs not making it into fused output** than “a few missed candidate pairs”.
#
# Net: blocking could contribute to under-linking, but the *pattern (NaN fused_id / missing fused records)* points more to **fusion/correspondence/id handling**.
#
# ### 2.2 Matching thresholds/comparators: **likely too conservative / fragmented clusters**
# Evidence:
# - Cluster analysis: ~85–99% clusters of size 2, almost no 3+ clusters, and **no singletons reported** in correspondences-based cluster stats.
# Interpretation:
# - Either (a) the matcher outputs mostly isolated pairs (under-matching), **and/or**
# - (b) your clustering stats are computed only from “matched edges” (so size-1 clusters are inherently absent), masking coverage.
#
# This aligns with many gold entities not being connected across sources → they may still appear as singletons in fusion *if* `include_singletons=True` works as intended. But debug suggests they still don’t appear (fused_id NaN), so something else is also wrong.
#
# ### 2.3 Schema / preprocessing: **major contributor for track fields; possible contributor for duration**
# - Track fields: still ending up as strings in fused output in multiple cases; order issues also kill exact-match.
# - Duration: you normalize to numeric-ish strings, but then fuse with `longest_string` which can pick the wrong numeric representation; plus potential seconds/ms inconsistencies remain unhandled.
#
# ### 2.4 Pipeline logic: **very likely contributing to the “missing fused entity” problem**
# Two red flags:
# 1) **`fused_id: NaN` in evaluation debug**
#    That typically happens when the fused dataset does not contain a row for the expected entity (not just missing an attribute).
# 2) **Fusion `id_column="id"` across all datasets after LLM-based renaming**
#    If schema matching/renaming accidentally renames or drops the `id` column in one dataset (or creates duplicate `id` columns / mismapped IDs), fusion can fail to carry records correctly, producing missing entities or empty inputs → `inputs: []` in debug.
#
# Also, you create EmbeddingBlockers with `id_column=id_discogs` even when left dataset is musicbrainz in one blocker; if PyDI expects the left id column to match `df_left`, passing the wrong `id_column` can corrupt candidate IDs and downstream correspondences.
#
# ---
#
# ## 3) Concrete, actionable improvements (next iteration)
#
# ### A) Fix “missing fused entity” / ID integrity (highest priority)
# 1) **Hard-assert ID columns after schema matching**
#    - After renaming, check that each df has exactly one `id` column, non-null, unique enough, and unchanged row count.
#    - Example checks:
#      - `assert "id" in df.columns`
#      - `assert df["id"].notna().all()`
#      - `assert df["id"].astype(str).str.len().gt(0).all()`
# 2) **Ensure blockers/matchers use the correct `id_column` for the *left* dataframe**
#    - `blocker_discogs_lastfm`: id_column should be discogs id (ok)
#    - `blocker_discogs_musicbrainz`: id_column should be discogs id (ok)
#    - **`blocker_musicbrainz_lastfm`: id_column should be musicbrainz id** (you did that—good).
#    But also verify RuleBasedMatcher’s `id_column` matches `df_left` for each call (you did). If PyDI also needs right-id, ensure correspondences output contains both IDs correctly.
# 3) **Validate correspondences output schema**
#    - Confirm the CSV has columns that fusion expects (e.g., left_id/right_id + source names). If fusion can’t interpret edges, it will produce empty inputs.
#
# ### B) Make track-list fusion match evaluation expectations (stop 0% exact-match)
# 1) **Stop using set-union for ordered track lists**
#    - `union` is set-like: it destroys order and can drop duplicates; `exact_match` will fail.
#    - Use an order-preserving fuser (e.g., “take from most complete source”, or “choose longest list”, or “align by track_position” and then build a list).
# 2) **Normalize list element types consistently**
#    - Ensure track durations are strings (or ints) consistently and never serialized back to a single string representation.
#    - Add a post-fusion step to guarantee lists are actual lists (not `"['a','b']"`).
# 3) **Fuse tracks by position**
#    - Best: build a structured track table keyed by `(release_id, track_position)` and fuse per-track, then re-aggregate.
#
# ### C) Fix duration fusion (reduce wrong numeric picks)
# 1) Replace `longest_string` for numeric attributes with a numeric-aware fuser:
#    - e.g., median/mean, or “most frequent”, or “prefer musicbrainz over others”.
# 2) Add unit harmonization:
#    - Detect ms vs seconds (common music data issue). Heuristic: if duration > 10,000 treat as ms and divide by 1000.
#
# ### D) Matching/blocking adjustments (to reduce fragmentation without blowing up FP)
# 1) **Align blocking implementation with the tuned “semantic_similarity”** if possible in PyDI
#    - If PyDI has a blocker matching those params (min_token_len/ngram/window), use it; otherwise increase `top_k` (e.g., 20–50) to regain recall.
# 2) Slightly relax thresholds where cluster report shows extreme pairing
#    - Especially for musicbrainz_lastfm (F1 lower): small threshold reduction (e.g., 0.72 → 0.68) *paired with* a stronger comparator (see next).
# 3) Add a high-signal comparator to safely connect more true matches
#    - For releases: incorporate `release-date` (already in discogs_musicbrainz) and `release-country` where available.
#    - Consider label similarity as an additional weak feature (low weight) once you fix label coverage.
#
# ### E) Evaluation-driven debugging (fast feedback loop)
# 1) For each `missing_fused_value`, log whether:
#    - the expected ID exists in any input dataset after schema matching,
#    - it appears in any correspondence edge,
#    - it appears in fused output (row count and id coverage check).
# 2) Compute “singleton coverage”: how many input records become fused rows when `include_singletons=True`. If far below total inputs, fusion ingestion/ID logic is broken.
#
# ---
#
# ### Bottom line
# - The dominant failures are **false negatives/coverage** (entities not appearing in fused output or having zero contributing inputs) and **systematic track-list fusion mismatches** (order/format).
# - Errors are more likely caused by **pipeline logic + preprocessing/fusion design** than by pure threshold tuning.
# - Next iteration should prioritize: **ID integrity checks + correspondence schema validation + ordered track fusion + numeric-aware duration fusion**, then only afterwards fine-tune blocking/top_k and thresholds to reduce fragmentation.
# [*] Improving pipeline based on evaluation
# [*] Running generated pipeline
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Pipeline successfully completed
# [*] Running cluster analysis
# [*] Analyzing clusters from output/correspondences/correspondences_musicbrainz_lastfm.csv
#     Total clusters: 2501
#     Max cluster size: 4
#     Cluster Distribution:
#    cluster_size  frequency  percentage
# 0             2       2492   99.640144
# 1             3          8    0.319872
# 2             4          1    0.039984
#     Analysis for correspondences_musicbrainz_lastfm.csv: The distribution is extremely concentrated at cluster size 2 (99.64%), with no singletons and no clusters larger than 4. This does not resemble a healthy long tail and strongly suggests an overly restrictive or pairwise-only matching behavior: the system is effectively producing almost exclusively 1:1 matches and rarely allowing multi-record clusters. This pattern is consistent with under-matching (failing to link additional true duplicates) and/or a clustering step that is preventing transitive closure or collapsing matches into only pairs.
# [*] Analyzing clusters from output/correspondences/correspondences_discogs_lastfm.csv
#     Total clusters: 2414
#     Max cluster size: 16
#     Cluster Distribution:
#     cluster_size  frequency  percentage
# 0              2       2060   85.335543
# 1              3        194    8.036454
# 2              4         88    3.645402
# 3              5         23    0.952775
# 4              6         11    0.455675
# 5              7         15    0.621375
# 6              8          8    0.331400
# 7              9          5    0.207125
# 8             10          3    0.124275
# 9             11          2    0.082850
# 10            13          2    0.082850
# 11            14          1    0.041425
# 12            15          1    0.041425
# 13            16          1    0.041425
#     Analysis for correspondences_discogs_lastfm.csv: The distribution is extremely concentrated at cluster size 2 (85.3%), with a small long tail up to size 16 and very few clusters of size 10+ (~0.41%). There are no giant clusters, so there is no obvious sign of runaway transitive closure or severe over-matching. However, the dominance of pairs far exceeds the typical healthy pattern (~42% at size 2) and suggests the matcher is mostly forming simple one-to-one links while failing to merge additional related records into larger groups. This points to likely under-clustering/under-matching across more than two records (e.g., duplicates not being connected due to thresholds, missing blocking recall, or overly strict comparators), even though the matches it does make may be precise.
# [*] Analyzing clusters from output/correspondences/correspondences_discogs_musicbrainz.csv
#     Total clusters: 2437
#     Max cluster size: 7
#     Cluster Distribution:
#    cluster_size  frequency  percentage
# 0             2       2192   89.946656
# 1             3        192    7.878539
# 2             4         36    1.477226
# 3             5         12    0.492409
# 4             6          3    0.123102
# 5             7          2    0.082068
#     Analysis for correspondences_discogs_musicbrainz.csv: The distribution is extremely concentrated in very small clusters: ~90% of clusters are size 2 and the maximum cluster size is only 7. There are no size-1 clusters reported, which suggests the stats may be filtered to only matched/linked entities or singletons were excluded. Assuming this is the full post-clustering output, it indicates under-matching and/or overly conservative linkage that mostly forms isolated pairs rather than recovering larger real-world entity groups. The absence of any long tail beyond size 3–4 and the very low proportion of 5+ clusters (~0.7%) suggests limited transitive merging and likely missed links between records that should connect these pairs into larger clusters.
#     Aggregated cluster analysis report saved to output/cluster-evaluation/cluster_analysis_report.json
# [*] Adapting evaluation code
# [*] Running generated evaluation
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.36548223350253806, "macro_accuracy": 0.36262077294685985, "num_evaluated_records": 23, "num_evaluated_attributes": 9, "total_evaluations": 197, "total_correct": 72, "artist_accuracy": 0.6086956521739131, "artist_count": 23, "tracks_track_duration_accuracy": 0.0, "tracks_track_duration_count": 20, "release-country_accuracy": 0.6086956521739131, "release-country_count": 23, "duration_accuracy": 0.4782608695652174, "duration_count": 23, "release-date_accuracy": 0.5652173913043478, "release-date_count": 23, "tracks_track_name_accuracy": 0.0, "tracks_track_name_count": 23, "label_accuracy": 0.4375, "label_count": 16, "name_accuracy": 0.5652173913043478, "name_count": 23, "tracks_track_position_accuracy": 0.0, "tracks_track_position_count": 23}
# [*] Overall Accuracy: 36.548%
