# %%
import os
import json 
import getpass
import logging
from pathlib import Path
from time import sleep
import subprocess
import sys

from langgraph.graph import StateGraph, END
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage, AIMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI
from langchain.callbacks import get_openai_callback
from langchain.tools import BaseTool

from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
import traceback

from typing import TypedDict, Dict, List

from PyDI.io import load_xml, load_parquet, load_csv
from PyDI.utils import DataProfiler
from blocking_tester import BlockingTester
from matching_tester import MatchingTester
from schema_matching_node import run_schema_matching

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialize

# %%
OUTPUT_DIR = "output/"
INPUT_DIR = "input/"

INCLUDE_DOCS = False # IMPORTANT: Use carefully since token usage is increased drastically with documentation
USE_LLM = "gpt"
#USE_LLM = "gemini"
#USE_LLM = "groq"

# %%
if USE_LLM == "gemini": # or USE_LLM == "gemini_broken":
    if "GOOGLE_API_KEY" not in os.environ:
        os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")
elif USE_LLM == "groq":
    if "GROQ_API_KEY" not in os.environ:
        os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")
elif USE_LLM == "gpt":
    if "OPENAI_API_KEY" not in os.environ:
        os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

# %%
logging.basicConfig(filename= OUTPUT_DIR + 'agent.log',
                    filemode='a',
                    format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.DEBUG,
                    encoding='utf-8')

# %% [markdown]
# ## Utilities

# %%
def load_dataset(path):
    # check file exists
    if not os.path.exists(path):
        raise FileNotFoundError(f"Dataset not found at: {path}")
    ext = os.path.splitext(path)[1].lower()

    # load dataset according to extension
    if ext == ".parquet":
        df = load_parquet(path)
    elif ext == ".csv":
        df = load_csv(path)
    elif ext == ".xml":
        df = load_xml(path, nested_handling="aggregate")
    else:
        raise ValueError(f"Unsupported format: {ext}. Supported: .csv, .parquet, .xml")
    return df

# %% [markdown]
# ## Tools

# %%
class ProfileDatasetTool(BaseTool):
    name: str = "profile_dataset"
    description: str = """
        A tool that takes the path as a argument called `path` of type str of the dataset file as string and performs data analysis. 
        A JSON string is returned with the profile data.
    """
    
    def _run(self, path) -> str:   
        return self.create_profile(path)

    def create_profile(self, path):

        if not path or not isinstance(path, str):
                raise ValueError("ProfileDatasetTool requires a single path string argument.")

        df = load_dataset(path)    
        
        if df is None or getattr(df, "empty", False):
            # return a structured JSON error string (LLM will see this as content)
            return json.dumps({"error": f"Dataset at {path} loaded as empty or failed to load."})

        profiler = DataProfiler()
        profile = profiler.summary(df, print_summary=False)

        # ensure to return a JSON string (your docstring promised JSON string)
        try:
            profile_json = json.dumps(profile, default=str)
        except Exception:
            # fallback: convert to str if not json-serializable
            profile_json = json.dumps({"profile_str": str(profile)})

        return profile_json

# %%
class SearchDocumentationTool(BaseTool):
    """
    A tool to search the PyDI documentation vector database.
    """
    name: str = "search_documentation"
    description: str = (
        "Searches the PyDI library documentation for a given query. "
        "Use this to find information about functions, classes, or how-to instructions. "
        "The input should be a specific question about the library."
    )
    call_count: int = 0

    def _run(self, query: str) -> str:
        """Executes the documentation search."""
        self.call_count += 1
        print(f"[SEARCH TOOL CALL {self.call_count}]: Asking '{query}'")
        
        embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
        vector_db_path = os.path.join(INPUT_DIR, "api_documentation/pydi_apidocs_vector_db/")

        if not os.path.exists(vector_db_path):
            return f"Error: Vector DB not found at {vector_db_path}"
        try:
            db = Chroma(persist_directory=vector_db_path, embedding_function=embeddings)
            docs = db.similarity_search(query, k=4)
            
            if not docs:
                return "No relevant documentation found for your query."

            return "\n\n-----\n\n".join([r.page_content for r in docs])
        except Exception as e:
            return f"An error occurred while searching documentation: {str(e)}\n{traceback.format_exc()}"

    def reset(self):
        """Resets the call count for a new agent run."""
        self.call_count = 0

# %% [markdown]
# ## Agents

# %%
class SimpleModelAgentState(TypedDict):
    datasets: list
    entity_matching_testsets: list
    fusion_testset: str
    blocking_config: Dict  # NEW: Blocking config from BlockingTester
    matching_config: Dict  # NEW: Matching config from MatchingTester
    matcher_mode: str  # NEW: Matcher mode (rule_based/ml/auto)
    schema_correspondences: Dict  # NEW: Schema matching results
    
    data_profiles: Dict

    messages: List[AnyMessage] # Save conversation history during research
    
    integration_pipeline_code: str
    pipeline_execution_result: str
    pipeline_execution_attempts: int

    evaluation_code: str
    evaluation_execution_result: str
    evaluation_execution_attempts: int

    evaluation_attempts: int
    evaluation_metrics: Dict
    evaluation_analysis: str

class SimpleModelAgent:
    
    def __init__(self, model, tools: Dict[str, BaseTool]):
        # initialize logger
        self.logger = logging.getLogger()
        # self.base_model = model
        self.token_usage = {"prompt_tokens": 0, "completion_tokens": 0, "total_tokens": 0, "total_cost": 0.0}
        self.tools = tools
        self.base_model = model.bind_tools(list(self.tools.values()))
        
        # prepare the StateGraph
        graph = StateGraph(SimpleModelAgentState)

        # create nodes
        graph.add_node("match_schemas", self.match_schemas)
        graph.add_node("profile_data", self.profile_data)
        graph.add_node("run_blocking_tester", self.run_blocking_tester)
        graph.add_node("run_matching_tester", self.run_matching_tester)
        graph.add_node("pipeline_adaption", self.pipeline_adaption)
        graph.add_node("execute_pipeline", self.execute_pipeline)
        graph.add_node("evaluation_adaption", self.evaluation_adaption)
        graph.add_node("execute_evaluation", self.execute_evaluation)
        graph.add_node("evaluation_decision", self.evaluation_decision)
        graph.add_node("evaluation_reasoning", self.evaluation_reasoning)

        # create edges
        graph.add_edge("match_schemas", "profile_data")
        graph.add_edge("profile_data", "run_blocking_tester")
        graph.add_edge("run_blocking_tester", "run_matching_tester")
        graph.add_edge("run_matching_tester", "pipeline_adaption")

        graph.add_conditional_edges(
            "pipeline_adaption",
            self.should_continue_research,
            {
                "continue": "pipeline_adaption",
                "end": "execute_pipeline"
            }
        )
        
        graph.add_conditional_edges(
            "execute_pipeline",
            lambda state: (
                "evaluation_adaption"
                if isinstance(state.get("pipeline_execution_result", ""), str)
                   and state["pipeline_execution_result"].lower().startswith("success")
                else "pipeline_adaption"
                if state.get("pipeline_execution_attempts", 0) < 3
                else END
            ),
            {
                "pipeline_adaption": "pipeline_adaption",
                "evaluation_adaption": "evaluation_adaption",
                END: END
            }
        )

        graph.add_edge("evaluation_adaption", "execute_evaluation")

        graph.add_conditional_edges(
            "execute_evaluation",
            lambda state: (
                "evaluation_decision" 
                if isinstance(state.get("evaluation_execution_result", ""), str)
                   and state["evaluation_execution_result"].lower().startswith("success")
                else "evaluation_adaption"
                if state.get("evaluation_attempts", 0) < 3
                else END
            ),
            {
                "evaluation_adaption": "evaluation_adaption",
                "evaluation_decision": "evaluation_decision",
                END: END
            }
        )


        graph.add_conditional_edges(
            "evaluation_decision",
            lambda state: (
                "evaluation_reasoning"
                if state.get("evaluation_metrics", {}).get("overall_accuracy", 0) < 0.85
                   and state.get("evaluation_attempts", 0) < 3
                else END
            ),
            {
                "evaluation_reasoning": "evaluation_reasoning",
                END: END
            }
        )

        graph.add_edge("evaluation_reasoning", "pipeline_adaption")

        graph.set_entry_point("match_schemas")
        self.graph = graph.compile()

        # make tools available to the model based on model type
        # self.tools = {profileTool.name: profileTool}
#        if USE_LLM == "groq" or USE_LLM == "gpt" or USE_LLM == "gemini":
        # self.model = model.bind_tools([profileTool])
#        elif USE_LLM == "gemini_broken":
#            self.model = model.bind_tools(profileTool)
        

    def _invoke_with_usage(self, message, tag):
        with get_openai_callback() as cb:
            result = self.base_model.invoke(message)
        self.token_usage["prompt_tokens"] += cb.prompt_tokens
        self.token_usage["completion_tokens"] += cb.completion_tokens
        self.token_usage["total_tokens"] += cb.total_tokens
        self.token_usage["total_cost"] += cb.total_cost
        print(f"TOKEN USAGE ({tag}):")
        print(f"   Prompt tokens: {cb.prompt_tokens:,}")
        print(f"   Completion tokens: {cb.completion_tokens:,}")
        print(f"   Total tokens: {cb.total_tokens:,}")
        print(f"   Estimated cost: ${cb.total_cost:.6f}")
        return result

    def _print_total_usage(self):
        t = self.token_usage
        print("TOTAL TOKEN USAGE:")
        print(f"   Prompt tokens: {t['prompt_tokens']:,}")
        print(f"   Completion tokens: {t['completion_tokens']:,}")
        print(f"   Total tokens: {t['total_tokens']:,}")
        print(f"   Estimated cost: ${t['total_cost']:.6f}")

    def should_continue_research(self, state: SimpleModelAgentState) -> str:
        """Determines whether to continue the research loop or end."""
        messages = state['messages']
        last_message = messages[-1]
        # If the LLM made a tool call, continue the loop to process it.
        if hasattr(last_message, 'tool_calls') and last_message.tool_calls:
            return "continue"
        # If the LLM responded with code (no tool call), end the loop.
        else:
            return "end"

    # Creates tool calls to profile the data and saves it into agent state 
    def match_schemas(self, state: SimpleModelAgentState):
        self.logger.info("----------------------- Entering match_schemas -----------------------")
        if state.get("schema_correspondences"):
            print("[*] Schema correspondences already present; skipping match_schemas")
            return {}

        print("[*] Running schema matching")
        result = run_schema_matching(
            dataset_paths=state["datasets"],
            model=self.base_model,
            output_dir="output/schema-matching",
        )
        self.logger.info("Leaving match_schemas")
        return result

    def profile_data(self, state:SimpleModelAgentState):
        self.logger.info('----------------------- Entering profile_data -----------------------')

        print("[*] Profiling datasets")

        system_prompt = """
            You are a data scientist tasked with the integration of several datasets.
            For each dataset path provided, call the tool `profile_dataset` with the path
            (one tool call per dataset).
        """
        
        datasets_list_str = "\n".join(state['datasets'])
        human_content = f"Please profile these datasets (one call per dataset):\n{datasets_list_str}"
        message = [SystemMessage(content=system_prompt), HumanMessage(content=human_content)]
        self.logger.info("Input Message:" + str(message))
        
        result = self._invoke_with_usage(message, "profile_data")
        self.logger.info("RESULT:" + str(result))

        # call tools
        tool_calls = result.tool_calls

        self.logger.info("Tool Calls:" + str(tool_calls))
        results = {}
        for t in tool_calls:
            if not t['name'] in self.tools:      # check for bad tool name from LLM
                self.logger.info("adapt_pipeline: ....bad tool name....")
                result = "bad tool name, retry"  # instruct LLM to retry if bad
            else:
                result = self.tools[t['name']].invoke(t['args'])
            
#            if USE_LLM == "groq" or USE_LLM == "gpt" or USE_LLM == "gemini":
            results[t['args']['path']] = result
#            elif USE_LLM == "gemini_broken":
#                results[t['args']['__arg1']] = result

        with open(OUTPUT_DIR + "profile/profiles.json", "w") as file:
            file.write(json.dumps(results, indent=2))
          
        self.logger.info('Leaving profile_data')
        return {'data_profiles': results}

    def run_blocking_tester(self, state: SimpleModelAgentState):
        self.logger.info("----------------------- Entering run_blocking_tester -----------------------")

        if SKIP_BLOCKING_TESTER:
            path = Path(OUTPUT_DIR + "blocking-evaluation/blocking_config.json")
            if path.exists():
                with path.open("r", encoding="utf-8") as f:
                    blocking_config = json.load(f)
                    print("[+] Using saved blocking strategy: " + json.dumps(blocking_config, indent=2))
                    return {"blocking_config": blocking_config}
            else:
                print("[-] Cannot skip blocking tester. No saved blocking strategy found")
        
        if state.get("blocking_config"):
            print("[*] Blocking config already present in state; skipping BlockingTester")
            return {}

        print("[*] Running BlockingTester")
        tester = BlockingTester(
            llm=self.base_model,
            datasets=state["datasets"],
            max_candidates=350000,
            blocking_testsets=state['entity_matching_testsets'],
            output_dir="output/blocking-evaluation",
            pc_threshold=0.9,
            max_attempts=5,
            max_error_retries=2,
            verbose=True
        )
        _, blocking_config = tester.run_all_pairs()
        print("[*] Blocking config computed:\n" + json.dumps(blocking_config, indent=2))
        self.logger.info("Leaving run_blocking_tester")
        return {"blocking_config": blocking_config}

    def run_matching_tester(self, state: SimpleModelAgentState):
        self.logger.info("----------------------- Entering run_matching_tester -----------------------")

        if SKIP_MATCHING_TESTER:
            path = Path(OUTPUT_DIR + "matching-evaluation/matching_config.json")
            if path.exists():
                with path.open("r", encoding="utf-8") as f:
                    matching_config = json.load(f)
                    print("[+] Using saved matching strategy: " + json.dumps(matching_config, indent=2))
                    return {"matching_config": matching_config}
            else:
                print("[-] Cannot skip matching tester. No saved matching strategy found")
        
        if state.get("matching_config"):
            print("[*] Matching config already present in state; skipping MatchingTester")
            return {}

        print("[*] Running MatchingTester")
        tester = MatchingTester(
            llm=self.base_model,
            datasets=state["datasets"],
            matching_testsets=state['entity_matching_testsets'],
            blocking_config=state.get("blocking_config", {}),
            output_dir="output/matching-evaluation",
            f1_threshold=0.75,
            max_attempts=4,
            max_error_retries=2,
            verbose=True,
        )
        _, matching_config = tester.run_all()
        print("[*] Matching config computed:\n" + json.dumps(matching_config, indent=2))
        self.logger.info("Leaving run_matching_tester")
        return {"matching_config": matching_config}


    def pipeline_adaption(self, state: SimpleModelAgentState):
        self.logger.info('----------------------- Entering pipeline_adaption -----------------------')

        ####### PREPARE SYSTEM PROMT #######
    
        # Load example pipeline code
        matcher_mode = state.get("matcher_mode", "ml")
        example_name = "example_pipeline_ml.py" if matcher_mode == "ml" else "example_pipeline.py"
        example_pipeline_path = os.path.join(INPUT_DIR, f"example_pipelines/{example_name}")
        if not os.path.exists(example_pipeline_path):
            raise FileNotFoundError(f"Example pipeline not found at: {example_pipeline_path}")
    
        with open(example_pipeline_path, "r", encoding="utf-8") as f:
            example_pipeline_code = f.read()

        # Prepare first-row previews for each dataset
        dataset_previews = {}
        for path in state['datasets']:
            df = load_dataset(path)
            if df is not None and not df.empty:
                # Take only first row and convert to dictionary
                dataset_previews[path] = df.iloc[0].to_dict()
            else:
                dataset_previews[path] = "Failed to load or empty dataset"
                
        # Prepare prompt for the model
        entity_matching_section = ""

        if state["matcher_mode"] == "ml":
            entity_matching_section = f"""
            2b. Entity matching testsets paths:
            {state["entity_matching_testsets"]}
            """
        
        system_prompt = f"""
        You are a data scientist tasked with the integration of several datasets.
        You are provided with the following inputs:

        1. An example integration pipeline (Python code using PyDI library). Pay
        attention to the comments within the pipeline, as they also contain important instructions:
        {example_pipeline_code}
    
        2. A list of dataset file paths:
        {json.dumps(state['datasets'], indent=2)}

        {entity_matching_section}
    
        3. The first row of each dataset to help understand the structure:
        {json.dumps(dataset_previews, indent=2)}
    
        4. A dictionary containing the profile data of the datasets
        (including number of rows, nulls_per_column and dtypes of 
        the columns):
        {json.dumps(state['data_profiles'], indent=2)}
        """
        
        # Include blocking config if available (from BlockingTester)
        blocking_config = state.get('blocking_config')
        if blocking_config:
            system_prompt += f"""

        5. **BLOCKING CONFIGURATION** (pre-computed optimal blocking strategies):
        This configuration was determined by a blocking evaluation agent. Use these settings
        for your blocking step in the pipeline:
        {json.dumps(blocking_config, indent=2)}
        
        IMPORTANT: Use the id_columns and blocking_strategies from this config:
        - Use the correct id_column for each dataset as specified
        - Use the recommended strategy (exact_match_single/multi or semantic_similarity)
        - Use the recommended columns for blocking
        - Strategy to blocker mapping:
          * exact_match_single / exact_match_multi -> StandardBlocker (exact match on columns)
          * token_blocking / ngram_blocking -> TokenBlocker (token or n-gram blocking)
          * sorted_neighbourhood -> SortedNeighbourhoodBlocker (window)
          * semantic_similarity -> EmbeddingBlocker (top_k)
        """

        # Include matching config if available (from MatchingTester)
        matching_config = state.get('matching_config')
        if matching_config:
            if matcher_mode == "ml":
                system_prompt += f"""

        6. **MATCHING CONFIGURATION** (pre-computed comparator settings):
        This configuration was determined by a matching evaluation agent. Use these settings
        for your MLBasedMatcher feature extraction and training:
        {json.dumps(matching_config, indent=2)}

        IMPORTANT: Use the matching_strategies from this config:
        - Build comparators (StringComparator/NumericComparator/DateComparator) for each dataset pair
        - Use the comparators as features in FeatureExtractor
        - Train a classifier on the labeled pairs (labels in the testset) and use MLBasedMatcher
        - Do NOT set weights; ML model learns weights internally
        - Do NOT add RuleBasedMatcher fallback branches
        - Follow the example ML pipeline structure and naming closely; do not invent new variable roles
        - preprocess mapping: "lower" -> str.lower, "strip" -> str.strip, "lower_strip" -> lambda x: str(x).lower().strip()
        """
            else:
                system_prompt += f"""

        6. **MATCHING CONFIGURATION** (pre-computed comparator settings):
        This configuration was determined by a matching evaluation agent. Use these settings
        for your RuleBasedMatcher step in the pipeline:
        {json.dumps(matching_config, indent=2)}

        IMPORTANT: Use the matching_strategies from this config:
        - Build comparators (StringComparator/NumericComparator/DateComparator) for each dataset pair
        - Use the specified weights and threshold
        - preprocess mapping: "lower" -> str.lower, "strip" -> str.strip, "lower_strip" -> lambda x: str(x).lower().strip()
        """

        system_prompt += """

        Your task is to **create a similar integration pipeline** so that it works with
        the datasets provided. Output should only consist of the relevant Python code
        for the integration pipeline.
        """

        evaluation_analysis = state.get("evaluation_analysis", None)
        if evaluation_analysis:
            system_prompt += f"""
            8. Evaluation reasoning from prior pipeline run:
            {evaluation_analysis}
            """
        # Include documentation if global variable is set
        # if INCLUDE_DOCS:
        #     doc_path = os.path.join(INPUT_DIR, "documentation")
        #     if os.path.exists(doc_path):
        #         doc_files = [f for f in os.listdir(doc_path) if f.endswith(".md")]
        #         all_docs = ""
        #         for f_name in doc_files:
        #             with open(os.path.join(doc_path, f_name), "r", encoding="utf-8", errors="replace") as f:
        #                 all_docs += f.read() + "\n\n"
        #         system_prompt += "\n\n### Documentation\n" + all_docs

        ####### PREPARE TASK PROMT #######

        # Determine if this is initial generation, fix due to execution error, or fix due to poor evaluation
        if "pipeline_execution_result" not in state and "evaluation_metrics" not in state:
            print("[*] Creating initial pipeline")
            human_content = "Create the integration pipeline for the provided datasets."
    
        else:
            # Either a pipeline execution error or evaluation-based adaption
            broken_pipeline_path = OUTPUT_DIR + "code/pipeline.py"
            with open(broken_pipeline_path, "r", encoding="utf-8", errors="ignore") as f:
                broken_code = f.read()
    
            human_content = "You previously generated Python integration pipeline code.\n"
            
            # Add execution error if exists
            if "pipeline_execution_result" in state and state["pipeline_execution_result"].lower().startswith("error"):
                print("[*] Trying to fix pipeline")
                human_content += f"Executing this pipeline caused the following error:\n{state['pipeline_execution_result']}\n"
    
            # Add evaluation feedback if available
            if "evaluation_metrics" in state:
                print("[*] Trying to improve pipeline based on evaluation")
                human_content += f"Evaluation of the last run shows the following metrics:\n{json.dumps(state['evaluation_metrics'], indent=2)}\n"
                human_content += "Improve the pipeline to increase overall accuracy and correct errors highlighted by the evaluation.\n"
    
            human_content += "Here is the current pipeline code:\n" + broken_code
            human_content += "\nOutput ONLY the corrected Python code."
            
        ####### SEARCH DOCUMENTATION TOOL #######
        if "search_documentation" in self.tools and "pipeline_execution_result" not in state.get('messages', []):
             self.tools["search_documentation"].reset()

        if not state.get('messages'):
            # Initial prompt for the research and adaption task
            system_prompt += """
            **PROCESS:**
            1.  **THINK**: Analyze the provided data profiles, configurations, and any previous error reports.
            2.  **RESEARCH**: If you are unsure how to use a PyDI function or class, you MUST use the `search_documentation` tool. You can call it multiple times based on given information such as, blocking configurations, matching configurations, data profile etc. Ask specific questions (e.g., "How to use SortedNeighbourhoodBlocker?", "What are the parameters for RuleBasedMatcher?").
            3.  **CODE**: Once you have gathered enough information, write the complete, executable Python code for the pipeline. **Your final output in this process must be only the Python code itself.**"""
        
            messages = [
                SystemMessage(content=system_prompt),
                HumanMessage(content=human_content)
            ]
        else:
            messages = state["messages"]
    
        self.logger.info("Input Message:" + str(messages))
    
        # Call the model
        adapted_pipeline = self._invoke_with_usage(messages, "pipeline_adaption")
        messages.append(adapted_pipeline)

        if adapted_pipeline.tool_calls:
            tool_messages = []
            for tool_call in adapted_pipeline.tool_calls:
                tool_name = tool_call["name"]
                if tool_name in self.tools:
                    tool_output = self.tools[tool_name].invoke(tool_call["args"])
                    tool_messages.append(ToolMessage(content=str(tool_output), tool_call_id=tool_call["id"]))
            messages.extend(tool_messages)
            
            # After tool calls, invoke the model again to get the final code
            final_response = self._invoke_with_usage(messages, "pipeline_adaption")
            messages.append(final_response)
            adapted_pipeline = final_response
        
        # Extract the code from the final response
        if hasattr(adapted_pipeline, 'tool_calls') and adapted_pipeline.tool_calls:
            # If still has tool calls after second invocation, recursively handle
            adapted_pipeline = "Pipeline code not available - too many tool calls"
        else:
            adapted_pipeline = adapted_pipeline.content if hasattr(adapted_pipeline, "content") else str(adapted_pipeline)
            self.logger.info("RESULT:" + str(adapted_pipeline))
            if adapted_pipeline.startswith("```python") and adapted_pipeline.endswith("```"):
                adapted_pipeline = adapted_pipeline[9:-3].strip()
                with open(OUTPUT_DIR + "code/pipeline.py", 'w', errors="ignore") as file:
                    file.write(str(adapted_pipeline))
            elif not adapted_pipeline.startswith("Pipeline code not available"):
                # Code without markdown markers - still save it
                with open(OUTPUT_DIR + "code/pipeline.py", 'w', errors="ignore") as file:
                    file.write(str(adapted_pipeline))

        self.logger.info('Leaving pipeline_adaption')
        return {"messages": messages, "integration_pipeline_code": adapted_pipeline}

    def execute_pipeline(self, state: SimpleModelAgentState):
        self.logger.info('----------------------- Entering execute_pipeline -----------------------')

        print("[*] Running generated pipeline")

        attempts = state.get("pipeline_execution_attempts", 0) + 1
        state["pipeline_execution_attempts"] = attempts
    
        pipeline_path = OUTPUT_DIR + "code/pipeline.py"
    
        try:
            result = subprocess.run(
                [sys.executable, pipeline_path],
                capture_output=True,
                text=True,
                timeout=3600
            )
    
            if result.returncode == 0:
                print("[+] Pipeline successfully completed")
                execution_result = "success"
            else:
                execution_result = f"error: {result.stderr}"[:10000]
                print("Error: " + str(execution_result))
    
        except Exception as e:
            execution_result = f"error: {str(e)}"
    
        self.logger.info("Pipeline execution result: " + execution_result)
        self.logger.info('Leaving execute_pipeline')
    
        return {
            "pipeline_execution_result": execution_result,
            "pipeline_execution_attempts": attempts
        }
        
    def evaluation_adaption(self, state: SimpleModelAgentState):
        self.logger.info('----------------------- Entering evaluation_adaption -----------------------')
        
        example_eval_path = INPUT_DIR + "example_pipelines/example_evaluation.py"
        example_eval_code = open(example_eval_path).read()
    
        fused_output_path = "output/data_fusion/fusion_rb_standard_blocker.csv"
    
        system_prompt = f"""
        You are a data scientist evaluating a data fusion pipeline.
    
        Example evaluation code:
        {example_eval_code}
    
        Generated integration pipeline:
        {state['integration_pipeline_code']}
    
        Dataset profiles:
        {json.dumps(state['data_profiles'], indent=2)}
    
        The fused output is located at:
        {fused_output_path}

        The testset is located at:
        {state['fusion_testset']}
    
        Create evaluation code that:
        - Uses the correct fusion strategy
        - Loads the fused output
        - Loads the gold standard test set
        - Prints structured evaluation metrics
        - Prints chosen evaluation functions in a compact one-line summary
        """

        ####### HUMAN PROMPT #######
        if not state.get("evaluation_execution_result"):
            print("[*] Adapting evaluation code")
            # First generation
            human_content = """
            Create the evaluation code.
            """
        else:
            # Fix broken evaluation
            print("[*] Fixing evaluation code")
            attempts = state.get("evaluation_execution_attempts", 0)
    
            if attempts >= 3:
                self.logger.info("Maximum evaluation fix attempts reached")
                return {"evaluation_execution_result": "error: max attempts reached"}
    
            eval_path = OUTPUT_DIR + "code/evaluation.py"
            with open(eval_path, "r", encoding="utf-8") as f:
                broken_code = f.read()
    
            error = state["evaluation_execution_result"]
    
            human_content = f"""
            You previously generated Python evaluation code.
            Executing this code caused the following error:
    
            {error}
    
            Here is the current evaluation code:
            {broken_code}
    
            Fix the code so that it executes successfully.
            Output ONLY the corrected Python code.
            """
    
        ####### MODEL CALL #######
    
        message = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content)
        ]
    
        self.logger.info("Input Message:" + str(message))
    
        result = self._invoke_with_usage(message, "evaluation_adaption")
        code = result.content.strip("```python").strip("```")
    
        self.logger.info("RESULT:" + str(code))
    
        with open(OUTPUT_DIR + "code/evaluation.py", "w") as f:
            f.write(code)

        self.logger.info('Leaving evaluation_adaption')
    
        return {"evaluation_code": code}

    def execute_evaluation(self, state: SimpleModelAgentState):
        self.logger.info('----------------------- Entering execute_evaluation -----------------------')
    
        print("[*] Running generated evaluation")
    
        attempts = state.get("evaluation_execution_attempts", 0) + 1
        state["evaluation_execution_attempts"] = attempts
    
        evaluation_path = OUTPUT_DIR + "code/evaluation.py"
    
        try:
            result = subprocess.run(
                [sys.executable, evaluation_path],
                capture_output=True,
                text=True,
                timeout=3600
            )
    
            if result.returncode == 0:
                print("[+] Evaluation successfully completed")
                execution_result = "success"
            else:
                print("[-] Evaluation could not be executed")
                execution_result = f"error: {result.stderr}"[:10000]
                print("Error: " + str(execution_result))
    
        except Exception as e:
            execution_result = f"error: {str(e)}"
    
        self.logger.info("Evaluation execution result: " + execution_result)
        self.logger.info('Leaving execute_evaluation')
    
        return {
            "evaluation_execution_result": execution_result,
            "evaluation_execution_attempts": attempts
        }

    def evaluation_decision(self, state: SimpleModelAgentState):
        self.logger.info('----------------------- Entering evaluation_decision -----------------------')
        print("[*] Reading evaluation metrics")

        attempts = state.get("evaluation_attempts", 0) + 1
    
        eval_path = "output/pipeline_evaluation/pipeline_evaluation.json"
    
        if not os.path.exists(eval_path):
            self.logger.warning("Evaluation file missing")
            metrics = {"error": "evaluation file missing"}
        else:
            with open(eval_path, "r", encoding="utf-8") as f:
                metrics = json.load(f)
    
        self.logger.info(f"Evaluation metrics: {metrics}")
        print(f"Evaluation metrics: {json.dumps(metrics)}")
    
        # Store metrics in the state
        state["evaluation_metrics"] = metrics

        overall_acc = metrics.get("overall_accuracy", 0.0)
        print(f"[*] Overall Accuracy: {overall_acc:.3%}")
    
        self.logger.info('Leaving evaluation_decision')

        return {
            "evaluation_metrics": metrics,
            "evaluation_attempts": attempts,
            "pipeline_execution_result": "",
            "pipeline_execution_attempts": 0,
            "evaluation_execution_result": "",
            "evaluation_execution_attempts": 0
        }
    def evaluation_reasoning(self, state: SimpleModelAgentState):
        self.logger.info('----------------------- Entering evaluation_reasoning -----------------------')
    
        debug_path = "output/pipeline_evaluation/debug_fusion_eval.jsonl"
        debug_events = []
    
        if os.path.exists(debug_path):
            with open(debug_path, "r", encoding="utf-8") as f:
                for line in f:
                    try:
                        debug_events.append(json.loads(line))
                    except Exception:
                        continue
    
        # Prepare system prompt
        system_prompt = """
        You are a data integration expert analyzing the evaluation results of a data integration pipeline.
    
        You are given:
        - Aggregate evaluation metrics
        - Detailed per-record debugging events from a fusion evaluation
        - The current integration pipeline code
        - The optimal blocking and matching configurations
    
        Your task:
        1. Identify the dominant error types (false positives, false negatives, missed blocks, bad matches)
        2. Determine whether errors are more likely caused by:
           - Blocking being too restrictive or too loose
           - Matching thresholds or comparator choices
           - Schema or preprocessing issues
           - Logic in the current pipeline code
        3. Suggest concrete, actionable improvements for the next pipeline iteration
    
        Respond with concise, structured reasoning.
        """
    
        # Prepare human content
        human_content = f"""
        Evaluation metrics:
        {json.dumps(state.get("evaluation_metrics", {}), indent=2)}
    
        Debug fusion events (JSONL):
        {json.dumps(debug_events[:50], indent=2)}
    
        Current integration pipeline code:
        {state.get("integration_pipeline_code", "Pipeline code not available")}
    
        Optimal blocking configuration:
        {json.dumps(state.get("blocking_config", {}), indent=2)}
    
        Optimal matching configuration:
        {json.dumps(state.get("matching_config", {}), indent=2)}
        """
    
        # Model call
        message = [
            SystemMessage(content=system_prompt),
            HumanMessage(content=human_content)
        ]
    
        result = self.base_model.invoke(message)
        analysis = result.content if hasattr(result, "content") else str(result)
    
        self.logger.info("Evaluation reasoning produced")
        print("[*] Evaluation reasoning:\n" + analysis)
    
        return {"evaluation_analysis": analysis}

# %% [markdown]
# ## Invoke Pipeline

# %%
if USE_LLM == "gemini":
    llm = ChatGoogleGenerativeAI(
        model="gemini-2.0-flash",
        temperature=0,
        max_tokens=None,
        timeout=None,
        max_retries=2,
    )
elif USE_LLM == "groq":
    llm = ChatGroq(
        model="llama-3.3-70b-versatile",
        temperature=0.2
    )
elif USE_LLM == "gpt":
    llm = ChatOpenAI(
        model="gpt-5.1",
        temperature=0,
        max_tokens=None,
    )

# %%
# Music use case
entity_matching_testsets = {
    ("discogs", "lastfm"): INPUT_DIR + "datasets/music/testsets/discogs_lastfm_goldstandard_blocking.csv",
    ("discogs", "musicbrainz"): INPUT_DIR + "datasets/music/testsets/discogs_musicbrainz_goldstandard_blocking.csv",
    ("musicbrainz", "lastfm"): INPUT_DIR + "datasets/music/testsets/musicbrainz_lastfm_goldstandard_blocking.csv",
}
datasets = [
    INPUT_DIR + "datasets/music/discogs.xml",
    INPUT_DIR + "datasets/music/lastfm.xml",
    INPUT_DIR + "datasets/music/musicbrainz.xml"
]
fusion_testset = INPUT_DIR + "datasets/music/testsets/test_set.xml"

# %%
# Restaurants use case
entity_matching_testsets = {
    ("kaggle_small", "uber_eats_small"): INPUT_DIR + "datasets/restaurant/testsets/kaggle_uber_eats_goldstandard_blocking_small.csv",
    ("kaggle_small", "yelp_small"): INPUT_DIR + "datasets/restaurant/testsets/kaggle_yelp_goldstandard_blocking_small.csv",
    ("yelp_small", "uber_eats_small"): INPUT_DIR + "datasets/restaurant/testsets/uber_eats_yelp_goldstandard_blocking_small.csv",
}

datasets = [
    INPUT_DIR + "datasets/restaurant/kaggle_small.parquet",
    INPUT_DIR + "datasets/restaurant/uber_eats_small.parquet",
    INPUT_DIR + "datasets/restaurant/yelp_small.parquet"
]
fusion_testset = INPUT_DIR + "datasets/restaurant/testsets/Restaurant_Fusion_Test_Set.csv"

# %%
# Skip Blocking and Matching node and use existing strategies saved in 
# "output/blocking-evaluation/blocking_config.json" and "output/matching-evaluation/matching_config.json"
SKIP_BLOCKING_TESTER=True
SKIP_MATCHING_TESTER=False

# %%
# prepare agent
# agent = SimpleModelAgent(llm, ProfileDatasetTool())
profile_tool = ProfileDatasetTool()
search_tool = SearchDocumentationTool()
all_tools = {profile_tool.name: profile_tool, search_tool.name: search_tool}

agent = SimpleModelAgent(llm, tools=all_tools)

# invoke agent
result = agent.graph.invoke({
    "datasets": datasets,
    "entity_matching_testsets": entity_matching_testsets,
    "fusion_testset": fusion_testset,
    "matcher_mode": "rulebased"
})
# Out:
# [*] Running schema matching
# [*] Schema alignment columns:
#     kaggle_small: ['kaggle380k_id', 'source', 'name', 'name_norm', 'website', 'map_url', 'phone_raw', 'phone_e164', 'address_line1', 'address_line2', 'street', 'house_number', 'city', 'state', 'postal_code', 'country', 'latitude', 'longitude', 'categories', 'rating']
#     uber_eats_small: ['kaggle380k_id', 'source', 'name', 'name_norm', 'address_line1', 'address_line2', 'street', 'house_number', 'city', 'state', 'postal_code', 'country', 'latitude', 'longitude', 'categories', 'rating', 'rating_count']
#     yelp_small: ['kaggle380k_id', 'source', 'name', 'name_norm', 'map_url', 'phone_raw', 'phone_e164', 'address_line1', 'address_line2', 'street', 'house_number', 'city', 'state', 'postal_code', 'country', 'latitude', 'longitude', 'categories', 'rating', 'rating_count']
# [*] Profiling datasets
# TOKEN USAGE (profile_data):
#    Prompt tokens: 293
#    Completion tokens: 94
#    Total tokens: 387
#    Estimated cost: $0.000000
# [+] Using saved blocking strategy: {
#   "blocking_strategies": {
#     "discogs_lastfm": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "artist",
#         "name",
#         "tracks_track_name"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.7090909090909091,
#       "num_candidates": 451918,
#       "is_acceptable": false
#     },
#     "discogs_musicbrainz": {
#       "strategy": "semantic_similarity",
#       "columns": [
#         "name",
#         "artist",
#         "release-date"
#       ],
#       "params": {
#         "top_k": 20
#       },
#       "pair_completeness": 0.9487179487179487,
#       "num_candidates": 450205,
#       "is_acceptable": true
#     },
#     "musicbrainz_lastfm": {
#       "strategy": "token_blocking",
#       "columns": [
#         "name"
#       ],
#       "params": {
#         "min_token_len": 4
#       },
#       "pair_completeness": 0.9113924050632911,
#       "num_candidates": 505108,
#       "is_acceptable": true
#     }
#   },
#   "id_columns": {
#     "discogs": "id",
#     "lastfm": "id",
#     "musicbrainz": "id"
#   }
# }
# [*] Running MatchingTester
# [*] Loading dataset: kaggle_small
# [*] Loading dataset: uber_eats_small
# [*] Loading dataset: yelp_small
# [*] Loading matching gold standard for kaggle_small <-> uber_eats_small
#     Loaded 100 ground truth pairs
# [*] Loading matching gold standard for kaggle_small <-> yelp_small
#     Loaded 100 ground truth pairs
# [*] Loading matching gold standard for yelp_small <-> uber_eats_small
#     Loaded 100 ground truth pairs
#
# ==================================================
# MATCHING EVALUATION
# ==================================================
#
# ==================================================
# MATCHING: kaggle_small <-> uber_eats_small
# ==================================================
#     Using ID column: 'kaggle380k_id'
# Blocking columns: []
#     No blocking config found. Falling back to StandardBlocker on house_number
#
# --- Attempt 1/4 ---
# Comparators: ['name_norm:jaro_winkler', 'address_line1:jaro_winkler', 'latitude:0.001', 'longitude:0.001', 'postal_code:levenshtein', 'city:jaro_winkler', 'state:jaro_winkler', 'categories:jaccard']
# Threshold: 0.7
#     Reasoning: Use normalized name and full address as primary signals, reinforced by tight lat/long proximity and postal/city/state consistency; categories provide softer support. Jaro-Winkler suits relatively short textual fields, Jaccard models list-like categories, and small numeric tolerances on coordinates capture true co-located venues. Weights emphasize strong identifiers, with a threshold tuned for good precision in an ML-assisted matching setup.
#     [ML] Building comparators
#     [ML] Comparators count: 8
#     [ML] Creating features
#     [ML] Gold pairs filtered: 100 -> 100
#     [ML] Feature rows: 100
#     [ML] Feature columns: 8
#     [ML] Training classifier
#     [ML] Matching candidates
#     [ML] Correspondences: 126
#     [ML] Evaluation complete
# SUCCESS: F1=0.9756
#
# ==================================================
# MATCHING: kaggle_small <-> yelp_small
# ==================================================
#     Using ID column: 'kaggle380k_id'
# Blocking columns: []
#     No blocking config found. Falling back to StandardBlocker on postal_code
#
# --- Attempt 1/4 ---
# Comparators: ['name_norm:jaro_winkler', 'categories:jaccard', 'address_line1:jaro_winkler', 'city:jaro_winkler', 'state:jaro_winkler', 'postal_code:levenshtein', 'latitude:0.01', 'longitude:0.01', 'phone_e164:levenshtein']
# Threshold: 0.78
#     Reasoning: Business matching across Kaggle and Yelp: use normalized name and address as primary signals, supported by city/state/postal code and geo coordinates; phone and categories add precision. Jaro-Winkler/Levenshtein handle short text/IDs, Jaccard suits list-like categories. Tight lat/long differences reflect same venue proximity. Slightly high threshold favors precision for ML training labels while still allowing for minor noise.
#     [ML] Building comparators
#     [ML] Comparators count: 9
#     [ML] Creating features
#     [ML] Gold pairs filtered: 100 -> 100
#     [ML] Feature rows: 100
#     [ML] Feature columns: 9
#     [ML] Training classifier
#     [ML] Matching candidates
#     [ML] Correspondences: 11247
#     [ML] Evaluation complete
# SUCCESS: F1=1.0000
#
# ==================================================
# MATCHING: yelp_small <-> uber_eats_small
# ==================================================
#     Using ID column: 'kaggle380k_id'
# Blocking columns: []
#     No blocking config found. Falling back to StandardBlocker on house_number
#
# --- Attempt 1/4 ---
# Comparators: ['name_norm:jaro_winkler', 'address_line1:jaro_winkler', 'latitude:0.001', 'longitude:0.001', 'categories:jaccard', 'city:jaro_winkler', 'state:jaro_winkler', 'postal_code:levenshtein']
# Threshold: 0.75
#     Reasoning: Use normalized name and full address as primary textual identifiers with typo-robust similarity; latitude/longitude as strong geographic constraints with tight numeric tolerance; categories as supportive semantic signal using set-based similarity; and city/state/postal_code as additional location consistency checks. Address_line2 and rating fields are too sparse or noisy to be reliable. The weight distribution emphasizes name/address and location, with a moderately high threshold to favor precision for business matching across Yelp and Uber Eats.
#     [ML] Building comparators
#     [ML] Comparators count: 8
#     [ML] Creating features
#     [ML] Gold pairs filtered: 100 -> 0
#     ML error: ML matcher has no gold pairs after ID filtering... Falling back to RuleBasedMatcher.
#     Retry 1: fixing error...
# F1=0.0000 < 0.75
#
# --- Attempt 2/4 ---
# Comparators: ['name_norm:jaro_winkler', 'address_line1:jaro_winkler', 'city:jaro_winkler', 'state:jaro_winkler', 'postal_code:levenshtein', 'latitude:0.001', 'longitude:0.001', 'categories:jaccard']
# Weights: [0.25, 0.2, 0.08, 0.07, 0.1, 0.12, 0.12, 0.06]
# Threshold: 0.82
#     Reasoning: Use high-precision string similarity (Jaro-Winkler/Levenshtein) on normalized name and full address, supported by city/state/postal and tight lat/lon numeric windows plus Jaccard over category sets. Previous setup got 0.0, likely due to overly loose token-based similarity and/or poor weighting; this configuration emphasizes strong co-location (geo + address) and resilient name matching, with a higher threshold to favor precision in business-place matching.
# F1=0.0000 < 0.75
#
# --- Attempt 3/4 ---
# Comparators: ['name_norm:jaro_winkler', 'address_line1:jaro_winkler', 'city:jaro_winkler', 'state:jaro_winkler', 'postal_code:levenshtein', 'latitude:0.001', 'longitude:0.001', 'categories:jaccard']
# Weights: [0.22, 0.18, 0.08, 0.05, 0.07, 0.18, 0.18, 0.04]
# Threshold: 0.78
#     Reasoning: Use more typo-robust token-aware string metrics (jaro_winkler/levenshtein, jaccard) and tighten the geo numeric comparators; increase emphasis on name_norm and lat/long, de-emphasize noisy categories. Slightly raise the threshold to exploit the strong joint signal from name, address, and location, differing from the previous cosine-based setup that produced 0 scores.
# F1=0.0000 < 0.75
#
# --- Attempt 4/4 ---
# Comparators: ['name_norm:jaro_winkler', 'address_line1:jaccard', 'city:jaro_winkler', 'state:jaro_winkler', 'postal_code:levenshtein', 'latitude:0.001', 'longitude:0.001', 'categories:jaccard']
# Weights: [0.22, 0.18, 0.08, 0.08, 0.08, 0.16, 0.16, 0.04]
# Threshold: 0.82
#     Reasoning: Previous config likely failed because it treated multiple strong signals too weakly or with unsuitable similarity metrics. Here, we rely heavily on normalized name and tight lat/long numeric comparators, add token-based Jaccard for address and categories, and use typo-robust string metrics for city/state/postal_code. Weights emphasize name and geolocation as primary identifiers with address and locality as supporting evidence, and a slightly higher threshold favors precision for business-level matching across Yelp and Uber Eats.
# F1=0.0000 < 0.75
# Max attempts reached. Best F1=0.0000
#
# 📊 Results: 3 pairs evaluated
#   OK kaggle_small_uber_eats_small: F1=0.9756
#   OK kaggle_small_yelp_small: F1=1.0000
#   WARN yelp_small_uber_eats_small: F1=0.0000
# Config saved to matching_config.json
# [*] Matching config computed:
# {
#   "id_columns": {
#     "discogs": "id",
#     "lastfm": "id",
#     "musicbrainz": "id"
#   },
#   "matching_strategies": {
#     "kaggle_small_uber_eats_small": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name_norm",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "address_line1",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "numeric",
#           "column": "latitude",
#           "max_difference": 0.001
#         },
#         {
#           "type": "numeric",
#           "column": "longitude",
#           "max_difference": 0.001
#         },
#         {
#           "type": "string",
#           "column": "postal_code",
#           "similarity_function": "levenshtein",
#           "preprocess": "strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "city",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "state",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "categories",
#           "similarity_function": "jaccard",
#           "preprocess": "lower_strip",
#           "list_strategy": "set_jaccard"
#         }
#       ],
#       "weights": [
#         0.3,
#         0.25,
#         0.1,
#         0.1,
#         0.08,
#         0.07,
#         0.05,
#         0.05
#       ],
#       "threshold": 0.7,
#       "f1": 0.975609756097561
#     },
#     "kaggle_small_yelp_small": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name_norm",
#           "similarity_function": "jaro_winkler",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "categories",
#           "similarity_function": "jaccard",
#           "preprocess": "lower_strip",
#           "list_strategy": "set_jaccard"
#         },
#         {
#           "type": "string",
#           "column": "address_line1",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "city",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "state",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "postal_code",
#           "similarity_function": "levenshtein",
#           "preprocess": "strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "numeric",
#           "column": "latitude",
#           "max_difference": 0.01
#         },
#         {
#           "type": "numeric",
#           "column": "longitude",
#           "max_difference": 0.01
#         },
#         {
#           "type": "string",
#           "column": "phone_e164",
#           "similarity_function": "levenshtein",
#           "preprocess": "strip",
#           "list_strategy": "concatenate"
#         }
#       ],
#       "weights": [
#         0.22,
#         0.1,
#         0.16,
#         0.08,
#         0.05,
#         0.05,
#         0.12,
#         0.12,
#         0.1
#       ],
#       "threshold": 0.78,
#       "f1": 1.0
#     },
#     "yelp_small_uber_eats_small": {
#       "comparators": [
#         {
#           "type": "string",
#           "column": "name_norm",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "address_line1",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "numeric",
#           "column": "latitude",
#           "max_difference": 0.001
#         },
#         {
#           "type": "numeric",
#           "column": "longitude",
#           "max_difference": 0.001
#         },
#         {
#           "type": "string",
#           "column": "categories",
#           "similarity_function": "jaccard",
#           "preprocess": "lower_strip",
#           "list_strategy": "set_jaccard"
#         },
#         {
#           "type": "string",
#           "column": "city",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "state",
#           "similarity_function": "jaro_winkler",
#           "preprocess": "lower_strip",
#           "list_strategy": "concatenate"
#         },
#         {
#           "type": "string",
#           "column": "postal_code",
#           "similarity_function": "levenshtein",
#           "preprocess": "strip",
#           "list_strategy": "concatenate"
#         }
#       ],
#       "weights": [
#         0.22,
#         0.18,
#         0.08,
#         0.06,
#         0.08,
#         0.16,
#         0.16,
#         0.06
#       ],
#       "threshold": 0.78,
#       "f1": 0.0
#     }
#   }
# }
# [*] Creating initial pipeline
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 6,751
#    Completion tokens: 164
#    Total tokens: 6,915
#    Estimated cost: $0.000000
# [SEARCH TOOL CALL 1]: Asking 'PyDI StandardBlocker usage and parameters'
# [SEARCH TOOL CALL 2]: Asking 'PyDI EmbeddingBlocker usage and parameters'
# [SEARCH TOOL CALL 3]: Asking 'PyDI TokenBlocker usage and parameters'
# [SEARCH TOOL CALL 4]: Asking 'PyDI RuleBasedMatcher usage and parameters'
# [SEARCH TOOL CALL 5]: Asking 'PyDI DataFusionEngine and DataFusionStrategy usage and parameters'
# [SEARCH TOOL CALL 6]: Asking 'PyDI LLMBasedSchemaMatcher usage and parameters'
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 8,974
#    Completion tokens: 2,514
#    Total tokens: 11,488
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 4,160
#    Completion tokens: 1,006
#    Total tokens: 5,166
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.7171464330413017, "macro_accuracy": 0.7306169836355595, "num_evaluated_records": 40, "num_evaluated_attributes": 21, "total_evaluations": 799, "total_correct": 573, "name_accuracy": 0.925, "name_count": 40, "categories_accuracy": 0.925, "categories_count": 40, "rating_count_accuracy": 0.9705882352941176, "rating_count_count": 34, "address_line2_accuracy": 1.0, "address_line2_count": 7, "map_url_accuracy": 0.375, "map_url_count": 40, "website_accuracy": 0.9473684210526315, "website_count": 38, "source_accuracy": 0.275, "source_count": 40, "phone_e164_accuracy": 0.0, "phone_e164_count": 40, "street_accuracy": 0.85, "street_count": 40, "address_line1_accuracy": 0.925, "address_line1_count": 40, "rating_accuracy": 0.45, "rating_count": 40, "city_accuracy": 0.95, "city_count": 40, "longitude_accuracy": 0.95, "longitude_count": 40, "name_norm_accuracy": 0.8, "name_norm_count": 40, "country_accuracy": 0.95, "country_count": 40, "_id_accuracy": 0.275, "_id_count": 40, "house_number_accuracy": 0.925, "house_number_count": 40, "phone_raw_accuracy": 0.0, "phone_raw_count": 40, "postal_code_accuracy": 0.95, "postal_code_count": 40, "latitude_accuracy": 0.95, "latitude_count": 40, "state_accuracy": 0.95, "state_count": 40}
# [*] Overall Accuracy: 71.715%
# [*] Evaluation reasoning:
# 1. Dominant error types
#
# From the metrics + debug events:
#
# - Overall fusion accuracy ~0.72, but attribute-level picture is very uneven:
#   - Very high: name, categories, address, geo, city/state/postal_code (0.85–0.97)
#   - Very low: map_url (0.375), source (0.275), rating (0.45), _id (0.275)
#   - Completely broken: phone_raw, phone_e164 (0.0)
#
# From the debug JSONL:
#
# - Many `"missing_fused_value"` events with `fused_id: NaN` and `inputs: []` for records that clearly should have matches (e.g., `kaggle380k-008975`, `kaggle380k-001820`):
#   - Missing name, categories, rating_count, map_url, website, source
#   - These are **false negatives at the cluster level**: the true entity never got into a fused group → no fused row → all attributes evaluated as missing.
# - A few “wrong entity” fusions:
#   - `kaggle380k-001561` fused as `"BLACKSTONE PUB & EATERY"` while gold expects `"Jefferson's Gadsden"` → attributes (name, categories, map_url, website, source) all mismatched. This is a **false positive match / bad cluster**.
# - For attributes like `map_url` and `source`, the fused record exists but picks the wrong value (or wrong source dataset) even when the cluster is correct (e.g., Google vs Yelp URL, `kaggle_380k` vs `yelp`). These are **bad fusion logic errors**, not blocking/matching errors.
#
# Summary of dominant error types:
#
# - Most impactful:
#   - False negatives due to:
#     - No cluster formed for some gold entities (missing fused row; `fused_id: NaN`).
#     - Singleton kaggle-only records being dropped (`include_singletons=False`).
#   - Bad matches (wrong entities grouped) causing cascaded attribute mismatches.
# - Attribute-level fusion errors:
#   - Phones (0.0 accuracy): likely always null in fused output.
#   - Source, _id: fusion logic systematically wrong.
#   - Map_url: consistently takes the wrong “kind” of URL (Google vs Yelp API URL).
#
# ---
#
# 2. Where the errors come from
#
# I’ll go layer by layer.
#
# ### 2.1 Blocking
#
# - Current blocking: `StandardBlocker(..., on=["city"])` for all three pairs.
# - Optimal blocking config shown is for a different domain (music datasets) and not used here, but we know:
#   - Pair completeness there is high when using name-based / semantic blocking.
# - Evidence in this run:
#   - Some expected entities (e.g., `kaggle380k-008975`, `kaggle380k-001820`) have **no inputs at all** in fusion debug, and `fused_id: NaN`:
#     - Either:
#       - These kaggle IDs never appear in any correspondence (blocked out by city mismatch / null city), **or**
#       - They appear only as singletons and are then dropped in fusion.
#   - Because blocking is only on exact `city`, any city spelling/normalization differences or missing city in one source immediately kill candidates.
#
# Conclusion on blocking:
#
# - Blocking is **too restrictive**:
#   - Single exact-city key is brittle for real-world restaurant data (typos, neighborhood vs city names, alternate city strings).
# - However, for most evaluated attributes, matched records exist and align well (hence 0.9+ on address/geo), so blocking isn’t catastrophic, but it is a contributor to the “missing_fused_value” cases.
#
# ### 2.2 Matching configuration
#
# - Your code’s matching config matches the provided “optimal matching configuration” for the restaurant datasets almost exactly:
#   - `kaggle_small_uber_eats_small` comparators, weights, thresholds: identical.
#   - `kaggle_small_yelp_small` comparators, weights, thresholds: identical.
#   - `yelp_small_uber_eats_small` comparators, weights, thresholds: identical.
# - The optimal F1 values from config:
#   - k2u: F1 = 0.9756
#   - k2y: F1 = 1.0
#   - u2y: F1 = 0.0 (this is interesting; more below)
#
# Given that:
#
# - k2u and k2y matching should be **very good** if the same candidate sets are used (i.e., same blocking).
# - The debug mismatches like `BLACKSTONE PUB & EATERY` vs `Jefferson's Gadsden` tell us:
#   - Some **false positive** matches are happening. This is likely driven by:
#     - Both in same city.
#     - Similar categories and maybe similar address (e.g., near each other).
#     - Threshold 0.7/0.78 might accept ambiguous near-matches.
# - The u2y F1 = 0.0 in config means the learned/optimal parameters could not find a good decision boundary for that pair. You are still using the same comparators and threshold 0.78, so:
#   - u2y correspondences are likely either:
#     - Empty (no matches above threshold), or
#     - Full of bad matches, depending on the real scores.
#   - In either case, u2y links can create **erroneous “triangles”** in the graph of correspondences and thus bad fusion clusters.
#
# Conclusion on matching:
#
# - k2u and k2y matchers are mostly fine; they’re not the main source of widespread error.
# - u2y matcher is **not reliable** (configuration itself has F1 = 0.0) and can distort clusters.
# - A few false positives from thresholds still appear and create bad clusters.
#
# ### 2.3 Schema / preprocessing issues
#
# - Phones:
#   - phone_e164 and phone_raw have 0.0 accuracy, both with count 40.
#   - Fusion strategy: `longest_string`.
#   - Likely issues:
#     - Inconsistent mapping of phone fields during LLMBasedSchemaMatcher:
#       - e.g., Uber phone vs Yelp phone not coherently renamed to `phone_e164` / `phone_raw`.
#     - Or one source has formatted strings and another is null; longest_string may select a noisy or malformed version that doesn’t match gold.
#   - Also, the matcher uses a Levenshtein comparator on phone_e164; if schema matching misaligned this column, similarity scores are meaningless.
# - Categories:
#   - In debug, fused categories sometimes include **extra category lists** from other restaurants:
#     - For `kaggle380k-001561`, fused categories = union of multiple unrelated restaurants (`'Pizza restaurant', 'Live music venue'`, `'Taco restaurant'`, etc.).
#     - That is a red flag that different entities were merged into one cluster (matching issue + fusion rule), not schema mapping per se.
# - Map_url:
#   - Fused values are *Google Maps URLs* from Kaggle vs expected *Yelp API URLs*.
#   - That means:
#     - Schema was mapped correctly (map_url → map_url).
#     - Fusion rule `longest_string` chooses whichever URL is longer. Yelp API URLs are often longer, but in examples the Google URLs are also long with map query params – winning on length.
#     - Evaluation expects a *specific* source (Yelp) per record; fusion is agnostic to source.
#
# Conclusion on schema/preprocessing:
#
# - Primary schema issue: phone fields likely misaligned or not cleaned, leading to all errors.
# - Otherwise schema matching seems acceptable; text fields (name, address, categories) perform reasonably.
# - Preprocessing for map_url / source / _id doesn’t exist; but these need **source-aware logic**, not standard string fusion.
#
# ### 2.4 Fusion engine / pipeline logic
#
# Two critical logic choices:
#
# 1. `include_singletons=False` in DataFusionEngine:
#    - Any entity that only appears in a single dataset (e.g., only in Kaggle, no Uber/Yelp match) is **dropped** from the fused output.
#    - During evaluation, those gold IDs still appear in the ground truth, so:
#      - Every attribute for these records becomes `"missing_fused_value"` → false negatives.
#    - This is almost certainly causing many of the `fused_id: NaN` cases.
#
# 2. Attribute fusers:
#
#    - For `map_url`:
#      - Using `longest_string` across sources leads to arbitrarily selecting Google/Yelp/other, which won’t align with evaluation’s expectation (which seems to want Yelp’s Yelp-API URL where applicable).
#    - For `source`:
#      - Always takes the longest string: `kaggle_380k` > `yelp`/`uber_eats`.
#      - So for any fused multi-source record, `source` almost always ends up as `"kaggle_380k"`, while gold expects the **canonical/source-of-truth** dataset label per gold record.
#    - For `_id`:
#      - There’s no explicit fuser in your strategy. If `_id` exists in the data, it’s probably:
#        - Either dropped, or
#        - Implicitly fused in some default, non-semantic way.
#      - Accuracy 0.275 suggests IDs are often wrong or missing.
#
# Conclusion on logic:
#
# - The **fusion strategy and DataFusionEngine settings are a major source of error**, even when blocking/matching are good.
# - Specifically:
#   - Dropping singletons.
#   - Source-agnostic “longest_string” for map_url, website, source, phones, IDs.
#
# ---
#
# 3. Concrete, actionable improvements
#
# ### 3.1 Fix the biggest structural issue: keep singletons
#
# - Change fusion call:
#
# ```python
# rb_fused_standard_blocker = engine.run(
#     datasets=[kaggle_small, uber_eats_small, yelp_small],
#     correspondences=all_rb_correspondences,
#     id_column="kaggle380k_id",
#     include_singletons=True,  # instead of False
# )
# ```
#
# Impact:
#
# - All Kaggle records without cross-dataset matches will still appear in the fused dataset.
# - The current “missing_fused_value” for attributes of these singletons will turn into their original Kaggle values.
# - This should substantially increase `_id`, `source`, `map_url`, and rating/rating_count accuracy for those entities.
#
# ### 3.2 Soften and diversify blocking
#
# Given city-only exact blocking is brittle:
#
# 1. Expand blocking key to include another robust field:
#
#    - For example, block on:
#      - `city` AND 3-char prefix of `name_norm` (or a token-based block)
#    - Or use a token-blocking on `name_norm` with `min_token_len=3` plus city as a secondary filter.
#
#    Pseudocode sketch:
#
#    ```python
#    blocker_k2u = StandardBlocker(
#        kaggle_small,
#        uber_eats_small,
#        on=["city", "name_norm"],  # if StandardBlocker supports multi-column
#        ...
#    )
#    ```
#
#    If StandardBlocker doesn’t support fuzzy / partial, add an additional pass or preprocess with normalized city + name fragments.
#
# 2. At minimum, ensure city normalization before blocking:
#
#    - Convert all `city` fields to lowercase, strip whitespace, and possibly map common variants (e.g., “L.A.” vs “Los Angeles”).
#
# 3. Optionally add a **fallback blocking** on approximate name + geo for records with missing city:
#
#    - Use a second StandardBlocker on rounded latitude/longitude columns or on postal_code.
#
# Goal:
#
# - Reduce the number of genuinely duplicate entities that never become candidates → reduce false negatives due to blocking.
#
# ### 3.3 Disable or constrain the weakest matcher (u2y)
#
# From config, `yelp_small_uber_eats_small` has F1 = 0.0 under the same comparators/thresholds, meaning:
#
# - Either no good threshold exists, or
# - The current pair is fundamentally too noisy.
#
# Until you tune it:
#
# - Either remove u2y correspondences from fusion entirely:
#
# ```python
# all_rb_correspondences = pd.concat(
#     [rb_correspondences_k2u, rb_correspondences_k2y],  # drop rb_correspondences_u2y
#     ignore_index=True,
# )
# ```
#
# - Or, make u2y more conservative:
#   - Increase threshold (e.g., from 0.78 → 0.9) and only retain very high similarity links.
#   - Or require high agreement on multiple strong fields (name_norm, address, lat/lon).
#
# Impact:
#
# - Fewer spurious “cycles” (Kaggle ↔ Uber ↔ Yelp where Uber–Yelp is wrong) that merge unrelated restaurants into a single fused entity.
#
# ### 3.4 Attribute-specific fusion logic
#
# #### 3.4.1 `source`
#
# - Instead of `longest_string`, implement a deterministic rule such as:
#   - Always prefer the Kaggle source label for Kaggle-dominated clusters, OR
#   - For evaluation, set `source` to the **dataset whose ID is being used as fused_id** (likely Kaggle in your case).
# - If evaluation expects the original dataset name per record (like “yelp” for Yelp records), your fusion may not be designed to reproduce that; if the gold fused set is Kaggle-centric, then:
#   - Set `source` simply to `"kaggle_380k"` for all fused rows that derive from a Kaggle base ID.
# - Implement a small custom fuser function instead of `longest_string`.
#
# #### 3.4.2 `_id`
#
# - Decide what `_id` should represent in the fused schema:
#   - If gold treats `_id` as the Kaggle ID, then:
#     - Make a fuser that always returns `kaggle380k_id` for the cluster.
#   - If it should be some canonical ID, implement that mapping explicitly.
# - Add an explicit `_id` fuser to `strategy`.
#
# #### 3.4.3 `map_url` and `website`
#
# - Current long-string logic picks arbitrary sources; evaluation wants specific ones (often Yelp URLs).
# - Options:
#   - If the evaluation dataset is Kaggle-enriched-with-Yelp-URLs:
#     - Prefer URLs coming from Yelp rows in the cluster.
#     - Fallback to Kaggle/Google maps if Yelp is missing.
#   - Or, choose based on domain:
#     - For `map_url`, prefer `yelp.com` URLs if present; else prefer `maps.google.com` URLs.
# - Implement a custom URL fuser that:
#   - Parses domains and ranks them: `yelp.com` > `maps.google.com` > others.
#   - Returns the highest-ranked existing URL.
#
# #### 3.4.4 Phones (phone_raw, phone_e164)
#
# - Investigate schema_correspondences to confirm:
#   - Uber/Yelp phone columns were correctly mapped to `phone_raw` or `phone_e164`.
# - Introduce cleaning before fusion:
#   - Strip all non-digit characters, standardize country code if known (e.g., US).
# - For fusion:
#   - Use a fuser that picks the **most complete** normalized number across sources (e.g., longest after stripping non-digits), but only if they agree after normalization.
# - For matching:
#   - Consider using exact equality on normalized phone for a strong, but optional comparator in k2y/u2y (you already have a Levenshtein comparator; ensure the input is normalized).
#
# This should move phone accuracy away from 0.0, assuming gold uses normalized phones.
#
# ### 3.5 Guard against multi-entity clusters
#
# Given cases like `kaggle380k-001561` having fused categories that clearly include other restaurants:
#
# - Add a post-processing step on fused clusters:
#   - For each cluster, inspect:
#     - Distribution of latitude/longitude: if points are far apart (e.g., > 0.05 degrees), likely multi-entity cluster → split/flag.
#     - Name similarity: if within cluster there are sub-groups with very low name similarity, you likely merged multiple restaurants.
# - At minimum, enforce a stricter rule: only fuse records that match through Kaggle:
#   - Use Kaggle as the hub: only accept Uber/Yelp entities that match Kaggle; avoid Uber–Yelp-only clusters that might be noisy.
#
# ---
#
# 4. Summary diagnosis
#
# - Dominant errors:
#   - Many false negatives from excluded singleton records (`include_singletons=False`) and possibly over-restrictive city-only blocking.
#   - A smaller but important set of false positives / bad clusters from noisy u2y correspondences and thresholds.
#   - Systematic attribute fusion issues for `source`, `_id`, `map_url`, `phone_*` due to naive `longest_string` and weak schema alignment.
#
# - Main causes:
#   - Fusion engine logic (singletons dropped; source-agnostic fusers).
#   - Blocking too strict (exact city only).
#   - One matching pair (u2y) has unusably low F1 but is still used.
#   - Phone schema/preprocessing/fusion not handled.
#
# - Next iteration priorities:
#   1. Enable `include_singletons=True`.
#   2. Loosen/improve blocking beyond exact `city` and normalize city values.
#   3. Remove or heavily tighten `rb_correspondences_u2y` until it’s reliable.
#   4. Replace `longest_string` with domain-aware fusers for `source`, `_id`, `map_url`, `website`, `phone_*`.
#   5. Optionally add cluster-quality checks (geo/name consistency) to prevent multi-entity clusters.
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 11,485
#    Completion tokens: 2,411
#    Total tokens: 13,896
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 4,057
#    Completion tokens: 1,154
#    Total tokens: 5,211
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.2453066332916145, "macro_accuracy": 0.25317021545460294, "num_evaluated_records": 40, "num_evaluated_attributes": 21, "total_evaluations": 799, "total_correct": 196, "postal_code_accuracy": 0.275, "postal_code_count": 40, "map_url_accuracy": 0.275, "map_url_count": 40, "street_accuracy": 0.25, "street_count": 40, "phone_raw_accuracy": 0.0, "phone_raw_count": 40, "name_accuracy": 0.275, "name_count": 40, "website_accuracy": 0.2894736842105263, "website_count": 38, "house_number_accuracy": 0.275, "house_number_count": 40, "phone_e164_accuracy": 0.0, "phone_e164_count": 40, "address_line1_accuracy": 0.25, "address_line1_count": 40, "longitude_accuracy": 0.25, "longitude_count": 40, "rating_accuracy": 0.275, "rating_count": 40, "name_norm_accuracy": 0.275, "name_norm_count": 40, "address_line2_accuracy": 0.42857142857142855, "address_line2_count": 7, "country_accuracy": 0.275, "country_count": 40, "source_accuracy": 0.275, "source_count": 40, "_id_accuracy": 0.275, "_id_count": 40, "state_accuracy": 0.275, "state_count": 40, "categories_accuracy": 0.275, "categories_count": 40, "latitude_accuracy": 0.225, "latitude_count": 40, "city_accuracy": 0.275, "city_count": 40, "rating_count_accuracy": 0.3235294117647059, "rating_count_count": 34}
# [*] Overall Accuracy: 24.531%
# [*] Evaluation reasoning:
# **1. Dominant error types**
#
# From the metrics + debug log:
#
# - Very low **overall attribute accuracy (~0.25)** and **0 for phone fields** → most attributes are wrong or missing.
# - Debug events for `postal_code` and `map_url` all have:
#   - `fused_id: NaN`
#   - `inputs: []`
#   - `reason: "missing_fused_value"`
#
# This means:
#
# - The fusion engine is **not receiving any input records** for these evaluated entities (no cluster, so no attributes to fuse).
# - As a result, the fused dataset is **missing entire entities**, not just wrong attribute values.
#
# So the dominant error type is:
#
# > **False negatives at the entity level due to missing clusters (no matched pairs / no singleton entities), not bad attribute fusion.**
#
# There is **no evidence in the debug log of bad matches (false positives)** for these attributes; instead we just see “nothing matched, so value is null”.
#
# ---
#
# **2. Where the errors come from**
#
# I’ll walk through the pipeline components.
#
# ### 2.1 Blocking
#
# - Current blocking:
#
#   ```python
#   blocker_k2u = StandardBlocker(... on=["city"], ...)
#   blocker_k2y = StandardBlocker(... on=["city"], ...)
#   blocker_u2y = StandardBlocker(... on=["city"], ...)
#   ```
#
# - For restaurants across multiple US cities, **blocking on exact `city` is often too restrictive**:
#   - Any schema-matching misalignment on `city` → record never becomes a candidate.
#   - City format differences (“Scottsdale” vs “Scottsdale, AZ”, abbreviations, missing accents) → missed blocks.
#   - If one dataset has missing or null `city` → these entities never get any candidates.
#
# - In the debug events, for every expected Yelp / Uber Eats ID:
#   - `inputs: []` and `fused_id: NaN` strongly suggest **many true matches never even made it into a fused group**.
#   - Given that your optimal matching config for `kaggle_small_yelp_small` achieved **F1 = 1.0** on the labeled matches, the matcher itself is solid when it gets candidates.
#   - That points strongly at **blocking** as the main bottleneck for recall.
#
# Conclusion:
# **Blocking is too restrictive; it is causing many missed matches and thus missing fused entities.**
#
# ---
#
# ### 2.2 Matching thresholds / comparators
#
# Compare current vs optimal config:
#
# - For `kaggle_small_uber_eats_small` and `kaggle_small_yelp_small` the **code uses exactly the same comparators, weights, thresholds** as the optimal config (including lat/long tolerances, postal_code preprocessing).
# - For `yelp_small_uber_eats_small`, code also matches the “optimal” comparators and weights, but the config reports `f1: 0.0` (i.e., this pair is known to be bad).
# - However, the **main symptom in the fusion debug** is *no inputs* rather than low similarity scores.
#
# Given:
# - k2u and k2y have high F1 in the optimal config.
# - The same configs are implemented in code.
# - The debug events show missing inputs, not low-similarity mismatches.
#
# Conclusion:
# - **Matching thresholds/comparator choices are not the primary cause for k2u and k2y**.
# - The u2y matcher is likely poor (F1 = 0.0), so its correspondences are either missing or wrong, but that alone should not make all fused inputs empty; k2u/k2y should still produce clusters.
#
# So matching issues are secondary; the dominant failure is earlier (blocking / grouping).
#
# ---
#
# ### 2.3 Schema / preprocessing issues
#
# Potential issues, but secondary to blocking:
#
# 1. **Schema matching / renaming correctness**
#    You rely on an LLM-based schema matcher twice:
#
#    ```python
#    schema_correspondences = matcher.match(kaggle_small, uber_eats_small)
#    ...
#    uber_eats_small = uber_eats_small.rename(columns=rename_map)
#
#    schema_correspondences = matcher.match(kaggle_small, yelp_small)
#    ...
#    yelp_small = yelp_small.rename(columns=rename_map)
#    ```
#
#    Risks:
#    - LLM might mis-map `city`, `address_line1`, `postal_code`, etc.
#    - If `city` is not mapped correctly in either Uber Eats or Yelp after renaming, then:
#      - `StandardBlocker(... on=["city"])` sees many nulls or wrong values → no candidates.
#      - Comparators on `city`, `address_line1`, etc. may silently compare wrong columns (leading to low scores / no matches).
#
#    Given the extremely low fusion recall and the fact that **blocking and matching configs in code match the optimal JSON**:
#    - LLM schema matching errors on join keys like `city` are **likely amplifying the blocking problem**.
#
# 2. **Preprocessing of postal codes and phones**
#    - `postal_code` comparator uses `.strip()` (ok), but:
#      - Many source postal codes may be numeric vs string; casting/format may differ across sources.
#    - `phone_raw`/`phone_e164` accuracies are 0.0:
#      - Could be because:
#        - `phone_e164` not present or not mapped in all datasets.
#        - Fusion uses `longest_string`—if an entity only appears in 1 dataset (say Yelp) and you disable singletons, phone fields are absent from the fused output.
#
#    But again: the debug messages for `postal_code` show **completely missing fused records**, not value-level normalization issues.
#
# Conclusion:
# **Schema matching errors (especially misalignment of `city`) are likely exacerbating the too-strict blocking.**
# Phone / postal preprocessing may need cleanup, but first fix missing-entity issue.
#
# ---
#
# ### 2.4 Fusion logic / pipeline logic
#
# Two key logic choices are hurting recall:
#
# 1. **`include_singletons=False` in fusion**
#
#    ```python
#    rb_fused_standard_blocker = engine.run(
#        datasets=[kaggle_small, uber_eats_small, yelp_small],
#        correspondences=all_rb_correspondences,
#        id_column="kaggle380k_id",
#        include_singletons=False,
#    )
#    ```
#
#    - Any entity that **does not appear in at least one match pair** is dropped from the fused output.
#    - For evaluation, many ground-truth records (e.g., Yelp-only or Uber-only, or those whose matches were missed by blocking) will simply **not exist in the fused dataset**.
#    - The evaluator then checks them and finds:
#      - `fused_id: NaN`
#      - `fused_value: null`
#      - `inputs: []`
#    - This is exactly what we see in the debug events.
#
#    So even for entities that appear in only a single dataset (no cross-source match), you are currently **discarding them**, which tanks recall.
#
# 2. **Triple-wise correspondences vs entity-level clusters**
#
#    - You concatenate all pairwise correspondences:
#
#      ```python
#      all_rb_correspondences = pd.concat(
#          [rb_correspondences_k2u, rb_correspondences_k2y, rb_correspondences_u2y],
#          ignore_index=True,
#      )
#      ```
#
#    - If `kaggle_small` is incomplete (e.g., missing some Yelp/Uber records present in GT) and `yelp_small_uber_eats_small` matcher is poor (F1=0.0), then:
#      - Those true Yelp–Uber matches might never form a group.
#      - Since you require a cluster built via these correspondences and also exclude singletons, such entities vanish from fused output.
#
# Conclusion:
# **Fusion configuration (excluding singletons) and reliance on complete match graphs is a major recall-killer, in addition to blocking.**
#
# ---
#
# ### 3. Concrete, actionable improvements
#
# #### 3.1 Fix the biggest recall killer: produce fused records for all entities
#
# 1. **Enable singletons in fusion** (for the next evaluation run):
#
#    ```python
#    rb_fused_standard_blocker = engine.run(
#        datasets=[kaggle_small, uber_eats_small, yelp_small],
#        correspondences=all_rb_correspondences,
#        id_column="kaggle380k_id",
#        include_singletons=True,  # <-- change this
#    )
#    ```
#
#    Effect:
#    - Every source record will appear in the fused dataset, even if no match is found.
#    - For singleton entities, fused attributes will just be a copy from that one dataset.
#    - This directly fixes the “`inputs: []` / `fused_id: NaN` / `missing_fused_value`” failure mode.
#
# 2. **Optionally, keep track of source membership** (already done via `source` column) to make evaluation easier.
#
# ---
#
# #### 3.2 Relax and improve blocking
#
# Given we know the matching configs are strong for k2u and k2y:
#
# 1. **Do not block on raw `city` only.** Options:
#
#    - Use **multi-attribute blocking**, e.g.:
#
#      ```python
#      blocker_k2u = StandardBlocker(
#          kaggle_small,
#          uber_eats_small,
#          on=["city", "state"],   # and possibly coarse normalized name
#          batch_size=1000,
#          output_dir="output/blocking-evaluation",
#          id_column=id_col_kaggle,
#      )
#      ```
#
#    But this can still be brittle if schema mapping of `city` or `state` is wrong.
#
# 2. **Prefer token/blocking or phonetic-based blocking on `name_norm` + coarse location** (closer to “token_blocking” from optimal config):
#
#    - Example:
#
#      ```python
#      blocker_k2u = StandardBlocker(
#          kaggle_small,
#          uber_eats_small,
#          on=["name_norm"],  # or a normalized `name_city` concat
#          batch_size=1000,
#          output_dir="output/blocking-evaluation",
#          id_column=id_col_kaggle,
#          strategy="token_blocking",  # depending on PyDI API
#          params={"min_token_len": 3}
#      )
#      ```
#
#    - If PyDI’s `StandardBlocker` only supports exact equality on columns, create:
#      - A normalized `city_norm` (lowercase, strip punctuation).
#      - Or a `city_prefix` like `city[:3]` to allow more joinability.
#      - Or a combined key like `name_city_key = normalize(name_norm) + '|' + normalize(city)` and block on that.
#
# 3. **Evaluate blocking completeness** (if PyDI supports it):
#    - Use labeled pairs (from your optimal config evaluation) to empirically measure **pair completeness** with your new blocking logic, and tune until you get >0.9 completeness for k2u/k2y.
#
# ---
#
# #### 3.3 Reduce dependence on LLM schema matcher for critical blocking attributes
#
# 1. **Manually enforce mappings for key attributes** that directly affect blocking and comparators:
#    - `name_norm`
#    - `city`
#    - `state`
#    - `postal_code`
#    - `latitude`
#    - `longitude`
#    - `address_line1`
#    - `phone_e164`
#
# 2. For example, instead of using the LLM’s `schema_correspondences` blindly:
#
#    ```python
#    # Example: force critical mappings
#    uber_eats_small = uber_eats_small.rename(columns={
#        "ue_city_column": "city",
#        "ue_state_column": "state",
#        "ue_postcode_col": "postal_code",
#        # ...
#    })
#    ```
#
#    and only use LLMBasedSchemaMatcher to map **non-critical** / auxiliary fields (e.g., descriptions).
#
#    Or, post-process `schema_correspondences` with assertions:
#
#    ```python
#    assert "city" in schema_correspondences["target_column"].values
#    # Inspect which source column maps to "city" and confirm it's reasonable.
#    ```
#
# 3. At minimum, log and manually inspect the LLM schema mapping output for these three datasets to confirm that:
#    - `city` is correctly mapped in both Uber Eats and Yelp.
#    - `postal_code`, `address_line1`, etc. are not mis-assigned to something odd (e.g., mapping zip to phone).
#
# This will reduce silent misalignments that currently cause blocking & comparison to operate on the wrong columns.
#
# ---
#
# #### 3.4 Matching configuration tweaks (secondary)
#
# Given k2u and k2y are already high-performing:
#
# 1. **Keep current k2u and k2y configs** as they are aligned with optimal.
#
# 2. **Address known-bad u2y matcher**:
#    - The optimal config reports `f1: 0.0` for `yelp_small_uber_eats_small`, suggesting:
#      - Either no true matches in the labeled set.
#      - Or your current threshold (0.78) is too high for this pair.
#    - To avoid noise:
#      - Option A: **Drop u2y correspondences entirely** for now and rely on k2u and k2y to connect Uber and Yelp **through Kaggle**.
#      - Option B: Lower `threshold_u2y` (e.g., to 0.6–0.7) and re-evaluate F1 for that pair separately; if still bad, stick with option A.
#
# Given Kaggle is present in all three, using it as a hub is reasonable.
#
# ---
#
# #### 3.5 Attribute-level / preprocessing improvements (after recall is fixed)
#
# Once fused entities exist:
#
# 1. **Phone fields (`phone_raw`, `phone_e164`)**
#    - Build a simple normalizer:
#      - Remove non-digits, standardize to E.164 where country code is known (e.g., US).
#    - Use a dedicated comparator for phones instead of plain Levenshtein on raw strings.
#
# 2. **Postal code**
#    - Ensure all postal codes are strings with zero-padding (for US ZIP+4, if present).
#    - You might not need Levenshtein; for US ZIP codes exact/string equality is often enough.
#
# 3. **Map URL**
#    - These URLs are highly source-specific (Yelp vs Google Maps). In many cases:
#      - Fused truth may expect the Yelp URL for Yelp records only.
#    - Given map_url is 0.275 accuracy and all mismatches in the log are due to missing entities, once you fix fusion recall, map_url will behave much more predictably (you’ll at least have one source URL to pick with `longest_string`).
#
# ---
#
# ### 4. Summary diagnosis
#
# - **Dominant error type:**
#   Entity-level **false negatives**: many GT records are absent from the fused output, leading to `missing_fused_value` for all attributes.
#
# - **Root causes (priority order):**
#   1. **Fusion logic**: `include_singletons=False` drops all entities that don’t participate in a successful match.
#   2. **Blocking too restrictive** on `city` + vulnerable to schema mismapping of `city`.
#   3. **LLM schema matching** may mis-map critical columns, worsening blocking and matching.
#   4. **u2y matcher** likely low-quality but not the main cause of missing entities.
#
# - **Next iteration, minimal concrete changes:**
#   1. Set `include_singletons=True` in `DataFusionEngine.run`.
#   2. Redesign blocking away from strict `city` equality:
#      - Use token-based / name-based blocking; or robust normalized `city`/`state` keys.
#   3. Manually verify/override LLM schema mappings for critical columns (`city`, `state`, `postal_code`, `address_line1`, `name_norm`, `lat`, `lon`).
#   4. Optionally remove or re-tune the `yelp_small_uber_eats_small` matcher until it shows acceptable F1.
#
# These changes should move you from “almost all attributes are missing because the entity is missing” to a situation where attribute-level fusion quality can be meaningfully evaluated and then incrementally improved.
# [*] Trying to improve pipeline based on evaluation
# TOKEN USAGE (pipeline_adaption):
#    Prompt tokens: 13,893
#    Completion tokens: 2,407
#    Total tokens: 16,300
#    Estimated cost: $0.000000
# [*] Running generated pipeline
# [+] Pipeline successfully completed
# [*] Adapting evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 4,053
#    Completion tokens: 961
#    Total tokens: 5,014
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# [-] Evaluation could not be executed
# Error: error: Missing 2 expected/reference records in fused dataset: kaggle380k-008975, kaggle380k-001820
# Traceback (most recent call last):
#   File "/Users/abd/Developer/di_team_project/agents/output/code/evaluation.py", line 114, in <module>
#     eval_funcs = strategy.evaluation_functions  # {attribute: function}
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'DataFusionStrategy' object has no attribute 'evaluation_functions'. Did you mean: 'add_evaluation_function'?
#
# [*] Fixing evaluation code
# TOKEN USAGE (evaluation_adaption):
#    Prompt tokens: 5,154
#    Completion tokens: 1,095
#    Total tokens: 6,249
#    Estimated cost: $0.000000
# [*] Running generated evaluation
# [+] Evaluation successfully completed
# [*] Reading evaluation metrics
# Evaluation metrics: {"overall_accuracy": 0.7171464330413017, "macro_accuracy": 0.7306169836355595, "num_evaluated_records": 40, "num_evaluated_attributes": 21, "total_evaluations": 799, "total_correct": 573, "longitude_accuracy": 0.95, "longitude_count": 40, "street_accuracy": 0.85, "street_count": 40, "source_accuracy": 0.275, "source_count": 40, "_id_accuracy": 0.275, "_id_count": 40, "phone_e164_accuracy": 0.0, "phone_e164_count": 40, "country_accuracy": 0.95, "country_count": 40, "address_line1_accuracy": 0.925, "address_line1_count": 40, "categories_accuracy": 0.925, "categories_count": 40, "name_norm_accuracy": 0.8, "name_norm_count": 40, "address_line2_accuracy": 1.0, "address_line2_count": 7, "phone_raw_accuracy": 0.0, "phone_raw_count": 40, "website_accuracy": 0.9473684210526315, "website_count": 38, "city_accuracy": 0.95, "city_count": 40, "rating_accuracy": 0.45, "rating_count": 40, "latitude_accuracy": 0.95, "latitude_count": 40, "house_number_accuracy": 0.925, "house_number_count": 40, "postal_code_accuracy": 0.95, "postal_code_count": 40, "map_url_accuracy": 0.375, "map_url_count": 40, "name_accuracy": 0.925, "name_count": 40, "state_accuracy": 0.95, "state_count": 40, "rating_count_accuracy": 0.9705882352941176, "rating_count_count": 34}
# [*] Overall Accuracy: 71.715%

# %%
from IPython.display import Image, display

display(Image(agent.graph.get_graph().draw_mermaid_png()))
